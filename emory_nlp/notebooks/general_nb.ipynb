# %%
import json
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from itertools import chain
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### Read data

# %%
# # Load the pickled list
# with open("/Utilisateurs/umushtaq/emotion_analysis_comics/incontext_learning/results/icl_llama-3-8b-Instruct-bnb-4bit/results_10.pickle", 'rb') as f:
    
#     results = pickle.load(f)

# %%
# Load the pickled list
with open("/Utilisateurs/umushtaq/emotion_analysis_comics/emory_nlp/saved_models/emorynlp_Qwen2.5-7B-Instruct-bnb-4bit/emorynlp_results_3.pickle", 'rb') as f:
    
    results = pickle.load(f)

# %%
#all_labels = ["anger", "surprise", "fear", "disgust", "sadness", "joy", "neutral"]

# %%
grounds = results['ground_truths']
predictions = results['predictions']

# %%
len(grounds), len(predictions)
# Out:
# (984, 984)

# %%
grounds
# Out:
# ['{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Scared"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Mad"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Powerful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Peaceful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Neutral"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Joyful"]}',
#  '{"emotion_class": ["Sad"]}',
#  '{"emotion_class": ["Powerful"]}']

# %%
predictions
# Out:
# [{'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
# ...
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Peaceful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Scared"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Mad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Powerful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Sad"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Neutral"]}'},
#  {'role': 'assistant', 'content': '{"emotion_class": ["Joyful"]}'}]

# %%
grounds = [json.loads(x)["emotion_class"] for x in grounds]

# %%
predictions = [json.loads(x["content"]) for x in predictions]

# %%
predictions = [x['emotion_class'] for x in predictions]

# %%
len(grounds), len(predictions)
# Out:
# (984, 984)

# %%
predictions
# Out:
# [['Scared'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Powerful'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Sad'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Sad'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Scared'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Sad'],
#  ['Powerful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Sad'],
#  ['Sad'],
#  ['Neutral'],
#  ['Scared'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Sad'],
#  ['Scared'],
#  ['Scared'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Mad'],
#  ['Peaceful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Peaceful'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Scared'],
#  ['Mad'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Mad'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Sad'],
#  ['Scared'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Sad'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Sad'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Scared'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Peaceful'],
#  ['Mad'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Scared'],
#  ['Mad'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Mad'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Scared'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Sad'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Sad'],
#  ['Scared'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Mad'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Scared'],
#  ['Scared'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Sad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Sad'],
#  ['Mad'],
#  ['Mad'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Peaceful'],
#  ['Mad'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Scared'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Sad'],
#  ['Sad'],
#  ['Scared'],
#  ['Sad'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Mad'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Sad'],
#  ['Peaceful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Mad'],
#  ['Scared'],
#  ['Mad'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Mad'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Mad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Mad'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Sad'],
#  ['Scared'],
#  ['Powerful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Scared'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Sad'],
#  ['Mad'],
#  ['Mad'],
#  ['Peaceful'],
#  ['Mad'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Sad'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Mad'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Peaceful'],
#  ['Mad'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Mad'],
#  ['Scared'],
#  ['Joyful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Sad'],
#  ['Peaceful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Mad'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Mad'],
#  ['Powerful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Scared'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Scared'],
#  ['Joyful'],
#  ['Mad'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Powerful'],
#  ['Scared'],
#  ['Powerful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Scared'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Powerful'],
#  ['Peaceful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Neutral'],
#  ['Scared'],
#  ['Scared'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Scared'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Scared'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Mad'],
#  ['Mad'],
#  ['Neutral'],
#  ['Sad'],
#  ['Powerful'],
#  ['Sad'],
#  ['Neutral'],
#  ['Sad'],
#  ['Neutral'],
#  ['Neutral'],
#  ['Joyful'],
#  ['Joyful'],
#  ['Neutral'],
#  ['Joyful']]

# %%
grounds_l = [len(element) for element in grounds]
predictions_l = [len(element) for element in predictions]

# %%
counts_grounds = Counter(grounds_l)
counts_predictions = Counter(predictions_l)

# %%
counts_grounds
# Out:
# Counter({1: 984})

# %%
counts_predictions
# Out:
# Counter({1: 984})

# %%
# def labels_to_binary_matrix(label_list, all_labels):
#     binary_matrix = np.zeros((len(label_list), len(all_labels)))
    
#     for i, labels in enumerate(label_list):
#         for label in labels:
#             if label in all_labels:
#                 binary_matrix[i][all_labels.index(label)] = 1
                
#     return binary_matrix

# def opposite(component_type):

#     if component_type == "anger":
#         return "surprise"
#     elif component_type == "disgust":
#         return "joy"
#     elif component_type == "fear":
#         return "sadness"
#     elif component_type == "sadness":
#         return "anger"
#     elif component_type == "surprise":
#         return "disgust"
#     elif component_type == "joy":
#         return "fear"
#     elif component_type == "Neutral":
#         return "sadness"
    

# def harmonize_preds(grounds, preds):

#     l1, l2 = len(preds), len(grounds)
#     if l1 < l2:
#         diff = l2 - l1
#         preds = preds + [opposite(x) for x in grounds[l1:]]
#     else:
#         preds = preds[:l2]
        
#     return preds 

# def post_process_icl(grounds, preds):

#     for i,(x,y) in enumerate(zip(grounds, preds)):
        
#         if len(x) != len(y):
            
#             preds[i] = harmonize_preds(x, y)

#     true_matrix = labels_to_binary_matrix(grounds, all_labels)
#     predicted_matrix = labels_to_binary_matrix(preds, all_labels)

#     return true_matrix, predicted_matrix

# %%
#true_matrix, predicted_matrix = post_process_icl(grounds, predictions)

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(grounds, predictions, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#       Joyful      0.451     0.470     0.460       217
#          Mad      0.368     0.372     0.370        86
#      Neutral      0.468     0.635     0.539       288
#     Peaceful      0.127     0.063     0.084       111
#     Powerful      0.074     0.052     0.061        96
#          Sad      0.340     0.229     0.274        70
#       Scared      0.409     0.388     0.398       116
#
#     accuracy                          0.396       984
#    macro avg      0.320     0.316     0.312       984
# weighted avg      0.363     0.396     0.374       984

# %% [raw]
# precision    recall  f1-score   support
#
#       Joyful      0.470     0.507     0.488       217
#          Mad      0.342     0.302     0.321        86
#      Neutral      0.464     0.580     0.515       288
#     Peaceful      0.224     0.135     0.169       111
#     Powerful      0.169     0.104     0.129        96
#          Sad      0.292     0.200     0.237        70
#       Scared      0.300     0.362     0.328       116
#
#     accuracy                          0.390       984
#    macro avg      0.323     0.313     0.312       984
# weighted avg      0.367     0.390     0.374       984

# %% [raw]
# precision    recall  f1-score   support
#
#       Joyful      0.514     0.521     0.517       217
#          Mad      0.337     0.349     0.343        86
#      Neutral      0.429     0.587     0.496       288
#     Peaceful      0.159     0.063     0.090       111
#     Powerful      0.132     0.104     0.116        96
#          Sad      0.359     0.200     0.257        70
#       Scared      0.279     0.293     0.286       116
#
#     accuracy                          0.383       984
#    macro avg      0.315     0.302     0.301       984
# weighted avg      0.357     0.383     0.363       984
