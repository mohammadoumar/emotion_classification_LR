# %%
import json
import pickle
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
#from json_repair import repair_json

from itertools import chain
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ### Read data

# %%
# Load the pickled list
with open("/Utilisateurs/umushtaq/emotion_analysis_comics/meld_ZSL/results/meld_zs_Meta-Llama-3.1-405B-Instruct-bnb-4bit/results.pickle", 'rb') as f:
    
    results = pickle.load(f)

# %%
results
# Out:
# {'grounds': ['neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'surprise',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'fear',
#   'neutral',
#   'surprise',
#   'neutral',
#   'surprise',
#   'sadness',
#   'surprise',
#   'fear',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'joy',
#   'sadness',
#   'surprise',
#   'neutral',
#   'disgust',
#   'sadness',
#   'neutral',
#   'neutral',
#   'joy',
#   'neutral',
#   'joy',
#   'surprise',
#   'surprise',
#   'surprise',
#   'neutral',
#   'neutral',
#   'neutral',
#   'surprise',
#   'sadness',
#   'neutral',
#   'surprise',
#   'joy',
#   'surprise',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'joy',
#   'joy',
#   'joy',
#   'sadness',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'neutral',
#   'surprise',
#   'joy',
#   'surprise',
#   'joy',
#   'neutral',
#   'neutral',
#   'anger',
# ...

# %%
grounds = results['grounds']
predictions = results['predictions']

# %%
len(grounds), len(predictions)
# Out:
# (13708, 13708)

# %%
grounds
# Out:
# ['neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'sadness',
#  'surprise',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'surprise',
#  'neutral',
#  'disgust',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'surprise',
#  'surprise',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'surprise',
#  'anger',
#  'anger',
#  'anger',
# ...

# %%
predictions
# Out:
# ['{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "fear"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "surprise"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "disgust"}',
#  '{"emotion_class": "anger"}',
#  '{"emotion_class": "surprise"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "joy"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "disgust"}',
#  '{"emotion_class": "joy"}',
#  '{"emotion_class": "sadness"}',
#  '{"emotion_class": "surprise"}',
#  '{"emotion_class": "neutral"}',
#  '{"emotion_class": "sadness"}',
# ...

# %%
bad_idx = []
clean_predictions = []

for i, pred in enumerate(predictions):
    try:
        clean_predictions.append(json.loads(pred)["emotion_class"])
    except:
        bad_idx.append(i)
        print(i)
# Out:
# 247
# 609
# 846
# 884
# 1095
# 1238
# 1270
# 1503
# 1549
# 1634
# 1686
# 1961
# 2041
# 2292
# 2369
# 2382
# 2488
# 2553
# 2569
# 2971
# 3580
# 3612
# 3626
# 3700
# 4074
# 4151
# 4322
# 4418
# 4432
# 4453
# 4456
# 4521
# 4729
# 4776
# 4801
# 4888
# 5114
# 5154
# 5493
# 6007
# 6147
# 6369
# 6946
# 7152
# 7184
# 7225
# 7397
# 7477
# 7486
# 7914
# 8080
# 8211
# 8502
# 8736
# 8869
# 8886
# 8933
# 8954
# 9173
# 9450
# 9520
# 9701
# 9736
# 9977
# 10067
# 10143
# 10371
# 10394
# 10768
# 11259
# 11308
# 11397
# 11403
# 11602
# 11626
# 11630
# 11868
# 12026
# 12123
# 12487
# 12578
# 12844
# 13143
# 13299
# 13534
# 13699

# %%
bad_idx.sort(reverse=True)

for idx in bad_idx:
    del grounds[idx]

# %%
len(grounds), len(clean_predictions)
# Out:
# (13622, 13622)

# %%
print(classification_report(grounds, clean_predictions, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        anger      0.507     0.518     0.513      1586
#      disgust      0.190     0.535     0.281       359
#         fear      0.340     0.336     0.338       354
#          joy      0.550     0.654     0.598      2302
#      neutral      0.838     0.660     0.739      6404
#      sadness      0.492     0.423     0.455       991
#     surprise      0.539     0.667     0.596      1626
#
#     accuracy                          0.614     13622
#    macro avg      0.494     0.542     0.503     13622
# weighted avg      0.660     0.614     0.628     13622

# %%
with open("/Utilisateurs/umushtaq/emotion_analysis_comics/meld_ZSL/results/meld_zs_Meta-Llama-3.1-405B-Instruct-bnb-4bit/classification_report.pickle", 'wb') as fh:
    
    pickle.dump(classification_report(grounds, clean_predictions, digits=3, output_dict=True), fh)
