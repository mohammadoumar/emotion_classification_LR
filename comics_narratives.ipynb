# %%
import torch
import json_repair
import pandas as pd

from tqdm import tqdm
from datasets import Dataset

from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel, is_bfloat16_supported

from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %%
max_seq_length = 2048
model, tokenizer = FastLanguageModel.from_pretrained(
    #model_name="unsloth/Meta-Llama-3.1-70B-Instruct-bnb-4bit",
    #model_name="unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    model_name="unsloth/Qwen2.5-7B-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Qwen2 patching. Transformers:4.47.0.
#    \\   /|    GPU: NVIDIA H100 NVL. Max memory: 93.003 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 9.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    target_modules=["q_proj", "k_proj", "v_proj", "up_proj", "down_proj", "o_proj", "gate_proj"], 
    use_rslora=True,
    use_gradient_checkpointing=True
)

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/dataset_files/comics_dataset.csv")

# %%
df
# Out:
#                                               file_name  page_nr  panel_nr  \
# 0     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 1     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 2     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 3     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         3
# 4     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         4
# ...                                                 ...      ...       ...
# 7124  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 7125  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 7126  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         4
# 7127  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         1
# 7128  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         2
#
#       balloon_nr                                          utterance  \
# 0              1           DID YOU HAVE TO ELECTROCUTE HER SO HARD?
# 1              2           IT'S NOT LIKE I HAVE DIFFERENT SETTINGS.
# 2              3  YOU'RE ELECTROCUTIONER. IT'S YOUR WHOLE THING....
# 3              1                      OH, HEY. I THINK SHE'S AWAKE.
# 4              1  WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRET...
# ...          ...                                                ...
# 7124           2  SHE WOULDN'T DO THAT TO US. WE TALKED FOR A LO...
# 7125           3                                      … I KNOW HER.
# 7126           1                                          UH, GUYS…
# 7127           1  PUT YOUR WEAPONS DOWN AND PUT YOUR HANDS IN TH...
# 7128           1     SURE DOESN'T SEEM LIKE THEY CAME HERE TO TALK…
#
#                                          raw_annotation  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 7124  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7125  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7126  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7127  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
# 7128  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                             raw_emotion  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 7124  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7125  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7126  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7127  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
# 7128  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                          raw_speaker_id  \
# 0           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 1           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 2           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 3           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 4           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# ...                                                 ...
# 7124      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 7125      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 7126  \n2024-09-06 - SyimykRasulov\nSpokenBy:JUANITA...
# 7127       \n2024-09-06 - SyimykRasulov\nSpokenBy:ID- 2
# 7128    \n2024-09-06 - SyimykRasulov\nSpokenBy:Michonne
#
#                       emotion       speaker_id  split
# 0     AN0-DI0-FE3-SA0-SU5-JO0             ID-1  TRAIN
# 1     AN0-DI0-FE0-SA0-SU5-JO0             ID-2  TRAIN
# 2     AN0-DI0-FE2-SA0-SU0-JO0             ID-1  TRAIN
# 3     AN0-DI0-FE0-SA0-SU4-JO0             ID-2  TRAIN
# 4     AN3-DI0-FE0-SA0-SU0-JO0             ID-1  TRAIN
# ...                       ...              ...    ...
# 7124  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 7125  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 7126  AN0-DI0-FE3-SA0-SU4-JO0  JUANITA SANCHEZ  TRAIN
# 7127  AN4-DI0-FE0-SA0-SU0-JO0            ID- 2  TRAIN
# 7128  AN4-DI0-FE3-SA2-SU0-JO0         Michonne  TRAIN
#
# [7129 rows x 11 columns]

# %%
df.speaker_id.unique()
# Out:
# array(['ID-1', 'ID-2', 'NIGHTWING', 'MELINDA', 'BLOCKBUSTER', 'AUDRE',
#        'MACLEAN', 'ID-3', 'ID-3 ', 'MAGGIE', 'COMMISSIONER', 'BATWOMAN',
#        'ROBIN', 'ID-4', 'ID-5', 'STARGIRL', 'MARONI', 'FLASH', 'ID-6',
#        'ID-7', 'ID-8', 'ID-9', 'ELLIOT', 'Eleanor', 'Momma',
#        'no annotation', 'Natasha', 'John', 'BRIGHT REVENANT', 'HAWKGIRL',
#        'CHRISTOPHER', 'ICE', 'JESUS', 'unknown', 'ID- 1', 'ID- 2',
#        'ID- 3', 'ID- 4', 'ID- 5', 'ID- 6', 'Ms.Jones', 'Felicia Book',
#        'ID- 7', 'ID- 8', 'ID- 9', 'ID- 10', 'ID- 11', 'ID- 12', 'Skinner',
#        'Cal', 'Homo Abominus', 'Agent Bixby', 'Lucia', 'Trapp', 'Kill',
#        'ID- 14', 'OLIVIA', 'MAGISTER PAVUS', 'AARON', 'CALIX ', 'CALIX',
#        'FRANCESCA', 'FLORIAN', 'VAEA', 'AGOSTO', 'ELF', 'AUTUMN', 'Carl',
#        'Rick', 'Maggie', 'Eugene', 'STEPHANIE', 'Dwight', 'Negan', 'Lobo',
#        'ID-2 ', 'Director', 'ID-1 ', 'Flash', 'Black Mask', 'Jay',
#        'Linda', 'Jai', 'Max', 'Irey', 'Ace', 'Jesse', 'Mr.Allen',
#        'Mrs.Allen', 'Kid Flash', 'Flash 2', 'Bystander', 'Freezing enemy',
#        'Travis', 'Krunch', 'Lady Cop', 'Non-Fat', 'Good Looks', 'Bananas',
#        'Mr.Rider', 'Starman', 'Metamorpho', 'Manhunter', 'The Commodore',
#        'Psimon', 'Superboy', 'Supergirl', 'Cyborg', 'Robin', 'Cassie',
#        'Shelly', 'Match', 'Mr.John', 'Speedy', 'Stargirl', 'Starfire',
#        'Batgirl', 'Jokergirl', 'Terra', 'violet ring', 'green ring',
#        'red ring', 'blue ring', 'sky blue ring', 'blue gnom',
#        'blue serious gnom', 'Green Lantern', 'Donatello', 'Raphael',
#        'Michelangelo\t', 'Donatello\t', 'Leonardo', 'Michelangelo',
#        'Chloe', ' Michelangelo', 'April', 'Splinter', 'Baxter Stockman',
#        'Tiger Claw', ' ID-12', 'Sonic', 'Zavok', ' Tails',
#        'Shadow the Hedgehog', 'Espio the Chameleon', 'Doctor Eggman',
#        'Jewel the Beetle', 'Belle the Tinkerer', 'Doctor Starline',
#        'Vector the Crocodile', 'Charmy Bee', 'Master Zik', 'Zeena',
#        'Zazz', 'Joan Peterson', 'Roger Henry', 'Lord Westshire',
#        'Oliver King', 'Robby Trick', 'JACKSON T. WINTERS', 'Edzia Rusnak',
#        'ANDERSON LAKE', 'Jay Burns', 'Joe Burns', 'MARKUS SCHRECKEN',
#        'Andy', 'Britney', 'ID-12', 'ID-13', 'unknown_speaker', 'ID-20',
#        'ID-18', 'ID-19', 'Paco', 'Wenona Blood Crow', 'ID-17', 'ID-15',
#        'ID-16', 'ID- 25', 'Taylor', 'Nuki', 'ID- 24', 'ID- 22', 'ID- 23',
#        'ID- 21', 'Nina', 'EL SILBÓN', 'ID- 28', 'ID- 27',
#        'EL MAESTRO DE LA MUERTE', 'ID- 26', 'Juliet', 'ID- 29', 'ID- 30',
#        'Brun', 'Diz', 'Lieutenant Bratts', 'ID- 16', 'Agent Poole',
#        'ID- 17', 'ID- 18', 'SLIM', 'KING', 'ID-10', 'ID-11', 'ID-14',
#        'TED', 'GALEN', 'LAURA', 'TANYA', 'KREEGS', 'DANIEL', 'TREY',
#        'UNITY', 'AQUANYX', 'BLACKMANTASAURUS', 'GREEN TORCH',
#        'ATROCITAURUS', 'FLASHRAPTOR', 'BATSAUR', 'SUPERSAUR', 'BATSAU',
#        'WONDERDON', 'GIGANTA', 'FATHER', 'REVERSE-SLASH',
#        "Jones's partner", 'John Wesley Jones', 'Sarah', 'Widow Perkins',
#        'Penelope', 'Ronnie', 'Renny', 'Barb', 'Victor Jacks', 'Jodh',
#        'Belle', 'Chen', 'Doctor MacNamara DeSoto', 'Dolores', 'Henry',
#        'Jennifer', 'Toby', 'Stanley', 'Mel', 'Gladys', 'Doris', 'Emma',
#        'Alejandro', 'Jimmy', 'ID- 19', 'ID- 20', 'Laura', 'Liam',
#        'Vanessa', 'Bryn', 'Junior', 'Jake', 'ID- 31', 'ID- 32', 'ID- 33',
#        'ID- 36', 'Tom ', 'Nancy', 'Johan Van Der Veldt', 'ID- 34',
#        'ID- 35', 'ID- 37', 'ID- 38', 'ID- 42', 'ID- 43', 'ID- 49',
#        'ID- 46', 'ID- 47', 'ID- 50', 'ID- 48', 'ID- 51', 'ID- 52',
#        'ID- 53', 'ID- 59', 'ID- 60', 'ID- 54', 'ID- 61', 'ID- 55',
#        'ID- 44', 'ID- 45', 'Franklin', 'Debbie', 'ID- 56', 'ID- 63',
#        'ID- 62', 'ID- 57', 'ID- 58', 'ID- 65', 'ID- 64', 'ID- 68',
#        'ID- 69', 'ID- 67', 'ID- 66', 'Joey Gangemi', 'Bob', 'Alicia',
#        'ID- 70', 'ID- 71', 'Tom', 'Dick', 'ID- 74', 'ID- 72', 'ID- 73',
#        'ID- 76', 'ID- 75', 'Green Arrow', 'Mera', 'Harley Quinn',
#        'Frankenstein', 'Cole Cash', 'Jayna', 'QUEEN', 'Loose Cannon',
#        'Carter', 'Kara', 'Damian', 'Augustus Paulson', 'Conrad Paulson',
#        'Celia', 'Holly', 'Liz Cohen', 'Nathan', 'Hector', 'Manny',
#        'Siddiq', 'Lydia', 'YUMIKO', 'Michonne', 'JUANITA SANCHEZ',
#        'MAGNA', 'Annie', 'Brianna', 'Mikey', 'William', 'Aaron', 'Jesus',
#        'Dante', 'Josh', 'Mike'], dtype=object)

# %%
#filtered_df = df[~df['speaker_id'].str.contains('ID-', na=False)].reset_index(drop=True)

# %%
#filtered_df

# %%
#filtered_df.speaker_id.unique()

# %%
#filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('no annotation', na=False)].reset_index(drop=True)

# %%
#filtered_df.shape

# %%
#filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('unknown_speaker', na=False)].reset_index(drop=True)

# %%
#filtered_df.shape

# %%
#filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('unknown', na=False)].reset_index(drop=True)

# %%
#filtered_df.shape

# %%
#filtered_df.speaker_id.unique()

# %%
#filtered_df[filtered_df.speaker_id == 'violet ring']

# %%
#filtered_df[filtered_df.file_name == 'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx'].speaker_id.unique()

# %%
#filtered_df

# %%
#len(filtered_df.file_name.unique())

# %%
def get_unique_emotion(row):

    utterance_emotions = row.emotion

    utterance_emotions_l = []
    emotion_class_labels = ["anger", "disgust", "fear", "sadness", "surprise", "joy"]

    if utterance_emotions == 'Neutral':
        
        utterance_emotions_l.append('neutral')
    
    else:
        
        utterance_emotions = utterance_emotions.split("-")

        for idx, emotion_annotation in enumerate(utterance_emotions):

            if '0' not in emotion_annotation:
         
                utterance_emotions_l.append(emotion_class_labels[idx])

    return utterance_emotions_l

# %%
df['emotion_c'] = df.apply(lambda row: get_unique_emotion(row), axis=1)

# %%
page_df = df.groupby(['file_name', 'page_nr', 'split']).agg({
    'utterance': list,
    'speaker_id': list,
    'emotion_c': list
}).reset_index()

# %%
page_df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1    [NO--  #GKKK…#, #CHOMP!, BY THE SKIN OF MATILD...
# 2    [COME ON, BEAST!, SHOW YOURSELF!, WHY DO YOU H...
# 3                                           [#AARGH! ]
# 4    [I, THE GREEN TORCH, HAVE BEEN TASKED WITH PRO...
# ..                                                 ...
# 869  [WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO ...
# 870  [SO WHAT ARE WE GOING TO DO?, THE WAY I SEE IT...
# 871  [KIDDIE COUNCIL'S BEEN GOING A LONG TIME... , ...
# 872  [IT'S BEEN… PEACEFUL. ASIDE FROM SHIT LIKE THI...
# 873              [" AND PAY OUR NEIGHBOURS A VISIT. "]
#
#                                             speaker_id  \
# 0    [AQUANYX, AQUANYX, ID-1, ID-1, AQUANYX, ID-1, ...
# 1    [ID-1, BLACKMANTASAURUS, AQUANYX, AQUANYX, BLA...
# 2                 [AQUANYX, AQUANYX, AQUANYX, AQUANYX]
# 3                                            [AQUANYX]
# 4    [GREEN TORCH, GREEN TORCH, ATROCITAURUS, ATROC...
# ..                                                 ...
# 869  [LAURA, LAURA, LAURA, DANIEL, DANIEL, DANIEL, ...
# 870    [ID-6, GALEN, ID-7, GALEN, GALEN, GALEN, GALEN]
# 871  [TED, KREEGS, ID-8, ID-8, GALEN, GALEN, KREEGS...
# 872  [KREEGS, GALEN, GALEN, KREEGS, GALEN, GALEN, K...
# 873                                            [GALEN]
#
#                                              emotion_c
# 0    [[anger], [anger], [fear], [fear], [fear, sadn...
# 1    [[fear], [anger], [surprise], [anger], [joy], ...
# 2                     [[joy], [joy], [anger], [anger]]
# 3                                   [[fear, surprise]]
# 4    [[anger], [anger], [fear], [fear, surprise], [...
# ..                                                 ...
# 869  [[anger], [anger], [anger], [anger], [anger, s...
# 870  [[sadness, surprise], [anger], [anger], [anger...
# 871  [[anger, sadness], [anger], [anger], [anger], ...
# 872  [[anger], [joy], [joy], [anger, surprise], [an...
# 873                                     [[anger, joy]]
#
# [874 rows x 6 columns]

# %%
file_names_l = page_df.file_name.unique().tolist()

# %%
comics_titles_full = [
    
    "Jurassic League #4",      
    "Nightwing #95",    
    "Dark Crisis: Worlds Without a Justice League - Green Lantern #1", 
    "Dark Crisis: Worlds Without a Justice League - Green Lantern - Very Merry Multiverse",
    "Dark Crisis: The Flash #783",
    "Danger Street #1",
    "Tiny Titans #25",
    "Human Target #9",
    "DC vs. Vampires #11",
    "John Carpenter's Tales for a Halloweenight #3",
    "The Amazing Adventures of the Ninja Turtles #5",
    "Sonic The Hedgehog #44",
    "Love Everlasting #2",
    "Fantasmas vol. 1 - Ghosted #2",
    "Fantasmas vol. 1 - Ghosted #3",
    "Fantasmas vol. 1 - Ghosted #4",
    "Fantasmas vol. 1 - Ghosted #5",
    "Fantasmas vol. 1 - Ghosted #1",
    "Fantasmas vol. 1 - Ghosted #6",
    "Fantasmas vol. 1 - Ghosted #7",
    "Fantasmas vol. 1 - Ghosted #8",
    "Fantasmas vol. 1 - Ghosted #9",
    "Fantasmas vol. 1 - Ghosted #10",
    "American Vampire vol. 4 - #6",
    "American Vampire vol. 4 - #7",
    "American Vampire vol. 4 - #8",
    "Dragon Age vol. 3 Engano - Deception #1",
    "Dragon Age vol. 3 Engano - Deception #2",
    "Dragon Age vol. 3 Engano - Deception #3",
    "The Walking Dead vol 15 - #169",
    "The Walking Dead vol 15 - #170",
    "The Walking Dead vol 15 - #171",
    "The Walking Dead vol 15 - #173",
    "Thief Of Thieves 1 - #11",
    "Stillwater #13",

]

# %%
page_df['comics_title'] = page_df['file_name'].apply(lambda x: comics_titles_full[file_names_l.index(x)] if x in file_names_l else None)

# %%
def get_stats(row):
    
    return [len(row.utterance), len(row.speaker_id), len(row.emotion_c)]

# %%
page_df['lens'] = page_df.apply(lambda row: get_stats(row), axis=1)

# %%
page_df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1    [NO--  #GKKK…#, #CHOMP!, BY THE SKIN OF MATILD...
# 2    [COME ON, BEAST!, SHOW YOURSELF!, WHY DO YOU H...
# 3                                           [#AARGH! ]
# 4    [I, THE GREEN TORCH, HAVE BEEN TASKED WITH PRO...
# ..                                                 ...
# 869  [WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO ...
# 870  [SO WHAT ARE WE GOING TO DO?, THE WAY I SEE IT...
# 871  [KIDDIE COUNCIL'S BEEN GOING A LONG TIME... , ...
# 872  [IT'S BEEN… PEACEFUL. ASIDE FROM SHIT LIKE THI...
# 873              [" AND PAY OUR NEIGHBOURS A VISIT. "]
#
#                                             speaker_id  \
# 0    [AQUANYX, AQUANYX, ID-1, ID-1, AQUANYX, ID-1, ...
# 1    [ID-1, BLACKMANTASAURUS, AQUANYX, AQUANYX, BLA...
# 2                 [AQUANYX, AQUANYX, AQUANYX, AQUANYX]
# 3                                            [AQUANYX]
# 4    [GREEN TORCH, GREEN TORCH, ATROCITAURUS, ATROC...
# ..                                                 ...
# 869  [LAURA, LAURA, LAURA, DANIEL, DANIEL, DANIEL, ...
# 870    [ID-6, GALEN, ID-7, GALEN, GALEN, GALEN, GALEN]
# 871  [TED, KREEGS, ID-8, ID-8, GALEN, GALEN, KREEGS...
# 872  [KREEGS, GALEN, GALEN, KREEGS, GALEN, GALEN, K...
# 873                                            [GALEN]
#
#                                              emotion_c        comics_title  \
# 0    [[anger], [anger], [fear], [fear], [fear, sadn...  Jurassic League #4
# 1    [[fear], [anger], [surprise], [anger], [joy], ...  Jurassic League #4
# 2                     [[joy], [joy], [anger], [anger]]  Jurassic League #4
# 3                                   [[fear, surprise]]  Jurassic League #4
# 4    [[anger], [anger], [fear], [fear, surprise], [...  Jurassic League #4
# ..                                                 ...                 ...
# 869  [[anger], [anger], [anger], [anger], [anger, s...      Stillwater #13
# 870  [[sadness, surprise], [anger], [anger], [anger...      Stillwater #13
# 871  [[anger, sadness], [anger], [anger], [anger], ...      Stillwater #13
# 872  [[anger], [joy], [joy], [anger, surprise], [an...      Stillwater #13
# 873                                     [[anger, joy]]      Stillwater #13
#
#              lens
# 0    [10, 10, 10]
# 1       [9, 9, 9]
# 2       [4, 4, 4]
# 3       [1, 1, 1]
# 4       [6, 6, 6]
# ..            ...
# 869  [14, 14, 14]
# 870     [7, 7, 7]
# 871  [11, 11, 11]
# 872  [12, 12, 12]
# 873     [1, 1, 1]
#
# [874 rows x 8 columns]

# %%
model = FastLanguageModel.for_inference(model)

# %%
title_summaries_d = {}

for title in tqdm(comics_titles_full):
    
    summary_instruction = f"""You are an expert in comics with deep insight into both narrative and emotional storytelling. When given a comics title, provide a thorough yet concise emotional journey analysis that includes:

    1. The core emotional arc of the story from beginning to end
    2. Key character transformations and their emotional evolution
    3. Pivotal emotional moments that drive the narrative
    4. The emotional resonance and impact of major themes
    5. How the story's emotional stakes build and resolve

Important guidelines:
- Keep the summary focused and under 200 words while ensuring it has a proper conclusion. Do not leave any sentence unfinished.
- Focus on emotional depth rather than just plot points
- Highlight character relationships and their emotional dynamics
- Describe how the story makes readers feel at critical moments
- Connect emotional beats to show the story's psychological progression
- Ensure proper resolution of both plot and emotional arcs

Please create a cohesive summary that reveals both the story's external journey and its deeper emotional currents, showing how they interweave to create meaning."""
    
    sys_msg = {'role': 'system', 'content': summary_instruction}
    user_msg = {'role': 'user', 'content': "Here is the comics title: \n" + title}
    assistant_msg = {'role': 'assistant', 'content': ""}
    
    messages = [sys_msg, user_msg, assistant_msg]
    
    input_text = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt").to("cuda")
    
    outputs = model.generate(
        input_ids=input_text,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        top_p=0.9,
        repetition_penalty=1.1
    )
    
    input_length = input_text.shape[1]
    generated_tokens = outputs[0][input_length:]
    #print(outputs)
    decoded_output = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    title_summaries_d[title] = decoded_output
# Out:
# 100%|██████████| 35/35 [05:34<00:00,  9.55s/it]

# %%
title_summaries_d
# Out:
# {'Jurassic League #4': 'In Jurassic League #4, the core emotional arc centers around the team’s struggle against a massive dinosaur threat while grappling with internal conflicts. Initially, the characters are tense and defensive, mirroring their collective fears and past traumas. By the issue’s climax, each member undergoes significant emotional transformations—Derek (the stoic leader) becomes more empathetic, Lisa (the scientist) finds courage, and Marcus (the survivor) confronts his guilt.\n\nA pivotal moment occurs when Derek risks his life to save a teammate, symbolizing his growing trust in others. This act resonates deeply as it represents overcoming isolation and embracing teamwork. The emotional stakes grow as the dinosaurs threaten not only their physical safety but also their mental well-being. \n\nThe story delves into themes of survival, trust, and redemption. Readers feel a mix of tension, hope, and catharsis as the team faces their deepest fears together. By the end, the emotional resonance lies in the team’s newfound unity and personal growth, resolving their initial isolation and trauma through mutual support.',
#  'Nightwing #95': "In Nightwing #95, Dick Grayson grapples with the legacy of his mentor, Batman, as he confronts a newscaster who manipulates public news for profit. The story begins with Dick feeling overwhelmed by his role as Nightwing and his father figure to Damian Wayne, causing tension between them. As the issue progresses, Dick delves into a museum exhibit about Batman’s past, experiencing a mix of nostalgia and guilt over his own failures.\n\nA pivotal moment occurs when Dick realizes the naysayer's true identity, leading to a tense confrontation where he must stand up against someone who represents everything he admires but also fears. This encounter forces Dick to face his own insecurities and doubts, ultimately allowing him to grow emotionally and reaffirm his commitment to justice.\n\nDick’s relationship with Damian evolves; while there remains friction due to their differing approaches, Dick shows patience and understanding, helping Damian see the value of teamwork and trust. By the end, Dick has transformed from a conflicted hero to one who embraces his responsibilities with renewed confidence and a clearer sense of purpose.\n\nThe emotional journey resonates deeply, exploring themes of legacy, responsibility, and the struggle to live up to one's heroes. The story builds emotional stakes through intimate character interactions and high-stakes",
#  'Dark Crisis: Worlds Without a Justice League - Green Lantern #1': 'In "Dark Crisis: Worlds Without a Justice League - Green Lantern #1," the core emotional arc revolves around Hal Jordan’s struggle to find purpose after the Justice League disbands. Hal begins as a disillusioned hero, grappling with feelings of abandonment and inadequacy.\n\nHal’s emotional transformation is profound; he evolves from seeking validation through the Justice League to embracing his role as a protector of his own world, Oa. This shift is catalyzed by pivotal moments like discovering the truth about the disbandment (which was orchestrated for a greater good) and the emotional support from fellow Lanterns like Sinestro.\n\nThe emotional resonance lies in exploring Hal’s internal conflict between loyalty and self-doubt. His relationship with Sinestro becomes a key dynamic, showcasing mutual respect and understanding. Major themes of responsibility and redemption deepen Hal’s emotional journey, making him question his worth and capabilities.\n\nAs the issue builds towards a climactic confrontation, Hal’s emotional stakes grow. His determination to restore order and protect his people drives him to face significant challenges. By the end, Hal finds renewed purpose and confidence, symbolically resolving his personal turmoil and setting a path forward for the remaining heroes.\n\nThis issue masterfully weaves external action with deep emotional exploration, leaving readers emotionally invested in Hal',
#  'Dark Crisis: Worlds Without a Justice League - Green Lantern - Very Merry Multiverse': '**Core Emotional Arc:**\n"Dark Crisis: Worlds Without a Justice League – Green Lantern – Very Merry Multiverse" delves into themes of isolation, redemption, and the weight of responsibility. The story begins with Hal Jordan grappling with his newfound powers after the destruction of the Green Lantern Corps, feeling alone and questioning his worth. As he travels through the multiverse, Hal faces various manifestations of his inner demons and past traumas, leading to profound emotional turmoil.\n\n**Character Transformations & Evolution:**\nHal Jordan undergoeses a significant transformation, evolving from a self-doubting hero to one who learns to trust himself and others again. His interactions with other versions of himself and key figures like Sinestro and Martian Manhunter reveal layers of guilt, regret, and ultimately, forgiveness.\n\n**Pivotal Moments:**\nA pivotal moment occurs when Hal must confront his past mistakes in a parallel universe where he betrayed his friends. This confrontation leads to a cathartic release of pent-up emotions and a renewed sense of purpose. Another critical point is when Hal allies with different versions of Green Lanternsbearers, symbolizing unity and overcoming division.\n\n**Emotional Resonance & Major Themes:**\nThe story resonates deeply with feelings of loneliness, the burden of leadership, and',
#  'Dark Crisis: The Flash #783': 'In "Dark Crisis: The Flash #783," Barry Allen grapples with the weight of his heroic legacy as he races against time to prevent a catastrophic event that threatens Central City. The core emotional arc begins with Barry’s initial denial and reluctance to confront his destiny, evolving through intense grief over the loss of Wally West and a renewed sense of purpose.\n\nBarry transforms from a reluctant hero to one willing to make ultimate sacrifices for justice. His relationship with Iris West deepens, marked by mutual support and shared trauma. Their emotional bond provides solace but also intensifies his internal conflict between duty and personal life.\n\nA pivotal moment occurs when Barry faces his doppelganger, Zoom, who symbolizes the darker side of his powers and choices. This confrontation forces Barry to confront his inner demons and accept his role as a guardian. The emotional resonance of Barry’s journey lies in his struggle to balance heroism with humanity.\n\nAs the issue builds toward its climax, the emotional stakes grow exponentially, culminating in Barry’s decision to use his speed to save lives at the cost of his own existence. This act of self-sacrifice resolves both the plot and emotional arcs, reaffirming Barry’s commitment to his city and leaving readers feeling a mix of profound sorrow',
#  'Danger Street #1': "**Core Emotional Arc:** Danger Street #1 delves into the gritty world of of a young streetwise kid named Tommy as he navigates the dangerous streets of a decaying city. From initial hope and naivety, Tommy undergoeses a harrowing transformation as he faces violence, betrayal, and loss.\n\n**Key Character Transformations:** Initially innocent and trusting, Tommy's worldview shatters when he witnesses his friend's brutal murder. This trauma fuels a dark determination to survive and seek revenge against those who wronged him, leading to a hardened, vengeful persona by the issue’s end.\n\n**Pivotal Moments:** The pivotal moment comes when Tommy accidentally kills someone during a confrontation, sparking intense guilt and fear of becoming what he hates. This crisis forces him to confront his own darkness and the cyclical nature of violence.\n\n**Emotional Resonance & Themes:** The story explores themes of survival, innocence lost, and the moral complexities of urban life. It evokes feelings of dread, anger, and ultimately a somber acceptance. Readers are emotionally invested through Tommy's raw, visceral experiences.\n\n**Stakes & Resolution:** As danger escalates, the emotional tension builds to a climactic showdown where Tommy must choose between vengeance and redemption. While no definitive resolution",
#  'Tiny Titans #25': 'In Tiny Titans #22, the core emotional arc revolves around Beast Boy’s struggle with his identity as a metamorph and a Titans member. Initially, he feels pressure to prove himself and fit in, leading to strained relationships with his teammates. The emotional journey peaks when he overcomes his own insecurities during a mission, learning to embrace his unique abilities without conforming to others’ expectations. This pivotal moment transforms him from a reluctant hero to one who confidently stands up for what he believes in.\n\nBeast Boy undergoeses significant transformation; he evolves from feeling inferior due to his changing nature to becoming self-assured about his true form. His relationship with Robin also deepens emotionally, showcasing mutual respect and understanding through shared experiences. By the end, Beast Boy’s acceptance of his identity resonates deeply, inspiring hope and unity among the team.\n\nThe story’s emotional stakes build throughout, culminating in a climactic confrontation where Beast Boy must choose between fitting in or staying true to himself. This choice drives home the theme of authenticity versus conformity, leaving readers with a sense of empowerment and encouragement to be true to oneself. The story ultimately resolves with a reaffirmation of team cohesion based on individual strengths and differences, creating a powerful message of acceptance and belonging.',
#  'Human Target #9': 'In Human Target #9, the emotional arc centers on Kyle Shrike’s struggle with his identity as both a hired assassin and a compassionate individual. Initially, Shrike feels detached and numb, driven by duty and a sense of purpose. However, this issue marks a pivotal shift as he begins to question his moral compass.\n\nShrike’s relationship with Detective Leland Sinclair evolves from mutual respect to a complex emotional bond, with Leland serving as a moral counterpoint to Shrike’s darker nature. Shrike’s interactions with Leland deepen his introspection about his choices and the cost of his actions. This emotional tension builds as Shrike faces increasingly morally ambiguous targets, forcing him to confront the consequences of his work.\n\nA key emotional moment occurs when Shrike witnesses a client’s tragic past, leading to a profound realization of the human toll of his profession. This experience breaks through his emotional defenses, making him vulnerable for the first time in the series. Shrike’s internal conflict reaches a climax during a confrontation where he must decide between his job and his newfound empathy.\n\nThe emotional resonance lies in Shrike’s gradual transformation from a cold, calculating killer to someone grappling with the ethics of his profession. His ultimate decision to quit the targeting business and pursue a more ethical path represents a significant',
#  'DC vs. Vampires #11': '**DC vs. Vampires #11**\n\nThe core emotional arc of DC vs. Vampires #11 is one of stark confrontation and reluctant alliance. From the start, the issue delves into the tense relationship between Batman and the vampire Lobo, highlighting their mutual distrust and growing unease.\n\n**Key Character Transformations:**\nBatman remains stoic but increasingly wary as he faces his vampiric foes. Lobo, initially belligerent, begins to show signs of vulnerability and respect for his human adversary. Supporting characters like Batwoman and Red Hood experience heightened anxiety and camaraderie, bonding over shared danger.\n\n**Pivotal Emotional Moments:**\nA pivotal moment occurs when Batman and Lobo face off against a powerful vampire lord, forcing them to work together despite their differences. This encounter underscores their mutual dependence and forces them to confront their fears.\n\n**Major Themes and Resonance:**\nThe issue explores themes of survival, trust, and redemption. Despite their bloodlust, the vampires are shown to have complex emotions and motivations. The emotional resonance lies in seeing these antagonists evolve beyond simple villainy, making readers empathize even if they don’t agree.\n\n**Stakes and Resolution:**\nAs the issue builds towards a climactic battle',
#  "John Carpenter's Tales for a Halloweenight #3": "**Emotional Journey Analysis of John Carpenter's Tales for a Halloweenight #3**\n\n**Core Emotional Arc:** The story delves into the haunting legacy of a family’s dark secrets, weaving through fear, guilt, and redemption. From the initial terror as the protagonist, Sarah, discovers her haunted heritage, the narrative unfolds into a poignant exploration of familial bonds and the struggle against inherited trauma.\n\n**Key Character Transformations & Evolution:** Sarah begins as a skeptic, dismissing the supernatural until she confronts her ancestors' violent past. Through harrowing encounters and revelations, she evolves from a victimized outsider to a courageous leader who must face and ultimately forgive her lineage’s sins. Her mother, initially complicit in keeping the family’s history hidden, comes to terms with her own guilt and seeks to make amends by protecting Sarah.\n\n**Pivotal Moments:** The pivotal moment occurs when Sarah uncovers a diary revealing her ancestor’s crimes, leading to a confrontation with her father about his role in covering up these truths. This revelation intensifies her fear but also ignites a sense of duty to expose the truth, driving her toward reconciliation with her troubled past.\n\n**Themes & Resonance:** Themes of inherited guilt and the cyclical nature of trauma resonate deeply, making readers question their",
#  'The Amazing Adventures of the Ninja Turtles #5': 'In "The Amazing Adventures of the Ninja Turtles" #5, the core emotional arc revolves around the turtles\' struggle against an increasingly malevolent villain, Victor Venkov, while grappling with internal conflicts and growing up. From the initial optimism to the depths of despair and ultimate redemption, the emotional journey is profound.\n\nDonatello undergoeses a significant transformation from a tech-savvy but socially awkward turtle to a leader driven by purpose. His relationship with Leonardo becomes strained as Donnie seeks new ways to save his brothers, pushing them away emotionally. Leonardo, meanwhile, struggles with leadership responsibilities and maintaining his brotherly bonds amidst the escalating conflict.\n\nA pivotal moment occurs when Michelangelo nearly sacrifices himself for the team’s safety, forcing the others to confront their fear and insecurities. This leads to a cathartic release of pent-up emotions and a renewed sense of unity among the siblings.\n\nThemes of family, sacrifice, and personal growth resonate deeply, making readers empathize with each character’s journey. As Victor Venkov\'s threat escalates, the turtles’ emotional stakes rise exponentially, culminating in a climactic battle where they must rely on their deepest reserves of trust and love. \n\nBy the issue’s end, the emotional resonance of loyalty, forgiveness, and familial bond creates',
#  'Sonic The Hedgehog #44': 'In Sonic the Hedgehog #44, the core emotional arc centers around Sonic’s internal struggle between his desire for speed and his growing concern for his friends’ safety. Initially, Sonic prioritizes his own adventures and races, leading to conflicts with Tails and Amy who are increasingly worried about his reckless behavior.\n\nKey transformations include Sonic learning to trust his friends more deeply and understanding the importance of teamwork over his individual achievements. A pivotal moment comes when Shadow, returning from his solo mission, expresses his loneliness and regret, prompting Sonic to reevaluate his priorities.\n\nThe emotional resonance of the theme of sacrifice is profound; Sonic ultimately chooses to stay behind to protect his friends during a dangerous situation, showcasing growth and maturity. Emotional stakes build as the team faces a looming threat, culminating in a climactic battle where Sonic’s newfound sense of responsibility helps secure victory.\n\nBy the story’s end, Sonic has evolved from a lone speedster to a leader willing to make tough choices for the greater good, leaving readers emotionally satisfied by this blend of action and heartfelt connection.',
#  'Love Everlasting #2': '**Love Everlasting #22: Emotional Journey Analysis**\n\n**Core Emotional Arc:** Love Everlasting #21 delves into the profound and often tumultuous nature of love over time. The story begins with the protagonist, Sarah, grappling with the loss of her long-term partner, Mark, through a devastating accident. As she navigates her grief, Sarah discovers evidence suggesting Mark was alive after the crash, leading her to question his true fate. The emotional journey spirals between intense sorrow and hopeful speculation about what might have been.\n\n**Key Character Transformations:** Sarah evolves from a devastated widow to someone who must confront the possibility of losing the one she loved again. She grapples with the idea of moving forward without closure, which tests her resilience and capacity for hope. Meanwhile, Sarah’s friends and family witness this transformation, shifting from comforting support to understanding her need to explore the unknown.\n\n**Pivotal Moments:** A pivotal moment occurs when Sarah visits the site of the accident, finding a small piece of evidence that hints at Mark’s survival. This discovery ignites a mix of relief and fear, as she wonders if she should accept reality or hold onto the illusion of him still being alive. Another significant scene involves Sarah confronting Mark’s sister, who reveals painful truths',
#  'Fantasmas vol. 1 - Ghosted #2': '**Fantasmas vol. 1 - Ghosted #2 2**\n\nIn "Ghosted," the emotional journey begins with protagonist Mireya facing the loss of her family and her own identity, leaving her feeling adrift and alone. As she navigates the complexities of her new identity as a Latinx woman in America, her emotional arc involves confronting her past traumas and finding strength in her heritage.\n\nMireya’s transformation is profound; she transitions from a victim of circumstance to an empowered individual who must reclaim her history and cultural roots. Her relationship with her estranged mother, who initially offers little support, becomes a pivotal emotional moment when Mireya finally confronts her for the first time since childhood. This encounter, filled with tension and unresolved emotions, marks a turning point where Mireya begins to assert her independence and demand understanding.\n\nThe comic’s climax sees Mireya standing up against the very forces that have tried to erase her identity—both metaphorically and literally. Through this confrontation, she finds a sense of belonging and validation, symbolizing the broader struggle against systemic oppression faced by marginalized communities.\n\nThemes of cultural identity, family legacy, and personal resilience resonate deeply throughout the issue, evoking a range of emotions—from heartbreak to empowerment. By',
#  'Fantasmas vol. 1 - Ghosted #3': "In Fantasmas vol. 1 - Ghosted #3, the core emotional arc revolves around the protagonist, Luis, grappling with abandonment and seeking connection amidst loss. Initially isolated after his girlfriend leaves him, Luis descends into loneliness and despair. By issue three, he begins to transform, finding solace in unexpected friendships and a sense of belonging.\n\nA pivotal moment occurs when Luis confronts his ex-girlfriend about her sudden departure, only to discover she was deeply traumatized by a past betrayal. This revelation prompts Luis to empathize and forgive, marking a significant emotional shift towards compassion and understanding.\n\nThe theme of trust and vulnerability resonates strongly throughout, as Luis must navigate his own fears while supporting others who have been hurt. His journey culminates in a powerful scene where he stands up for a friend against bullies, demonstrating newfound confidence and solidarity.\n\nThe emotional stakes escalate as Luis faces the possibility of losing these new connections if he doesn't address his lingering insecurities head-on. In the finale, Luis resolves his internal conflicts by reaching out to his ex-girlfriend, initiating a tentative reconciliation rooted in mutual respect.\n\nThis emotional journey encapsulates the complexities of human connection, the pain of loss, and the transformative power of empathy and forgiveness, leaving readers feeling a mix",
#  'Fantasmas vol. 1 - Ghosted #4': 'In "Fantasmas vol. 1 - Ghosted #4," the core emotional arc centers around the protagonist, Dani, who grapples with loneliness and the fear of being forgotten after her boyfriend leaves her without explanation. Dani\'s emotional transformation is profound; she evolves from feeling abandoned and worthless to finding strength and purpose by embracing her own identity and reconnecting with her roots.\n\nA pivotal moment occurs when Dani confronts her ex-boyfriend, revealing the pain and betrayal she felt but also demonstrating newfound self-worth. This confrontation marks a turning point where Dani must decide whether to let her past define her or forge a new path forward.\n\nThe theme of abandonment versus belonging resonates deeply, as Dani navigates between her current emptiness and the ghosts of her past, including her family and cultural heritage. These emotions are further amplified through flashbacks, illustrating how her relationship shaped her identity and how reclaiminging her history gives her a sense of grounding and validation.\n\nAs the issue concludes, Dani faces her fears head-on, choosing to embrace her unique identity and the support of of her community. The emotional stakes build throughout the series, culminating in this final issue where Dani’s journey towards self-worth and acceptance reaches a satisfying resolution, leaving readers with a powerful message about',
#  'Fantasmas vol. 1 - Ghosted #5': 'In "Fantasmas vol. 1 - Ghosted #5," the emotional arc begins with a sense of abandonment as the main characters, Luis, struggles to cope after being left by his girlfriend for another woman. Luis\' internal turmoil intensifies as he grapples with feelings of betrayal and worthlessness.\n\nKey character transformation: Luis undergoes a profound emotional shift from despair to resilience. He learns to face his fears and confronts the ghosts (both literal and metaphorical) from his past relationships. This journey leads him to a place of acceptance and self-love.\n\nPivotal emotional moment: In issue #5, Luis reunites with his ex-girlfriend, who apologizes for her actions but struggles to fully explain herself. This confrontation forces Luis to reevaluate his feelings and decide whether to forgive or move on, driving the narrative towards resolution.\n\nMajor themes resonate deeply: Abandonment, forgiveness, and personal growth are woven through the story. Luis\' journey highlights the pain of loss and the strength required to heal emotionally.\n\nEmotional stakes build as Luis faces his deepest insecurities, ultimately leading to a cathartic release where he finds closure and a new path forward. The story leaves readers feeling hopeful about overcoming past traumas and finding redemption.',
#  'Fantasmas vol. 1 - Ghosted #1': 'In "Fantasmas vol. 1 - Ghosted #1," the core emotional arc revolves around the protagonist, Leticia, grappling with loneliness and the loss of her identity after being abandoned by her girlfriend. Leticia transforms from a confident woman to one who struggles with self-worth and trust issues, ultimately finding a tentative sense of belonging among a group of outcasts.\n\nA pivotal moment occurs when Leticia reconnects with her childhood friend, Marco, only for him to reveal he too has been betrayed and feels lost. This shared experience brings them closer emotionally, but also highlights their insecurities. Themes of rejection and connection resonate deeply as Leticia navigates these complex feelings.\n\nThe emotional stakes intensify as Leticia faces the challenge of reclaiminging her life without relying solely on others’ validation. By the end, she must confront her fears and decide whether to embrace her newfound community or remain isolated. The story leaves readers feeling a mix of empathy, hope, and introspection, emphasizing the universal struggle against loneliness and the search for genuine connections.',
#  'Fantasmas vol. 1 - Ghosted #6': 'In "Fantasmas vol. 1 - Ghosted #6," the core emotional arc centers around the protagonist, Marisol, as she navigates the loss of her best friend, Luna, who abruptly disappears (or "ghosts") without explanation. Initially, Marisol is devastated by Luna’s absence but gradually learns of Luna’s struggles with mental health and substance abuse. This revelation brings a mix of anger, guilt, and acceptance.\n\nMarisol undergoes a profound transformation from seeking revenge against those she believes wronged Luna to embracing forgiveness and understanding. She learns to cope with her grief through art and connecting with others who have experienced similar losses.\n\nA pivotal moment occurs when Marisol confrontssto confront Luna’s family about the circumstances surrounding her disappearance, leading to a cathartic release of pent-up emotions. This confrontation marks a turning point where Marisol transitions from denial to facing reality head-on.\n\nThe emotional resonance lies in exploring themes of friendship, mental health stigma, and healing after trauma. The story deeply resonates with readers who have lost loved ones or struggled with mental health issues themselves. As Marisol comes to terms with her past, the reader experiences a bittersweet sense of closure and hope for moving forward.\n\nUltimately, the emotional stakes build from Marisol’s',
#  'Fantasmas vol. 1 - Ghosted #7': "**Core Emotional Arc:** Fantasmas vol. 1 - Ghosted #7 delves into themes of isolation and connection, ultimately exploring the transformative power of human bonds. The story begins with protagonist Maria feeling increasingly disconnected after her boyfriend breaks up with her, leaving behind only her family's ghostly past. As she grapples with loneliness and grief, Maria reconnects with her estranged father and learns about his own broken heart. This reunion rekindles her faith in love and humanity.\n\n**Key Character Transformations:** Maria evolves from a lost, disillusioned individual to one who finds hope and healing through understanding and forgiveness. Her father’s journey mirrors hers, as he overcomes his own regrets and fears, ultimately finding closure and a renewed sense of purpose.\n\n**Pivotal Moments:** The breaking point comes when Maria confronts her ex-boyfriend, forcing him to face the consequences of his actions. This confrontation marks a turning point where she gains the strength to move forward without bitterness. Another crucial moment occurs during a heartfelt conversation with her father, where they share their deepest regrets, leading to a powerful emotional breakthrough for both.\n\n**Emotional Resonance & Themes:** The story deeply resonates with feelings of loss, longing, and redemption. Themes of inherited trauma",
#  'Fantasmas vol. 1 - Ghosted #8': 'In "Fantasmas vol. 1 - Ghosted #8," the core emotional arc revolves around the protagonist, Nina, grappling with abandonment and the loss of her identity as she navigates the aftermath of being "ghosted" by her ex-boyfriend, Victor. Initially, Nina feels a mix of hurt and confusion, but as the issue progresses, she experiences profound emotional turmoil and self-doubt.\n\nNina transforms from a vulnerable and uncertain individual to one who gains strength and resilience through introspection and support from her friends. She faces pivotal moments where her emotional vulnerability is tested, such as confronting Victor\'s ghostly apparition and reevaluating her past relationship. These encounters force Nina to confront her fears and insecurities deeply embedded within her psyche.\n\nThe emotional resonance of the theme of "being seen and heard" drives the narrative, highlighting Nina’s journey towards self-love and independence. Her emotional stakes grow as she must decide whether to move forward or remain stuck in the past, ultimately leading to a cathartic resolution where Nina finds closure and a renewed sense of purpose.\n\nThrough this emotional odyssey, the story evokes a range of feelings—from heartbreak and frustration to empowerment and liberation—ultimately leaving the reader with a poignant understanding of the complexities of human',
#  'Fantasmas vol. 1 - Ghosted #9': '**Fantasmas vol. 1 - Ghosted #9**\n\n**Core Emotional Arc:** \nThe series culminates in #9 as the main characters, Fantasmas, confronts her past traumas and the ghostly entity that haunts her. Initially, she struggles with guilt and fear, but by the end, she finds redemption and closure.\n\n**Key Character Transformations:**\nFantasmas evolves from a paralysed victim to an empowered survivor. She overcomes her fear of ghosts and learns to face them directly. Her relationship with her mentor, Mr. Gabe, deepens; he becomes a source of strength and guidance.\n\n**Pivotal Emotional Moments:**\n- **Guilt and Isolation (Issue 8):** Fantasmas relives traumatic memories, feeling isolated and overwhelmed.\n- **Confrontation (Issue 9):** Fantasmas finally faces the ghost, leading to a climactic battle where she must choose between revenge or forgiveness.\n\n**Emotional Resonance:**\nThe series explores themes of trauma, resilience, and self-forgiveness. Readers experience a rollercoer of emotions—fear, anger, hope, and ultimately, peace.\n\n**Building and Resolving Emotional Stakes:**\nInitially',
#  'Fantasmas vol. 1 - Ghosted #10': 'In "Fantasmas vol. 1 - Ghosted #10," the core emotional arc centers around the protagonist, Lourdes, as she grapples with the loss of her family and the haunting memories of her past. From the beginning, Lourdes is isolated and struggling to find her place in the present world, haunted by her dead family members who continue to visit her.\n\nLourdes undergoeses significant transformation throughout the issue. She transitions from a withdrawn and fearful individual to someone who begins to confront her grief head-on. By the end, she emerges stronger and more resilient, learning to let go of her past and find solace in her new life.\n\nA pivotal moment occurs when Lourdes encounters her deceased mother, who finally understands why she was sent away and provides closure for both characters and reader. This scene deeply resonates emotionally, highlighting the theme of unresolved familial bonds and the pain of separation.\n\nThe emotional stakes build as Lourdes faces the reality of her family\'s abandonment and her own struggle to fit in among the living. The climax of the issue sees Lourdes making a choice between staying in the past or moving forward, which culminates in a bittersweet but ultimately freeing resolution. \n\nThroughout the issue, the',
#  'American Vampire vol. 4 - #6': 'In "American Vampire" Vol. 4 #6, the core emotional arc revolves around the protagonist, Daniel Dracula Kent, as he grapples with his identity and destiny. Initially, Daniel feels torn between his human life and his supernatural heritage, leading to internal conflict and anxiety. As the issue progresses, Daniel’s relationship with his adoptive father, John Constantine, intensifies, creating a bond based on mutual respect and shared trauma.\n\nDaniel’s emotional transformation is pivotal when he confronts his vampire ancestry, forcing him to confront his deepest fears about being different. This moment triggers a cathartic release of pent-up anger and sadness, ultimately empowering him to accept his true self. The climax sees Daniel making a choice that aligns with his newfound sense of self, symbolizing personal growth and resilience.\n\nThe issue’s emotional resonance lies in exploring themes of acceptance, identity, and family bonds. Key emotional moments include Daniel’s tearful conversation with John, revealing the depth of their connection and trust. Additionally, Daniel’s confrontation with his past mistakes drives home the theme of redemption and moving forward. These moments build the emotional stakes, culminating in a satisfying resolution where Daniel solidifies his place within both his human and vampire worlds.\n\nUltimately, “American Vampire” Vol. ',
#  'American Vampire vol. 4 - #7': '**Emotional Journey Analysis for American Vampire Vol. 4 - #7**\n\n**Core Emotional Arc:** In this issue, the core emotional arc revolves around the tension between loyalty and betrayal, as well as the struggle to maintain one’s identity amidst overwhelming forces. From the initial confrontation where protagonist Mick Stane confronts his vampire kin about a dark secret, the issue builds towards a climactic moment of truth.\n\n**Key Character Transformations:** Mick transitions from a reluctant leader to someone who must make difficult choices for the greater good. His relationship with his sister, Julia, evolves from sibling rivalry to a bond forged through shared trauma and mutual support. Julia’s transformation is more internal; she grapples with her own burgeoning vampiric nature and the loss of control it brings.\n\n**Pivotal Emotional Moments:** The issue begins with Mick’s discovery of a conspiracy involving his family, leading to a tense standoff. This moment heightens suspense and sets up a personal conflict. Another pivotal scene occurs when Mick and Julia confront their father, revealing a painful past and challenging their trust in each other. These scenes evoke a mix of fear, anger, and vulnerability.\n\n**Major Themes and Resonance:** Themes of family, duty, and the burden of secrets resonate deeply. The issue',
#  'American Vampire vol. 4 - #8': 'In "American Vampire" Vol. 4 #8, the core emotional arc centers around the tragic loss and subsequent grief of Abigail Craven as she faces the reality of her husband\'s death. Initially, Abigail clings to hope and denial, but by this issue, she has descended into a dark despair, struggling to find solace or purpose.\n\nAbigail undergoeses a profound transformation from a woman who once thrived on life to one now haunted by her husband’s memory and consumed by his death. She evolves from a survivor to a victim, grappling with guilt over her inability to save him. Her relationship with Mick Stane becomes strained, as he tries to offer support but ultimately feels inadequate against her overwhelming sorrow.\n\nA pivotal moment occurs when Abigail confrontsst the vampire community, demanding answers about her husband’s fate. This confrontation marks a turning point, as she transitions from passive victimhood to active defiance, driven by a newfound determination to uncover the truth.\n\nThe emotional resonance of the themes of love, loss, and resilience resonates deeply, making readers acutely aware of Abigail’s pain and inner struggle. The story explores the devastating impact of losing a loved one and the complex emotions that follow, such as anger, guilt, and longing.\n\nAs',
#  'Dragon Age vol. 3 Engano - Deception #1': 'In "Dragon Age vol. 3 Engano - Deception #1," the core emotional arc revolves around the protagonist, Cullen, grappling with his identity and loyalty. Initially torn between his love for Meredith and his past as Alistair, Cullen’s emotional journey is one of betrayal and redemption.\n\nCullen undergoes significant transformation as he uncovers the truth about Meredith\'s manipulations, leading him to question everything he thought he knew about himself and those around him. His relationship with Meredith deteriorates sharply when she tries to manipulate him further, culminating in a pivotal moment where Cullen must choose between his love and his principles.\n\nThe emotional resonance of these themes lies in the stark contrast between trust and deception, highlighting the psychological toll of living a lie. The story amplifies these feelings through intense confrontations and intimate revelations, making readers experience the raw emotions of betrayal and self-discovery.\n\nAs the issue builds towards a climactic revelation, the emotional stakes grow exponentially. By the end, Cullen faces a difficult choice that will irrevocably alter his destiny, leaving the reader emotionally invested in his ultimate decision. This issue masterfully intertwines the external plot of political intrigue with the internal struggle of identity, creating a deeply moving emotional journey.',
#  'Dragon Age vol. 3 Engano - Deception #2': 'In "Dragon Age vol. 3 Engano - Deception #2," the core emotional arc centers around the protagonist, Aveline, grappling with betrayal and trust. Initially, she navigates through suspicion and fear as old allies turn against her. By the climax, Aveline must confront her own doubts and make a difficult choice that reshapes her identity.\n\nAveline undergoes significant transformation from a loyal follower to someone who questions allegiances and values. She evolves from a blindly trusting individual to one who learns to discern true friends amidst deception. Her relationship with Cullen deepens, but their differing perspectives on loyalty strain their bond.\n\nKey emotional moments include when Aveline discovers her former comrades\' betrayal, leading to intense feelings of vulnerability and anger. Another pivotal moment occurs during a tense confrontation where Aveline faces the harsh reality of her situation alone, forcing her to confront her fears head-on.\n\nThe theme of trust vs. mistrust resonates deeply, highlighting the psychological toll of being betrayed by those close to you. These themes evoke a sense of unease and introspection, making readers question their own judgments and loyalties.\n\nAs the story progresses, Aveline’s emotional stakes grow exponentially. Her decision to act on her suspicions tests her resolve',
#  'Dragon Age vol. 3 Engano - Deception #3': '**Emotional Journey Analysis for Dragon Age vol. 3 Engano - Deception #3**\n\n**Core Emotional Arc:** The story begins with a sense of betrayal and distrust as characters Alistair confronts his past actions, leading to a profound internal struggle between loyalty and guilt. By the climax, he must face the consequences of his deception, culminating in redemption through self-sacrifice.\n\n**Character Transformations:** Alistair’s arc sees him grappling with the weight of of past decisions, moving from defensive denial to accepting responsibility and finding peace. This transformation is mirrored by the growth of trust among the companions, particularly between Alistair and Leliana, as they navigate shared hardships together.\n\n**Pivotal Moments:** The confrontation where Alistair realizes the true extent of his past lies forms a turning point, triggering intense emotional turmoil. The final battle scene where Alistair chooses to protect others despite his own safety, solidifies his journey towards redemption.\n\n**Major Themes & Resonance:** The themes of guilt, redemption, and trust resonate deeply, evoking feelings of empathy and hope. The story explores the complex emotions tied to personal choices and their long-term effects on relationships.\n\n**Stakes & Resolution:** As the emotional stakes rise, so does',
#  'The Walking Dead vol 15 - #169': 'In "The Walking Dead" Vol. 15 - #169, the core emotional arc centers around the loss and resilience of the remaining survivors as they navigate the harsh realities of post-apocalyptic existence. The series delves deeply into themes of grief, survival, and the bonds that hold a community together despite overwhelming odds.\n\nRick Grimes undergoes significant transformation; his initial leadership evolves into a more complex role of mourning and making difficult decisions for the greater good. His relationship with Michonne becomes increasingly strained, culminating in a pivotal moment where Rick must choose between protecting his group or maintaining a fragile peace with another survivor. This choice showcases Rick’s internal conflict between duty and personal connection, heightening the emotional tension.\n\nA pivotal emotional moment occurs when Daryl faces the brutal reality of the world without any hope of returning return to normalcy. His breakdown reveals profound despair but also hints at a new strength born from acceptance. This scene resonates emotionally, emphasizing the universal struggle against hopelessness.\n\nThe emotional stakes build throughout the issue, particularly during a tense encounter with a group of survivors who challenge Rick’s authority. This confrontation forces Rick to confront his own mortality and the cyclical nature of loss and survival. As the issue concludes, the emotional journeys of key characters intersect',
#  'The Walking Dead vol 15 - #170': 'In "The Walking Dead" Vol. 15 - #170, the core emotional arc revolves around Rick Grimes\' struggle for survival and his growing acceptance of his new role as a leader among survivors. Initially torn between his need to protect others and his grief over those lost, Rick evolves from a reluctant leader to a determined one, though still haunted by his past failures.\n\nKey character transformations include Rick\'s complex relationship with Michonne, who becomes both a comrade and emotional support despite their differing philosophies. Carl also undergoes a significant emotional growth, learning to take responsibility and make difficult decisions. \n\nPivotal emotional moments include the tragic loss of several key characters, which deepen the group\'s bond through shared grief and sacrifice. The decision to attack a large zombie horde demonstrates the characters\'s resilience but also the crushing toll of the apocalypse. These events heighten the sense of urgency and the characters\'s internal conflicts.\n\nThemes of loss, survival, and moral compromise resonate deeply, evoking empathy and tension. The escalating danger and dwindling resources underscore the harsh reality of their situation, creating an intense emotional atmosphere.\n\nAs the issue builds towards its climax, the emotional stakes reach a peak with the group’s final stand against overwhelming odds. The outcome leaves the characters',
#  'The Walking Dead vol 15 - #171': '**The Walking Dead Vol. 15 – #171**\n\n**Core Emotional Arc:** The issue delves into the group’s survival against both walkers and human threats, focusing on Carl Grimes’ emotional maturity as he transitions from a child to a young adult. The story begins with tension and loss, culminating in a profound sense of responsibility and resilience.\n\n**Key Character Transformations:** Carl grapples with guilt over his mother’s death, leading him to take charge more assertively. Daryl undergoeses a subtle shift from a lone survivor mentality to forming stronger bonds within the group.\n\n**Pivotal Moments:** The moment when Carl leads a mission to find safe ground without his father’s guidance marks a turning point, showcasing his growing independence and leadership skills. The group’s decision to fight off an attack together highlights their evolving unity and trust.\n\n**Emotional Resonance:** Themes of family, duty, and survival resonate deeply, evoking feelings of hope amidst despair and inspiring readers to reflect on their own responsibilities during crisis.\n\n**Stakes and Resolution:** The emotional stakes grow exponentially as the group faces increasingly dire situations, pushing characters to confront their fears and vulnerabilities. By the end, Carl and the others achieve a fragile but vital stability, symbolizing',
#  'The Walking Dead vol 15 - #173': '**The Walking Dead Vol. 15 - #173**\n\n**Core Emotional Arc:** This issue delves into themes of survival, loss, and resilience amidst a post-apocalyptic world. The emotional journey begins with intense grief as Rick Grimes loses his wife Lori to a walker. The arc then shifts towards acceptance and renewed determination as Rick navigates the harsh realities of his new life.\n\n**Character Transformations & Evolution:** Rick transitions from a devoted husband to a hardened leader, struggling with guilt over Lori’s death and the weight of leadership. Carl, now more independent, grapples with the reality of his mother’s demise and his growing role as a protector for the group.\n\n**Pivotal Moments:** The pivotal moment occurs when Rick confronts’s a survivor who was responsible for Lori’s death, leading to a brutal fight. This scene heightens the tension and Rick’s internal conflict, symbolizing his struggle between justice and survival.\n\n**Themes & Resonance:** Themes of family, sacrifice, and hope resonate deeply. The emotional impact comes through the raw vulnerability of characters facing their deepest fears and losses. The issue leaves readers feeling profoundly affected by the stark reality of the characters’s situations.\n\n**Emotional Stakes & Resolution:** As Rick and the group',
#  'Thief Of Thieves 1 - #11': 'In "Thief of Thieves #1," the core emotional arc centers around protagonist Jack Ketchum’s descent into criminality and his ultimate redemption quest. Initially arrogant and amoral, Jack’s emotional transformation begins when he encounters the enigmatic thief known as “The King,” who becomes his mentor. Key moments include Jack stealing from a wealthy family, which triggers guilt and introspection, leading him to question his life choices.\n\nJack’s relationship with The King evolves from rivalry to a complex bond, with mutual respect and dependence. This dynamic drives Jack towards moral clarity and self-sacrifice. Emotional resonances emerge through Jack’s internal monologues, showcasing his struggle between ambition and conscience. Themes of identity and legacy profoundly impact Jack, forcing him to confront his past actions and their consequences.\n\nAs the story progresses, Jack’s emotional stakes escalate, culminating in a final confrontation where he must choose between loyalty and justice. His decision ultimately leads to a bittersweet resolution, blending personal growth with a sense of closure. The narrative leaves readers emotionally invested in Jack’s journey, reflecting on the costs of ambition and the potential for redemption.',
#  'Stillwater #13': 'In Stillwater #13, the core emotional arc centers around the protagonist, a retired superhero named Stillwater, grappling with his past as he helps a young boy cope with trauma. From the initial reluctance to engage with the present, Stillwater evolves into a mentor figure, forming a bond with the boy through shared experiences and mutual growth.\n\nKey character transformations include Stillwater’s transition from isolation to connection, and the boy’s shift from fear to resilience. A pivotal moment occurs when Stillwater saves the boy from a threatening situation, marking a turning point where trust and reliance develop between them. This event drives the narrative forward, emphasizing themes of redemption and second chances.\n\nThe story explores the emotional resonance of confronting one’s own flaws and offering hope to others. Stillwater’s internal struggle with guilt over past mistakes amplifies the emotional impact, making readers feel a mix of empathy and inspiration. As the issue concludes, the emotional stakes build towards a heartfelt resolution where Stillwater finds peace by helping someone else, resolving both his personal demons and providing closure for the boy’s healing journey.\n\nOverall, Stillwater #13 leaves readers emotionally fulfilled with a sense of hope and the power of human connection to overcome adversity.'}

# %%
page_df['summary'] = page_df['comics_title'].map(title_summaries_d)

# %%
page_df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1    [NO--  #GKKK…#, #CHOMP!, BY THE SKIN OF MATILD...
# 2    [COME ON, BEAST!, SHOW YOURSELF!, WHY DO YOU H...
# 3                                           [#AARGH! ]
# 4    [I, THE GREEN TORCH, HAVE BEEN TASKED WITH PRO...
# ..                                                 ...
# 869  [WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO ...
# 870  [SO WHAT ARE WE GOING TO DO?, THE WAY I SEE IT...
# 871  [KIDDIE COUNCIL'S BEEN GOING A LONG TIME... , ...
# 872  [IT'S BEEN… PEACEFUL. ASIDE FROM SHIT LIKE THI...
# 873              [" AND PAY OUR NEIGHBOURS A VISIT. "]
#
#                                             speaker_id  \
# 0    [AQUANYX, AQUANYX, ID-1, ID-1, AQUANYX, ID-1, ...
# 1    [ID-1, BLACKMANTASAURUS, AQUANYX, AQUANYX, BLA...
# 2                 [AQUANYX, AQUANYX, AQUANYX, AQUANYX]
# 3                                            [AQUANYX]
# 4    [GREEN TORCH, GREEN TORCH, ATROCITAURUS, ATROC...
# ..                                                 ...
# 869  [LAURA, LAURA, LAURA, DANIEL, DANIEL, DANIEL, ...
# 870    [ID-6, GALEN, ID-7, GALEN, GALEN, GALEN, GALEN]
# 871  [TED, KREEGS, ID-8, ID-8, GALEN, GALEN, KREEGS...
# 872  [KREEGS, GALEN, GALEN, KREEGS, GALEN, GALEN, K...
# 873                                            [GALEN]
#
#                                              emotion_c        comics_title  \
# 0    [[anger], [anger], [fear], [fear], [fear, sadn...  Jurassic League #4
# 1    [[fear], [anger], [surprise], [anger], [joy], ...  Jurassic League #4
# 2                     [[joy], [joy], [anger], [anger]]  Jurassic League #4
# 3                                   [[fear, surprise]]  Jurassic League #4
# 4    [[anger], [anger], [fear], [fear, surprise], [...  Jurassic League #4
# ..                                                 ...                 ...
# 869  [[anger], [anger], [anger], [anger], [anger, s...      Stillwater #13
# 870  [[sadness, surprise], [anger], [anger], [anger...      Stillwater #13
# 871  [[anger, sadness], [anger], [anger], [anger], ...      Stillwater #13
# 872  [[anger], [joy], [joy], [anger, surprise], [an...      Stillwater #13
# 873                                     [[anger, joy]]      Stillwater #13
#
#              lens                                            summary
# 0    [10, 10, 10]  In Jurassic League #4, the core emotional arc ...
# 1       [9, 9, 9]  In Jurassic League #4, the core emotional arc ...
# 2       [4, 4, 4]  In Jurassic League #4, the core emotional arc ...
# 3       [1, 1, 1]  In Jurassic League #4, the core emotional arc ...
# 4       [6, 6, 6]  In Jurassic League #4, the core emotional arc ...
# ..            ...                                                ...
# 869  [14, 14, 14]  In Stillwater #13, the core emotional arc cent...
# 870     [7, 7, 7]  In Stillwater #13, the core emotional arc cent...
# 871  [11, 11, 11]  In Stillwater #13, the core emotional arc cent...
# 872  [12, 12, 12]  In Stillwater #13, the core emotional arc cent...
# 873     [1, 1, 1]  In Stillwater #13, the core emotional arc cent...
#
# [874 rows x 9 columns]

# %%
# def build_generation_instruction():
   
#     emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
#     formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
#     instruction = f"""### Emotion Analysis Expert Role

# You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content, taking into account the overall emotional context of the comic.

# INPUT:
# - You will receive a list of utterances from a page in a comic book
# - You will receive an emotional summary in this format:
#   "emotional_summary": "A detailed description of the comic's emotional themes, character arcs, and major emotional shifts throughout the story"

# TASK:
# 1. Use both the emotional summary and immediate context to analyze each utterance
# 2. Consider how the overall emotional themes influence individual dialogue moments
# 3. Identify applicable emotions from the following classes:
#    {formatted_classes}
# 4. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order

# RULES:
# 1. Use ONLY the labels listed above
# 2. Output must be a JSON with single key "page_utterance_emotions"
# 3. Value must be an array where:
#    - Each element is an array of emotions for one utterance
#    - Order matches the input utterances order
#    - Multiple emotions are allowed per utterance
# 4. No explanations, only JSON output

# IMPORTANT:
# - Each array element corresponds to one utterance
# - One utterance can have multiple emotions
# - Maintain exact spelling and case of emotion labels
# - Keep emotions in arrays even for single emotions
# - Use the emotional summary to inform the broader context of each utterance

# """
#     return instruction

# %%
def build_generation_instruction():
   
    emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
    formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
    instruction = f"""### Emotion Analysis for Comics

You are an emotion analysis expert for comic dialogue. Analyze utterances based on both the provided emotional summary and immediate context.

INPUT:
- List of utterances from a comic page
- Comic's emotional summary describing themes and character arcs

OUTPUT:
- JSON with single key "page_utterance_emotions"
- Value: array of emotion arrays matching utterance order
- ONLY use these emotions: {formatted_classes}
- NO OTHER EMOTION LABELS ARE ALLOWED

RULES:
1. Each utterance must have at least one emotion from the list above
2. Multiple emotions per utterance are allowed
3. Keep emotions in arrays even for single emotions
4. Maintain exact emotion spelling and case
5. No explanations, only JSON output

Example format:
{{"page_utterance_emotions": [["joy"], ["anger", "fear"], ["neutral"]]}}
"""
    return instruction

# %%
def build_user_prompt(comics_title, emotional_summary, pg_utterances):
    usr_prompt = f"""Comic Information:
Title: {comics_title}
Emotional Summary: {emotional_summary}

Utterances to Classify:
{pg_utterances}"""
    return usr_prompt

# %%
generation_instruction = build_generation_instruction()

# %%
sys_msg_l = []
user_msg_l = []
assistant_msg_l = []

for _, row in page_df.iterrows():
        
        sys_msg = {'role': 'system', 'content': generation_instruction}
        
        comics_title = row['comics_title']
        comics_summary = row['summary']
        
        utterances_l = row['utterance']
        pg_utterances = "\n".join(f"{i+1}. {title}" for i, title in enumerate(utterances_l))
        
        # usr_prompt = f"Comics title: {comics_title}\n" + f"Comics summary: {comics_summary}\n" + "Here is the list of utterances that you will classify: \n" + pg_utterances
        usr_prompt = build_user_prompt(comics_title, comics_summary, pg_utterances)
        
        user_msg = {'role': 'user', 'content': usr_prompt}        
        assistant_msg = {'role': 'assistant', 'content': ""}


        sys_msg_l.append(sys_msg)
        user_msg_l.append(user_msg)
        assistant_msg_l.append(assistant_msg)

# %%
comics_dataset = []

for i in range(len(sys_msg_l)):

    comics_dataset.append([sys_msg_l[i], user_msg_l[i], assistant_msg_l[i]])

# %%
comics_dataset[10]
# Out:
# [{'role': 'system',
#   'content': '### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Analyze utterances based on both the provided emotional summary and immediate context.\n\nINPUT:\n- List of utterances from a comic page\n- Comic\'s emotional summary describing themes and character arcs\n\nOUTPUT:\n- JSON with single key "page_utterance_emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"page_utterance_emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n'},
#  {'role': 'user',
#   'content': "Comic Information:\nTitle: Jurassic League #4\nEmotional Summary: In Jurassic League #4, the core emotional arc centers around the team’s struggle against a massive dinosaur threat while grappling with internal conflicts. Initially, the characters are tense and defensive, mirroring their collective fears and past traumas. By the issue’s climax, each member undergoes significant emotional transformations—Derek (the stoic leader) becomes more empathetic, Lisa (the scientist) finds courage, and Marcus (the survivor) confronts his guilt.\n\nA pivotal moment occurs when Derek risks his life to save a teammate, symbolizing his growing trust in others. This act resonates deeply as it represents overcoming isolation and embracing teamwork. The emotional stakes grow as the dinosaurs threaten not only their physical safety but also their mental well-being. \n\nThe story delves into themes of survival, trust, and redemption. Readers feel a mix of tension, hope, and catharsis as the team faces their deepest fears together. By the end, the emotional resonance lies in the team’s newfound unity and personal growth, resolving their initial isolation and trauma through mutual support.\n\nUtterances to Classify:\n1. GIGANTA SAID, IN ORDER TO FIND THIS EVIL'S LOCATION, I HAD TO SEE IT FROM UP HIGH.\n2. THIS WILL GET US THERE.\n3. COME, CHILD…\n4. … LET'S GO FIND JOKERZARD!"},
#  {'role': 'assistant', 'content': ''}]

# %%
raw_outputs = []

for message in tqdm(comics_dataset):
    
    inputs = tokenizer.apply_chat_template(
    message,
    tokenize=True,
    add_generation_prompt=True,
    #return_dict=True,
    return_tensors="pt",
).to("cuda")
    #print(inputs)
    #break
    
    output = model.generate(input_ids=inputs, max_new_tokens=128)[0]
    #output = model.generate(**inputs, max_new_tokens=128)[0]
    
    input_length = inputs.shape[1]
    generated_tokens = output[input_length:]
    
    decoded_output = tokenizer.decode(generated_tokens, skip_special_tokens=True)  
    #decoded_output = tokenizer.decode(output, skip_special_tokens=True)
    raw_outputs.append(decoded_output)
    #break
# Out:
# 100%|██████████| 874/874 [31:22<00:00,  2.15s/it]

# %%
raw_outputs
# Out:
# ['{\n  "page_utterance_emotions": [\n    ["disgust", "anger"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["sadness"],\n    ["anger"],\n    ["surprise"],\n    ["surprise"],\n    ["fear"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["anger", "fear"],\n    ["anger", "fear"],\n    ["disgust", "fear"],\n    ["disgust", "fear"],\n    ["surprise"],\n    ["neutral"],\n    ["anger", "fear"],\n    ["anger", "fear"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["fear", "anger"],\n    ["disgust", "anger"],\n    ["anger"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger", "fear"], ["disgust"], ["disgust"], ["joy"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["threat"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["tension", "disgust"],\n    ["insight", "surprise"],\n    ["surprise"],\n    ["confidence"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["anger", "fear"],\n    ["fear"],\n    ["fear", "disgust"],\n    ["fear", "disgust"],\n    ["anger"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["anger"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["fear"],\n    ["fear"],\n    ["joy", "hope"],\n    ["sadness", "anger"],\n    ["surprise"],\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["sadness"],\n    ["anger"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["sadness", "disgust"],\n    ["neutral"],\n    ["joy", "hope"],\n    ["disgust", "anger"],\n    ["anger", "fear"],\n    ["fear", "sadness"],\n    ["sadness"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["fear", "disgust"],\n    ["sadness", "disgust"],\n    ["nostalgia", "sadness"],\n    ["fear", "sadness"],\n    ["joy", "hope"],\n    ["anxiety", "sadness"],\n    ["fear", "sadness"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["anger", "disgust"],\n    ["sadness", "fear"],\n    ["anger", "disgust"],\n    ["sadness", "fear"],\n    ["fear", "disgust"],\n    ["neutral"],\n    ["joy"],\n    ["anger", "disgust"],\n    ["sadness", "fear"],\n    ["joy"],\n    ["neutral"],\n    ["joy"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"], ["disgust", "fear"], ["joy"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["joy", "surprise"],\n    ["joy"],\n    ["fear", "anger"],\n    ["fear"],\n    ["disgust"],\n    ["disgust"],\n    ["fear"],\n    ["fear"],\n    ["neutral"],\n    ["relief"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [["neutral"], ["anger", "fear"], ["joy"]]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger"], ["disgust", "sadness"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["surprise"]]}',
#  '{"page_utterance_emotions": [["anger"], ["anger", "disgust"], ["neutral"], ["anger"], ["fear"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["fear", "disgust"],\n    ["fear"],\n    ["fear"],\n    ["fear"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["disgust", "fear"],\n    ["surprise"],\n    ["neutral"],\n    ["sadness"],\n    ["anger", "disgust"],\n    ["anger", "sadness"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["disappointment"], ["neutral"], ["neutral"], ["anger", "disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["joy"],\n    ["disgust"],\n    ["fear"],\n    ["anger"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "anger"],\n    ["fear", "disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["fear", "sadness"],\n    ["anger"],\n    ["fear", "anger"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["sadness"],\n    ["fear"],\n    ["disgust"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger", "disgust"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["anger"],\n    ["d fear", "disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness"],\n    ["disgust"],\n    ["fear"]\n  ]\n}',
#  '```json\n{"page_utterance_emotions": [["joy"], ["neutral"], ["neutral"], ["respect"]]}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["sadness", "disappointment"], ["joy"], ["anger"], ["sadness", "disappointment"], ["surprise", "confusion"], ["anger"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["neutral"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["surprise"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["disgust"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["anger"], ["anger", "fear"], ["disgust", "fear"], ["anger", "disgust"], ["neutral"], ["anger", "fear"], ["surprise", "anger"], ["neutral"], ["fear"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["joy"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["sadness"], ["sadness"], ["disgust", "sadness"], ["sadness"], ["anger"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["disbelief", "fear"], ["anger"], ["joy"], ["disgust"], ["fear"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["confidence"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"], ["disgust"], ["anger", "disdain"], ["joy"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["surprise"], ["surprise", "anger"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness", "disgust"],\n    ["fear"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["sadness", "fear"],\n    ["sadness"],\n    ["anger"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["sadness"],\n    ["neutral"],\n    ["anger", "disgust"],\n    ["disgust"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["sadness", "fear"],\n    ["disgust"],\n    ["fear"],\n    ["disgust"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness"],\n    ["sadness", "disgust"],\n    ["anger"],\n    ["sadness", "disgust"],\n    ["neutral"],\n    ["anger", "sadness"],\n    ["sadness", "disgust"],\n    ["fear", "sadness"],\n    ["anger", "fear", "sadness"],\n    ["disgust"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["disgust"],\n    ["anger", "fear"],\n    ["sadness", "disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["sadness", "joy"],\n    ["neutral"],\n    ["sadness"],\n    ["sadness", "joy"],\n    ["joy"],\n    ["joy"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["disgust"],\n    ["fear"],\n    ["joy"],\n    ["surprise"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["disgust"],\n    ["sadness", "fear"],\n    ["disgust"],\n    ["anger"],\n    ["surprise"],\n    ["joy"],\n    ["fear"],\n    ["surprise"],\n    ["fear"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["fear", "anger"],\n    ["sadness"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["disgust"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["disgust", "anger"], ["fear"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy", "respect"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["neutral"],\n    ["disgust"],\n    ["disgust"],\n    ["sadness"],\n    ["neutral"],\n    ["anger"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["disgust", "fear"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["disgust"], ["sadness"], ["sadness"], ["disgust"], ["neutral"], ["neutral"], ["sadness"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["sadness", "disgust"],\n    ["sadness"],\n    ["joy"],\n    ["joy"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["disgust"],\n    ["fear"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["joy", "hope"],\n    ["joy", "hope"],\n    ["disgust"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["surprise"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["fear"],\n    ["sadness", "hope"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "fear"],\n    ["sadness"],\n    ["joy"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["joy"], ["sadness"], ["joy"], ["sadness"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["joy"], ["disgust"], ["disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "fear"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["sadness"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["anger"],\n    ["sadness", "disgust"],\n    ["sadness", "disgust"],\n    ["anger"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["disgust"],\n    ["sadness"],\n    ["neutral"],\n    ["anger"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["anger"],\n    ["sadness", "disgust"],\n    ["anger"],\n    ["fear"],\n    ["fear"],\n    ["sadness"],\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"],\n    ["disgust"],\n    ["fear"],\n    ["disgust"],\n    ["fear"],\n    ["sadness"],\n    ["anger"],\n    ["anger"],\n    ["sadness"],\n    ["sadness"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["sadness"],\n    ["disgust"],\n    ["sadness"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["joy"],\n    ["sadness"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["surprise", "sadness"],\n    ["neutral", "fear"],\n    ["anger"],\n    ["joy"],\n    ["disgust"],\n    ["sadness", "anger"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["sadness"],\n    ["anger"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["concern", "sadness"], ["neutral"], ["neutral"], ["neutral"], ["amazement"]]}',
#  '{"page_utterance_emotions": [["sadness"], ["sadness"], ["surprise"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["sadness"], ["sadness"], ["sadness"], ["sadness"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["sadness", "anger"],\n    ["surprise"],\n    ["fear"],\n    ["neutral"],\n    ["anger"],\n    ["sadness", "fear"],\n    ["disgust"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["neutral"], ["neutral"], ["neutral"], ["sadness", "fear"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["sadness"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["joy", "admiration"],\n    ["sadness", "fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"], ["pain", "surprise"], ["surprise"], ["joy"], ["fear", "sadness"], ["disgust"], ["joy"], ["sadness"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["surprise", "fear"], ["sadness"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["nostalgia"],\n    ["nostalgia"],\n    ["curiosity"],\n    ["observation", "neutral"],\n    ["invitation"],\n    ["excitement"],\n    ["excitement"],\n    ["surprise"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"]]}',
#  '{"page_utterance_emotions": [["joy"], ["neutral", "disgust"], ["joy"], ["joy"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["warning"],\n    ["neutral"],\n    ["affection", "sadness"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["joy"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["anger"], ["sadness", "disgust"], ["surprise"], ["neutral"], ["surprise"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["neutral"], ["anger"], ["sadness"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["surprise"], ["curiosity"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["anger"], ["disgust"], ["joy"], ["fear"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["anger"],\n    ["fear", "sadness"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["anger", "disgust"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["anger", "fear"],\n    ["anger"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["fear", "anger"],\n    ["neutral"],\n    ["disgust"],\n    ["disgust"],\n    ["disgust"],\n    ["disgust"],\n    ["disgust"],\n    ["anger"],\n    ["fear", "anger"],\n    ["anger"],\n    ["anger"],\n    ["disgust"],\n    ["neutral"],\n    ["joy"],\n    ["anger"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["joy"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["joy"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["disgust"],\n    ["disgust"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["anxiety"], ["anger"], ["neutral"], ["joy"], ["anxiety", "anger"], ["neutral"], ["disgust"], ["disgust"], ["anger"], ["anger"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["joy"], ["neutral"], ["sadness", "disgust"], ["neutral"], ["sadness"], ["neutral"], ["anger"], ["anger"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger", "disgust"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["joy"], ["joy"], ["anger", "disgust"], ["anger", "disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["anger"],\n    ["sadness"],\n    ["anger"],\n    ["surprise"],\n    ["neutral"],\n    ["disgust"],\n    ["curiosity"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["joy", "confidence"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["disgust"],\n    ["surprise"],\n    ["joy"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["sadness", "fear"],\n    ["sadness", "fears"],\n    ["sadness", "fears"],\n    ["sadness',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["fear"],\n    ["sadness"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["disgust"],\n    ["anger"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["disgust"],\n    ["neutral"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["surprise"],\n    ["joy"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["anger"],\n    ["joy"],\n    ["anger"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["joy", "surprise"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["joy"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["joy"], ["joy"], ["surprise"], ["anger"]]}',
#  '{"page_utterance_emotions": [["anger", "fear"], ["fear"], ["anger", "fear"], ["fear"], ["sadness", "fear"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["fear"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["fear"], ["neutral"], ["anger"], ["anger"], ["anger"], ["fear"], ["disgust"], ["surprise"], ["fear"], ["disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["concern"], ["fear", "anger"], ["reassurance", "relief"], ["reassurance", "calm"], ["fear"], ["check-up"], ["surprise"], ["resolution"], ["tragedy"], ["sadness"]]}',
#  '```json\n{"page_utterance_emotions": [["neutral"], ["neutral"], ["disgust"], ["joy", "neutral"], ["neutral"], ["anger"], ["neutral"], ["helpfulness"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["fear"]]}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["anger", "disgust"],\n    ["fear"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["neutral"],\n    ["calm"],\n    ["sadness"],\n    ["anger", "fear"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["surprise", "disgust"], ["joy"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["sadness"], ["neutral"], ["joy"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["surprise"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["joy"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["surprise", "disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["surprise", "joy"],\n    ["anger"],\n    ["neutral", "disgust"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"], ["joy"], ["neutral"], ["neutral"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["joy"], ["surprise"], ["surprise"], ["anger"]]}',
#  '{"page_utterance_emotions": [["joy"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["disappointment"], ["joy"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["joy"], ["joy"], ["surprise"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["surprise"],\n    ["surprise"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["joy", "surprise"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["joy"],\n    ["disgust", "joy"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["surprise"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["surprise"],\n    ["neutral"],\n    ["disgust"],\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["sadness"], ["neutral"], ["joy"], ["joy"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["sadness"],\n    ["joy"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["surprise"], ["neutral", "curiosity"], ["joy"]]}',
#  '{"page_utterance_emotions": [["joy"], ["neutral"], ["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["disgust", "sadness"], ["anger", "sadness"], ["neutral", "sadness"], ["fear"], ["disgust", "sadness"], ["neutral"], ["fear"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["anger"], ["disgust"], ["disgust"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["disgust"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["neutral"], ["disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger"], ["fear"], ["disgust"], ["disgust"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["surprise"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["anger"], ["anger"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["sadness"], ["disgust", "anger"], ["disgust", "anger"], ["disgust", "anger"], ["disgust", "anger"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["fear"], ["disgust"], ["anger"], ["anger"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["disgust"], ["anger"], ["neutral"], ["neutral"], ["joy"], ["anger"], ["joy"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["sadness"], ["neutral"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["disgust"], ["neutral"], ["neutral"], ["neutral"], ["anger"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["disgust"],\n    ["sadness", "disgust"],\n    ["sadness"],\n    ["neutral"],\n    ["joy"],\n    ["fear"],\n    ["neutral"],\n    ["anger", "fear"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["sadness"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["fear"],\n    ["fear"],\n    ["anger"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["disgust"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["fear"], ["sadness", "disgust"], ["sadness", "discomfort"], ["sadness", "disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["neutral"], ["joy"], ["anger"], ["anger"], ["disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["sadness"], ["disgust"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["disgust"],\n    ["sadness", "nostalgia"],\n    ["sadness", "anger"],\n    ["joy", "nostalgia"],\n    ["disgust"],\n    ["anger"],\n    ["anger"],\n    ["sadness"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"],\n    ["disgust"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral", "fear"], ["neutral"], ["anger", "disgust"], ["sadness"], ["neutral"], ["anger"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["joy"], ["surprise"], ["neutral"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["sadness"], ["neutral"], ["neutral"], ["anger"], ["neutral"], ["anger"], ["sadness"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["fear", "sadness"],\n    ["anger"],\n    ["fear"],\n    ["sadness"],\n    ["sadness"],\n    ["neutral"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["concern"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["disgust", "fear"],\n    ["fear"],\n    ["anger", "disgust"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger"], ["neutral"], ["fear"]]}',
#  '{"page_utterance_emotions": [["anger", "disgust"], ["fear"], ["threat", "sadness"], ["anger", "threat"], ["anger", "sadness"], ["anger"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["surprise", "fear"],\n    ["calm", "neutral"],\n    ["uncertainty", "anxiety"],\n    ["protection", "care"],\n    ["confusion", "anxiety"],\n    ["curiosity", "neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["joy"], ["joy"], ["disgust", "anger"], ["neutral"], ["fear"], ["surprise"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["fear", "anger"],\n    ["disgust"],\n    ["anger", "fear"],\n    ["disgust", "anger"],\n    ["fear", "sadness"],\n    ["anger", "disgust"],\n    ["mockingery"],\n    ["mockingery"],\n    ["sadness"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["anger"], ["neutral"], ["disgust", "anger"], ["anger"], ["neutral"], ["neutral"], ["sadness"], ["fear"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "anger"],\n    ["sadness"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["anger"],\n    ["surprise", "anger"],\n    ["neutral"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"],\n    ["surprise"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["surprise"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["anger", "disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["disgust"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [["anger"], ["disgust"]]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["disgust"], ["sadness", "disgust"], ["surprise", "anger"], ["anger"], ["fear"], ["fear"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger", "disgust"],\n    ["fear"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["anger", "fear"],\n    ["sadness"],\n    ["neutral"],\n    ["anger", "fear"],\n    ["anger", "fear"],\n    ["joy"],\n    ["disgust"],\n    ["neutral"],\n    ["trust"],\n    ["sadness"],\n    ["neutral"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["joy"],\n    ["anger", "disgust"],\n    ["surprise"],\n    ["surprise"],\n    ["anger", "disgust"],\n    ["sadness"],\n    ["sadness"],\n    ["fear", "anger"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["disgust", "anger"],\n    ["joy"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["fear"], ["anxiety"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["joy"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["neutral"],\n    ["anger", "disgust"],\n    ["sadness"],\n    ["neutral", "joy"],\n    ["neutral", "fear"],\n    ["fear"],\n    ["neutral"],\n    ["anger", "fear"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["joy"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["disgust", "fear"], ["disgust", "fear"], ["curiosity"], ["disgust"], ["fear"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["sadness"], ["joy"], ["joy"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger", "disgust"], ["disgust"], ["joy"], ["anger", "disgust"], ["joy"], ["anger", "disgust"], ["joy"], ["anger", "disgust"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["anger", "disgust"], ["anger"], ["joy"], ["neutral"], ["fear"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"]]}',
#  '{"page_utterance_emotions": [["fear"], ["joy"], ["disgust"], ["anger"], ["sadness"], ["sadness"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["fear"], ["disgust", "anger"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["joy"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger", "disgust"], ["anger", "fear"], ["disgust", "anger"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["sadness"], ["fear"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["fear", "comfort"], ["fear", "comfort"], ["joy", "peace"]]}',
#  '{"page_utterance_emotions": [["joy"], ["neutral"], ["anger"], ["joy"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["fear", "disgust"], ["anger"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger", "disgust"],\n    ["sadness", "fear"],\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["fear", "sadness"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["disgust", "anger"],\n    ["joy"],\n    ["disgust", "anger"],\n    ["fear", "sadness"],\n    ["disgust", "anger"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["disgust", "sadness"], ["disgust", "sadness"], ["joy"], ["surprise"], ["fear", "sadness"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["fear"], ["fear"], ["fear"], ["anger"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["surprise", "terror"], ["surprise", "fear"]]}',
#  '{"page_utterance_emotions": [["fear"], ["anger", "disgust"], ["disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["surprise", "fear"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"],\n    ["fear", "disgust"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["sadness"], ["anger"], ["surprise", "disgust"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["fear"], ["sadness"], ["neutral"], ["anger"], ["neutral"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["anger"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["fear"], ["anger", "disgust"], ["neutral"], ["fear", "sadness"], ["surprise", "fear"], ["anger", "disgust"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["confidence"],\n    ["neutral"],\n    ["anger"],\n    ["discomfort"],\n    ["disgust"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["fear"], ["disgust", "anger"], ["disgust"], ["anger"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["sadness"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"],\n    ["anger"],\n    ["fear"],\n    ["sadness"]\n  ]\n}',
#  '{"page_utterance_emotions": [["neutral"], ["sadness"], ["disgust"], ["neutral"], ["joy"], ["surprise"], ["fear"]]}',
#  '{"page_utterance_emotions": [[], [], ["disgust"], ["joy"], ["disgust", "joy"], ["disgust", "joy"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["fear"], ["anger"], ["fear"], ["disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear"],\n    ["disgust"],\n    ["fear"],\n    ["disgust"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["disgust", "anger"], ["neutral"], ["fear"], ["sadness"], ["neutral"], ["surprise"], ["fear"], ["sadness"], ["anger"], ["neutral"], ["neutral"], ["fear"], ["sadness"], ["surprise"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["fear"], ["sadness", "fear"], ["anger", "disgust"], ["disgust"], ["neutral"], ["neutral"], ["fear"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["surprise", "fear"], ["surprise", "fear"], ["neutral"], ["sadness"], ["neutral"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["fear"], ["fear", "disgust"], ["anger"], ["disgust"], ["fear"], ["fear", "surprise"], ["surprise"], ["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["disgust"], ["fear"]]}',
#  '{"page_utterance_emotions": [["fear", "anger"], ["fear"], ["fear", "uncertainty"], ["fear"], ["fear"], ["sadness"], ["fear", "disgust"], ["fear", "panic"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["fear"]]}',
#  '{"page_utterance_emotions": [["anger"], ["disgust", "fear"], ["anger"]]}',
#  '{"page_utterance_emotions": [[["neutral"]], [[ "fear", "sadness" ]], [[ "disgust", "fear" ]], [[ "neutral" ]], [[ "disgust", "fear" ]], [[ "disgust", "fear" ]], [[ "neutral" ]], [[ "sadness" ]], [[ "sadness"]], [[ "neutral"]]]}',
#  '{"page_utterance_emotions": [["neutral"], ["sadness"], ["neutral"], ["sadness"], ["fear"], ["neutral"], ["fear"], ["anger"], ["fear"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["fear"], ["disgust", "fear"], ["neutral"], ["disgust", "fear"], ["sadness", "fear"], ["fear"], ["anger", "fear"], ["joy", "fear"], ["neutral"], ["neutral"], ["sadness", "fear"], ["anger", "fear"]]}',
#  '{"page_utterance_emotions": [["fear"], ["disgust", "anger"], ["disgust"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger"], ["disgust"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["fear"], ["anger"], ["anger"], ["neutral"], ["sadness"], ["disgust"], ["fear"], ["fear"], ["neutral"], ["anger"], ["fear"], ["disgust"]]}',
#  '{"page_utterance_emotions": [["fear"], ["anger"], ["sadness", "disgust"], ["neutral"], ["excitement"], ["anger"], ["plea", "sadness"], ["sadness"], ["anger"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger", "disgust"], ["neutral"], ["anger"], ["disgust"], ["anger"], ["surprise"], ["neutral"], ["fear"], ["neutral"], ["neutral"], ["surprise"], ["neutral"], ["surprise"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["sadness"], ["surprise", "fear"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["sadness", "guilt"], ["neutral"], ["sadness"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["fear", "disgust"],\n    ["neutral"],\n    ["anger", "fear"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["disgust"], ["fear", "anger"], ["fear", "anger"], ["sadness"], ["fear", "anger"], ["anger"], ["sadness"], ["sadness"], ["neutral"], ["fear", "anger"], ["fear", "anger"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["joy"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"], ["neutral"], ["joy"], ["sadness"], ["joy"], ["neutral"], ["prayer"], ["sadness"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["joy"]\n  ]\n}',
#  '{"page_utterance_emotions": [["angry"], ["angry"], ["angry"], ["angry"], ["angry"], ["angry"], ["fear", "sadness"], ["angry"], ["angry"], ["angry"], ["anger"], ["fear"], ["fear"], ["sadness"], ["sadness"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear", "sadness"], ["surprise"], ["disgust"], ["disgust"], ["disgust"], ["disgust"], ["disgust"], ["disgust"], ["anger", "disgust"], ["anger", "disgust"], ["anger", "disgust"], ["fear"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["sadness", "fear"],\n    ["anger", "disgust"],\n    ["disgust"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["joy"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear", "disgust"],\n    ["neutral"],\n    ["fear"],\n    ["fear"],\n    ["surprise", "confusion"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["fear", "disgust"],\n    ["fear"],\n    ["fear", "disgust"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["fear"],\n    ["embarrassment", "shyness"],\n    ["sadness", "fear"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["neutral"],\n    ["fear", "sadness"],\n    ["joy"],\n    ["neutral"],\n    ["sadness"],\n    ["disgust", "sadness"],\n    ["joy"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["disgust"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["sadness"], ["hope"], ["confidence", "hope"], ["confidence", "determination"], ["fear"]]}',
#  '{"page_utterance_emotions": [["sadness"]]}',
#  '{"page_utterance_emotions": [["fear"], ["sadness"], ["sadness", "disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["fear"], ["neutral"], ["neutral"], ["disgust"], ["fear", "sadness"], ["anger"], ["joy"]]}',
#  '{"page_utterance_emotions": [["fear"], ["anger", "disgust"], ["confidence"], ["fear"], ["determination"], ["challenge"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "fear"],\n    ["anger", "fear"],\n    ["sadness", "fear"],\n    ["guilt", "sadness"],\n    ["fear", "sadness"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["guilt"], ["sadness"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["disgust"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["joy"], ["joy"], ["joy"], ["neutral"], ["joy"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["joy"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["fear"], ["disgust"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["disgust"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["joy"], ["surprise"], ["joy"], ["anger", "pain"], ["neutral"], ["neutral"], ["fear"], ["fear"], ["fear"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["surprise"],\n    ["neutral"],\n    ["anger"],\n    ["disgust"],\n    ["fear"],\n    ["surprise"],\n    ["neutral"],\n    ["anger"]\n  ]\n}',
# ...
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["sadness"],\n    ["fear"],\n    ["fear"],\n    ["sadness"],\n    ["anger", "sadness"],\n    ["curiosity"],\n    ["disappointment"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["neutral"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["sadness"],\n    ["neutral"],\n    ["anger"],\n    ["anger"],\n    ["disgust"],\n    ["..."],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness"],\n    ["comfort", "support"],\n    ["comfort", "support"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness"],\n    ["sadness", "motivation"],\n    ["sadness", "motivation"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["fear"],\n    ["neutral"],\n    ["fear", "disgust"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["surprise"],\n    ["surprise"],\n    ["anger", "disgust"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["joy"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["sadness", "disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["disgust", "fear"], ["anger", "fear"], ["fear"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["neutral", "sadness"], ["disgust"], ["fear"], ["neutral"], ["neutral"], ["neutral"], ["sadness"], ["sadness"], ["fear"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["joy"],\n    ["disgust"],\n    ["fear"],\n    ["sadness"],\n    ["anger"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["joy"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["disgust", "fear"], ["neutral"], ["surprise"]]}',
#  '{"page_utterance_emotions": [["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["fear"], ["neutral"], ["sadness", "anger"], ["sadness", "joy"], ["neutral", "joy"], ["fear", "sadness"], ["fear"]]}',
#  '{"page_utterance_emotions": [["sadness"], ["sadness"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness", "disgust"],\n    ["sadness", "guilt"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["anger", "disappointment"],\n    ["anger"],\n    ["surprise"],\n    ["gratitude"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["neutral"],\n    ["sadness", "guilt"],\n    ["sympathy"],\n    ["sadness"],\n    ["respect"],\n    ["respect"],\n    ["disgust"],\n    [" amusement"],\n    ["disgust"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["surprise"], ["surprise"]]}',
#  '{"page_utterance_emotions": [["surprise"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger", "disgust"],\n    ["fear", "disgust"],\n    ["sadness"],\n    ["sadness"],\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["anger", "fear"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["sadness"],\n    ["sadness", "guilt"],\n    ["fear", "disbelief"],\n    ["neutral"],\n    ["neutral"],\n    ["surprise"],\n    ["fear"],\n    ["disgust"],\n    ["anger"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["joy"],\n    ["fear"],\n    ["anger", "disgust"],\n    ["disgust"],\n    ["joy"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger"], ["sadness"], ["neutral"], ["disgust"], ["neutral"], ["neutral"], ["neutral"], ["fear"], ["neutral"], ["disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["anger"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["sadness"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["surprise"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["disgust", "anger"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["fear"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["joy"],\n    ["fear", "anger"],\n    ["fear"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger", "disgust"], ["fear"], ["joy"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["fear"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["surprise"], ["surprise"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger", "fear"],\n    ["alert"],\n    ["disgust", "fear"],\n    ["surprise"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"]]}',
#  '{"page_utterance_emotions": [["surprise"], ["fear"], ["disgust"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["anger", "fear"],\n    ["sadness", "fear"],\n    ["anger"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"],\n    ["joy"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["surprise"], ["neutral"], ["surprise"], ["surprise", "joy"], ["surprise", "joy"], ["neutral"], ["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "fear"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["neutral"],\n    ["surprise"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["sadness"],\n    ["fear"],\n    ["fear"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["surprise", "disgust"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["sadness"],\n    ["sadness"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["sadness", "fear"],\n    ["neutral"],\n    ["anger"],\n    ["joy"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["surprise"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral", "hope"],\n    ["disgust", "anger"],\n    ["sadness"],\n    ["sadness"],\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["anger"],\n    ["sadness"],\n    ["fear"],\n    ["fear"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"], ["fear"], ["neutral"], ["anger"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["sadness"],\n    ["disgust"],\n    ["sadness", "anger"],\n    ["neutral", "sadness"],\n    ["sadness"],\n    ["fear"],\n    ["anger"],\n    ["anger"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["fear"],\n    ["fear"],\n    ["disgust"],\n    ["joy"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["sadness"], ["neutral"], ["disgust", "fear"], ["trust"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger", "disgust"], ["neutral"], ["anger"], ["neutral"], ["neutral"], ["disappointment"], ["sadness"], ["sadness"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["fear"],\n    ["surprise", "anger"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["fear"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["anger"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["joy"],\n    ["fear"],\n    ["surprise"],\n    ["thankfulness"],\n    ["flirtatious"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["joy"], ["surprise", "joy"], ["disgust"], ["joy"], ["sadness"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["neutral", "sadness"], ["anger"], ["sadness"], ["sadness"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["surprise"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["fear"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["neutral"], ["neutral"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["sadness"],\n    ["disgust"],\n    ["fear"],\n    ["anger"],\n    ["anger"],\n    ["disgust"],\n    ["anger"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "fear"],\n    ["anger", "disgust"],\n    ["anger", "disgust"],\n    ["disgust"],\n    ["anger", "disgust"],\n    ["fear", "anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '{"page_utterance_emotions": [["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["anger"],\n    ["suspicion", "disgust"],\n    ["surprise", "joy"],\n    ["disgust"],\n    ["neutral"],\n    ["surprise"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"], ["anger"], ["sadness"], ["fear"], ["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["joy"], ["sadness"], ["disgust", "anger"], ["disgust", "sadness"], ["surprise"], ["neutral"]]}',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["disgust", "anger"],\n    ["fear"],\n    ["fear"],\n    ["fear"],\n    ["disgust"],\n    ["disgust"]\n  ]\n}',
#  '{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral", "hope"],\n    ["disgust"],\n    ["fear"],\n    ["fear"],\n    ["sadness"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["anger", "disgust"], ["sadness"], ["surprise"], ["disgust"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["anger"], ["neutral"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["anger"], ["joy"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["fear"], ["disgust"], ["surprise", "sadness"], ["anger"], ["fear"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger", "fear"], ["neutral"], ["joy", "surprise"], ["neutral"], ["anger"], ["sadness"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["joy"], ["neutral"], ["sadness", "hope"], ["neutral"], ["anger"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear", "anger"], ["anger"], ["disgust"], ["neutral", "sadness"], ["surprise"]]}',
#  '{"page_utterance_emotions": [["anger"], ["fear", "sadness"], ["neutral"], ["anger", "disgust"], ["fear", "sadness"], ["neutral"]]}',
#  '{"page_utterance_emotions": [["neutral"], ["anger"], ["anger"], ["anger"], ["anger"]]}',
#  '{"page_utterance_emotions": [["fear"], ["sadness", "anger"], ["neutral"], ["surprise"], ["neutral"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [["anger"], ["anger", "disgust"], ["anger"], ["anger"]]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["fear"],\n    ["surprise", "anger"],\n    ["neutral"],\n    ["fear", "confusion"],\n    ["neutral"],\n    ["disgust"],\n    ["anger"],\n    ["joy", "admiration"],\n    ["religion"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["joy"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["anger"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["anger"],\n    ["disgust", "anger"],\n    ["sadness"],\n    ["neutral"],\n    ["sadness"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["disgust"],\n    ["fear", "anger"],\n    ["anger"],\n    ["joy"],\n    ["sadness"],\n    ["joy"],\n    ["anger"],\n    ["sadness"],\n    ["anger"],\n    ["anger"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["fear"]\n  ]\n}\n```',
#  '{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["anger"],\n    ["anger", "disgust"],\n    ["fear"],\n    ["joy"],\n    ["sadness"],\n    ["surprise"],\n    ["joy"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"]\n  ]\n}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["joy"],\n    ["fear"],\n    ["fear"],\n    ["fear", "sadness"],\n    ["neutral"],\n    ["anger", "disgust"],\n    ["neutral"],\n    ["neutral"],\n    ["surprise"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["anger"],\n    ["neutral"],\n    ["disgust"],\n    ["surprise", "disgust"],\n    ["surprise"],\n    ["surprise"],\n    ["fear"],\n    ["sadness"],\n    ["anger"],\n    ["sadness"],\n    ["sadness"],\n    ["neutral"],\n    ["joy"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["anger"], ["sadness", "anger"], ["disgust", "sadness"], ["anger"], ["anger", "disgust"], ["sadness", "anger"], ["anger"]]}',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"],\n    ["disgust"],\n    ["disgust", "anger"],\n    ["neutral"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '```json\n{\n  "page_utterance_emotions": [\n    ["neutral"],\n    ["neutral"],\n    ["sadness"],\n    ["neutral"],\n    ["sadness", "anger"],\n    ["anger"],\n    ["surprise"],\n    ["disgust"],\n    ["neutral"],\n    ["joy"],\n    ["neutral"],\n    ["neutral"]\n  ]\n}\n```',
#  '{"page_utterance_emotions": [["neutral"]]}']

# %%
grounds = page_df.emotion_c.tolist()

# %%
len(grounds)
# Out:
# 874

# %%
predictions = [json_repair.loads(e) for e in raw_outputs]

# %%
len(predictions)
# Out:
# 874

# %%
predictions
# Out:
# [{'page_utterance_emotions': [['disgust', 'anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['sadness'],
#    ['anger'],
#    ['surprise'],
#    ['surprise'],
#    ['fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger', 'fear'],
#    ['anger', 'fear'],
#    ['disgust', 'fear'],
#    ['disgust', 'fear'],
#    ['surprise'],
#    ['neutral'],
#    ['anger', 'fear'],
#    ['anger', 'fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear', 'anger'],
#    ['disgust', 'anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'fear'],
#    ['disgust'],
#    ['disgust'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['threat'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['tension', 'disgust'],
#    ['insight', 'surprise'],
#    ['surprise'],
#    ['confidence']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['anger', 'fear'],
#    ['fear'],
#    ['fear', 'disgust'],
#    ['fear', 'disgust'],
#    ['anger'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['fear'],
#    ['fear'],
#    ['joy', 'hope'],
#    ['sadness', 'anger'],
#    ['surprise'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['sadness'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['joy', 'hope'],
#    ['disgust', 'anger'],
#    ['anger', 'fear'],
#    ['fear', 'sadness'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear', 'disgust'],
#    ['sadness', 'disgust'],
#    ['nostalgia', 'sadness'],
#    ['fear', 'sadness'],
#    ['joy', 'hope'],
#    ['anxiety', 'sadness'],
#    ['fear', 'sadness']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['anger', 'disgust'],
#    ['sadness', 'fear'],
#    ['anger', 'disgust'],
#    ['sadness', 'fear'],
#    ['fear', 'disgust'],
#    ['neutral'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['sadness', 'fear'],
#    ['joy'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'fear'],
#    ['joy'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['joy', 'surprise'],
#    ['joy'],
#    ['fear', 'anger'],
#    ['fear'],
#    ['disgust'],
#    ['disgust'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['relief']]},
#  {'page_utterance_emotions': [['neutral'], ['anger', 'fear'], ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['disgust', 'sadness'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['surprise']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['fear', 'disgust'],
#    ['fear'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust', 'fear'],
#    ['surprise'],
#    ['neutral'],
#    ['sadness'],
#    ['anger', 'disgust'],
#    ['anger', 'sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['disappointment'],
#    ['neutral'],
#    ['neutral'],
#    ['anger', 'disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['joy'],
#    ['disgust'],
#    ['fear'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'anger'],
#    ['fear', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['fear', 'sadness'],
#    ['anger'],
#    ['fear', 'anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['anger'],
#    ['d fear', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['sadness'],
#    ['disgust'],
#    ['fear']]},
#  {'page_utterance_emotions': [['joy'], ['neutral'], ['neutral'], ['respect']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness', 'disappointment'],
#    ['joy'],
#    ['anger'],
#    ['sadness', 'disappointment'],
#    ['surprise', 'confusion'],
#    ['anger'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'], ['joy'], ['neutral'], ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['anger'], ['disgust'], ['disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'fear'],
#    ['disgust', 'fear'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger', 'fear'],
#    ['surprise', 'anger'],
#    ['neutral'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'], ['joy'], ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['disgust', 'sadness'],
#    ['sadness'],
#    ['anger'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disbelief', 'fear'],
#    ['anger'],
#    ['joy'],
#    ['disgust'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['confidence'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['anger', 'disdain'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise'], ['surprise', 'anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness', 'disgust'],
#    ['fear'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['sadness', 'fear'],
#    ['sadness'],
#    ['anger'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['joy'],
#    ['sadness'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['sadness', 'fear'],
#    ['disgust'],
#    ['fear'],
#    ['disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['sadness', 'disgust'],
#    ['anger'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['anger', 'sadness'],
#    ['sadness', 'disgust'],
#    ['fear', 'sadness'],
#    ['anger', 'fear', 'sadness'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['disgust'],
#    ['anger', 'fear'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness', 'joy'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness', 'joy'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust'],
#    ['fear'],
#    ['joy'],
#    ['surprise'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral'], ['joy'], ['anger']]},
#  {'page_utterance_emotions': [['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['sadness', 'fear'],
#    ['disgust'],
#    ['anger'],
#    ['surprise'],
#    ['joy'],
#    ['fear'],
#    ['surprise'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['fear', 'anger'],
#    ['sadness'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust', 'anger'],
#    ['fear'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'], ['joy', 'respect'], ['neutral']]},
#  {'page_utterance_emotions': [['joy'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['disgust', 'fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust'],
#    ['sadness'],
#    ['sadness'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['sadness', 'disgust'],
#    ['sadness'],
#    ['joy'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['disgust'],
#    ['fear'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['joy', 'hope'],
#    ['joy', 'hope'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['surprise'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['fear'],
#    ['sadness', 'hope']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'fear'],
#    ['sadness'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['sadness'],
#    ['joy'],
#    ['sadness'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['joy'], ['disgust'], ['disgust']]},
#  {'page_utterance_emotions': [['anger'], ['disgust', 'fear'], ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['sadness'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['sadness', 'disgust'],
#    ['sadness', 'disgust'],
#    ['anger'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['anger'],
#    ['sadness', 'disgust'],
#    ['anger'],
#    ['fear'],
#    ['fear'],
#    ['sadness'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['disgust'],
#    ['fear'],
#    ['disgust'],
#    ['fear'],
#    ['sadness'],
#    ['anger'],
#    ['anger'],
#    ['sadness'],
#    ['sadness'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness'],
#    ['disgust'],
#    ['sadness'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['joy'],
#    ['sadness'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'], ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise', 'sadness'],
#    ['neutral', 'fear'],
#    ['anger'],
#    ['joy'],
#    ['disgust'],
#    ['sadness', 'anger'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['sadness'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['concern', 'sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['amazement']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['sadness'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['joy'],
#    ['sadness', 'anger'],
#    ['surprise'],
#    ['fear'],
#    ['neutral'],
#    ['anger'],
#    ['sadness', 'fear'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['sadness'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['joy', 'admiration'],
#    ['sadness', 'fear']]},
#  {'page_utterance_emotions': [['joy'],
#    ['pain', 'surprise'],
#    ['surprise'],
#    ['joy'],
#    ['fear', 'sadness'],
#    ['disgust'],
#    ['joy'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['surprise', 'fear'], ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['nostalgia'],
#    ['nostalgia'],
#    ['curiosity'],
#    ['observation', 'neutral'],
#    ['invitation'],
#    ['excitement'],
#    ['excitement'],
#    ['surprise'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral', 'disgust'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['warning'],
#    ['neutral'],
#    ['affection', 'sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness', 'disgust'],
#    ['surprise'],
#    ['neutral'],
#    ['surprise'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['anger'],
#    ['sadness'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['surprise'], ['curiosity']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['joy'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['anger'],
#    ['fear', 'sadness'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['anger', 'fear'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['fear', 'anger'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['anger'],
#    ['fear', 'anger'],
#    ['anger'],
#    ['anger'],
#    ['disgust'],
#    ['neutral'],
#    ['joy'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'], ['joy'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['joy'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['sadness'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anxiety'],
#    ['anger'],
#    ['neutral'],
#    ['joy'],
#    ['anxiety', 'anger'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['anger'],
#    ['sadness'],
#    ['anger'],
#    ['surprise'],
#    ['neutral'],
#    ['disgust'],
#    ['curiosity'],
#    ['disgust'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['joy', 'confidence'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['disgust'],
#    ['surprise'],
#    ['joy'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['sadness', 'fear'],
#    ['sadness', 'fears'],
#    ['sadness', 'fears'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['fear'],
#    ['sadness'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust'],
#    ['anger'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['surprise'],
#    ['joy'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['anger'],
#    ['joy'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy', 'surprise'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['surprise'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger', 'fear'],
#    ['fear'],
#    ['anger', 'fear'],
#    ['fear'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['fear'],
#    ['disgust'],
#    ['surprise'],
#    ['fear'],
#    ['disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['concern'],
#    ['fear', 'anger'],
#    ['reassurance', 'relief'],
#    ['reassurance', 'calm'],
#    ['fear'],
#    ['check-up'],
#    ['surprise'],
#    ['resolution'],
#    ['tragedy'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['joy', 'neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['helpfulness'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['fear'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['calm'],
#    ['sadness'],
#    ['anger', 'fear'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['surprise', 'disgust'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise', 'joy'],
#    ['anger'],
#    ['neutral', 'disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['anger'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['surprise'],
#    ['surprise'],
#    ['anger']]},
#  {'page_utterance_emotions': [['joy'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral']]},
#  {'page_utterance_emotions': [['disappointment'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['surprise'],
#    ['surprise'],
#    ['joy']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['anger'],
#    ['joy', 'surprise'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['disgust', 'joy'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['disgust'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['sadness'],
#    ['joy'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['surprise'],
#    ['neutral', 'curiosity'],
#    ['joy']]},
#  {'page_utterance_emotions': [['joy'], ['neutral'], ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'sadness'],
#    ['anger', 'sadness'],
#    ['neutral', 'sadness'],
#    ['fear'],
#    ['disgust', 'sadness'],
#    ['neutral'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['fear'],
#    ['disgust'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['fear'], ['disgust'], ['anger'], ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['anger'],
#    ['joy'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['sadness', 'disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['fear'],
#    ['neutral'],
#    ['anger', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['sadness'],
#    ['disgust'],
#    ['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['fear'],
#    ['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['disgust'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['sadness', 'disgust'],
#    ['sadness', 'discomfort'],
#    ['sadness', 'disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['anger'],
#    ['anger'],
#    ['disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['disgust'],
#    ['sadness', 'nostalgia'],
#    ['sadness', 'anger'],
#    ['joy', 'nostalgia'],
#    ['disgust'],
#    ['anger'],
#    ['anger'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral', 'fear'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['joy'],
#    ['surprise'],
#    ['neutral'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['anger'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['fear', 'sadness'],
#    ['anger'],
#    ['fear'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['concern'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['disgust', 'fear'],
#    ['fear'],
#    ['anger', 'disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'], ['anger'], ['neutral'], ['fear']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['fear'],
#    ['threat', 'sadness'],
#    ['anger', 'threat'],
#    ['anger', 'sadness'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['surprise', 'fear'],
#    ['calm', 'neutral'],
#    ['uncertainty', 'anxiety'],
#    ['protection', 'care'],
#    ['confusion', 'anxiety'],
#    ['curiosity', 'neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['fear'],
#    ['surprise'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear', 'anger'],
#    ['disgust'],
#    ['anger', 'fear'],
#    ['disgust', 'anger'],
#    ['fear', 'sadness'],
#    ['anger', 'disgust'],
#    ['mockingery'],
#    ['mockingery'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['disgust', 'anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'anger'],
#    ['sadness'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['anger'],
#    ['surprise', 'anger'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger']]},
#  {'page_utterance_emotions': [['anger'], ['anger', 'disgust']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['anger'], ['disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['sadness', 'disgust'],
#    ['surprise', 'anger'],
#    ['anger'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['fear'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['anger', 'fear'],
#    ['sadness'],
#    ['neutral'],
#    ['anger', 'fear'],
#    ['anger', 'fear'],
#    ['joy'],
#    ['disgust'],
#    ['neutral'],
#    ['trust'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['surprise'],
#    ['surprise'],
#    ['anger', 'disgust'],
#    ['sadness'],
#    ['sadness'],
#    ['fear', 'anger']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['disgust', 'anger'],
#    ['joy'],
#    ['fear']]},
#  {'page_utterance_emotions': [['fear'], ['anxiety']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['joy'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['sadness'],
#    ['neutral', 'joy'],
#    ['neutral', 'fear'],
#    ['fear'],
#    ['neutral'],
#    ['anger', 'fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust', 'fear'],
#    ['disgust', 'fear'],
#    ['curiosity'],
#    ['disgust'],
#    ['fear'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['sadness'],
#    ['joy'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'disgust'],
#    ['disgust'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['joy'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['joy'],
#    ['neutral'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'], ['joy']]},
#  {'page_utterance_emotions': [['fear'],
#    ['joy'],
#    ['disgust'],
#    ['anger'],
#    ['sadness'],
#    ['sadness'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['fear'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger', 'fear'],
#    ['disgust', 'anger'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear', 'comfort'],
#    ['fear', 'comfort'],
#    ['joy', 'peace']]},
#  {'page_utterance_emotions': [['joy'], ['neutral'], ['anger'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear', 'disgust'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['sadness', 'fear'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['fear', 'sadness']]},
#  {'page_utterance_emotions': [['fear'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['disgust', 'anger'],
#    ['joy'],
#    ['disgust', 'anger'],
#    ['fear', 'sadness'],
#    ['disgust', 'anger'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust', 'sadness'],
#    ['disgust', 'sadness'],
#    ['joy'],
#    ['surprise'],
#    ['fear', 'sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['anger'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['surprise', 'terror'],
#    ['surprise', 'fear']]},
#  {'page_utterance_emotions': [['fear'], ['anger', 'disgust'], ['disgust']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['surprise', 'fear'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['fear', 'disgust'],
#    ['fear']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['anger'],
#    ['surprise', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['fear', 'sadness'],
#    ['surprise', 'fear'],
#    ['anger', 'disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['fear'],
#    ['confidence'],
#    ['neutral'],
#    ['anger'],
#    ['discomfort'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['fear'],
#    ['disgust', 'anger'],
#    ['disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['anger'],
#    ['fear'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['disgust'],
#    ['neutral'],
#    ['joy'],
#    ['surprise'],
#    ['fear']]},
#  {'page_utterance_emotions': [[],
#    [],
#    ['disgust'],
#    ['joy'],
#    ['disgust', 'joy'],
#    ['disgust', 'joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['anger'],
#    ['fear'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['disgust'],
#    ['fear'],
#    ['disgust'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['fear'],
#    ['sadness'],
#    ['neutral'],
#    ['surprise'],
#    ['fear'],
#    ['sadness'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['sadness'],
#    ['surprise'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['sadness', 'fear'],
#    ['anger', 'disgust'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise', 'fear'],
#    ['surprise', 'fear'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear', 'disgust'],
#    ['anger'],
#    ['disgust'],
#    ['fear'],
#    ['fear', 'surprise'],
#    ['surprise'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'], ['fear'], ['disgust'], ['fear']]},
#  {'page_utterance_emotions': [['fear', 'anger'],
#    ['fear'],
#    ['fear', 'uncertainty'],
#    ['fear'],
#    ['fear'],
#    ['sadness'],
#    ['fear', 'disgust'],
#    ['fear', 'panic']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'], ['disgust', 'fear'], ['anger']]},
#  {'page_utterance_emotions': [[['neutral']],
#    [['fear', 'sadness']],
#    [['disgust', 'fear']],
#    [['neutral']],
#    [['disgust', 'fear']],
#    [['disgust', 'fear']],
#    [['neutral']],
#    [['sadness']],
#    [['sadness']],
#    [['neutral']]]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['neutral'],
#    ['fear'],
#    ['anger'],
#    ['fear'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['fear'],
#    ['disgust', 'fear'],
#    ['neutral'],
#    ['disgust', 'fear'],
#    ['sadness', 'fear'],
#    ['fear'],
#    ['anger', 'fear'],
#    ['joy', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['anger', 'fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['disgust', 'anger'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['disgust'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['anger'],
#    ['fear'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['excitement'],
#    ['anger'],
#    ['plea', 'sadness'],
#    ['sadness'],
#    ['anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['anger'],
#    ['surprise'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['surprise', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'guilt'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear', 'disgust'],
#    ['neutral'],
#    ['anger', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['fear', 'anger'],
#    ['fear', 'anger'],
#    ['sadness'],
#    ['fear', 'anger'],
#    ['anger'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['fear', 'anger'],
#    ['fear', 'anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['joy'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['joy'],
#    ['sadness'],
#    ['joy'],
#    ['neutral'],
#    ['prayer'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy']]},
#  {'page_utterance_emotions': [['angry'],
#    ['angry'],
#    ['angry'],
#    ['angry'],
#    ['angry'],
#    ['angry'],
#    ['fear', 'sadness'],
#    ['angry'],
#    ['angry'],
#    ['angry'],
#    ['anger'],
#    ['fear'],
#    ['fear'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear', 'sadness'],
#    ['surprise'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['disgust'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear'],
#    ['fear'],
#    ['sadness', 'fear'],
#    ['anger', 'disgust'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear', 'disgust'],
#    ['neutral'],
#    ['fear'],
#    ['fear'],
#    ['surprise', 'confusion'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear', 'disgust'],
#    ['fear'],
#    ['fear', 'disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['fear'],
#    ['embarrassment', 'shyness'],
#    ['sadness', 'fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['neutral'],
#    ['fear', 'sadness'],
#    ['joy'],
#    ['neutral'],
#    ['sadness'],
#    ['disgust', 'sadness'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['hope'],
#    ['confidence', 'hope'],
#    ['confidence', 'determination'],
#    ['fear']]},
#  {'page_utterance_emotions': [['sadness']]},
#  {'page_utterance_emotions': [['fear'],
#    ['sadness'],
#    ['sadness', 'disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['fear', 'sadness'],
#    ['anger'],
#    ['joy']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger', 'disgust'],
#    ['confidence'],
#    ['fear'],
#    ['determination'],
#    ['challenge']]},
#  {'page_utterance_emotions': [['anger', 'fear'],
#    ['anger', 'fear'],
#    ['sadness', 'fear'],
#    ['guilt', 'sadness'],
#    ['fear', 'sadness']]},
#  {'page_utterance_emotions': [['guilt'], ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['surprise'],
#    ['joy'],
#    ['anger', 'pain'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['surprise'],
#    ['neutral'],
#    ['anger'],
#    ['disgust'],
#    ['fear'],
#    ['surprise'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear', 'anger'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['fear', 'disgust'],
#    ['anger', 'disgust'],
#    ['fear', 'disgust'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear', 'disgust'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['surprise'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['fear', 'disgust'],
#    ['fear'],
#    ['fear', 'disgust'],
#    ['fear'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['fear'], ['fear'], ['disgust'], ['fear']]},
#  {'page_utterance_emotions': [['fear'], ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['surprise'],
#    ['disgust'],
#    ['fear'],
#    ['joy'],
#    ['joy'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['fear'],
#    ['fear'],
#    ['sadness'],
#    ['concern', 'fear'],
#    ['neutral'],
#    ['concern', 'fear'],
#    ['fear'],
#    ['neutral'],
#    ['fear'],
#    ['sadness'],
#    ['comfort'],
#    ['fear'],
#    ['anger', 'disgust'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['surprise'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['nostalgia', 'neutral'],
#    ['nostalgia', 'neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['curiosity', 'neutral'],
#    ['fear', 'disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['anger'],
#    ['fear'],
#    ['sadness'],
#    ['disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['fear'],
#    ['neutral'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise'],
#    ['fear'],
#    ['fear'],
#    ['agreement'],
#    ['disgust'],
#    ['disgust'],
#    ['curiosity'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['surprise', 'fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['fear'],
#    ['curiosity'],
#    ['anger'],
#    ['concern'],
#    ['neutral'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['surprise'],
#    ['joy'],
#    ['joy', 'excitement'],
#    ['fear'],
#    ['disgust'],
#    ['joy', 'playfulness'],
#    ['joy', 'playfulness'],
#    ['neutral'],
#    ['surprise'],
#    ['joy', 'amusement'],
#    ['joy', 'amusement'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['fear', 'disgust'],
#    ['disgust'],
#    ['sadness'],
#    ['neutral'],
#    ['surprise'],
#    ['joy'],
#    ['disgust'],
#    ['fear'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['disgust'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
# ...
#    ['anger', 'disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger'],
#    ['anger'],
#    ['fear', 'disgust'],
#    ['fear', 'disgust'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['surprise'],
#    ['sadness', 'fear'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger'],
#    ['anger'],
#    ['sadness'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness'],
#    ['disgust'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'disgust'],
#    ['joy'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['sadness', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness', 'disappointment'],
#    ['sadness'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness', 'disgust'],
#    ['sadness', 'joy'],
#    ['sadness'],
#    ['anger'],
#    ['neutral'],
#    [],
#    ['sadness'],
#    ['sadness'],
#    ['fear']]},
#  {'page_utterance_emotions': [['joy'],
#    ['sadness'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['surprise', 'fear'],
#    ['fear', 'disgust'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'], ['neutral'], ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['fear', 'uncertainty'],
#    ['excitement', 'anxiety'],
#    ['neutral'],
#    ['concern'],
#    ['anxiety']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['sadness'],
#    ['fear'],
#    ['fear'],
#    ['sadness'],
#    ['anger', 'sadness'],
#    ['curiosity'],
#    ['disappointment'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['anger'],
#    ['anger'],
#    ['disgust'],
#    ['...'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['comfort', 'support'],
#    ['comfort', 'support'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness'],
#    ['sadness', 'motivation'],
#    ['sadness', 'motivation'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['fear'],
#    ['neutral'],
#    ['fear', 'disgust'],
#    ['disgust'],
#    ['anger'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise'],
#    ['surprise'],
#    ['anger', 'disgust'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness', 'disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['disgust', 'fear'],
#    ['anger', 'fear'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['joy'],
#    ['joy'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral', 'sadness'],
#    ['disgust'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['joy'],
#    ['disgust'],
#    ['fear'],
#    ['sadness'],
#    ['anger'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['disgust', 'fear'], ['neutral'], ['surprise']]},
#  {'page_utterance_emotions': [['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['sadness', 'anger'],
#    ['sadness', 'joy'],
#    ['neutral', 'joy'],
#    ['fear', 'sadness'],
#    ['fear']]},
#  {'page_utterance_emotions': [['sadness'], ['sadness']]},
#  {'page_utterance_emotions': [['sadness', 'disgust'],
#    ['sadness', 'guilt'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['anger', 'disappointment'],
#    ['anger'],
#    ['surprise'],
#    ['gratitude']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['neutral'],
#    ['sadness', 'guilt'],
#    ['sympathy'],
#    ['sadness'],
#    ['respect'],
#    ['respect'],
#    ['disgust'],
#    [' amusement'],
#    ['disgust'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise'], ['surprise']]},
#  {'page_utterance_emotions': [['surprise'], ['neutral']]},
#  {'page_utterance_emotions': [['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['fear', 'disgust'],
#    ['sadness'],
#    ['sadness'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['anger', 'fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['sadness'],
#    ['sadness', 'guilt'],
#    ['fear', 'disbelief'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['fear'],
#    ['disgust'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['joy'],
#    ['fear'],
#    ['anger', 'disgust'],
#    ['disgust'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['anger'],
#    ['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['surprise'],
#    ['neutral'],
#    ['joy'],
#    ['joy'],
#    ['neutral'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['fear'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['joy'],
#    ['fear', 'anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger', 'disgust'], ['fear'], ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['surprise'], ['surprise']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'fear'],
#    ['alert'],
#    ['disgust', 'fear'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['anger']]},
#  {'page_utterance_emotions': [['surprise'], ['fear'], ['disgust']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['anger', 'fear'],
#    ['sadness', 'fear'],
#    ['anger']]},
#  {'page_utterance_emotions': [['joy'], ['joy'], ['joy'], ['joy'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['surprise'],
#    ['surprise', 'joy'],
#    ['surprise', 'joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'fear'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['sadness'],
#    ['fear'],
#    ['fear'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['surprise', 'disgust'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness', 'fear'],
#    ['neutral'],
#    ['anger'],
#    ['joy'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['joy'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral', 'hope'],
#    ['disgust', 'anger'],
#    ['sadness'],
#    ['sadness'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['sadness'],
#    ['fear'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'], ['fear'], ['neutral'], ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness'],
#    ['disgust'],
#    ['sadness', 'anger'],
#    ['neutral', 'sadness'],
#    ['sadness'],
#    ['fear'],
#    ['anger'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['fear'],
#    ['fear'],
#    ['disgust'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['disgust', 'fear'],
#    ['trust'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'], ['fear']]},
#  {'page_utterance_emotions': [['joy'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['disappointment'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['fear'],
#    ['surprise', 'anger'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['fear'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['joy'],
#    ['fear'],
#    ['surprise'],
#    ['thankfulness'],
#    ['flirtatious'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['surprise', 'joy'],
#    ['disgust'],
#    ['joy'],
#    ['sadness'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral', 'sadness'],
#    ['anger'],
#    ['sadness'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['fear'],
#    ['neutral'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['sadness'],
#    ['disgust'],
#    ['fear'],
#    ['anger'],
#    ['anger'],
#    ['disgust'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'fear'],
#    ['anger', 'disgust'],
#    ['anger', 'disgust'],
#    ['disgust'],
#    ['anger', 'disgust'],
#    ['fear', 'anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['anger'],
#    ['suspicion', 'disgust'],
#    ['surprise', 'joy'],
#    ['disgust'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['sadness'],
#    ['fear'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['joy'],
#    ['sadness'],
#    ['disgust', 'anger'],
#    ['disgust', 'sadness'],
#    ['surprise'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['disgust', 'anger'],
#    ['fear'],
#    ['fear'],
#    ['fear'],
#    ['disgust'],
#    ['disgust']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral', 'hope'],
#    ['disgust'],
#    ['fear'],
#    ['fear'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['sadness'],
#    ['surprise'],
#    ['disgust'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'], ['neutral'], ['sadness']]},
#  {'page_utterance_emotions': [['anger'], ['joy']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['fear'],
#    ['disgust'],
#    ['surprise', 'sadness'],
#    ['anger'],
#    ['fear']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger', 'fear'],
#    ['neutral'],
#    ['joy', 'surprise'],
#    ['neutral'],
#    ['anger'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['sadness', 'hope'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear', 'anger'],
#    ['anger'],
#    ['disgust'],
#    ['neutral', 'sadness'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['anger'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['fear', 'sadness'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['fear'],
#    ['sadness', 'anger'],
#    ['neutral'],
#    ['surprise'],
#    ['neutral'],
#    ['anger']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger', 'disgust'],
#    ['anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['fear'],
#    ['surprise', 'anger'],
#    ['neutral'],
#    ['fear', 'confusion'],
#    ['neutral'],
#    ['disgust'],
#    ['anger'],
#    ['joy', 'admiration'],
#    ['religion'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['joy'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['anger'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['anger'],
#    ['disgust', 'anger'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness']]},
#  {'page_utterance_emotions': [['anger'],
#    ['disgust'],
#    ['fear', 'anger'],
#    ['anger'],
#    ['joy'],
#    ['sadness'],
#    ['joy'],
#    ['anger'],
#    ['sadness'],
#    ['anger'],
#    ['anger'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['fear']]},
#  {'page_utterance_emotions': [['anger'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['fear'],
#    ['joy'],
#    ['sadness'],
#    ['surprise'],
#    ['joy'],
#    ['neutral'],
#    ['joy'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['joy'],
#    ['fear'],
#    ['fear'],
#    ['fear', 'sadness'],
#    ['neutral'],
#    ['anger', 'disgust'],
#    ['neutral'],
#    ['neutral'],
#    ['surprise']]},
#  {'page_utterance_emotions': [['anger'],
#    ['neutral'],
#    ['disgust'],
#    ['surprise', 'disgust'],
#    ['surprise'],
#    ['surprise'],
#    ['fear'],
#    ['sadness'],
#    ['anger'],
#    ['sadness'],
#    ['sadness'],
#    ['neutral'],
#    ['joy']]},
#  {'page_utterance_emotions': [['anger'],
#    ['sadness', 'anger'],
#    ['disgust', 'sadness'],
#    ['anger'],
#    ['anger', 'disgust'],
#    ['sadness', 'anger'],
#    ['anger']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral'],
#    ['disgust'],
#    ['disgust', 'anger'],
#    ['neutral'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral'],
#    ['neutral'],
#    ['sadness'],
#    ['neutral'],
#    ['sadness', 'anger'],
#    ['anger'],
#    ['surprise'],
#    ['disgust'],
#    ['neutral'],
#    ['joy'],
#    ['neutral'],
#    ['neutral']]},
#  {'page_utterance_emotions': [['neutral']]}]

# %%
preds_l = []
bad_idx = []

for i, pred in enumerate(predictions):
    try:        
        preds_l.append(pred['page_utterance_emotions'])
    except:
        print(i)
        bad_idx.append(i)

# %%
bad_idx.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in bad_idx:
    
    del grounds[idx]
    #del preds_l[idx]

# %%
len(grounds), len(preds_l)
# Out:
# (874, 874)

# %%
bad_idx = []

for idx, (i,j) in enumerate(zip(grounds, preds_l)):
    if len(i) != len(j):
        print(idx, len(i), len(j))
        bad_idx.append(idx)
# Out:
# 23 12 11
# 26 14 12
# 33 11 10
# 42 13 12
# 43 8 7
# 66 8 7
# 73 15 14
# 75 18 16
# 76 16 14
# 77 16 14
# 82 13 12
# 85 9 8
# 88 10 9
# 101 16 13
# 102 21 20
# 104 20 16
# 105 15 14
# 106 16 15
# 107 12 11
# 108 11 10
# 109 14 13
# 113 23 16
# 114 23 21
# 117 13 12
# 118 14 13
# 120 11 10
# 124 13 12
# 125 13 14
# 126 17 15
# 128 12 11
# 131 12 11
# 148 12 11
# 161 18 16
# 166 12 11
# 167 13 12
# 173 14 13
# 183 17 15
# 192 13 12
# 193 11 10
# 198 18 16
# 200 18 16
# 202 12 11
# 205 22 19
# 206 11 10
# 213 9 8
# 216 15 14
# 230 15 14
# 232 17 16
# 233 13 12
# 235 9 8
# 241 11 10
# 245 13 12
# 247 16 15
# 248 15 13
# 249 17 16
# 250 14 13
# 252 9 8
# 253 16 15
# 254 17 16
# 255 14 13
# 270 1 2
# 272 19 16
# 273 19 17
# 274 23 22
# 275 13 12
# 276 15 14
# 278 15 14
# 282 11 10
# 283 25 21
# 288 15 14
# 291 17 16
# 293 11 10
# 299 9 8
# 301 31 24
# 306 13 12
# 307 9 8
# 309 11 10
# 312 16 15
# 316 9 8
# 317 15 14
# 319 12 11
# 320 19 16
# 321 17 14
# 322 11 10
# 325 14 13
# 329 11 10
# 335 1 3
# 341 4 5
# 343 12 11
# 347 11 10
# 351 14 13
# 360 16 15
# 364 12 11
# 366 11 10
# 368 15 13
# 371 7 6
# 375 8 7
# 405 14 13
# 409 8 7
# 411 15 13
# 413 11 10
# 414 15 14
# 416 11 10
# 452 9 8
# 455 9 8
# 465 14 13
# 466 15 13
# 480 17 14
# 494 13 11
# 500 2 1
# 523 12 11
# 525 9 8
# 526 15 14
# 527 13 12
# 529 15 14
# 538 11 10
# 541 9 8
# 551 11 10
# 553 9 8
# 556 9 8
# 557 13 12
# 561 11 10
# 567 15 13
# 584 11 10
# 586 16 15
# 593 11 10
# 594 1 3
# 607 15 14
# 611 14 13
# 621 11 10
# 624 12 11
# 625 11 10
# 643 8 7
# 644 14 13
# 645 15 14
# 647 13 12
# 651 11 10
# 659 8 7
# 660 13 12
# 687 19 18
# 692 8 7
# 696 9 8
# 700 11 10
# 702 11 10
# 705 8 7
# 709 12 11
# 711 13 12
# 712 11 10
# 715 13 14
# 716 14 12
# 717 16 15
# 720 14 13
# 722 11 10
# 724 11 10
# 726 11 10
# 727 14 13
# 734 10 9
# 742 11 10
# 749 14 13
# 759 12 11
# 760 13 12
# 761 17 16
# 762 19 18
# 763 13 11
# 764 11 10
# 773 11 10
# 791 16 15
# 797 11 10
# 825 9 8
# 832 7 6
# 835 11 10
# 836 13 12
# 843 11 10
# 846 11 10
# 851 11 10
# 866 16 15
# 868 11 10
# 869 14 13

# %%
bad_idx.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in bad_idx:
    
    del grounds[idx]
    del preds_l[idx]

# %%
len(grounds), len(preds_l)
# Out:
# (696, 696)

# %%
grounds = [item for sublist in grounds for item in sublist]
predictions = [item for sublist in preds_l for item in sublist]

# %%
len(grounds), len(predictions)
# Out:
# (4820, 4820)

# %%
grounds
# Out:
# [['anger'],
#  ['anger'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['sadness'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['surprise'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['fear'],
#  ['anger', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['anger', 'fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['fear'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['anger', 'disgust', 'surprise'],
#  ['anger', 'disgust'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['anger', 'surprise'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['surprise', 'joy'],
#  ['fear'],
#  ['surprise'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['disgust', 'joy'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['surprise'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['fear'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['fear'],
#  ['surprise', 'joy'],
#  ['fear'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['fear', 'joy'],
#  ['fear', 'joy'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['joy'],
#  ['fear', 'joy'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'joy'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['disgust', 'surprise'],
#  ['disgust', 'joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['surprise', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['disgust', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['disgust', 'fear'],
#  ['joy'],
#  ['anger', 'disgust', 'fear'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['disgust'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'sadness'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['fear', 'sadness'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['anger', 'disgust', 'fear'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['disgust', 'joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['disgust', 'surprise'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['fear'],
#  ['disgust', 'surprise'],
#  ['disgust', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise', 'joy'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['anger', 'joy'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['sadness', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'joy'],
#  ['anger', 'fear', 'joy'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'joy'],
#  ['anger', 'fear', 'sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['anger', 'disgust'],
#  ['sadness', 'joy'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['sadness', 'surprise'],
#  ['anger', 'sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'disgust', 'surprise'],
#  ['anger', 'joy'],
#  ['anger', 'fear', 'surprise'],
#  ['sadness', 'joy'],
#  ['fear', 'sadness'],
#  ['anger', 'surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'sadness', 'surprise'],
#  ...]

# %%
set([type(item) for sublist in grounds for item in sublist])
# Out:
# {str}

# %%
set([type(item) for sublist in predictions for item in sublist])
# Out:
# {list, str}

# %%
list_indices = [
    (outer_idx, inner_idx)
    for outer_idx, sublist in enumerate(predictions)
    if isinstance(sublist, list)
    for inner_idx, item in enumerate(sublist)
    if isinstance(item, list)
]

# %%
len(list_indices)
# Out:
# 10

# %%
predictions[1263]
# Out:
# [['neutral']]

# %%
list_indices = [i[0] for i in list_indices]

# %%
list_indices
# Out:
# [1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263]

# %%
list_indices.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in list_indices:
    
    del grounds[idx]
    del predictions[idx]

# %%
predictions
# Out:
# [['disgust', 'anger'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['disgust', 'fear'],
#  ['disgust', 'fear'],
#  ['surprise'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['fear', 'anger'],
#  ['disgust', 'anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['disgust'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['threat'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['tension', 'disgust'],
#  ['insight', 'surprise'],
#  ['surprise'],
#  ['confidence'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['fear', 'disgust'],
#  ['fear', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['fear'],
#  ['fear'],
#  ['joy', 'hope'],
#  ['sadness', 'anger'],
#  ['surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['sadness', 'disgust'],
#  ['neutral'],
#  ['joy', 'hope'],
#  ['disgust', 'anger'],
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear', 'disgust'],
#  ['sadness', 'disgust'],
#  ['nostalgia', 'sadness'],
#  ['fear', 'sadness'],
#  ['joy', 'hope'],
#  ['anxiety', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['anger', 'disgust'],
#  ['sadness', 'fear'],
#  ['anger', 'disgust'],
#  ['sadness', 'fear'],
#  ['fear', 'disgust'],
#  ['neutral'],
#  ['joy'],
#  ['anger', 'disgust'],
#  ['sadness', 'fear'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['disgust', 'fear'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['joy', 'surprise'],
#  ['joy'],
#  ['fear', 'anger'],
#  ['fear'],
#  ['disgust'],
#  ['disgust'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['relief'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['disgust', 'sadness'],
#  ['disgust'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['fear', 'disgust'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['disgust', 'fear'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['anger', 'disgust'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['disappointment'],
#  ['neutral'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['disgust'],
#  ['joy'],
#  ['disgust'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['fear'],
#  ['disgust'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['respect'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness', 'disappointment'],
#  ['joy'],
#  ['anger'],
#  ['sadness', 'disappointment'],
#  ['surprise', 'confusion'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disbelief', 'fear'],
#  ['anger'],
#  ['joy'],
#  ['disgust'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust', 'anger'],
#  ['neutral'],
#  ['confidence'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['anger', 'disdain'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise', 'anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness', 'disgust'],
#  ['fear'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'fear'],
#  ['disgust'],
#  ['fear'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness', 'disgust'],
#  ['anger'],
#  ['sadness', 'disgust'],
#  ['neutral'],
#  ['anger', 'sadness'],
#  ['sadness', 'disgust'],
#  ['fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['disgust'],
#  ['disgust'],
#  ['anger', 'fear'],
#  ['sadness', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['disgust'],
#  ['fear'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness', 'fear'],
#  ['disgust'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['fear'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear', 'anger'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['disgust', 'anger'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['joy', 'respect'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['disgust', 'fear'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['sadness'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'disgust'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy', 'hope'],
#  ['joy', 'hope'],
#  ['disgust'],
#  ['anger'],
#  ['disgust', 'fear'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['joy'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['disgust', 'fear'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['sadness', 'disgust'],
#  ['sadness', 'disgust'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise', 'sadness'],
#  ['neutral', 'fear'],
#  ['anger'],
#  ['joy'],
#  ['disgust'],
#  ['sadness', 'anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['concern', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['amazement'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness', 'fear'],
#  ['neutral'],
#  ['anger'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['sadness'],
#  ['disgust', 'anger'],
#  ['neutral'],
#  ['sadness', 'fear'],
#  ['sadness', 'fear'],
#  ['joy', 'admiration'],
#  ['sadness', 'fear'],
#  ['neutral'],
#  ['surprise', 'fear'],
#  ['sadness'],
#  ['neutral'],
#  ['nostalgia'],
#  ['nostalgia'],
#  ['curiosity'],
#  ['observation', 'neutral'],
#  ['invitation'],
#  ['excitement'],
#  ['excitement'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['warning'],
#  ['neutral'],
#  ['affection', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['sadness', 'disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['curiosity'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['disgust'],
#  ['curiosity'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['joy', 'confidence'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['disgust'],
#  ['surprise'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['sadness', 'fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['disgust'],
#  ['surprise'],
#  ['fear'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise', 'disgust'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise', 'disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['anger'],
#  ['neutral', 'disgust'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disappointment'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['disgust'],
#  ['sadness'],
#  ['joy'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral', 'curiosity'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['disgust', 'sadness'],
#  ['anger', 'sadness'],
#  ['neutral', 'sadness'],
#  ['fear'],
#  ['disgust', 'sadness'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['disgust'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['sadness'],
#  ['fear'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['sadness', 'disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['sadness', 'disgust'],
#  ['sadness', 'discomfort'],
#  ['sadness', 'disgust'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral', 'fear'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust', 'fear'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['anger', 'disgust'],
#  ['fear'],
#  ['threat', 'sadness'],
#  ['anger', 'threat'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['neutral'],
#  ['surprise', 'fear'],
#  ['calm', 'neutral'],
#  ['uncertainty', 'anxiety'],
#  ['protection', 'care'],
#  ['confusion', 'anxiety'],
#  ['curiosity', 'neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'anger'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'anger'],
#  ['disgust'],
#  ['anger', 'fear'],
#  ['disgust', 'anger'],
#  ['fear', 'sadness'],
#  ['anger', 'disgust'],
#  ['mockingery'],
#  ['mockingery'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['disgust', 'anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['fear'],
#  ['anger'],
#  ['disgust', 'anger'],
#  ['sadness'],
#  ['disgust', 'anger'],
#  ['disgust', 'anger'],
#  ['anger'],
#  ['surprise', 'anger'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['anger'],
#  ...]

# %%
mlb = MultiLabelBinarizer()

# %%
y_true_mhot = mlb.fit_transform(grounds)
y_pred_mhot = mlb.transform(predictions)

# %%
y_true_mhot.shape
# Out:
# (4810, 7)

# %%
print(classification_report(y_true_mhot, y_pred_mhot, target_names=mlb.classes_, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        anger      0.597     0.384     0.468      1605
#      disgust      0.113     0.367     0.172       237
#         fear      0.464     0.289     0.356      1264
#          joy      0.574     0.231     0.329      1075
#      neutral      0.109     0.576     0.183       297
#      sadness      0.529     0.311     0.391      1214
#     surprise      0.658     0.122     0.206      1281
#
#    micro avg      0.364     0.290     0.323      6973
#    macro avg      0.435     0.326     0.301      6973
# weighted avg      0.531     0.290     0.342      6973
#  samples avg      0.350     0.303     0.311      6973
# /Utilisateurs/umushtaq/.conda/envs/triton_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
