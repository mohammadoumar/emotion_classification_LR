# %%
import torch
import json_repair
import pandas as pd

from tqdm import tqdm
from datasets import Dataset

from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel, is_bfloat16_supported

from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %%
max_seq_length = 2048
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
    #model_name="unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    #model_name="unsloth/Qwen2.5-7B-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.47.0.
#    \\   /|    GPU: NVIDIA H100 NVL. Max memory: 93.003 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 9.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    target_modules=["q_proj", "k_proj", "v_proj", "up_proj", "down_proj", "o_proj", "gate_proj"], 
    use_rslora=True,
    use_gradient_checkpointing=True
)
# Out:
# Unsloth 2024.12.4 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/dataset_files/comics_dataset.csv")

# %%
df
# Out:
#                                               file_name  page_nr  panel_nr  \
# 0     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 1     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 2     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         2
# 3     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         3
# 4     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1         4
# ...                                                 ...      ...       ...
# 7124  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 7125  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 7126  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         4
# 7127  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         1
# 7128  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         2
#
#       balloon_nr                                          utterance  \
# 0              1           DID YOU HAVE TO ELECTROCUTE HER SO HARD?
# 1              2           IT'S NOT LIKE I HAVE DIFFERENT SETTINGS.
# 2              3  YOU'RE ELECTROCUTIONER. IT'S YOUR WHOLE THING....
# 3              1                      OH, HEY. I THINK SHE'S AWAKE.
# 4              1  WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRET...
# ...          ...                                                ...
# 7124           2  SHE WOULDN'T DO THAT TO US. WE TALKED FOR A LO...
# 7125           3                                      … I KNOW HER.
# 7126           1                                          UH, GUYS…
# 7127           1  PUT YOUR WEAPONS DOWN AND PUT YOUR HANDS IN TH...
# 7128           1     SURE DOESN'T SEEM LIKE THEY CAME HERE TO TALK…
#
#                                          raw_annotation  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 7124  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7125  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7126  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7127  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
# 7128  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                             raw_emotion  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 7124  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7125  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7126  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 7127  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
# 7128  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                          raw_speaker_id  \
# 0           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 1           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 2           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 3           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 4           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# ...                                                 ...
# 7124      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 7125      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 7126  \n2024-09-06 - SyimykRasulov\nSpokenBy:JUANITA...
# 7127       \n2024-09-06 - SyimykRasulov\nSpokenBy:ID- 2
# 7128    \n2024-09-06 - SyimykRasulov\nSpokenBy:Michonne
#
#                       emotion       speaker_id  split
# 0     AN0-DI0-FE3-SA0-SU5-JO0             ID-1  TRAIN
# 1     AN0-DI0-FE0-SA0-SU5-JO0             ID-2  TRAIN
# 2     AN0-DI0-FE2-SA0-SU0-JO0             ID-1  TRAIN
# 3     AN0-DI0-FE0-SA0-SU4-JO0             ID-2  TRAIN
# 4     AN3-DI0-FE0-SA0-SU0-JO0             ID-1  TRAIN
# ...                       ...              ...    ...
# 7124  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 7125  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 7126  AN0-DI0-FE3-SA0-SU4-JO0  JUANITA SANCHEZ  TRAIN
# 7127  AN4-DI0-FE0-SA0-SU0-JO0            ID- 2  TRAIN
# 7128  AN4-DI0-FE3-SA2-SU0-JO0         Michonne  TRAIN
#
# [7129 rows x 11 columns]

# %%
df.speaker_id.unique()
# Out:
# array(['ID-1', 'ID-2', 'NIGHTWING', 'MELINDA', 'BLOCKBUSTER', 'AUDRE',
#        'MACLEAN', 'ID-3', 'ID-3 ', 'MAGGIE', 'COMMISSIONER', 'BATWOMAN',
#        'ROBIN', 'ID-4', 'ID-5', 'STARGIRL', 'MARONI', 'FLASH', 'ID-6',
#        'ID-7', 'ID-8', 'ID-9', 'ELLIOT', 'Eleanor', 'Momma',
#        'no annotation', 'Natasha', 'John', 'BRIGHT REVENANT', 'HAWKGIRL',
#        'CHRISTOPHER', 'ICE', 'JESUS', 'unknown', 'ID- 1', 'ID- 2',
#        'ID- 3', 'ID- 4', 'ID- 5', 'ID- 6', 'Ms.Jones', 'Felicia Book',
#        'ID- 7', 'ID- 8', 'ID- 9', 'ID- 10', 'ID- 11', 'ID- 12', 'Skinner',
#        'Cal', 'Homo Abominus', 'Agent Bixby', 'Lucia', 'Trapp', 'Kill',
#        'ID- 14', 'OLIVIA', 'MAGISTER PAVUS', 'AARON', 'CALIX ', 'CALIX',
#        'FRANCESCA', 'FLORIAN', 'VAEA', 'AGOSTO', 'ELF', 'AUTUMN', 'Carl',
#        'Rick', 'Maggie', 'Eugene', 'STEPHANIE', 'Dwight', 'Negan', 'Lobo',
#        'ID-2 ', 'Director', 'ID-1 ', 'Flash', 'Black Mask', 'Jay',
#        'Linda', 'Jai', 'Max', 'Irey', 'Ace', 'Jesse', 'Mr.Allen',
#        'Mrs.Allen', 'Kid Flash', 'Flash 2', 'Bystander', 'Freezing enemy',
#        'Travis', 'Krunch', 'Lady Cop', 'Non-Fat', 'Good Looks', 'Bananas',
#        'Mr.Rider', 'Starman', 'Metamorpho', 'Manhunter', 'The Commodore',
#        'Psimon', 'Superboy', 'Supergirl', 'Cyborg', 'Robin', 'Cassie',
#        'Shelly', 'Match', 'Mr.John', 'Speedy', 'Stargirl', 'Starfire',
#        'Batgirl', 'Jokergirl', 'Terra', 'violet ring', 'green ring',
#        'red ring', 'blue ring', 'sky blue ring', 'blue gnom',
#        'blue serious gnom', 'Green Lantern', 'Donatello', 'Raphael',
#        'Michelangelo\t', 'Donatello\t', 'Leonardo', 'Michelangelo',
#        'Chloe', ' Michelangelo', 'April', 'Splinter', 'Baxter Stockman',
#        'Tiger Claw', ' ID-12', 'Sonic', 'Zavok', ' Tails',
#        'Shadow the Hedgehog', 'Espio the Chameleon', 'Doctor Eggman',
#        'Jewel the Beetle', 'Belle the Tinkerer', 'Doctor Starline',
#        'Vector the Crocodile', 'Charmy Bee', 'Master Zik', 'Zeena',
#        'Zazz', 'Joan Peterson', 'Roger Henry', 'Lord Westshire',
#        'Oliver King', 'Robby Trick', 'JACKSON T. WINTERS', 'Edzia Rusnak',
#        'ANDERSON LAKE', 'Jay Burns', 'Joe Burns', 'MARKUS SCHRECKEN',
#        'Andy', 'Britney', 'ID-12', 'ID-13', 'unknown_speaker', 'ID-20',
#        'ID-18', 'ID-19', 'Paco', 'Wenona Blood Crow', 'ID-17', 'ID-15',
#        'ID-16', 'ID- 25', 'Taylor', 'Nuki', 'ID- 24', 'ID- 22', 'ID- 23',
#        'ID- 21', 'Nina', 'EL SILBÓN', 'ID- 28', 'ID- 27',
#        'EL MAESTRO DE LA MUERTE', 'ID- 26', 'Juliet', 'ID- 29', 'ID- 30',
#        'Brun', 'Diz', 'Lieutenant Bratts', 'ID- 16', 'Agent Poole',
#        'ID- 17', 'ID- 18', 'SLIM', 'KING', 'ID-10', 'ID-11', 'ID-14',
#        'TED', 'GALEN', 'LAURA', 'TANYA', 'KREEGS', 'DANIEL', 'TREY',
#        'UNITY', 'AQUANYX', 'BLACKMANTASAURUS', 'GREEN TORCH',
#        'ATROCITAURUS', 'FLASHRAPTOR', 'BATSAUR', 'SUPERSAUR', 'BATSAU',
#        'WONDERDON', 'GIGANTA', 'FATHER', 'REVERSE-SLASH',
#        "Jones's partner", 'John Wesley Jones', 'Sarah', 'Widow Perkins',
#        'Penelope', 'Ronnie', 'Renny', 'Barb', 'Victor Jacks', 'Jodh',
#        'Belle', 'Chen', 'Doctor MacNamara DeSoto', 'Dolores', 'Henry',
#        'Jennifer', 'Toby', 'Stanley', 'Mel', 'Gladys', 'Doris', 'Emma',
#        'Alejandro', 'Jimmy', 'ID- 19', 'ID- 20', 'Laura', 'Liam',
#        'Vanessa', 'Bryn', 'Junior', 'Jake', 'ID- 31', 'ID- 32', 'ID- 33',
#        'ID- 36', 'Tom ', 'Nancy', 'Johan Van Der Veldt', 'ID- 34',
#        'ID- 35', 'ID- 37', 'ID- 38', 'ID- 42', 'ID- 43', 'ID- 49',
#        'ID- 46', 'ID- 47', 'ID- 50', 'ID- 48', 'ID- 51', 'ID- 52',
#        'ID- 53', 'ID- 59', 'ID- 60', 'ID- 54', 'ID- 61', 'ID- 55',
#        'ID- 44', 'ID- 45', 'Franklin', 'Debbie', 'ID- 56', 'ID- 63',
#        'ID- 62', 'ID- 57', 'ID- 58', 'ID- 65', 'ID- 64', 'ID- 68',
#        'ID- 69', 'ID- 67', 'ID- 66', 'Joey Gangemi', 'Bob', 'Alicia',
#        'ID- 70', 'ID- 71', 'Tom', 'Dick', 'ID- 74', 'ID- 72', 'ID- 73',
#        'ID- 76', 'ID- 75', 'Green Arrow', 'Mera', 'Harley Quinn',
#        'Frankenstein', 'Cole Cash', 'Jayna', 'QUEEN', 'Loose Cannon',
#        'Carter', 'Kara', 'Damian', 'Augustus Paulson', 'Conrad Paulson',
#        'Celia', 'Holly', 'Liz Cohen', 'Nathan', 'Hector', 'Manny',
#        'Siddiq', 'Lydia', 'YUMIKO', 'Michonne', 'JUANITA SANCHEZ',
#        'MAGNA', 'Annie', 'Brianna', 'Mikey', 'William', 'Aaron', 'Jesus',
#        'Dante', 'Josh', 'Mike'], dtype=object)

# %%
filtered_df = df[~df['speaker_id'].str.contains('ID-', na=False)].reset_index(drop=True)

# %%
filtered_df
# Out:
#                                               file_name  page_nr  panel_nr  \
# 0     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 1     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 2     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 3     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         4
# 4     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         4
# ...                                                 ...      ...       ...
# 5787  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5788  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5789  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5790  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         4
# 5791  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         2
#
#       balloon_nr                                          utterance  \
# 0              1                                      CAN YOU WALK?
# 1              2                               HOW DID YOU FIND ME?
# 2              3  ORACLE HAD THE LAST PING OFF YOUR PHONE. AND A...
# 3              1                                      AUDRE'S HERE?
# 4              2                                  IN A CAR OUTSIDE.
# ...          ...                                                ...
# 5787           1  MAYBE THIS STEPHANIE PERSON WAS JUST MESSING W...
# 5788           2  SHE WOULDN'T DO THAT TO US. WE TALKED FOR A LO...
# 5789           3                                      … I KNOW HER.
# 5790           1                                          UH, GUYS…
# 5791           1     SURE DOESN'T SEEM LIKE THEY CAME HERE TO TALK…
#
#                                          raw_annotation  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# ...                                                 ...
# 5787  2024-09-06 - SyimykRasulov\nFeeling:AN1-DI0-FE...
# 5788  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5789  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5790  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5791  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                             raw_emotion  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# ...                                                 ...
# 5787  2024-09-06 - SyimykRasulov\nFeeling:AN1-DI0-FE...
# 5788  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5789  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5790  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5791  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                          raw_speaker_id  \
# 0      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# 1        2024-09-05 - aidaraliev12345\nSpokenBy:MELINDA
# 2      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# 3        2024-09-05 - aidaraliev12345\nSpokenBy:MELINDA
# 4      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# ...                                                 ...
# 5787      \n2024-09-06 - SyimykRasulov\nSpokenBy:Siddiq
# 5788      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 5789      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 5790  \n2024-09-06 - SyimykRasulov\nSpokenBy:JUANITA...
# 5791    \n2024-09-06 - SyimykRasulov\nSpokenBy:Michonne
#
#                       emotion       speaker_id  split
# 0     AN0-DI0-FE5-SA0-SU0-JO0        NIGHTWING  TRAIN
# 1     AN0-DI0-FE0-SA0-SU5-JO0          MELINDA  TRAIN
# 2     AN0-DI0-FE0-SA0-SU0-JO5        NIGHTWING  TRAIN
# 3     AN0-DI0-FE3-SA0-SU5-JO0          MELINDA  TRAIN
# 4     AN0-DI0-FE0-SA0-SU0-JO3        NIGHTWING  TRAIN
# ...                       ...              ...    ...
# 5787  AN1-DI0-FE3-SA0-SU0-JO0           Siddiq  TRAIN
# 5788  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 5789  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 5790  AN0-DI0-FE3-SA0-SU4-JO0  JUANITA SANCHEZ  TRAIN
# 5791  AN4-DI0-FE3-SA2-SU0-JO0         Michonne  TRAIN
#
# [5792 rows x 11 columns]

# %%
filtered_df.speaker_id.unique()
# Out:
# array(['NIGHTWING', 'MELINDA', 'BLOCKBUSTER', 'AUDRE', 'MACLEAN',
#        'MAGGIE', 'COMMISSIONER', 'BATWOMAN', 'ROBIN', 'STARGIRL',
#        'MARONI', 'FLASH', 'ELLIOT', 'Eleanor', 'Momma', 'no annotation',
#        'Natasha', 'John', 'BRIGHT REVENANT', 'HAWKGIRL', 'CHRISTOPHER',
#        'ICE', 'JESUS', 'unknown', 'Ms.Jones', 'Felicia Book', 'Skinner',
#        'Cal', 'Homo Abominus', 'Agent Bixby', 'Lucia', 'Trapp', 'Kill',
#        'OLIVIA', 'MAGISTER PAVUS', 'AARON', 'CALIX ', 'CALIX',
#        'FRANCESCA', 'FLORIAN', 'VAEA', 'AGOSTO', 'ELF', 'AUTUMN', 'Carl',
#        'Rick', 'Maggie', 'Eugene', 'STEPHANIE', 'Dwight', 'Negan', 'Lobo',
#        'Director', 'Flash', 'Black Mask', 'Jay', 'Linda', 'Jai', 'Max',
#        'Irey', 'Ace', 'Jesse', 'Mr.Allen', 'Mrs.Allen', 'Kid Flash',
#        'Flash 2', 'Bystander', 'Freezing enemy', 'Travis', 'Krunch',
#        'Lady Cop', 'Non-Fat', 'Good Looks', 'Bananas', 'Mr.Rider',
#        'Starman', 'Metamorpho', 'Manhunter', 'The Commodore', 'Psimon',
#        'Superboy', 'Supergirl', 'Cyborg', 'Robin', 'Cassie', 'Shelly',
#        'Match', 'Mr.John', 'Speedy', 'Stargirl', 'Starfire', 'Batgirl',
#        'Jokergirl', 'Terra', 'violet ring', 'green ring', 'red ring',
#        'blue ring', 'sky blue ring', 'blue gnom', 'blue serious gnom',
#        'Green Lantern', 'Donatello', 'Raphael', 'Michelangelo\t',
#        'Donatello\t', 'Leonardo', 'Michelangelo', 'Chloe',
#        ' Michelangelo', 'April', 'Splinter', 'Baxter Stockman',
#        'Tiger Claw', 'Sonic', 'Zavok', ' Tails', 'Shadow the Hedgehog',
#        'Espio the Chameleon', 'Doctor Eggman', 'Jewel the Beetle',
#        'Belle the Tinkerer', 'Doctor Starline', 'Vector the Crocodile',
#        'Charmy Bee', 'Master Zik', 'Zeena', 'Zazz', 'Joan Peterson',
#        'Roger Henry', 'Lord Westshire', 'Oliver King', 'Robby Trick',
#        'JACKSON T. WINTERS', 'Edzia Rusnak', 'ANDERSON LAKE', 'Jay Burns',
#        'Joe Burns', 'MARKUS SCHRECKEN', 'Andy', 'Britney',
#        'unknown_speaker', 'Paco', 'Wenona Blood Crow', 'Taylor', 'Nuki',
#        'Nina', 'EL SILBÓN', 'EL MAESTRO DE LA MUERTE', 'Juliet', 'Brun',
#        'Diz', 'Lieutenant Bratts', 'Agent Poole', 'SLIM', 'KING', 'TED',
#        'GALEN', 'LAURA', 'TANYA', 'KREEGS', 'DANIEL', 'TREY', 'UNITY',
#        'AQUANYX', 'BLACKMANTASAURUS', 'GREEN TORCH', 'ATROCITAURUS',
#        'FLASHRAPTOR', 'BATSAUR', 'SUPERSAUR', 'BATSAU', 'WONDERDON',
#        'GIGANTA', 'FATHER', 'REVERSE-SLASH', "Jones's partner",
#        'John Wesley Jones', 'Sarah', 'Widow Perkins', 'Penelope',
#        'Ronnie', 'Renny', 'Barb', 'Victor Jacks', 'Jodh', 'Belle', 'Chen',
#        'Doctor MacNamara DeSoto', 'Dolores', 'Henry', 'Jennifer', 'Toby',
#        'Stanley', 'Mel', 'Gladys', 'Doris', 'Emma', 'Alejandro', 'Jimmy',
#        'Laura', 'Liam', 'Vanessa', 'Bryn', 'Junior', 'Jake', 'Tom ',
#        'Nancy', 'Johan Van Der Veldt', 'Franklin', 'Debbie',
#        'Joey Gangemi', 'Bob', 'Alicia', 'Tom', 'Dick', 'Green Arrow',
#        'Mera', 'Harley Quinn', 'Frankenstein', 'Cole Cash', 'Jayna',
#        'QUEEN', 'Loose Cannon', 'Carter', 'Kara', 'Damian',
#        'Augustus Paulson', 'Conrad Paulson', 'Celia', 'Holly',
#        'Liz Cohen', 'Nathan', 'Hector', 'Manny', 'Siddiq', 'Lydia',
#        'YUMIKO', 'Michonne', 'JUANITA SANCHEZ', 'MAGNA', 'Annie',
#        'Brianna', 'Mikey', 'William', 'Aaron', 'Jesus', 'Dante', 'Josh',
#        'Mike'], dtype=object)

# %%
filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('no annotation', na=False)].reset_index(drop=True)

# %%
filtered_df.shape
# Out:
# (5727, 11)

# %%
filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('unknown_speaker', na=False)].reset_index(drop=True)

# %%
filtered_df.shape
# Out:
# (5724, 11)

# %%
filtered_df = filtered_df[~filtered_df['speaker_id'].str.contains('unknown', na=False)].reset_index(drop=True)

# %%
filtered_df.shape
# Out:
# (5697, 11)

# %%
filtered_df.speaker_id.unique()
# Out:
# array(['NIGHTWING', 'MELINDA', 'BLOCKBUSTER', 'AUDRE', 'MACLEAN',
#        'MAGGIE', 'COMMISSIONER', 'BATWOMAN', 'ROBIN', 'STARGIRL',
#        'MARONI', 'FLASH', 'ELLIOT', 'Eleanor', 'Momma', 'Natasha', 'John',
#        'BRIGHT REVENANT', 'HAWKGIRL', 'CHRISTOPHER', 'ICE', 'JESUS',
#        'Ms.Jones', 'Felicia Book', 'Skinner', 'Cal', 'Homo Abominus',
#        'Agent Bixby', 'Lucia', 'Trapp', 'Kill', 'OLIVIA',
#        'MAGISTER PAVUS', 'AARON', 'CALIX ', 'CALIX', 'FRANCESCA',
#        'FLORIAN', 'VAEA', 'AGOSTO', 'ELF', 'AUTUMN', 'Carl', 'Rick',
#        'Maggie', 'Eugene', 'STEPHANIE', 'Dwight', 'Negan', 'Lobo',
#        'Director', 'Flash', 'Black Mask', 'Jay', 'Linda', 'Jai', 'Max',
#        'Irey', 'Ace', 'Jesse', 'Mr.Allen', 'Mrs.Allen', 'Kid Flash',
#        'Flash 2', 'Bystander', 'Freezing enemy', 'Travis', 'Krunch',
#        'Lady Cop', 'Non-Fat', 'Good Looks', 'Bananas', 'Mr.Rider',
#        'Starman', 'Metamorpho', 'Manhunter', 'The Commodore', 'Psimon',
#        'Superboy', 'Supergirl', 'Cyborg', 'Robin', 'Cassie', 'Shelly',
#        'Match', 'Mr.John', 'Speedy', 'Stargirl', 'Starfire', 'Batgirl',
#        'Jokergirl', 'Terra', 'violet ring', 'green ring', 'red ring',
#        'blue ring', 'sky blue ring', 'blue gnom', 'blue serious gnom',
#        'Green Lantern', 'Donatello', 'Raphael', 'Michelangelo\t',
#        'Donatello\t', 'Leonardo', 'Michelangelo', 'Chloe',
#        ' Michelangelo', 'April', 'Splinter', 'Baxter Stockman',
#        'Tiger Claw', 'Sonic', 'Zavok', ' Tails', 'Shadow the Hedgehog',
#        'Espio the Chameleon', 'Doctor Eggman', 'Jewel the Beetle',
#        'Belle the Tinkerer', 'Doctor Starline', 'Vector the Crocodile',
#        'Charmy Bee', 'Master Zik', 'Zeena', 'Zazz', 'Joan Peterson',
#        'Roger Henry', 'Lord Westshire', 'Oliver King', 'Robby Trick',
#        'JACKSON T. WINTERS', 'Edzia Rusnak', 'ANDERSON LAKE', 'Jay Burns',
#        'Joe Burns', 'MARKUS SCHRECKEN', 'Andy', 'Britney', 'Paco',
#        'Wenona Blood Crow', 'Taylor', 'Nuki', 'Nina', 'EL SILBÓN',
#        'EL MAESTRO DE LA MUERTE', 'Juliet', 'Brun', 'Diz',
#        'Lieutenant Bratts', 'Agent Poole', 'SLIM', 'KING', 'TED', 'GALEN',
#        'LAURA', 'TANYA', 'KREEGS', 'DANIEL', 'TREY', 'UNITY', 'AQUANYX',
#        'BLACKMANTASAURUS', 'GREEN TORCH', 'ATROCITAURUS', 'FLASHRAPTOR',
#        'BATSAUR', 'SUPERSAUR', 'BATSAU', 'WONDERDON', 'GIGANTA', 'FATHER',
#        'REVERSE-SLASH', "Jones's partner", 'John Wesley Jones', 'Sarah',
#        'Widow Perkins', 'Penelope', 'Ronnie', 'Renny', 'Barb',
#        'Victor Jacks', 'Jodh', 'Belle', 'Chen', 'Doctor MacNamara DeSoto',
#        'Dolores', 'Henry', 'Jennifer', 'Toby', 'Stanley', 'Mel', 'Gladys',
#        'Doris', 'Emma', 'Alejandro', 'Jimmy', 'Laura', 'Liam', 'Vanessa',
#        'Bryn', 'Junior', 'Jake', 'Tom ', 'Nancy', 'Johan Van Der Veldt',
#        'Franklin', 'Debbie', 'Joey Gangemi', 'Bob', 'Alicia', 'Tom',
#        'Dick', 'Green Arrow', 'Mera', 'Harley Quinn', 'Frankenstein',
#        'Cole Cash', 'Jayna', 'QUEEN', 'Loose Cannon', 'Carter', 'Kara',
#        'Damian', 'Augustus Paulson', 'Conrad Paulson', 'Celia', 'Holly',
#        'Liz Cohen', 'Nathan', 'Hector', 'Manny', 'Siddiq', 'Lydia',
#        'YUMIKO', 'Michonne', 'JUANITA SANCHEZ', 'MAGNA', 'Annie',
#        'Brianna', 'Mikey', 'William', 'Aaron', 'Jesus', 'Dante', 'Josh',
#        'Mike'], dtype=object)

# %%
filtered_df[filtered_df.speaker_id == 'violet ring']
# Out:
#                                           file_name  page_nr  panel_nr  \
# 1667  QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx       14         4
#
#       balloon_nr  utterance  \
# 1667           1  ACTIVATE!
#
#                                          raw_annotation  \
# 1667  2024-07-25 - SyimykRasulov\nFeeling:Neutral\n\...
#
#                                       raw_emotion  \
# 1667  2024-07-25 - SyimykRasulov\nFeeling:Neutral
#
#                                          raw_speaker_id  emotion   speaker_id  \
# 1667  \n2024-07-25 - SyimykRasulov\nSpokenBy:violet ...  Neutral  violet ring
#
#       split
# 1667  TRAIN

# %%
filtered_df[filtered_df.file_name == 'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx'].speaker_id.unique()
# Out:
# array(['Psimon', 'Superboy', 'Supergirl', 'Cyborg', 'Kid Flash', 'Robin',
#        'Cassie', 'Shelly', 'Match', 'Mr.John', 'Speedy', 'Stargirl',
#        'Starfire', 'Batgirl', 'Jokergirl', 'Terra', 'violet ring',
#        'green ring', 'red ring', 'blue ring', 'sky blue ring',
#        'blue gnom', 'blue serious gnom', 'Green Lantern'], dtype=object)

# %%
filtered_df
# Out:
#                                               file_name  page_nr  panel_nr  \
# 0     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 1     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 2     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         3
# 3     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         4
# 4     QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        3         4
# ...                                                 ...      ...       ...
# 5692  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5693  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5694  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         3
# 5695  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       21         4
# 5696  QC copy - 1737 - 34 The Walking Dead vol 15 - ...       22         2
#
#       balloon_nr                                          utterance  \
# 0              1                                      CAN YOU WALK?
# 1              2                               HOW DID YOU FIND ME?
# 2              3  ORACLE HAD THE LAST PING OFF YOUR PHONE. AND A...
# 3              1                                      AUDRE'S HERE?
# 4              2                                  IN A CAR OUTSIDE.
# ...          ...                                                ...
# 5692           1  MAYBE THIS STEPHANIE PERSON WAS JUST MESSING W...
# 5693           2  SHE WOULDN'T DO THAT TO US. WE TALKED FOR A LO...
# 5694           3                                      … I KNOW HER.
# 5695           1                                          UH, GUYS…
# 5696           1     SURE DOESN'T SEEM LIKE THEY CAME HERE TO TALK…
#
#                                          raw_annotation  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# ...                                                 ...
# 5692  2024-09-06 - SyimykRasulov\nFeeling:AN1-DI0-FE...
# 5693  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5694  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5695  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5696  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                             raw_emotion  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# ...                                                 ...
# 5692  2024-09-06 - SyimykRasulov\nFeeling:AN1-DI0-FE...
# 5693  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5694  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5695  2024-09-06 - SyimykRasulov\nFeeling:AN0-DI0-FE...
# 5696  2024-09-06 - SyimykRasulov\nFeeling:AN4-DI0-FE...
#
#                                          raw_speaker_id  \
# 0      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# 1        2024-09-05 - aidaraliev12345\nSpokenBy:MELINDA
# 2      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# 3        2024-09-05 - aidaraliev12345\nSpokenBy:MELINDA
# 4      2024-09-05 - aidaraliev12345\nSpokenBy:NIGHTWING
# ...                                                 ...
# 5692      \n2024-09-06 - SyimykRasulov\nSpokenBy:Siddiq
# 5693      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 5694      \n2024-09-06 - SyimykRasulov\nSpokenBy:Eugene
# 5695  \n2024-09-06 - SyimykRasulov\nSpokenBy:JUANITA...
# 5696    \n2024-09-06 - SyimykRasulov\nSpokenBy:Michonne
#
#                       emotion       speaker_id  split
# 0     AN0-DI0-FE5-SA0-SU0-JO0        NIGHTWING  TRAIN
# 1     AN0-DI0-FE0-SA0-SU5-JO0          MELINDA  TRAIN
# 2     AN0-DI0-FE0-SA0-SU0-JO5        NIGHTWING  TRAIN
# 3     AN0-DI0-FE3-SA0-SU5-JO0          MELINDA  TRAIN
# 4     AN0-DI0-FE0-SA0-SU0-JO3        NIGHTWING  TRAIN
# ...                       ...              ...    ...
# 5692  AN1-DI0-FE3-SA0-SU0-JO0           Siddiq  TRAIN
# 5693  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 5694  AN0-DI0-FE1-SA3-SU0-JO0           Eugene  TRAIN
# 5695  AN0-DI0-FE3-SA0-SU4-JO0  JUANITA SANCHEZ  TRAIN
# 5696  AN4-DI0-FE3-SA2-SU0-JO0         Michonne  TRAIN
#
# [5697 rows x 11 columns]

# %%
len(filtered_df.file_name.unique())
# Out:
# 35

# %%
def get_unique_emotion(row):

    utterance_emotions = row.emotion

    utterance_emotions_l = []
    emotion_class_labels = ["anger", "disgust", "fear", "sadness", "surprise", "joy"]

    if utterance_emotions == 'Neutral':
        
        utterance_emotions_l.append('neutral')
    
    else:
        
        utterance_emotions = utterance_emotions.split("-")

        for idx, emotion_annotation in enumerate(utterance_emotions):

            if '0' not in emotion_annotation:
         
                utterance_emotions_l.append(emotion_class_labels[idx])

    return utterance_emotions_l

# %%
filtered_df['emotion_c'] = filtered_df.apply(lambda row: get_unique_emotion(row), axis=1)

# %%
grouped_df = filtered_df.groupby(['file_name', 'split']).agg({
    'utterance': list,
    'speaker_id': list,
    'emotion_c': list
}).reset_index()

# %%
grouped_df
# Out:
#                                             file_name  split  \
# 0   QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...  TRAIN
# 1   QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...  TRAIN
# 2   QC copy - 1501 - 09 Mundos sin Liga de la Just...  TRAIN
# 3   QC copy - 1502 - 09 Mundos sin Liga de la Just...  TRAIN
# 4   QC copy - 1503 - 10 Crisis Oscura Flash - FLS ...  TRAIN
# 5            QC copy - 1507 - 22 Calle Peligro 1.xlsx   TEST
# 6       QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx  TRAIN
# 7            QC copy - 1513 - 21 Blanco Humano 9.xlsx  TRAIN
# 8      QC copy - 1514 - 15 DC contra Vampiros 11.xlsx   TEST
# 9   QC copy - 1517 - 37 John Carpenter Historias p...  TRAIN
# 10  QC copy - 1518 - 50 Las asombrosas aventuras d...  TRAIN
# 11     QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx   TEST
# 12             QC copy - 1521 - 40 Amor eterno 2.xlsx  TRAIN
# 13  QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 14  QC copy - 1560 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 15  QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 16  QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 17  QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted...   TEST
# 18  QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 19  QC copy - 1568 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 20  QC copy - 1569 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 21  QC copy - 1570 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 22  QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 23  QC copy - 1642 - 23 American Vampire vol. 4 - ...  TRAIN
# 24  QC copy - 1643 - 23 American Vampire vol. 4 - ...   TEST
# 25  QC copy - 1644 - 23 American Vampire vol. 4 - ...  TRAIN
# 26  QC copy - 1660 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 27  QC copy - 1661 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 28  QC copy - 1662 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 29  QC copy - 1733 - 34 The Walking Dead vol 15 - ...   TEST
# 30  QC copy - 1734 - 34 The Walking Dead vol 15 - ...  TRAIN
# 31  QC copy - 1735 - 34 The Walking Dead vol 15 - ...  TRAIN
# 32  QC copy - 1737 - 34 The Walking Dead vol 15 - ...  TRAIN
# 33  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...  TRAIN
# 34                QC copy - 2200 - Stillwater 13.xlsx   TEST
#
#                                             utterance  \
# 0   [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1   [CAN YOU WALK?, HOW DID YOU FIND ME?, ORACLE H...
# 2   [" Tell me another story, Momma. ", " What kin...
# 3   [MOTHERFRAGGER., LOOK, FRIEND, YOU BASTICHES A...
# 4   [I'M DONE LETTING YOU TORTURE ME!, YOU'RE NEVE...
# 5   [HEY., JUST A COKE., THANKS., IT'S ALL RIGHT.,...
# 6   [ SO, LET ME GET THIS STRAIGHT… THERE'S A SUPE...
# 7   [I'M ALREADY TOO LATE., $ % # @., I'M ALSO TOO...
# 8   [YOU LIKE THAT? IT'S MY OWN INVENTION. THREE P...
# 9   [FOUND IT ON THE WAY HERE. THERE WAS A BURNED ...
# 10  [BRING IT ON!, NOT GETTING PAST ME! I'M THE MA...
# 11  [YOU'RE NOT GOING TO OVER POWER TAILS' TECH., ...
# 12  [I WAS THE DAUGHTER OF THE NURSEMAID. HE WAS T...
# 13  [SO A LOT OF PEOPLE HAVE DIED IN THE TRASK MAN...
# 14  [#UK, UK,, #UK., Ya see this?, This is why you...
# 15  [" SO THE PLAN HAS ALWAYS BEEN THAT WE NEED TO...
# 16  [Something I'm often accused of is using peopl...
# 17  [You get used to it.  , The outside is really ...
# 18  [HEY, SHIT FOR BRAINS!, THEY'RE WITH ME. MY GU...
# 19  [NAH, MAN. NO THANK YOU., For a long time, whe...
# 20  [IF YOUR PLAN IS TO TORTURE ME, DON'T BOTHER. ...
# 21  [I've always had a way with the ladies., Or at...
# 22  [TRICK!, TRICK? DAMMIT!, WHERE ARE YOU, YA OLD...
# 23  [MEOW., SKINNER…, QUIT MESSING AROUND. THE GAT...
# 24  [WELL, THAT'S GRIM., IF IT'S THAT SECURE AND W...
# 25  [WHAT THE HELL… SKINNER…?!, IT'S TOO LATE, POO...
# 26  [THEY SAY THERE ARE NO SMALL ROLES. ONLY SMALL...
# 27  [EXCUSE ME. I'M LOOKING FOR A WOMAN., HER NAME...
# 28  [I MEANT NO OFFENSE!, IT'S COMMON KNOWLEDGE TH...
# 29  [THERE WERE THESE TWO BOYS, BEN AND BILLY. THE...
# 30  [NEXT FIFTEEN MILES OR SO ARE STILL IN THE SAF...
# 31  [I TOLD MYSELF I WAS PROTECTING YOU BY KEEPING...
# 32  [WHAT--?!, WHERE--?!, JESUS--GET DOWN !, I CAN...
# 33  [THAT WENT… A LOT SMOOTHER THAN I EXPECTED.  ,...
# 34  [WE HAVE A SITUATION AT THE EDGE, AT --AT THE ...
#
#                                            speaker_id  \
# 0   [AQUANYX, AQUANYX, AQUANYX, AQUANYX, AQUANYX, ...
# 1   [NIGHTWING, MELINDA, NIGHTWING, MELINDA, NIGHT...
# 2   [Eleanor, Momma, Eleanor, Eleanor, Momma, Elea...
# 3   [Lobo, Lobo, Lobo, Lobo, Lobo, Lobo, Lobo, Lob...
# 4   [Flash, Flash, Flash, Black Mask, Flash, Black...
# 5   [Travis, Travis, Travis, Travis, Krunch, Krunc...
# 6   [Psimon, Psimon, Superboy, Supergirl, Superboy...
# 7   [CHRISTOPHER, CHRISTOPHER, CHRISTOPHER, ICE, C...
# 8   [Green Arrow, Green Arrow, Green Arrow, Green ...
# 9   [Jones's partner, Jones's partner, John Wesley...
# 10  [Donatello, Raphael, Michelangelo\t, Raphael, ...
# 11  [Sonic, Sonic, Zavok, Zavok, Zavok, Sonic, Zav...
# 12  [Joan Peterson, Roger Henry, Roger Henry, Joan...
# 13  [Oliver King, Oliver King, Robby Trick, Robby ...
# 14  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 15  [Oliver King, Oliver King, Oliver King, Oliver...
# 16  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 17  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 18  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 19  [Taylor, JACKSON T. WINTERS, JACKSON T. WINTER...
# 20  [JACKSON T. WINTERS, JACKSON T. WINTERS, EL SI...
# 21  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 22  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 23  [Skinner, Cal, Cal, Skinner, Skinner, Cal, Cal...
# 24  [Ms.Jones, Ms.Jones, Felicia Book, Ms.Jones, F...
# 25  [Cal, Agent Bixby, Agent Bixby, Agent Bixby, C...
# 26  [OLIVIA, OLIVIA, OLIVIA, OLIVIA, OLIVIA, OLIVI...
# 27  [AARON, AARON, SLIM, SLIM, AARON, SLIM, AARON,...
# 28  [VAEA, AARON, AARON, VAEA, AARON, VAEA, AARON,...
# 29  [Carl, Carl, Carl, Carl, Carl, Carl, Carl, Car...
# 30  [Michonne, Michonne, Eugene, Eugene, Michonne,...
# 31  [Siddiq, Siddiq, Siddiq, Eugene, Lydia, Lydia,...
# 32  [Aaron, Aaron, Aaron, Jesus, Jesus, Jesus, Aar...
# 33  [Augustus Paulson, Conrad Paulson, Celia, Conr...
# 34  [TED, TED, TED, TED, TED, GALEN, GALEN, LAURA,...
#
#                                             emotion_c
# 0   [[anger], [anger], [fear, sadness], [anger], [...
# 1   [[fear], [surprise], [joy], [fear, surprise], ...
# 2   [[joy], [surprise], [joy], [joy], [sadness, su...
# 3   [[anger], [anger], [anger], [anger, surprise],...
# 4   [[anger], [anger, sadness], [surprise], [neutr...
# 5   [[joy], [joy], [joy], [joy], [anger, disgust],...
# 6   [[surprise], [surprise], [joy], [joy], [surpri...
# 7   [[fear, sadness], [anger], [fear], [fear, surp...
# 8   [[anger, joy], [sadness, joy], [sadness, joy],...
# 9   [[anger], [anger, joy], [anger], [anger], [ang...
# 10  [[anger], [anger], [surprise], [joy], [sadness...
# 11  [[joy], [joy], [anger], [anger, sadness], [sad...
# 12  [[sadness], [fear, sadness], [sadness], [sadne...
# 13  [[fear, surprise], [anger, surprise], [anger],...
# 14  [[anger, fear], [anger, fear], [sadness, surpr...
# 15  [[surprise], [sadness], [neutral], [anger], [n...
# 16  [[sadness], [sadness], [sadness], [sadness], [...
# 17  [[anger, disgust, sadness], [sadness], [fear, ...
# 18  [[anger, disgust], [anger], [anger], [anger], ...
# 19  [[anger, disgust], [sadness], [sadness], [surp...
# 20  [[sadness], [sadness], [sadness], [anger], [an...
# 21  [[joy], [sadness], [anger, surprise], [anger],...
# 22  [[fear], [anger, fear, surprise], [anger, fear...
# 23  [[anger], [anger], [anger, fear], [surprise, j...
# 24  [[disgust, fear, sadness], [fear, sadness, sur...
# 25  [[anger, fear, surprise], [fear], [anger, fear...
# 26  [[anger, disgust], [anger, disgust], [joy], [j...
# 27  [[fear, sadness], [fear, sadness], [surprise],...
# 28  [[sadness, surprise], [sadness], [sadness], [f...
# 29  [[sadness], [sadness], [sadness], [sadness], [...
# 30  [[neutral], [neutral], [fear, surprise], [fear...
# 31  [[sadness], [sadness], [sadness], [anger, sadn...
# 32  [[fear, surprise], [fear, surprise], [anger, f...
# 33  [[joy], [anger, sadness], [anger], [anger], [j...
# 34  [[fear, surprise], [fear], [fear], [fear, surp...

# %%
def get_stats(row):
    
    return [len(row.utterance), len(row.speaker_id), len(row.emotion_c)]

# %%
grouped_df['lens'] = grouped_df.apply(lambda row: get_stats(row), axis=1)

# %%
grouped_df
# Out:
#                                             file_name  split  \
# 0   QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...  TRAIN
# 1   QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...  TRAIN
# 2   QC copy - 1501 - 09 Mundos sin Liga de la Just...  TRAIN
# 3   QC copy - 1502 - 09 Mundos sin Liga de la Just...  TRAIN
# 4   QC copy - 1503 - 10 Crisis Oscura Flash - FLS ...  TRAIN
# 5            QC copy - 1507 - 22 Calle Peligro 1.xlsx   TEST
# 6       QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx  TRAIN
# 7            QC copy - 1513 - 21 Blanco Humano 9.xlsx  TRAIN
# 8      QC copy - 1514 - 15 DC contra Vampiros 11.xlsx   TEST
# 9   QC copy - 1517 - 37 John Carpenter Historias p...  TRAIN
# 10  QC copy - 1518 - 50 Las asombrosas aventuras d...  TRAIN
# 11     QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx   TEST
# 12             QC copy - 1521 - 40 Amor eterno 2.xlsx  TRAIN
# 13  QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 14  QC copy - 1560 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 15  QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 16  QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 17  QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted...   TEST
# 18  QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 19  QC copy - 1568 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 20  QC copy - 1569 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 21  QC copy - 1570 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 22  QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted...  TRAIN
# 23  QC copy - 1642 - 23 American Vampire vol. 4 - ...  TRAIN
# 24  QC copy - 1643 - 23 American Vampire vol. 4 - ...   TEST
# 25  QC copy - 1644 - 23 American Vampire vol. 4 - ...  TRAIN
# 26  QC copy - 1660 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 27  QC copy - 1661 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 28  QC copy - 1662 - 39 Dragon Age vol. 3 Engano -...  TRAIN
# 29  QC copy - 1733 - 34 The Walking Dead vol 15 - ...   TEST
# 30  QC copy - 1734 - 34 The Walking Dead vol 15 - ...  TRAIN
# 31  QC copy - 1735 - 34 The Walking Dead vol 15 - ...  TRAIN
# 32  QC copy - 1737 - 34 The Walking Dead vol 15 - ...  TRAIN
# 33  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...  TRAIN
# 34                QC copy - 2200 - Stillwater 13.xlsx   TEST
#
#                                             utterance  \
# 0   [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1   [CAN YOU WALK?, HOW DID YOU FIND ME?, ORACLE H...
# 2   [" Tell me another story, Momma. ", " What kin...
# 3   [MOTHERFRAGGER., LOOK, FRIEND, YOU BASTICHES A...
# 4   [I'M DONE LETTING YOU TORTURE ME!, YOU'RE NEVE...
# 5   [HEY., JUST A COKE., THANKS., IT'S ALL RIGHT.,...
# 6   [ SO, LET ME GET THIS STRAIGHT… THERE'S A SUPE...
# 7   [I'M ALREADY TOO LATE., $ % # @., I'M ALSO TOO...
# 8   [YOU LIKE THAT? IT'S MY OWN INVENTION. THREE P...
# 9   [FOUND IT ON THE WAY HERE. THERE WAS A BURNED ...
# 10  [BRING IT ON!, NOT GETTING PAST ME! I'M THE MA...
# 11  [YOU'RE NOT GOING TO OVER POWER TAILS' TECH., ...
# 12  [I WAS THE DAUGHTER OF THE NURSEMAID. HE WAS T...
# 13  [SO A LOT OF PEOPLE HAVE DIED IN THE TRASK MAN...
# 14  [#UK, UK,, #UK., Ya see this?, This is why you...
# 15  [" SO THE PLAN HAS ALWAYS BEEN THAT WE NEED TO...
# 16  [Something I'm often accused of is using peopl...
# 17  [You get used to it.  , The outside is really ...
# 18  [HEY, SHIT FOR BRAINS!, THEY'RE WITH ME. MY GU...
# 19  [NAH, MAN. NO THANK YOU., For a long time, whe...
# 20  [IF YOUR PLAN IS TO TORTURE ME, DON'T BOTHER. ...
# 21  [I've always had a way with the ladies., Or at...
# 22  [TRICK!, TRICK? DAMMIT!, WHERE ARE YOU, YA OLD...
# 23  [MEOW., SKINNER…, QUIT MESSING AROUND. THE GAT...
# 24  [WELL, THAT'S GRIM., IF IT'S THAT SECURE AND W...
# 25  [WHAT THE HELL… SKINNER…?!, IT'S TOO LATE, POO...
# 26  [THEY SAY THERE ARE NO SMALL ROLES. ONLY SMALL...
# 27  [EXCUSE ME. I'M LOOKING FOR A WOMAN., HER NAME...
# 28  [I MEANT NO OFFENSE!, IT'S COMMON KNOWLEDGE TH...
# 29  [THERE WERE THESE TWO BOYS, BEN AND BILLY. THE...
# 30  [NEXT FIFTEEN MILES OR SO ARE STILL IN THE SAF...
# 31  [I TOLD MYSELF I WAS PROTECTING YOU BY KEEPING...
# 32  [WHAT--?!, WHERE--?!, JESUS--GET DOWN !, I CAN...
# 33  [THAT WENT… A LOT SMOOTHER THAN I EXPECTED.  ,...
# 34  [WE HAVE A SITUATION AT THE EDGE, AT --AT THE ...
#
#                                            speaker_id  \
# 0   [AQUANYX, AQUANYX, AQUANYX, AQUANYX, AQUANYX, ...
# 1   [NIGHTWING, MELINDA, NIGHTWING, MELINDA, NIGHT...
# 2   [Eleanor, Momma, Eleanor, Eleanor, Momma, Elea...
# 3   [Lobo, Lobo, Lobo, Lobo, Lobo, Lobo, Lobo, Lob...
# 4   [Flash, Flash, Flash, Black Mask, Flash, Black...
# 5   [Travis, Travis, Travis, Travis, Krunch, Krunc...
# 6   [Psimon, Psimon, Superboy, Supergirl, Superboy...
# 7   [CHRISTOPHER, CHRISTOPHER, CHRISTOPHER, ICE, C...
# 8   [Green Arrow, Green Arrow, Green Arrow, Green ...
# 9   [Jones's partner, Jones's partner, John Wesley...
# 10  [Donatello, Raphael, Michelangelo\t, Raphael, ...
# 11  [Sonic, Sonic, Zavok, Zavok, Zavok, Sonic, Zav...
# 12  [Joan Peterson, Roger Henry, Roger Henry, Joan...
# 13  [Oliver King, Oliver King, Robby Trick, Robby ...
# 14  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 15  [Oliver King, Oliver King, Oliver King, Oliver...
# 16  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 17  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 18  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 19  [Taylor, JACKSON T. WINTERS, JACKSON T. WINTER...
# 20  [JACKSON T. WINTERS, JACKSON T. WINTERS, EL SI...
# 21  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 22  [JACKSON T. WINTERS, JACKSON T. WINTERS, JACKS...
# 23  [Skinner, Cal, Cal, Skinner, Skinner, Cal, Cal...
# 24  [Ms.Jones, Ms.Jones, Felicia Book, Ms.Jones, F...
# 25  [Cal, Agent Bixby, Agent Bixby, Agent Bixby, C...
# 26  [OLIVIA, OLIVIA, OLIVIA, OLIVIA, OLIVIA, OLIVI...
# 27  [AARON, AARON, SLIM, SLIM, AARON, SLIM, AARON,...
# 28  [VAEA, AARON, AARON, VAEA, AARON, VAEA, AARON,...
# 29  [Carl, Carl, Carl, Carl, Carl, Carl, Carl, Car...
# 30  [Michonne, Michonne, Eugene, Eugene, Michonne,...
# 31  [Siddiq, Siddiq, Siddiq, Eugene, Lydia, Lydia,...
# 32  [Aaron, Aaron, Aaron, Jesus, Jesus, Jesus, Aar...
# 33  [Augustus Paulson, Conrad Paulson, Celia, Conr...
# 34  [TED, TED, TED, TED, TED, GALEN, GALEN, LAURA,...
#
#                                             emotion_c             lens
# 0   [[anger], [anger], [fear, sadness], [anger], [...  [124, 124, 124]
# 1   [[fear], [surprise], [joy], [fear, surprise], ...  [103, 103, 103]
# 2   [[joy], [surprise], [joy], [joy], [sadness, su...  [167, 167, 167]
# 3   [[anger], [anger], [anger], [anger, surprise],...     [46, 46, 46]
# 4   [[anger], [anger, sadness], [surprise], [neutr...  [130, 130, 130]
# 5   [[joy], [joy], [joy], [joy], [anger, disgust],...  [259, 259, 259]
# 6   [[surprise], [surprise], [joy], [joy], [surpri...  [142, 142, 142]
# 7   [[fear, sadness], [anger], [fear], [fear, surp...  [229, 229, 229]
# 8   [[anger, joy], [sadness, joy], [sadness, joy],...  [120, 120, 120]
# 9   [[anger], [anger, joy], [anger], [anger], [ang...  [690, 690, 690]
# 10  [[anger], [anger], [surprise], [joy], [sadness...  [170, 170, 170]
# 11  [[joy], [joy], [anger], [anger, sadness], [sad...  [120, 120, 120]
# 12  [[sadness], [fear, sadness], [sadness], [sadne...  [215, 215, 215]
# 13  [[fear, surprise], [anger, surprise], [anger],...  [108, 108, 108]
# 14  [[anger, fear], [anger, fear], [sadness, surpr...  [136, 136, 136]
# 15  [[surprise], [sadness], [neutral], [anger], [n...  [175, 175, 175]
# 16  [[sadness], [sadness], [sadness], [sadness], [...  [156, 156, 156]
# 17  [[anger, disgust, sadness], [sadness], [fear, ...  [159, 159, 159]
# 18  [[anger, disgust], [anger], [anger], [anger], ...  [123, 123, 123]
# 19  [[anger, disgust], [sadness], [sadness], [surp...  [145, 145, 145]
# 20  [[sadness], [sadness], [sadness], [anger], [an...  [163, 163, 163]
# 21  [[joy], [sadness], [anger, surprise], [anger],...  [162, 162, 162]
# 22  [[fear], [anger, fear, surprise], [anger, fear...  [147, 147, 147]
# 23  [[anger], [anger], [anger, fear], [surprise, j...  [147, 147, 147]
# 24  [[disgust, fear, sadness], [fear, sadness, sur...     [88, 88, 88]
# 25  [[anger, fear, surprise], [fear], [anger, fear...  [129, 129, 129]
# 26  [[anger, disgust], [anger, disgust], [joy], [j...  [157, 157, 157]
# 27  [[fear, sadness], [fear, sadness], [surprise],...  [170, 170, 170]
# 28  [[sadness, surprise], [sadness], [sadness], [f...  [170, 170, 170]
# 29  [[sadness], [sadness], [sadness], [sadness], [...  [212, 212, 212]
# 30  [[neutral], [neutral], [fear, surprise], [fear...  [108, 108, 108]
# 31  [[sadness], [sadness], [sadness], [anger, sadn...  [130, 130, 130]
# 32  [[fear, surprise], [fear, surprise], [anger, f...  [106, 106, 106]
# 33  [[joy], [anger, sadness], [anger], [anger], [j...  [148, 148, 148]
# 34  [[fear, surprise], [fear], [fear], [fear, surp...  [143, 143, 143]

# %%
def build_prompt(row):
    
    utterances = row.utterance
    speakers = row.speaker_id
    emotions = row.emotions_c
    
    pg_utterances =
