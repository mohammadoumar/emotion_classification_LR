# %%
import sys
import torch
import pickle
import argparse
import pandas as pd

# sys.path.append('../')

from pathlib import Path
from tqdm.notebook import tqdm
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM

# %%
model_id = "unsloth/llama-3-8b-Instruct-bnb-4bit"
k = 20

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

embedding_tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased")
embedding_model = AutoModel.from_pretrained("google-bert/bert-base-uncased").to(device)
# Out:
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
inference_tokenizer = AutoTokenizer.from_pretrained(model_id, padding='left', padding_side='left')
#inference_tokenizer = AutoTokenizer.from_pretrained(model_id, padding_side='left')
inference_tokenizer.pad_token = inference_tokenizer.eos_token
terminators = [inference_tokenizer.eos_token_id, inference_tokenizer.convert_tokens_to_ids("<|eot_id|>")]

generation_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
# Out:
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.

# %%
def get_utterance_embeddings(df):    
    
    
    utterance_embed_d = {}

    for utterance in tqdm(df.utterance):
        # print(utterance)
        while True:
            try:
                inputs = embedding_tokenizer(utterance, return_tensors="pt").to(device)
                output = embedding_model(**inputs)
                embedding = output[1][0].squeeze().cpu()
                utterance_embed_d[utterance] = embedding.detach().numpy()
                break
            except Exception as e:
                print(e)
                
    return utterance_embed_d

# %%
emotion_map = {
    'AN': 'anger',
    'DI': 'disgust',
    'FE': 'fear',
    'SA': 'sadness',
    'SU': 'surprise',
    'JO': 'joy'
}

def extract_emotions(row):

    emotion_str = row.emotion

    if emotion_str == 'Neutral':
        return ['neutral']

    emotions = emotion_str.split('-')
    tags = []

    for emotion in emotions:
        abbrev = emotion[:2]  # Get the abbreviation
        value_part = emotion[2:]  # Get the value part
        
        # Ensure that the value part is a valid integer and abbrev is in the emotion_map
        if abbrev in emotion_map and value_part.isdigit():
            value = int(value_part)
            if value > 0:
                tags.append(emotion_map[abbrev].lower())
        else:
            print(f"Warning: Skipping invalid emotion entry: '{emotion}'")
    return tags

# %%
CURRENT_DIR = Path.cwd()
EAC_DIR = Path(CURRENT_DIR) / "emotion_analysis_comics"
ICL_DIR = Path(CURRENT_DIR) / "incontext_learning"
DATASET_DIR = Path(EAC_DIR) / "dataset_files"
OUTPUT_DIR = Path(EAC_DIR) / "incontext_learning" / "results" / f"comics35_icl_{model_id.split('/')[1]}"

# %%
OUTPUT_DIR
# Out:
# PosixPath('/Utilisateurs/umushtaq/emotion_analysis_comics/incontext_learning/results/comics35_icl_llama-3-8b-Instruct-bnb-4bit')

# %%
df = pd.read_csv(DATASET_DIR / "comics_dataset.csv")
df['emotions_list'] = df.apply(lambda row: extract_emotions(row), axis=1)

# %%
utterance_embed_d = get_utterance_embeddings(df)
df['utterance_embedding'] = df.utterance.apply(lambda x: utterance_embed_d[x])

train_df = df[df.split == "TRAIN"].reset_index(drop=True)
test_df = df[df.split == "TEST"].reset_index(drop=True)
# Out:
#   0%|          | 0/7129 [00:00<?, ?it/s]

# %%
import torch
import random
from operator import itemgetter
import torch.nn.functional as F

device = 'cuda' if torch.cuda.is_available() else 'cpu'

def get_k_neighbours(k, utterance, train_df, test_df):
    
    
    test_utterance_embedding = test_df[test_df.utterance == utterance]["utterance_embedding"].values[0]
    #test_utterance_embedding = torch.tensor(test_utterance_embedding)#.to(device)

    utterance_embed_d = {}
    for e in train_df.iterrows():
        if e[1].utterance not in utterance_embed_d:
            #utterance_embed_d[e[1].utterance] = e[1].utterance_embedding
            utterance_embed_d[e[1].utterance] = e[1].utterance_embedding#.to(device)

    # train_titles = set(df[df.split == 'TRAIN'].title.unique())
    train_utterances = set(train_df.utterance)

    dist_l = []
    for t, v in utterance_embed_d.items():
        if t in train_utterances:
            # d = cos_sim(title_embed_d[title], v)
            d = F.cosine_similarity(torch.tensor(test_utterance_embedding), torch.tensor(v), dim=0)
            dist_l.append((t, d.item()))

    sorted_dist_l = sorted(dist_l, key=itemgetter(1), reverse=True)
    
    return sorted_dist_l[0: k]

def prepare_similar_example_prompts(utterance, k, train_df, test_df, seed=33):
    """
    Create a part of prompt made of k examples in the train set, whose topic is most similar to a given title.
    """

    random.seed(seed)

    neighbours_l = get_k_neighbours(2*k, utterance, train_df=train_df, test_df=test_df) # Fetch the 2*k closest neighbors
    # print(neighbours_l)
    sampled_neighbours_l = random.sample(neighbours_l, k) # Only keep k of them
    # bprint(sampled_neighbours_l)

    prompt = ''
    cnt = 0
    for i, (utterance, dist) in enumerate(sampled_neighbours_l):
        prompt += f'EXAMPLE {i+1}\n'

        example_df = train_df[train_df.utterance == utterance]
        # example_df = example_df[example_df.aty != 'none'].reset_index()
        
        class_l = []
        for k in example_df.iterrows():
            
            # if k[0] == 0:

            #     prompt += f'# Abstract:\n{example_df.iloc[0].utterance}\n\n# Arguments:\n'
            #     cnt = 0
                
            # prompt += f'Argument {cnt + 1}={k[1].text} - Class={k[1].aty}\n'
            prompt += f'Input: {k[1].utterance}'
            class_l.append(k[1].emotions_list)
            cnt += 1
            
        prompt += '\nOutput: '
        prompt += '{' + ', '.join([f'"list_emotion_classes": "{class_l[i]}"' for i in range(len(class_l))]) + '}'
        prompt += '\n\n'

    return prompt

# %%
def build_instruction():
    
    emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
    formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
    instruction = f"""### Emotion Analysis Expert Role

You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.

INPUT:
- You will receive a single utterance from a comic book
- The utterance may express one or multiple emotions
- You will receive {k} example utterances and their emotion classifications
- Given example utterances and their emotion classifications, analyze the new utterance following the same pattern

TASK:
1. Carefully analyze the emotional context and tone of the utterance
2. Identify applicable emotions from the following classes:
   {formatted_classes}

OUTPUT REQUIREMENTS:
- Format: JSON object with a single key "list_emotion_classes"
- Value: Array of one or more emotion classes as strings
- Example: {{"list_emotion_classes": ["anger", "fear"]}}

IMPORTANT NOTES:
- Do not include any explanations in the output, only the JSON object

"""
    return instruction

# %%
instruction = build_instruction()

# %%
sys_msg_l = []
task_msg_l = []

# %%
# test_df = test_df[:10]

# %%
test_df.shape
# Out:
# (1326, 13)

# %%
for row in tqdm(test_df.iterrows(), total=len(test_df)):
    
    sys_msg = {"role": "user", "content": instruction + "EXAMPLES:\n\n" + prepare_similar_example_prompts(row[1].utterance, k, train_df=train_df, test_df=test_df)}
    #sys_msg = {"role":"system", "content": "### Task description: You are an expert biomedical assistant that takes 1) an abstract text, 2) the list of all arguments from this abstract text, and must classify all arguments into one of two classes: Claim or Premise. " + proportion_desc + " You must absolutely not generate any text or explanation other than the following JSON format {\"Argument 1\": <predicted class for Argument 1 (str)>, ..., \"Argument n\": <predicted class for Argument n (str)>}\n\n### Class definitions:" + " Claim = " + claim_fulldesc + " Premise = " + premise_fulldesc + "\n\n### Examples:\n\n" + prepare_similar_example_prompts(title_l[i], experiment_df, k=3, seed=seed)}  # Sample by similar title
    task_msg = {"role": "assistant", "content": f"Now classify this utternace:\nInput: {row[1].utterance}\nOutput: "}
    
    sys_msg_l.append(sys_msg)
    task_msg_l.append(task_msg)
# Out:
#   0%|          | 0/1326 [00:00<?, ?it/s]

# %%
print(sys_msg_l[0]['content'])
# Out:
# ### Emotion Analysis Expert Role
#
# You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.
#
# INPUT:
# - You will receive a single utterance from a comic book
# - The utterance may express one or multiple emotions
# - You will receive 20 example utterances and their emotion classifications
# - Given example utterances and their emotion classifications, analyze the new utterance following the same pattern
#
# TASK:
# 1. Carefully analyze the emotional context and tone of the utterance
# 2. Identify applicable emotions from the following classes:
#    "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"
#
# OUTPUT REQUIREMENTS:
# - Format: JSON object with a single key "list_emotion_classes"
# - Value: Array of one or more emotion classes as strings
# - Example: {"list_emotion_classes": ["anger", "fear"]}
#
# IMPORTANT NOTES:
# - Do not include any explanations in the output, only the JSON object
#
# EXAMPLES:
#
# EXAMPLE 1
# Input: WAKEY, WAKEY, YOU OLD FART.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 2
# Input: THANK YOU, CHILD.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 3
# Input: GIMME YOUR BEST SHOT.
# Output: {"list_emotion_classes": "['anger']"}
#
# EXAMPLE 4
# Input: I'M SORRY, GIRL.
# Output: {"list_emotion_classes": "['sadness']"}
#
# EXAMPLE 5
# Input: LET'S LOOK.
# Output: {"list_emotion_classes": "['neutral']"}
#
# EXAMPLE 6
# Input: YOU OUGHT KNOW BETTER THAN TO WATCH THAT STUFF.
# Output: {"list_emotion_classes": "['anger']"}
#
# EXAMPLE 7
# Input: SHUSH.
# Output: {"list_emotion_classes": "['anger', 'fear']"}
#
# EXAMPLE 8
# Input: ALL IS FORGIVEN, YOU LOVELY WOMAN YOU.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 9
# Input: DOWNTOWN, KID FLASH.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 10
# Input: THIS IS A WASTE OF TIME.
# Output: {"list_emotion_classes": "['anger', 'sadness']"}
#
# EXAMPLE 11
# Input: SAY NO MORE, MISTER WINTERS.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 12
# Input: HOPE WE'RE RIGHT.
# Output: {"list_emotion_classes": "['sadness', 'joy']"}
#
# EXAMPLE 13
# Input: IT'S TIME TO ROLL!
# Output: {"list_emotion_classes": "['anger', 'fear']"}
#
# EXAMPLE 14
# Input: Send the sucker. That's me. Today at least.
# Output: {"list_emotion_classes": "['sadness']"}
#
# EXAMPLE 15
# Input: I ENVY YOU, AMERICAN.
# Output: {"list_emotion_classes": "['anger']"}
#
# EXAMPLE 16
# Input: THERE WE GO, ALL SET.
# Output: {"list_emotion_classes": "['joy']"}
#
# EXAMPLE 17
# Input: YEAH, WE GOT YOU SURROUNDED, DUDE.
# Output: {"list_emotion_classes": "['surprise']"}
#
# EXAMPLE 18
# Input: VERY WELL.
# Output: {"list_emotion_classes": "['anger']"}
#
# EXAMPLE 19
# Input: WE ARE SO DEAD.
# Output: {"list_emotion_classes": "['disgust', 'fear', 'sadness']"}
#
# EXAMPLE 20
# Input: RIGHT YOU ARE, MA'AM.
# Output: {"list_emotion_classes": "['anger']"}

# %%
print(task_msg_l[0]['content'])
# Out:
# Now classify this utternace:
# Input: TIME TO FACE OUR FEARS, PEOPLE…
# Output:

# %%
prepared_sys_task_msg_l = []

for i in range(len(sys_msg_l)):
    prepared_sys_task_msg_l.append([sys_msg_l[i], task_msg_l[i]])

# %%
def batch_tensor(tensor, batch_size):
    return [tensor[i:i+batch_size] for i in range(0, tensor.size(0), batch_size)]

# %%
inputs = inference_tokenizer.apply_chat_template(
            prepared_sys_task_msg_l,
            #pad_token = inference_tokenizer.eos_token,
            padding=True,
            truncation=True,
            add_generation_prompt=True,
            return_dict=True,
            return_tensors="pt",
)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
BATCH_SIZE = 16

input_ids_batches = batch_tensor(inputs['input_ids'], BATCH_SIZE) # type: ignore
attention_mask_batches = batch_tensor(inputs['attention_mask'], BATCH_SIZE) # type: ignore

# %%
generated_outputs = []

for i, (input_ids_batch, attention_mask_batch) in tqdm(enumerate(zip(input_ids_batches, attention_mask_batches)), total=len(input_ids_batches)):
    
    print(f"\n\n ***** Processing batch {i + 1} *****\n\n")
    
    inputs = {
        'input_ids': input_ids_batch.to(generation_model.device), # type: ignore
        'attention_mask': attention_mask_batch.to(generation_model.device) # type: ignore
    }

    outputs = generation_model.generate(
    **inputs,
    max_new_tokens=64,
    pad_token_id=inference_tokenizer.eos_token_id,
    eos_token_id=terminators,
    do_sample=True,
    temperature=0.1,
    top_p=0.9,
    )
    
    generated_outputs.append(outputs)
# Out:
#   0%|          | 0/83 [00:00<?, ?it/s]
#  ***** Processing batch 1 *****
#
#
#
#
#  ***** Processing batch 2 *****
#
#
#
#
#  ***** Processing batch 3 *****
#
#
#
#
#  ***** Processing batch 4 *****
#
#
#
#
#  ***** Processing batch 5 *****
#
#
#
#
#  ***** Processing batch 6 *****
#
#
#
#
#  ***** Processing batch 7 *****
#
#
#
#
#  ***** Processing batch 8 *****
#
#
#
#
#  ***** Processing batch 9 *****
#
#
#
#
#  ***** Processing batch 10 *****
#
#
#
#
#  ***** Processing batch 11 *****
#
#
#
#
#  ***** Processing batch 12 *****
#
#
#
#
#  ***** Processing batch 13 *****
#
#
#
#
#  ***** Processing batch 14 *****
#
#
#
#
#  ***** Processing batch 15 *****
#
#
#
#
#  ***** Processing batch 16 *****
#
#
#
#
#  ***** Processing batch 17 *****
#
#
#
#
#  ***** Processing batch 18 *****
#
#
#
#
#  ***** Processing batch 19 *****
#
#
#
#
#  ***** Processing batch 20 *****
#
#
#
#
#  ***** Processing batch 21 *****
#
#
#
#
#  ***** Processing batch 22 *****
#
#
#
#
#  ***** Processing batch 23 *****
#
#
#
#
#  ***** Processing batch 24 *****
#
#
#
#
#  ***** Processing batch 25 *****
#
#
#
#
#  ***** Processing batch 26 *****
#
#
#
#
#  ***** Processing batch 27 *****
#
#
#
#
#  ***** Processing batch 28 *****
#
#
#
#
#  ***** Processing batch 29 *****
#
#
#
#
#  ***** Processing batch 30 *****
#
#
#
#
#  ***** Processing batch 31 *****
#
#
#
#
#  ***** Processing batch 32 *****
#
#
#
#
#  ***** Processing batch 33 *****
#
#
#
#
#  ***** Processing batch 34 *****
#
#
#
#
#  ***** Processing batch 35 *****
#
#
#
#
#  ***** Processing batch 36 *****
#
#
#
#
#  ***** Processing batch 37 *****
#
#
#
#
#  ***** Processing batch 38 *****
#
#
#
#
#  ***** Processing batch 39 *****
#
#
#
#
#  ***** Processing batch 40 *****
#
#
#
#
#  ***** Processing batch 41 *****
#
#
#
#
#  ***** Processing batch 42 *****
#
#
#
#
#  ***** Processing batch 43 *****
#
#
#
#
#  ***** Processing batch 44 *****
#
#
#
#
#  ***** Processing batch 45 *****
#
#
#
#
#  ***** Processing batch 46 *****
#
#
#
#
#  ***** Processing batch 47 *****
#
#
#
#
#  ***** Processing batch 48 *****
#
#
#
#
#  ***** Processing batch 49 *****
#
#
#
#
#  ***** Processing batch 50 *****
#
#
#
#
#  ***** Processing batch 51 *****
#
#
#
#
#  ***** Processing batch 52 *****
#
#
#
#
#  ***** Processing batch 53 *****
#
#
#
#
#  ***** Processing batch 54 *****
#
#
#
#
#  ***** Processing batch 55 *****
#
#
#
#
#  ***** Processing batch 56 *****
#
#
#
#
#  ***** Processing batch 57 *****
#
#
#
#
#  ***** Processing batch 58 *****
#
#
#
#
#  ***** Processing batch 59 *****
#
#
#
#
#  ***** Processing batch 60 *****
#
#
#
#
#  ***** Processing batch 61 *****
#
#
#
#
#  ***** Processing batch 62 *****
#
#
#
#
#  ***** Processing batch 63 *****
#
#
#
#
#  ***** Processing batch 64 *****
#
#
#
#
#  ***** Processing batch 65 *****
#
#
#
#
#  ***** Processing batch 66 *****
#
#
#
#
#  ***** Processing batch 67 *****
#
#
#
#
#  ***** Processing batch 68 *****
#
#
#
#
#  ***** Processing batch 69 *****
#
#
#
#
#  ***** Processing batch 70 *****
#
#
#
#
#  ***** Processing batch 71 *****
#
#
#
#
#  ***** Processing batch 72 *****
#
#
#
#
#  ***** Processing batch 73 *****
#
#
#
#
#  ***** Processing batch 74 *****
#
#
#
#
#  ***** Processing batch 75 *****
#
#
#
#
#  ***** Processing batch 76 *****
#
#
#
#
#  ***** Processing batch 77 *****
#
#
#
#
#  ***** Processing batch 78 *****
#
#
#
#
#  ***** Processing batch 79 *****
#
#
#
#
#  ***** Processing batch 80 *****
#
#
#
#
#  ***** Processing batch 81 *****
#
#
#
#
#  ***** Processing batch 82 *****
#
#
#
#
#  ***** Processing batch 83 *****

# %%
decoded_outputs = []

for batch in generated_outputs:

    for prediction in batch:

        decoded_outputs.append(inference_tokenizer.decode(prediction[inputs['input_ids'].shape[1]:], skip_special_tokens=True)) # type: ignore

# %%
decoded_outputs
# Out:
# ['{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["neutral", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": "[\'sadness\']"}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "neutral"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["disgust", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'fear\', \'neutral\']"}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise", "fear"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["surprise", "neutral"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": "[\'disgust\', \'anger\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'fear\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'disgust\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\', \'disgust\']"}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["disgust", "fear"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\', \'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise", "fear"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness", "fear"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["fear", "joy"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "joy"]}',
#  '{"list_emotion_classes": ["anger", "fear", "disgust"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": "[\'joy\', \'anger\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'neutral\', \'joy\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["disgust", "fear"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["disgust", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["fear", "disgust"]}',
#  '{"list_emotion_classes": "[\'fear\',\'sadness\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "anger", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["sadness", "fear", "anger"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["neutral", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": "[\'fear\']"}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["fear", "anger", "disgust"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["disgust", "anger"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear", "joy"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "disgust", "sadness"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["sadness", "anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\',\'sadness\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\', \'fear\']"}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "neutral"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'surprise\',\'sadness\']"}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "caution"]}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\', \'anger\']"}',
#  '{"list_emotion_classes": ["fear", "disgust"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["fear", "caution"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'anger\']"}',
#  '{"list_emotion_classes": ["fear", "joy"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["neutral", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'fear\', \'disgust\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["disgust", "surprise"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "surprise", "fear"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\',\'sadness\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'disgust\', \'anger\']"}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "neutral"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": ["anger", "surprise", "disgust"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anticipation", "neutral"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\',\'sadness\']"}',
#  '{"list_emotion_classes": "[\'neutral\', \'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "disgust"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["disgust", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "sadness"]}',
#  '{"list_emotion_classes": "[\'disgust\',\'sadness\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'anger\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'sadness\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\', \'anger\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'neutral\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["curiosity", "anger"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["disgust", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "disgust", "sadness"]}',
#  '{"list_emotion_classes": ["disgust", "sadness"]}',
#  '{"list_emotion_classes": ["disgust", "anger"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["neutral", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["sadness", "neutral"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["disgust", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'disgust\',\'surprise\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "sadness", "neutral"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["sadness", "joy", "fear"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": "[\'fear\', \'anger\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness", "shame"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["disgust", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "disgust", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["sadness", "neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\', \'disgust\']"}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise", "fear"]}',
#  '{"list_emotion_classes": ["fear", "concern"]}',
#  '{"list_emotion_classes": ["fear", "surprise", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": ["joy", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["disgust", "joy"]}',
#  '{"list_emotion_classes": "[\'anger\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\',\'sadness\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "fear"]}',
#  '{"list_emotion_classes": "[\'sadness\', \'joy\']"}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\']"}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["curiosity", "joy"]}',
#  '{"list_emotion_classes": "[\'anger\',\'sadness\']"}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy", "sadness"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["fear", "sadness", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": "[\'neutral\',\'surprise\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["sadness", "hope"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\', \'anger\']"}',
#  '{"list_emotion_classes": "[\'surprise\', \'fear\']"}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": "[\'joy\', \'neutral\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "sadness", "fear"]}',
#  '{"list_emotion_classes": "[\'sadness\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": "[\'anger\', \'joy\']"}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["disgust", "anger"]}',
#  '{"list_emotion_classes": "[\'sadness\', \'disgust\']"}',
#  '{"list_emotion_classes": ["sadness", "disgust"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": "[\'disgust\', \'anger\']"}',
#  '{"list_emotion_classes": ["disgust", "sadness", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["anger", "fear", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["fear", "sadness", "surprise"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "neutral"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["surprise", "sadness"]}',
#  '{"list_emotion_classes": ["sadness", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'anger\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'neutral\',\'surprise\']"}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["sadness", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "disgust", "surprise"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["sadness"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": "[\'anger\',\'sadness\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["disgust", "sadness"]}',
#  '{"list_emotion_classes": ["neutral", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "anger"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "sadness"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["anger", "fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["joy", "neutral"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": ["surprise", "fear"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["joy", "anger"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "fear", "disgust"]}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": "[\'anger\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'sadness\',\'surprise\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "anger"]}',
#  '{"list_emotion_classes": ["anger", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["sadness", "joy"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["sadness", "anger"]}',
#  '{"list_emotion_classes": "[\'joy\',\'surprise\']"}',
#  '{"list_emotion_classes": ["anger", "neutral"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["anger"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["surprise"]}',
#  '{"list_emotion_classes": ["fear", "sadness"]}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": "[\'disgust\', \'anger\']"}',
#  '{"list_emotion_classes": ["anger", "disgust"]}',
#  '{"list_emotion_classes": "[\'anger\', \'neutral\']"}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'sadness\', \'fear\']"}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": "[\'surprise\']"}',
#  '{"list_emotion_classes": "[\'joy\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["joy", "surprise"]}',
#  '{"list_emotion_classes": ["neutral"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["surprise", "joy", "fear"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": ["anger", "joy"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": "[\'anger\', \'disgust\']"}',
#  '{"list_emotion_classes": ["surprise", "joy"]}',
#  '{"list_emotion_classes": "[\'fear\',\'surprise\', \'joy\']"}',
#  '{"list_emotion_classes": ["anger", "fear"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["fear", "surprise"]}',
#  '{"list_emotion_classes": ["joy"]}',
#  '{"list_emotion_classes": ["neutral", "joy"]}',
#  '{"list_emotion_classes": "[\'fear\',\'sadness\']"}',
#  ...]

# %%
grounds = test_df.emotions_list.tolist()

# %%
results_file = Path(OUTPUT_DIR) / f"results_{k}.pickle"
results_file.parent.mkdir(parents=True, exist_ok=True)

# %%
results_d = {"grounds": grounds,
            "predictions": decoded_outputs    
        
    }

# %%
with results_file.open('wb') as fh:
  
    pickle.dump(results_d, fh)

# %%
## Post process

# %%
import json

# %%
predictions_l = []

for i, prediction in enumerate(decoded_outputs):
        try:
            # Use json.loads to safely parse the JSON-like string
            parsed_prediction = json.loads(prediction)
            # Append the values of the parsed prediction to preds
            predictions_l.append(parsed_prediction["list_emotion_classes"])
            
        except json.JSONDecodeError as e:
            print(f"Error decoding prediction: {i}")

# %%
grounds
# Out:
# [['neutral'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['joy'],
#  ['disgust', 'fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness', 'surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['disgust', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['disgust', 'surprise'],
#  ['surprise'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['sadness', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise', 'joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['disgust', 'sadness'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['anger', 'fear', 'sadness', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['surprise'],
#  ['anger', 'sadness'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['surprise'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'sadness', 'surprise'],
#  ['anger', 'sadness'],
#  ['anger', 'surprise'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness', 'joy'],
#  ['fear', 'sadness', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['fear'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['anger', 'fear', 'sadness'],
#  ['joy'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'surprise', 'joy'],
#  ['fear', 'surprise', 'joy'],
#  ['fear', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['disgust'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['disgust'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'joy'],
#  ['anger', 'disgust', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'disgust', 'joy'],
#  ['disgust', 'surprise', 'joy'],
#  ['sadness', 'joy'],
#  ['surprise'],
#  ['fear', 'sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['anger', 'fear'],
#  ['sadness', 'surprise'],
#  ['fear'],
#  ['anger', 'sadness', 'surprise', 'joy'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'joy'],
#  ['fear'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['anger', 'sadness'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger', 'joy'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'disgust', 'joy'],
#  ['sadness'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger', 'disgust', 'sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger', 'disgust'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['neutral'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['anger', 'sadness', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ...]

# %%
predictions_l
# Out:
# [['fear', 'anger'],
#  "['joy']",
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral', 'fear'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['sadness', 'disgust'],
#  "['sadness']",
#  ['anger', 'fear', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise', 'anger'],
#  ['sadness', 'fear'],
#  "['anger']",
#  ['neutral'],
#  "['anger','surprise']",
#  ['fear', 'neutral'],
#  "['anger', 'disgust']",
#  "['fear','surprise']",
#  ['disgust', 'fear'],
#  ['surprise', 'joy'],
#  "['fear', 'neutral']",
#  ['sadness', 'disgust'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['anger', 'disgust'],
#  "['surprise', 'fear']",
#  ['joy'],
#  ['joy', 'sadness'],
#  ['anger', 'fear'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise', 'fear'],
#  "['surprise', 'joy']",
#  ['surprise', 'fear'],
#  "['surprise']",
#  "['surprise', 'fear']",
#  ['surprise', 'neutral'],
#  ['neutral', 'surprise'],
#  "['disgust', 'anger']",
#  "['anger', 'fear']",
#  "['fear']",
#  "['surprise', 'disgust', 'fear']",
#  "['anger','surprise', 'disgust']",
#  ['surprise', 'fear'],
#  ['disgust', 'fear'],
#  "['fear','surprise']",
#  ['anger', 'surprise'],
#  ['joy', 'anger'],
#  ['surprise'],
#  "['fear','surprise']",
#  "['neutral']",
#  ['neutral'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger', 'fear'],
#  "['neutral']",
#  ['fear', 'sadness'],
#  ['neutral'],
#  "['anger', 'disgust']",
#  ['anger', 'disgust'],
#  ['neutral', 'joy'],
#  "['joy', 'neutral']",
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise', 'fear'],
#  ['joy', 'surprise'],
#  "['fear','surprise']",
#  ['joy', 'surprise'],
#  ['surprise', 'fear'],
#  ['sadness', 'surprise'],
#  ['anger', 'sadness', 'fear'],
#  ['fear', 'anger'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  "['anger','surprise']",
#  ['surprise', 'fear'],
#  ['fear', 'joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['surprise', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'joy'],
#  ['anger', 'fear', 'disgust'],
#  ['surprise', 'anger'],
#  "['anger', 'disgust', 'fear']",
#  ['anger', 'sadness'],
#  "['neutral']",
#  ['sadness', 'joy'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['fear', 'sadness'],
#  "['anger', 'fear']",
#  ['sadness', 'disgust'],
#  ['fear', 'sadness'],
#  ['anger', 'surprise'],
#  "['joy', 'anger']",
#  ['joy'],
#  "['neutral', 'joy']",
#  ['anger', 'surprise'],
#  ['disgust', 'fear'],
#  "['fear','surprise']",
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  "['neutral']",
#  ['sadness'],
#  ['sadness'],
#  "['neutral']",
#  ['anger', 'sadness'],
#  ['anger', 'fear'],
#  ['sadness', 'fear'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['fear', 'anger'],
#  ['anger', 'surprise'],
#  ['fear', 'sadness'],
#  ['disgust', 'fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['sadness', 'fear'],
#  ['fear', 'sadness'],
#  ['sadness', 'anger'],
#  ['neutral'],
#  ['joy', 'sadness'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['sadness', 'fear'],
#  "['neutral']",
#  ['fear', 'surprise'],
#  ['sadness', 'anger'],
#  ['fear'],
#  "['neutral']",
#  ['anger', 'fear', 'surprise'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['sadness', 'fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['surprise', 'disgust'],
#  ['sadness', 'fear', 'surprise'],
#  "['anger','surprise']",
#  ['sadness', 'disgust'],
#  ['fear', 'anger'],
#  "['surprise', 'joy']",
#  ['sadness', 'fear'],
#  ['neutral', 'surprise'],
#  ['joy', 'sadness'],
#  ['fear', 'sadness'],
#  "['neutral']",
#  ['surprise', 'anger'],
#  "['neutral']",
#  ['fear', 'surprise'],
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness'],
#  "['surprise', 'fear']",
#  ['neutral'],
#  ['anger', 'sadness'],
#  ['sadness', 'fear'],
#  ['fear', 'disgust'],
#  "['fear','sadness']",
#  ['fear', 'surprise'],
#  "['neutral']",
#  ['surprise', 'fear'],
#  "['neutral']",
#  ['anger', 'fear'],
#  ['sadness', 'joy'],
#  "['neutral']",
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  "['neutral']",
#  ['sadness', 'anger'],
#  ['sadness', 'joy'],
#  "['neutral']",
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  "['fear','surprise']",
#  "['neutral']",
#  ['sadness'],
#  "['neutral']",
#  ['neutral'],
#  ['joy'],
#  ['neutral', 'joy'],
#  ['joy', 'neutral'],
#  "['neutral']",
#  "['joy']",
#  "['neutral']",
#  ['anger', 'fear'],
#  ['fear', 'anger', 'surprise'],
#  "['neutral']",
#  ['joy', 'neutral'],
#  "['neutral']",
#  "['surprise', 'fear']",
#  ['sadness', 'fear', 'anger'],
#  "['anger', 'fear']",
#  ['fear', 'sadness'],
#  ['joy', 'surprise'],
#  ['neutral', 'fear'],
#  ['surprise', 'anger'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  "['neutral']",
#  ['anger', 'disgust'],
#  ['anger', 'joy'],
#  "['joy']",
#  ['surprise', 'anger'],
#  ['neutral'],
#  ['anger', 'fear', 'sadness'],
#  ['joy', 'neutral'],
#  ['anger', 'fear'],
#  ['surprise', 'anger'],
#  ['fear', 'anger'],
#  ['fear', 'sadness'],
#  ['sadness', 'fear'],
#  ['surprise', 'joy'],
#  ['sadness', 'surprise'],
#  "['surprise', 'fear']",
#  ['anger', 'surprise'],
#  ['neutral', 'joy'],
#  "['joy']",
#  ['surprise'],
#  "['fear']",
#  ['sadness', 'anger'],
#  ['fear', 'anger', 'disgust'],
#  ['neutral', 'joy'],
#  ['surprise', 'sadness'],
#  ['joy', 'surprise'],
#  ['sadness', 'fear'],
#  ['neutral'],
#  "['joy']",
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['disgust', 'anger'],
#  ['surprise', 'anger'],
#  ['sadness', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'joy'],
#  "['anger', 'fear']",
#  "['surprise']",
#  ['anger', 'surprise'],
#  ['sadness', 'surprise'],
#  ['fear', 'disgust', 'sadness'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'neutral'],
#  ['sadness', 'anger', 'fear'],
#  ['fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['sadness', 'joy'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'fear'],
#  "['anger', 'fear','sadness']",
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness', 'anger'],
#  "['surprise']",
#  ['sadness', 'fear'],
#  ['anger', 'disgust'],
#  ['anger', 'sadness'],
#  "['anger', 'fear']",
#  "['anger', 'disgust', 'fear']",
#  ['fear', 'anger'],
#  ['anger', 'fear'],
#  ['anger', 'disgust'],
#  ['sadness', 'fear'],
#  ['anger', 'disgust', 'sadness'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['sadness', 'joy'],
#  ['anger', 'surprise'],
#  ['sadness', 'fear'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['joy', 'fear'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['surprise', 'fear'],
#  ['fear', 'sadness'],
#  ['sadness', 'joy'],
#  "['surprise']",
#  ['fear', 'surprise'],
#  "['neutral']",
#  ['sadness', 'fear'],
#  ['joy'],
#  ['surprise', 'sadness'],
#  ['sadness', 'fear'],
#  ['sadness', 'fear'],
#  ['fear'],
#  ['joy'],
#  ['surprise', 'neutral'],
#  ['joy', 'surprise'],
#  ['anger', 'sadness'],
#  "['joy']",
#  "['anger', 'disgust']",
#  "['anger', 'disgust']",
#  ['joy', 'sadness'],
#  ['anger', 'joy'],
#  "['anger', 'disgust']",
#  ['anger', 'sadness'],
#  ['fear', 'surprise'],
#  ['sadness', 'fear'],
#  ['joy', 'sadness'],
#  ['anger', 'fear'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['anger', 'disgust'],
#  ['sadness'],
#  "['surprise','sadness']",
#  ['sadness', 'anger'],
#  ['joy', 'sadness'],
#  ['fear', 'surprise'],
#  ['joy', 'surprise'],
#  ['fear', 'caution'],
#  ['anger', 'fear', 'surprise'],
#  "['surprise', 'fear', 'anger']",
#  ['fear', 'disgust'],
#  "['joy']",
#  ['fear', 'caution'],
#  ['joy'],
#  ['fear', 'anger'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['fear', 'anger'],
#  ['neutral', 'surprise'],
#  "['neutral']",
#  ['joy', 'neutral'],
#  "['neutral']",
#  ['neutral', 'joy'],
#  ['joy'],
#  ['surprise', 'fear'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  "['anger', 'fear']",
#  "['anger', 'disgust']",
#  ['joy'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust', 'surprise'],
#  ['anger', 'sadness'],
#  "['anger', 'disgust']",
#  ['anger', 'surprise'],
#  ['surprise', 'neutral'],
#  "['neutral']",
#  "['surprise', 'anger']",
#  ['fear', 'joy'],
#  "['surprise', 'joy']",
#  ['joy'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['anger', 'sadness'],
#  ['joy'],
#  "['anger','surprise']",
#  ['anger', 'fear'],
#  ['surprise', 'fear'],
#  ['anger', 'fear'],
#  ['sadness', 'joy'],
#  ['neutral', 'sadness'],
#  ['neutral'],
#  "['neutral']",
#  ['anger'],
#  "['surprise', 'joy']",
#  "['anger', 'fear']",
#  ['anger', 'neutral'],
#  ['anger', 'sadness'],
#  "['fear', 'disgust']",
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['joy', 'neutral'],
#  "['joy']",
#  "['anger', 'disgust']",
#  "['anger', 'fear']",
#  ['surprise', 'anger'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'surprise'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['sadness', 'surprise', 'fear'],
#  "['joy']",
#  ['anger', 'surprise'],
#  ['fear', 'sadness'],
#  "['anger','sadness']",
#  ['joy'],
#  ['neutral'],
#  ['sadness', 'fear'],
#  "['joy']",
#  ['sadness'],
#  "['joy']",
#  "['joy']",
#  ['sadness', 'joy'],
#  "['joy']",
#  ['anger', 'sadness'],
#  "['disgust', 'anger']",
#  ['neutral', 'joy'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness', 'neutral'],
#  ['joy', 'surprise'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy', 'anger'],
#  ['anger', 'surprise', 'disgust'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy', 'neutral'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['anticipation', 'neutral'],
#  ['joy', 'surprise'],
#  "['anger', 'fear','sadness']",
#  "['neutral', 'joy']",
#  ['surprise', 'disgust'],
#  "['anger','surprise']",
#  ['anger', 'sadness'],
#  "['anger','surprise']",
#  ['neutral', 'joy'],
#  ['joy', 'neutral'],
#  ['disgust', 'sadness'],
#  ['surprise', 'sadness'],
#  "['disgust','sadness']",
#  "['joy']",
#  "['surprise', 'anger']",
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy', 'surprise'],
#  ['surprise', 'joy'],
#  "['sadness', 'fear']",
#  "['surprise']",
#  ['anger', 'surprise'],
#  ['anger', 'fear'],
#  ['surprise', 'joy'],
#  ['surprise', 'fear'],
#  "['joy']",
#  "['anger','surprise']",
#  ['sadness', 'joy'],
#  "['neutral']",
#  ['neutral'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['joy', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  "['neutral', 'anger']",
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['joy', 'neutral'],
#  ['fear', 'surprise'],
#  ['anger', 'fear'],
#  ['fear', 'sadness'],
#  ['sadness', 'fear'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['sadness', 'fear'],
#  ['sadness'],
#  ['sadness'],
#  ['joy', 'surprise'],
#  ['joy', 'surprise'],
#  "['anger', 'fear']",
#  "['anger', 'fear']",
#  ['neutral'],
#  ['surprise', 'joy'],
#  "['neutral', 'fear']",
#  ['anger', 'disgust'],
#  ['sadness', 'anger'],
#  "['anger', 'fear','surprise']",
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['curiosity', 'anger'],
#  ['anger', 'disgust'],
#  ['surprise', 'joy'],
#  "['joy']",
#  "['fear','surprise']",
#  ['joy', 'anger'],
#  "['joy']",
#  ['anger', 'neutral'],
#  ['joy'],
#  ['disgust', 'surprise'],
#  ['anger', 'disgust'],
#  "['joy']",
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['fear', 'anger'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['anger', 'disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'anger'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['anger', 'disgust'],
#  ['anger', 'fear'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'sadness'],
#  "['anger']",
#  "['joy']",
#  ['joy', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy', 'surprise'],
#  ['neutral', 'joy'],
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['anger'],
#  ['joy', 'neutral'],
#  ['fear', 'surprise'],
#  "['neutral']",
#  ['neutral', 'joy'],
#  "['joy']",
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral', 'joy'],
#  ['surprise', 'anger'],
#  ['sadness'],
#  ['joy', 'surprise'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['joy', 'surprise'],
#  ['surprise'],
#  "['surprise']",
#  ['neutral', 'sadness'],
#  ['joy', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['sadness', 'neutral'],
#  "['surprise', 'fear']",
#  ['anger'],
#  ['anger', 'fear'],
#  ['neutral'],
#  ['surprise', 'fear'],
#  ['anger', 'sadness'],
#  "['anger']",
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['neutral', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  "['anger', 'disgust']",
#  ['sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'fear'],
#  ['surprise', 'joy'],
#  ['disgust', 'sadness'],
#  ['anger', 'fear', 'surprise'],
#  "['disgust','surprise']",
#  ['joy'],
#  ['anger', 'fear'],
#  "['surprise', 'joy']",
#  "['anger', 'fear']",
#  ['surprise'],
#  ['fear', 'surprise'],
#  "['anger','surprise']",
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  "['surprise', 'joy']",
#  ['anger', 'disgust'],
#  "['surprise', 'joy']",
#  ['surprise', 'sadness', 'neutral'],
#  ['joy', 'neutral'],
#  "['anger','surprise']",
#  "['joy']",
#  "['fear','surprise']",
#  ['joy'],
#  ['joy', 'surprise'],
#  "['surprise']",
#  ['neutral'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy', 'surprise'],
#  "['neutral']",
#  ['joy', 'surprise'],
#  ['anger', 'fear'],
#  "['joy']",
#  ['surprise', 'joy'],
#  "['joy']",
#  ['joy'],
#  "['joy']",
#  "['surprise']",
#  "['anger','surprise']",
#  ['surprise', 'fear'],
#  ['fear', 'surprise'],
#  "['surprise', 'joy']",
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['sadness', 'anger'],
#  ['neutral'],
#  "['neutral']",
#  ['fear', 'surprise'],
#  "['anger','surprise']",
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['neutral'],
#  ['anger', 'joy'],
#  ['fear', 'surprise'],
#  ['fear'],
#  "['surprise']",
#  ['fear', 'surprise'],
#  "['surprise']",
#  ['fear', 'surprise'],
#  "['anger']",
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['fear', 'anger'],
#  ['sadness', 'joy', 'fear'],
#  ['joy', 'sadness'],
#  "['fear', 'anger']",
#  "['surprise', 'fear']",
#  "['anger', 'fear','surprise']",
#  ['anger', 'fear'],
#  ['sadness'],
#  ['sadness', 'shame'],
#  ['sadness', 'anger'],
#  ['disgust', 'sadness'],
#  "['neutral']",
#  ['anger', 'disgust', 'fear'],
#  ['joy'],
#  ['neutral', 'joy'],
#  ['anger', 'fear'],
#  ['neutral'],
#  "['joy']",
#  ['joy'],
#  "['joy']",
#  ['sadness', 'neutral'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['neutral'],
#  "['surprise', 'fear']",
#  "['anger','surprise', 'disgust']",
#  ['surprise'],
#  ['anger', 'surprise', 'fear'],
#  ['fear', 'concern'],
#  ['fear', 'surprise', 'disgust'],
#  ['fear', 'anger'],
#  ['joy', 'fear'],
#  ['anger', 'sadness', 'surprise'],
#  ['joy'],
#  ['joy', 'anger'],
#  "['joy']",
#  ['joy'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  "['joy']",
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['sadness', 'fear'],
#  ['sadness', 'surprise'],
#  ['surprise', 'anger'],
#  ['neutral'],
#  "['anger', 'fear']",
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  "['joy']",
#  ['joy'],
#  ['anger', 'disgust'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'fear'],
#  ['joy', 'surprise'],
#  ['disgust', 'joy'],
#  "['anger', 'fear']",
#  "['anger', 'disgust']",
#  ['joy', 'neutral'],
#  ['surprise', 'fear'],
#  ['fear', 'surprise'],
#  ['joy', 'neutral'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  "['fear','surprise']",
#  ['fear', 'surprise'],
#  ['surprise', 'joy'],
#  "['joy']",
#  "['fear','surprise','sadness']",
#  ['anger', 'sadness'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['joy', 'fear'],
#  "['sadness', 'joy']",
#  "['anger']",
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['anger', 'disgust'],
#  ['sadness'],
#  "['neutral']",
#  ['neutral', 'joy'],
#  "['joy']",
#  ['anger', 'disgust'],
#  ['joy', 'neutral'],
#  ['neutral', 'joy'],
#  ['anger', 'disgust'],
#  ['curiosity', 'joy'],
#  "['anger','sadness']",
#  ['joy', 'surprise'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['joy', 'surprise'],
#  ['anger', 'sadness'],
#  ['anger', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy', 'sadness'],
#  ['joy'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'anger'],
#  "['neutral','surprise']",
#  ['sadness'],
#  ['joy', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness', 'hope'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  "['joy','surprise']",
#  "['joy','surprise']",
#  ['sadness', 'anger'],
#  ['anger', 'fear'],
#  "['surprise', 'fear']",
#  "['surprise', 'fear', 'anger']",
#  "['surprise', 'fear']",
#  "['joy','surprise']",
#  ['anger', 'sadness'],
#  ['anger', 'fear'],
#  "['surprise', 'joy']",
#  ['neutral'],
#  ['joy', 'anger'],
#  ['joy', 'surprise'],
#  ['sadness', 'anger'],
#  ['anger', 'fear'],
#  ['anger', 'disgust'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger', 'fear'],
#  ['joy', 'surprise'],
#  "['joy', 'neutral']",
#  ['anger', 'fear'],
#  ['surprise', 'sadness', 'fear'],
#  "['sadness']",
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['joy', 'neutral'],
#  ['joy', 'surprise'],
#  ['joy'],
#  ['sadness', 'fear'],
#  ['sadness', 'disgust'],
#  ['sadness', 'anger'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['sadness', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  "['anger', 'joy']",
#  ['sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['sadness', 'fear'],
#  ['disgust', 'anger'],
#  "['sadness', 'disgust']",
#  ['sadness', 'disgust'],
#  ['sadness', 'anger'],
#  "['disgust', 'anger']",
#  ['disgust', 'sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  "['fear','surprise']",
#  ['anger'],
#  ['anger', 'fear', 'surprise'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise'],
#  ['sadness'],
#  "['joy']",
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['neutral', 'surprise'],
#  ['anger', 'fear'],
#  ['fear', 'neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise', 'sadness'],
#  ['sadness', 'fear'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['surprise', 'joy'],
#  "['anger','surprise']",
#  ['anger', 'fear'],
#  ['anger', 'sadness'],
#  ['anger', 'surprise'],
#  ['anger', 'joy'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['joy', 'surprise'],
#  ['anger', 'sadness'],
#  "['neutral','surprise']",
#  ['surprise'],
#  "['joy','surprise']",
#  "['anger', 'disgust']",
#  ['sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'disgust'],
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['anger', 'disgust'],
#  ['anger', 'joy'],
#  "['joy']",
#  ['anger', 'surprise'],
#  ['neutral', 'surprise'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  "['joy','surprise']",
#  ['anger', 'disgust', 'surprise'],
#  ['joy', 'surprise'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['sadness', 'anger'],
#  ['anger', 'fear'],
#  ['sadness'],
#  ['sadness', 'anger'],
#  ['joy', 'anger'],
#  "['fear','surprise']",
#  ['anger', 'sadness'],
#  "['surprise']",
#  "['anger','sadness']",
#  ['surprise', 'joy'],
#  ['disgust', 'sadness'],
#  ['neutral', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'anger'],
#  "['fear','surprise']",
#  ['anger', 'sadness'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['fear', 'sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy', 'neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger', 'neutral'],
#  ['anger', 'fear'],
#  ['anger', 'joy'],
#  ['sadness', 'anger'],
#  ['surprise', 'fear'],
#  ['anger', 'joy'],
#  ['joy', 'anger'],
#  ['joy', 'surprise'],
#  ['anger', 'fear', 'disgust'],
#  ['anger', 'disgust'],
#  "['anger']",
#  ['joy'],
#  "['sadness','surprise']",
#  ['joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['surprise', 'anger'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['fear', 'surprise'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['sadness', 'anger'],
#  "['joy','surprise']",
#  ['anger', 'neutral'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear', 'sadness'],
#  ['anger', 'fear'],
#  ['surprise', 'joy'],
#  "['joy']",
#  "['joy']",
#  "['disgust', 'anger']",
#  ['anger', 'disgust'],
#  "['anger', 'neutral']",
#  ['joy'],
#  "['sadness', 'fear']",
#  ['neutral'],
#  "['surprise']",
#  "['joy']",
#  ['anger', 'fear'],
#  ['joy', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise', 'joy', 'fear'],
#  ['joy'],
#  ['neutral', 'joy'],
#  ['anger', 'joy'],
#  ['joy'],
#  "['anger', 'disgust']",
#  ['surprise', 'joy'],
#  "['fear','surprise', 'joy']",
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['neutral', 'joy'],
#  "['fear','sadness']",
#  ...]

# %%
len(grounds), len(predictions_l)
# Out:
# (1326, 1326)

# %%
import ast

# %%
predictions = []

for item in predictions_l:
    if isinstance(item, str):
        # Convert the string to a list using ast.literal_eval
        predictions.append(ast.literal_eval(item))
    else:
        # If the item is already a list, append as is
        predictions.append(item)

# %%
len(grounds), len(predictions_l)
# Out:
# (1326, 1326)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
def get_mlb(grounds, predictions):
    
    mlb = MultiLabelBinarizer()
    grounds_mhot = mlb.fit_transform(grounds)
    predictions_mhot = mlb.transform(predictions)
    
    return grounds_mhot, predictions_mhot, mlb.classes_

# %%
grounds_matrix, predictions_matrix, classes = get_mlb(grounds, predictions)
# Out:
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['anticipation', 'apology', 'caution', 'concern', 'curiosity', 'hope', 'relief', 'shame'] will be ignored
#   warnings.warn(

# %%
print(classification_report(grounds_matrix, predictions_matrix, target_names=classes, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        anger      0.520     0.566     0.542       454
#      disgust      0.155     0.400     0.223        50
#         fear      0.371     0.569     0.449       299
#          joy      0.503     0.589     0.543       297
#      neutral      0.261     0.440     0.328       109
#      sadness      0.497     0.433     0.463       344
#     surprise      0.510     0.648     0.571       355
#
#    micro avg      0.444     0.550     0.491      1908
#    macro avg      0.402     0.521     0.446      1908
# weighted avg      0.464     0.550     0.498      1908
#  samples avg      0.461     0.555     0.482      1908

# %%
classification_file = Path(OUTPUT_DIR) / f"classification_report_{k}.pickle"

with classification_file.open('wb') as fh:
    
    pickle.dump(classification_report(grounds_matrix, predictions_matrix, target_names=classes, output_dict=True), fh)
