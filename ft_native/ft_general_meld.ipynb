# %%
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

from peft import (
    LoraConfig,
    PeftModel,
    prepare_model_for_kbit_training,
    get_peft_model,
)

import pandas as pd
from tqdm import tqdm
import os, json, torch

from accelerate import PartialState
from trl import SFTTrainer, setup_chat_format
from datasets import Dataset, DatasetDict

from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %%
from huggingface_hub import login

hf_token = "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"
login(token = hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Utilisateurs/umushtaq/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Model and Tokenizer

# %%
base_model = "unsloth/Meta-Llama-3.1-8B-Instruct"

# %%
if torch.cuda.get_device_capability()[0] >= 8:
    # %pip install -qqq flash-attn
    torch_dtype = torch.bfloat16
    attn_implementation = "flash_attention_2"
else:
    torch_dtype = torch.float16
    attn_implementation = "eager"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch_dtype,
    bnb_4bit_use_double_quant=True,
)
# Load model
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
    device_map="auto",
    #device_map={"": PartialState().process_index},
    attn_implementation=attn_implementation
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Dataset

# %%
df_train = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/meld_FT/data_files/train_sent_emo.csv")
df_test = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/meld_FT/data_files/test_sent_emo.csv")
df_dev = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/meld_FT/data_files/dev_sent_emo.csv")

# %%
def build_instruction():
    emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
    formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])

    instruction = f"""### You are an Expert Emotion Classifier for Friends TV Show Utterances

You are given an utterance from a Friends episode.

STRICT CLASSIFICATION RULES:
1. ONLY use EXACTLY ONE emotion from this PREDEFINED list:
   {formatted_classes}
2. NO OTHER emotions are allowed under ANY circumstances

Output Instructions:
1. Return ONLY a valid JSON object with EXACTLY ONE emotion class
2. The JSON must have this EXACT structure: {{"emotion_class": "EMOTION"}}
3. The "emotion_class" MUST be one of the PREDEFINED emotions listed above
4. ANY deviation from these emotions is STRICTLY FORBIDDEN

CRITICAL CONSTRAINT: 
- ONLY the listed emotions are valid
- ANY other emotion is INVALID
- You CANNOT create or use ANY emotion not in the original list

Example Output:
{{"emotion_class": "disgust"}}

"""    
    return instruction

# %%
def build_response(utterance_emotion):    
                

    return json.dumps({"emotion_class": [utterance_emotion]})

# %%
def format_chat_template(row):
    
    utterance = row.Utterance
    utterance_emotions = row.Emotion
    
    row_json = [{"role": "system", "content": build_instruction()},
               {"role": "user", "content": f"""\n\nNow classify this utterance: {utterance}"""},
               {"role": "assistant", "content": build_response(utterance_emotions)}]
    
    input_text = tokenizer.apply_chat_template(row_json, tokenize=False)
    
    return input_text

# %%
df_train['input_text'] = df_train.apply(lambda row: format_chat_template(row), axis=1)
df_test['input_text'] = df_test.apply(lambda row: format_chat_template(row), axis=1)
df_dev['input_text'] = df_dev.apply(lambda row: format_chat_template(row), axis=1)

# %%
print(df_test.iloc[0]['input_text'])
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# ### You are an Expert Emotion Classifier for Friends TV Show Utterances
#
# You are given an utterance from a Friends episode.
#
# STRICT CLASSIFICATION RULES:
# 1. ONLY use EXACTLY ONE emotion from this PREDEFINED list:
#    "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"
# 2. NO OTHER emotions are allowed under ANY circumstances
#
# Output Instructions:
# 1. Return ONLY a valid JSON object with EXACTLY ONE emotion class
# 2. The JSON must have this EXACT structure: {"emotion_class": "EMOTION"}
# 3. The "emotion_class" MUST be one of the PREDEFINED emotions listed above
# 4. ANY deviation from these emotions is STRICTLY FORBIDDEN
#
# CRITICAL CONSTRAINT:
# - ONLY the listed emotions are valid
# - ANY other emotion is INVALID
# - You CANNOT create or use ANY emotion not in the original list
#
# Example Output:
# {"emotion_class": "disgust"}<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Now classify this utterance: Why do all you’re coffee mugs have numbers on the bottom?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# {"emotion_class": ["surprise"]}<|eot_id|>

# %%
len(df_test), len(df_train), len(df_dev)
# Out:
# (2610, 9989, 1109)

# %%
hf_train = Dataset.from_pandas(df_train, preserve_index=False)
hf_test = Dataset.from_pandas(df_test, preserve_index=False)
hf_eval = Dataset.from_pandas(df_dev, preserve_index=False)

# %%
hf_dataset = DatasetDict({
    "train": hf_train,
    "test": hf_test,
    "eval": hf_eval
})

# %%
print(hf_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Sr No.', 'Utterance', 'Speaker', 'Emotion', 'Sentiment', 'Dialogue_ID', 'Utterance_ID', 'Season', 'Episode', 'StartTime', 'EndTime', 'input_text'],
#         num_rows: 9989
#     })
#     test: Dataset({
#         features: ['Sr No.', 'Utterance', 'Speaker', 'Emotion', 'Sentiment', 'Dialogue_ID', 'Utterance_ID', 'Season', 'Episode', 'StartTime', 'EndTime', 'input_text'],
#         num_rows: 2610
#     })
#     eval: Dataset({
#         features: ['Sr No.', 'Utterance', 'Speaker', 'Emotion', 'Sentiment', 'Dialogue_ID', 'Utterance_ID', 'Season', 'Episode', 'StartTime', 'EndTime', 'input_text'],
#         num_rows: 1109
#     })
# })

# %% [markdown]
# ### LORA adapters

# %%
import bitsandbytes as bnb

def find_all_linear_names(model):
    cls = bnb.nn.Linear4bit
    lora_module_names = set()
    for name, module in model.named_modules():
        if isinstance(module, cls):
            names = name.split('.')
            lora_module_names.add(names[0] if len(names) == 1 else names[-1])
    if 'lm_head' in lora_module_names:  # needed for 16 bit
        lora_module_names.remove('lm_head')
    return list(lora_module_names)

modules = find_all_linear_names(model)

# %%
modules
# Out:
# ['k_proj', 'up_proj', 'v_proj', 'q_proj', 'o_proj', 'gate_proj', 'down_proj']

# %%
# LoRA config
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=modules
)
model, tokenizer = setup_chat_format(model, tokenizer)
model = get_peft_model(model, peft_config)

# %%
#Hyperparamter
training_arguments = TrainingArguments(
    output_dir="/Utilisateurs/umushtaq/emotion_analysis_comics/ft_native/meld_ft_llama3.1-8B",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=2,
    optim="paged_adamw_32bit",
    do_eval=False,
    num_train_epochs=3,
    eval_strategy="steps",
    eval_steps=0.2,
    logging_steps=1,
    warmup_steps=10,
    logging_strategy="steps",
    learning_rate=2e-4,
    fp16=False,
    bf16=False,
    group_by_length=True,
    #report_to="wandb"
)

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=hf_dataset['train'],
    eval_dataset=hf_dataset['eval'],
    peft_config=peft_config,
    max_seq_length= 512,
    dataset_text_field="input_text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing= False,
)
# Out:
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_seq_length, dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:280: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/9989 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1109 [00:00<?, ? examples/s]
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:408: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='936' max='936' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [936/936 1:34:29, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>188</td>
#       <td>0.078900</td>
#       <td>0.153588</td>
#     </tr>
#     <tr>
#       <td>376</td>
#       <td>0.179800</td>
#       <td>0.159182</td>
#     </tr>
#     <tr>
#       <td>564</td>
#       <td>0.343200</td>
#       <td>0.154551</td>
#     </tr>
#     <tr>
#       <td>752</td>
#       <td>0.107400</td>
#       <td>0.157724</td>
#     </tr>
#   </tbody>
# </table><p>
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/peft/utils/save_and_load.py:232: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# TrainOutput(global_step=936, training_loss=0.13986805952989903, metrics={'train_runtime': 5676.353, 'train_samples_per_second': 5.279, 'train_steps_per_second': 0.165, 'total_flos': 3.603475061641052e+17, 'train_loss': 0.13986805952989903, 'epoch': 2.9952})

# %%
messages = []

for example in hf_test:
    
    message = [{"role": "system", "content": build_instruction()},
               {"role": "user", "content": f"Now classify this utterance: {example['Utterance']}"}]

    
    messages.append(message)

# %%
len(messages)
# Out:
# 2610

# %%
prompts = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
tokenizer.padding_side = "left"

# %%
print(prompts[1])
# Out:
# <|im_start|>system
# ### You are an Expert Emotion Classifier for Friends TV Show Utterances
#
# You are given an utterance from a Friends episode.
#
# STRICT CLASSIFICATION RULES:
# 1. ONLY use EXACTLY ONE emotion from this PREDEFINED list:
#    "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"
# 2. NO OTHER emotions are allowed under ANY circumstances
#
# Output Instructions:
# 1. Return ONLY a valid JSON object with EXACTLY ONE emotion class
# 2. The JSON must have this EXACT structure: {"emotion_class": "EMOTION"}
# 3. The "emotion_class" MUST be one of the PREDEFINED emotions listed above
# 4. ANY deviation from these emotions is STRICTLY FORBIDDEN
#
# CRITICAL CONSTRAINT:
# - ONLY the listed emotions are valid
# - ANY other emotion is INVALID
# - You CANNOT create or use ANY emotion not in the original list
#
# Example Output:
# {"emotion_class": "disgust"}
#
# <|im_end|>
# <|im_start|>user
# Now classify this utterance: Oh. That’s so Monica can keep track. That way if one on them is missing, she can be like, ‘Where’s number 27?!’<|im_end|>
# <|im_start|>assistant

# %%
raw_responses = []

# %%
batch_size = 64
batches = [prompts[i:i + batch_size] for i in range(0, len(prompts), batch_size)]

# %%
for batch in tqdm(batches, desc="Processing batches"):
    # Tokenize the batch
    inputs = tokenizer(batch, return_tensors='pt', padding=True, truncation=True, return_attention_mask=True).to("cuda")
    
    # Generate responses for the batch
    outputs = model.generate(**inputs, max_new_tokens=128, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id,)
    
    generated_ids = outputs[:, inputs["input_ids"].shape[-1]:]
    
    # Decode and store the responses
    batch_responses = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    raw_responses.extend(batch_responses)
    #break
# Out:
# Processing batches:   0%|          | 0/41 [00:00<?, ?it/s]Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Processing batches: 100%|██████████| 41/41 [17:42<00:00, 25.93s/it]

# %%
len(raw_responses)
# Out:
# 2610

# %%
raw_responses
# Out:
# ['{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh my God!assistant\n\n{"neutral"}assistant\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: That’s a good one.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay.assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, so you’re just gonna take off without telling me?assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I\'ll see you tomorrow.assistant{"emotion_class": ["neutral"]}userneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can’t believe I’m doing this.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can\'t believe you\'re going to Russia!assistant{"emotion_class": ["surprise"]}assistant{"emotion_class": ["neutral"]}userassistantassistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, you betcha!assistant\n\n{"emotion_class": ["joy"]}anger"}neutral"}joy"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, come on!assistant\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry, I’m sorry.assistant\n\n{"emotion_class": ["sadness"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}sadness"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I\'ll be right there.assistant{"emotion_class": ["neutral"]}usersadness", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, so that\'s a five.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I know.assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I think you’re gonna find that I’m a very difficult man to get over.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh my God!assistant{"emotion_class": ["surprise"]}assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What? What?assistant{"emotion_class": ["surprise"]}assistant',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: All right, well, we\'ll just have to try again some other time.assistant{"neutral"}assistantassistant{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: All right, you guys have fun, I\'m gonna go find my brother.assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I\'m just gonna go over here and...assistant{"neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, I’m just gonna go home and watch some TV.assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I am not!assistant{"neutral"}anger"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So, you\'re a genius?assistant\n\n{"emotion_class": ["surprise"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can’t believe you’re going out with Joey.assistant{"neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry.assistant"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: Okay, I’m not gonna get a shot.assistantassistant"\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh my God!assistant{"neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: Ohh!neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"emotion_class": ["neutral"]}userneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: Yeah, I know.assistant{"emotion_class": ["neutral"]}assistantassistant',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: I know!assistant"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I\'m sorry.assistant{"neutral"}assistant',
#  '{"emotion_class": ["fear"]}user\n\nNow classify this utterance: Okay.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}userneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I mean, what if I were a woman?assistantanger"}assistantanger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, yeah!assistant\n\n{"emotion_class": ["joy"]}assistant\n\n{"emotion_class": ["neutral"]}joy"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What?!assistant"\n\n{"emotion_class": ["surprise"]}anger"}neutral"}joy"}neutral"}joy"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: You’re coming on to the entire room!  I’m Chandler.assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Well, I’m sorry.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What?assistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What?!assistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, I’m not the one who’s too afraid to tell her that he loves her.assistant["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can’t believe I’m here.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]} Classifier\n\nCRITICAL CONSTRAINT: \n- ONLY "neutral"\n- ANY other emotion is STRICTLY FORBIDDEN\n\nOutput Instructions:\n1. Return ONLY a valid JSON object with EXACTLY ONE emotion class\n2. The JSON must have this EXACT structure: {"emotion_class": "neutral"}\n3. The "emotion_class" MUST be "neutral"\n4. ANY deviation from this emotion is STRICTLY FORBIDDEN\n\nCRITICAL CONSTRAINT: \n- ONLY "neutral"\n- ANY other emotion is INVALID\n\nExample Output:\n{"emotion_class": ["neutral"]} Classifier\n\n',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What?!assistant{"neutral"]}assistant{"neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I know!assistant{"emotion_class": ["joy"]}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I’m gonna go get some coffee.assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: It’s-it’s the most beautiful thing I’ve ever seen.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: I don’t know.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So, do you uh, do you have a boyfriend?assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry.assistant{"emotion_class": ["sadness"]}assistant"}',
#  '{"emotion_class": ["neutral"]}assistant"]}',
#  '{"emotion_class": ["neutral"]}assistant\n\nNow classify this utterance: So you can like, bite, and pull people’s hair and stuff?user\n\nNow classify this utterance: What?assistant\n\n{"neutral"}assistant\n\nneutralanger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry, I’m sorry, I’m sorry.assistant\n\n{"emotion_class": ["sadness"]}assistant\n\n{"emotion_class": ["sadness"]}userassistant\n\n{"emotion_class": ["neutral"]}anger", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I mean, I’m not saying it’s impossible, but it’s like you said, it\'s a long shot.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}userassistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You’re welcome.assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: It’s a three hour drive.assistant{"neutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: Oh, Bob, he was nothing compared to you. I had to bite my lip to keep from screaming your name.assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}neutral',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: Oh, I’m so sorry!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, no, no.assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m gonna go home and tell my wife all about the amazing things I saw today.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}userjoy", "neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, no, no, no, no.assistant\n\n{"emotion_class": ["neutral"]}useranger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}anger"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, come on!assistant\n\n{"emotion_class": ["anger"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}userassistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}userassistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, we’re gonna have to get you some new pants.assistant{"emotion_class": ["neutral"]}assistantassistantassistantassistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no,',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: It’s not the first time I’ve been in this situation.assistant\n\n{"emotion_class": ["neutral"]}userneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I’m not!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: I don’t think that’s necessary.assistant\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry.assistant"\n\n{"emotion_class": ["sadness"]}neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]neutral"]',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So what’s the deal with you and your sister?assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"neutral_class": ["neutral"]}assistant\n\nNow classify this utterance: Okay, let\'s see.neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I don\'t.assistant\n\n{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m gonna go find Joey.assistant{"neutral"}assistantassistantassistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, you’re right.assistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["disgust"]}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Well, we’re just gonna have to get you some new pants.assistant"]}assistant"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh.  Oh, I’m sorry.assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: It’s all right.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: I don’t know, I’m just not ready to give up the bag.assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, Joey!assistant\n\n{"emotion_class": ["joy"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I think that you’ve been very unfair to Rachel.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral"]}emotion_class": ["neutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I mean, this is a once in a lifetime opportunity!assistant\n\n{"emotion_class": ["joy"]}assistant\n\n{"emotion_class": ["neutral"]}useranger"]}assistant\n\n{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, okay, okay, okay.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What?!assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, I got a question.assistantassistant{"neutral"}assistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, that’s okay.assistant{"emotion_class": ["neutral"]}joy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Well, I don’t know, how about I give you a choice?assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, this is great.assistant {"neutral"}assistant {"neutral"}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, I know.assistant"]}assistant"}joy"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, we’re gonna have to get you a new phone.assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: What?assistant{"neutral"}assistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I\'m sorry, I\'m sorry.assistant{"emotion_class": ["sadness"]}assistant"]}',
#  '{"emotion_class": ["sadness"]}user\n\nNow classify this utterance: Oh my God.assistant\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I mean, what are the odds?assistant"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No. No.',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry.assistant{"emotion_class": ["sadness"]}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m gonna go get some coffee.assistant"]}assistant"]}assistant"}assistant"}assistant"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Do you really want to throw that all away over a room?assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don’t know, I don’t know.assistant\n\n{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You didn’t.assistant"]}assistant"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh my God!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, you guys.assistant{"neutral"]}assistant{"neutral"]}userneutral"}assistant{"neutral"]}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: It\'s not the same thing!assistant\n\n{"emotion_class": ["anger"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry, I’m sorry, I’m sorry.assistant\n\n{"neutral"}assistant\n\n{"neutral"}usersadness", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, well, I-I-I-I’m sorry I didn’t get to spend more time with you.assistant{"neutral"]}assistant{"neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"neutral_class": ["neutral"]}assistant\n\nNow classify this utterance: Oh, I can’t believe I’m doing this.neutral_class": ["fear"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: That’s okay.assistant"\n\n{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I’ll do it.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, my God!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You have no idea.assistant{"emotion_class": ["neutral"]}assistantassistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So you’re not mad?assistant{"neutral"]}assistant{"neutral"}userassistant{"neutral"}assistant{"neutral"}anger"}assistant{"neutral"}anger"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don\'t know, maybe it\'s because I\'m a little older now, but I don\'t think it\'s as big a deal as you guys make it out to be.assistant{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I just can’t help myself.assistant{"neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: I know!assistant"]}assistant"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So you\'re a fan of the Knicks?assistantassistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["disgust"]}user\n\nNow classify this utterance: I’m sorry.assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}userjoy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: I’m sorry.assistant"\n\n{"emotion_class": ["neutral"]}joy", "sadness"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: Yeah.assistant"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yes. Yes I have.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, I’m gonna go get some coffee.assistant{"neutral"}assistant{"neutral"}\n{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, you are!assistant{"emotion_class": ["joy"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’ll be there in 20 minutes.assistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m gonna go get some coffee.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"neutral_class": ["neutral"]}user\n\nNow classify this utterance: I\'m sorry.assistant{"neutral_class": ["neutral"]}usersadness"}assistant{"neutral_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, you can’t!assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay.assistant{"emotion_class": ["neutral"]}assistantassistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, you\'re up.assistant{"neutral"]}assistantneutralassistantneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know,',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So, have you guys decided what you’re gonna do yet?assistantassistantneutral"}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry, I’m sorry.assistant{"emotion_class": ["sadness"]}assistant["neutral"]}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You’re gonna be so happy.assistant"]}assistant"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I can\'t believe you didn\'t tell me.assistantsadness"}anger"}neutral"}sadness"}joy"]}neutral"}joy"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, that\'s okay.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, that’s great!assistant{"neutral"}joy", "joy", "joy", "joy"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no,',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don’t know, I’m still mad at him.assistant{"emotion_class": ["anger"]}assistantuserassistantassistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}assistantassistantassistantassistantassistantassistantneutral"}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}class"}\n{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I\'m sorry.assistant{"emotion_class": ["neutral"]}joy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: Oh, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know, I know',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I\'m telling you, this is a real opportunity for me.assistantassistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I\'m sorry.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["anger"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So?assistant\n\n{"emotion_class": ["neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I\'m sorry.assistant{"emotion_class": ["sadness"]}assistantuserassistant{"emotion_class": ["neutral"]}assistantassistant',
#  '{"emotion_class": ["anger"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I know!assistant\n\n{"emotion_class": ["joy"]}assistant\n\n{"emotion_class": ["neutral"]}userneutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You are so dead.assistant{"neutral"]}assistant{"neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I am so sorry.assistant{"emotion_class": ["sadness"]}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"neutral"}assistant',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: I can’t believe this!assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"neutral_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant"\n\n{"neutral_class": ["neutral"]}joy"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry, you’re not supposed to know yet.assistant{"neutral"}assistantneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["disgust"]}user\n\nNow classify this utterance: I’m sorry.assistant{"emotion_class": ["sadness"]}assistantneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["disgust"]}assistant\n\nNow classify this utterance: Oh, I cannot believe he’s using our divorce to sell mattresses.user\n\nNow classify this utterance: No, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: I know!assistant{"emotion_class": ["neutral"]}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: And four ninety-nine for a pillow top queen set, who cares about the divorce, those babies will sell themselves.assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["disgust"]}user\n\nNow classify this utterance: Oh, yeah, yeah.assistant{"neutral"}assistant{"neutral"}',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: And I don’t care what you say, I know you’re gonna be there.assistant{"neutral"}assistantjoy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["disgust"]}user\n\nNow classify this utterance: Hey!assistant{"emotion_class": ["joy"]}assistant{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don\'t think that\'s gonna happen.assistant{"neutral"}assistantneutralassistantneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I know. I know.assistant{"emotion_class": ["neutral"]}userneutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
# ...
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}neutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: That’s right.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}joy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"emotion_class": ["neutral"]}assistantassistantassistant',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: Well, I’m gonna go get some food.assistant{"emotion_class": ["neutral"]}assistant',
#  '{"neutral_class": ["neutral"]}user\n\nNow classify this utterance: Well, it’s not like I’m gonna be able to go out with him or anything.assistant{"neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral_class": ["neutral',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: All right, all right, I’ll do it.assistant{"neutral_class": ["neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I’m sorry.assistant{"emotion_class": ["sadness"]}assistantassistant',
#  '{"emotion_class": ["neutral"]}userassistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}userassistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}assistant"\n\n{"emotion_class": ["neutral"]}anger", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry, I didn’t realize you had a problem with your pants falling off.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}anger", "neutral"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, you can stay.assistant{"emotion_class": ["neutral"]} Classifier\n\nCRITICAL CONSTRAINT: \n- ONLY the listed emotions are valid\n- ANY other emotion is INVALID\n- You CANNOT create or use ANY emotion not in the original listassistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}{"emotion_class": ["neutral"]}{"emotion_class": ["neutral"]}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, I\'ve been thinking about that a lot.assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, but I’m telling you, if I had to choose between you and Ross, I would choose you.assistant{"neutral"}assistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, Pheebs, what-what are you doing here?assistant{"neutral"}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I mean, I\'m 33, I\'m single, I don\'t have any kids.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I think I\'m gonna do this one myself.assistant{"emotion_class": ["neutral"]}userassistant{"emotion_class": ["neutral"]}anger"}anger"}anger"}',
#  '{"emotion_class": ["surprise"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: All right, I\'ll be out in a minute.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey!assistant"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}assistant\n\nNow classify this utterance: I\'m not, I\'m not, I\'m not.user\n\nNow classify this utterance: Oh, hey, so you\'re gonna be at the party tonight?assistant\n\n{"neutral"}assistant\n\nNow classify this utterance: Oh, I\'m so sorry.assistant\n\nNow classify this utterance: So, what\'s the deal?assistant\n\n{"neutral"}user\n\nNow classify this utterance: Yeah.assistant\n\nNow classify this',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Well, I’m just gonna go on in there and tell them how I feel.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}useranger"}sadness"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["joy"]}user\n\nNow classify this utterance: You got a problem with that?assistant{"emotion_class": ["neutral"]}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, I just can’t help myself.assistant["neutral"]}assistant',
#  '{"emotion_class": ["neutral"]}assistant\n\nNow classify this utterance: Yeah, I can do that.assistant\n\nNow classify this utterance: You don’t have to do that.assistant\n\nNow classify this utterance: Okay, I\'ll be right there.neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I know.assistant{"emotion_class": ["neutral"]}useranger", "neutral"}assistant {"emotion_class": ["neutral"]}assistant {"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Hey, y\'know what you should do? You should take her back to the 1890\'s, when that phrase was last used.assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Well, I’m gonna go.assistant"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I\'m not gonna let you do that.assistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, okay, I’m sorry.assistant{"emotion_class": ["neutral"]}assistant',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: You kissed my best Ross!...Or something to that effect.assistant{"emotion_class": ["neutral"]}assistant',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Okay, okay, I’ll go.assistant{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I know, I know, it\'s just that, I\'m just really, really, really, really nervous about this.assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh!assistant{"emotion_class": ["surprise"]}{"emotion_class": ["neutral"]}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}{"neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can\'t believe you\'re doing this to me.assistant{"neutral"}anger"}neutral"}sadness"}sadness"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["sadness"]}user\n\nNow classify this utterance: I\'m sorry, honey, I promise it will never happen again.assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}assistant{"emotion_class": ["neutral"]}："neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant\n\n{"neutral"}assistant\n\n{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don’t know.assistant\n\n{"emotion_class": ["neutral"]}userneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Yeah, I’m pretty sure that’s what she meant.assistantassistantneutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You can’t keep it in your pants can you?assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: You\'re not gonna believe what I just did.assistantassistantanger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: What? What’s wrong with that?assistant["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: That’s right!assistant"]}assistant"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: So you’re just gonna go out with her again?assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}anger"}assistant\n\n{"neutral"}assistant\n\n{"neutral"}',
#  '{"emotion_class": ["anger"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I don’t think I can do this.assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, it’s okay, I’m just mad at you.assistant\n\n{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}neutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutralneutral',
#  '{"emotion_class": ["surprise"]}user\n\nNow classify this utterance: Oh, you’re right.assistant\n\n{"neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["neutral"]}assistant\n\n{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: And the whole time I was thinking, "I\'m gonna get him, I\'m gonna get him."assistant\n\n{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: Oh!assistant"\n\n{"emotion_class": ["surprise"]}anger"}neutral"}joy"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral',
#  '{"emotion_class": ["anger"]}user\n\nNow classify this utterance: I’m sorry.assistant{"emotion_class": ["sadness"]}assistantjoy", "neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: I can’t believe you’re doing this!assistant{"neutral"]}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}anger"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: You’re not gonna tell him are you?assistant{"neutral"}anger"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: No, I’m telling you, this is a good thing.assistantassistantassistantjoy", "neutral"}assistant',
#  '{"neutral_class": ["neutral"]}user\n\nNow classify this utterance: I don’t think so.assistant{"neutral_class": ["neutral"]}neutral_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}',
#  ...]

# %%
raw_responses[3]
# Out:
# '{"emotion_class": ["neutral"]}user\n\nNow classify this utterance: Oh, I’m sorry.assistant{"emotion_class": ["neutral"]}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}neutral"}'

# %%
predictions = []
bad_idx = []

for i, response in enumerate(raw_responses):
    
    try:
    
        resp = json.loads(response.split("user")[0])["emotion_class"]
        predictions.append(resp)
        
    except:
        print(i)
        bad_idx.append(i)
# Out:
# 0
# 9
# 10
# 24
# 44
# 50
# 51
# 53
# 54
# 56
# 62
# 73
# 74
# 77
# 82
# 83
# 84
# 105
# 108
# 125
# 126
# 130
# 140
# 144
# 145
# 147
# 152
# 155
# 166
# 167
# 171
# 181
# 184
# 186
# 209
# 210
# 211
# 219
# 223
# 224
# 236
# 249
# 255
# 258
# 267
# 270
# 279
# 280
# 283
# 284
# 295
# 296
# 301
# 316
# 321
# 326
# 338
# 339
# 342
# 343
# 350
# 357
# 358
# 365
# 366
# 367
# 368
# 381
# 386
# 387
# 388
# 393
# 412
# 415
# 434
# 437
# 445
# 448
# 451
# 452
# 453
# 455
# 460
# 462
# 464
# 466
# 467
# 472
# 476
# 477
# 479
# 480
# 484
# 486
# 487
# 490
# 493
# 503
# 511
# 526
# 530
# 564
# 566
# 571
# 572
# 577
# 578
# 588
# 590
# 592
# 595
# 597
# 601
# 602
# 604
# 605
# 612
# 613
# 617
# 620
# 621
# 628
# 632
# 634
# 636
# 637
# 641
# 649
# 650
# 651
# 655
# 660
# 661
# 664
# 677
# 685
# 688
# 690
# 692
# 695
# 698
# 699
# 700
# 716
# 723
# 724
# 735
# 737
# 740
# 741
# 742
# 743
# 745
# 753
# 755
# 762
# 763
# 771
# 781
# 782
# 784
# 785
# 786
# 792
# 800
# 804
# 812
# 831
# 835
# 837
# 839
# 840
# 847
# 849
# 851
# 855
# 858
# 866
# 869
# 870
# 877
# 878
# 883
# 899
# 900
# 902
# 909
# 911
# 917
# 922
# 924
# 931
# 933
# 934
# 940
# 949
# 950
# 953
# 964
# 966
# 967
# 970
# 985
# 989
# 990
# 991
# 993
# 999
# 1009
# 1010
# 1014
# 1016
# 1020
# 1023
# 1036
# 1039
# 1058
# 1059
# 1067
# 1074
# 1094
# 1096
# 1101
# 1110
# 1114
# 1115
# 1116
# 1117
# 1119
# 1120
# 1124
# 1131
# 1133
# 1134
# 1144
# 1146
# 1149
# 1153
# 1154
# 1157
# 1159
# 1163
# 1171
# 1175
# 1180
# 1182
# 1188
# 1189
# 1190
# 1199
# 1200
# 1201
# 1203
# 1205
# 1214
# 1219
# 1228
# 1231
# 1234
# 1237
# 1239
# 1241
# 1242
# 1243
# 1245
# 1248
# 1263
# 1266
# 1267
# 1269
# 1270
# 1272
# 1289
# 1290
# 1291
# 1303
# 1305
# 1309
# 1311
# 1313
# 1327
# 1337
# 1338
# 1342
# 1343
# 1351
# 1352
# 1353
# 1365
# 1369
# 1371
# 1389
# 1394
# 1402
# 1423
# 1431
# 1437
# 1438
# 1439
# 1440
# 1451
# 1461
# 1470
# 1473
# 1474
# 1479
# 1483
# 1488
# 1498
# 1506
# 1515
# 1516
# 1527
# 1530
# 1532
# 1535
# 1539
# 1540
# 1550
# 1551
# 1552
# 1556
# 1571
# 1573
# 1576
# 1577
# 1581
# 1582
# 1584
# 1585
# 1587
# 1590
# 1592
# 1595
# 1596
# 1597
# 1600
# 1602
# 1603
# 1604
# 1605
# 1612
# 1622
# 1627
# 1628
# 1652
# 1655
# 1666
# 1668
# 1669
# 1672
# 1674
# 1675
# 1677
# 1689
# 1696
# 1701
# 1715
# 1724
# 1732
# 1733
# 1735
# 1738
# 1742
# 1758
# 1774
# 1777
# 1780
# 1782
# 1792
# 1793
# 1795
# 1796
# 1802
# 1803
# 1805
# 1813
# 1814
# 1815
# 1817
# 1821
# 1825
# 1832
# 1843
# 1844
# 1859
# 1860
# 1869
# 1870
# 1877
# 1878
# 1883
# 1884
# 1887
# 1891
# 1898
# 1905
# 1919
# 1922
# 1934
# 1935
# 1938
# 1940
# 1941
# 1942
# 1964
# 1965
# 1966
# 1968
# 1969
# 1975
# 1981
# 1982
# 1985
# 1986
# 1987
# 1988
# 1990
# 2003
# 2020
# 2034
# 2036
# 2049
# 2052
# 2059
# 2067
# 2070
# 2079
# 2080
# 2084
# 2085
# 2086
# 2088
# 2091
# 2095
# 2098
# 2100
# 2109
# 2117
# 2130
# 2134
# 2137
# 2139
# 2143
# 2145
# 2152
# 2154
# 2159
# 2163
# 2165
# 2167
# 2181
# 2182
# 2194
# 2196
# 2197
# 2218
# 2220
# 2227
# 2231
# 2235
# 2240
# 2241
# 2258
# 2259
# 2263
# 2269
# 2276
# 2278
# 2281
# 2282
# 2283
# 2308
# 2312
# 2332
# 2348
# 2349
# 2356
# 2357
# 2366
# 2377
# 2383
# 2406
# 2408
# 2412
# 2416
# 2422
# 2423
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2445
# 2451
# 2453
# 2454
# 2457
# 2470
# 2471
# 2475
# 2477
# 2478
# 2479
# 2481
# 2486
# 2490
# 2495
# 2498
# 2499
# 2501
# 2503
# 2505
# 2506
# 2507
# 2508
# 2509
# 2516
# 2522
# 2536
# 2547
# 2548
# 2551
# 2554
# 2557
# 2558
# 2562
# 2564
# 2565
# 2578
# 2583
# 2584
# 2592
# 2595
# 2596
# 2597
# 2599
# 2606
# 2608

# %%
len(predictions)
# Out:
# 2070

# %%
predictions
# Out:
# [['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ...]

# %%
# def obtain_emotions(x):

#     utterance_emotions = x.emotion
#     utterance_emotions_l = []
#     emotion_class_labels = ["Anger", "Disgust", "Fear", "Sadness", "Surprise", "Joy"]

#     if utterance_emotions == 'Neutral':
        
#         utterance_emotions_l.append(utterance_emotions)
    
#     else:
#         utterance_emotions = utterance_emotions.split("-")

#         for idx, emotion_annotation in enumerate(utterance_emotions):

#             if '0' not in emotion_annotation:
        
#                 utterance_emotions_l.append(emotion_class_labels[idx])
                

#     return utterance_emotions_l

# %%
#df_test["emotions_c"] = df_test.apply(lambda x: obtain_emotions(x), axis=1)

# %%
grounds = df_test.Emotion.tolist()

# %%
len(grounds)
# Out:
# 2610

# %%
grounds
# Out:
# ['surprise',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'surprise',
#  'anger',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'anger',
#  'disgust',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'surprise',
#  'neutral',
#  'fear',
#  'disgust',
#  'anger',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'fear',
#  'neutral',
#  'sadness',
#  'surprise',
#  'surprise',
#  'neutral',
#  'surprise',
#  'anger',
#  'sadness',
#  'sadness',
#  'neutral',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'sadness',
#  'anger',
#  'anger',
#  'anger',
#  'sadness',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'anger',
#  'anger',
#  'anger',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'joy',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'sadness',
#  'disgust',
#  'anger',
#  'disgust',
#  'neutral',
#  'fear',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'sadness',
#  'anger',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'anger',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'anger',
#  'surprise',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'surprise',
#  'surprise',
#  'fear',
#  'joy',
#  'neutral',
#  'neutral',
#  'fear',
#  'joy',
#  'joy',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'surprise',
#  'disgust',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'disgust',
#  'joy',
#  'surprise',
#  'anger',
#  'surprise',
#  'disgust',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'surprise',
#  'anger',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'anger',
#  'fear',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'surprise',
#  'anger',
#  'surprise',
#  'disgust',
#  'neutral',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'disgust',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'surprise',
#  'neutral',
#  'anger',
#  'anger',
#  'surprise',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'sadness',
#  'sadness',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'disgust',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'anger',
#  'fear',
#  'neutral',
#  'joy',
#  'surprise',
#  'sadness',
#  'anger',
#  'anger',
#  'surprise',
#  'disgust',
#  'surprise',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'surprise',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'surprise',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'anger',
#  'neutral',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'disgust',
#  'disgust',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'sadness',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'surprise',
#  'joy',
#  'surprise',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'fear',
#  'neutral',
#  'joy',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'fear',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'surprise',
#  'neutral',
#  'anger',
#  'anger',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'disgust',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'surprise',
#  'sadness',
#  'neutral',
#  'sadness',
#  'anger',
#  'anger',
#  'anger',
#  'sadness',
#  'neutral',
#  'surprise',
#  'anger',
#  'anger',
#  'disgust',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'disgust',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'sadness',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'anger',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'joy',
#  'joy',
#  'anger',
#  'neutral',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'fear',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'disgust',
#  'joy',
#  'neutral',
#  'anger',
#  'disgust',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'joy',
#  'surprise',
#  'anger',
#  'surprise',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'fear',
#  'neutral',
#  'neutral',
#  'fear',
#  'sadness',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'neutral',
#  'anger',
#  'sadness',
#  'anger',
#  'sadness',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'fear',
#  'surprise',
#  'anger',
#  'surprise',
#  'joy',
#  'surprise',
#  'neutral',
#  'anger',
#  'fear',
#  'anger',
#  'anger',
#  'neutral',
#  'disgust',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'joy',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'disgust',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'surprise',
#  'surprise',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'surprise',
#  'surprise',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'sadness',
#  'joy',
#  'disgust',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'sadness',
#  'anger',
#  'sadness',
#  'sadness',
#  'sadness',
#  'fear',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'disgust',
#  'surprise',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  ...]

# %%
predictions
# Out:
# [['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ...]

# %%
grounds = [[x] for x in grounds]

# %%
grounds
# Out:
# [['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ...]

# %%
#predictions = [x if not isinstance(x, list) or not any(isinstance(i, list) for i in x) else ['Neutral'] for x in predictions]

# %%
# #predictions = [x[0] for x in predictions]
# preds = []

# for prediction in predictions:
    
#     preds.append(prediction[0])

# %%
#len(preds)

# %%
#preds

# %%
grounds
# Out:
# [['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ...]

# %%
grounds = [item for idx, item in enumerate(grounds) if idx not in bad_idx]

# %%
len(grounds)
# Out:
# 2070

# %%
grounds
# Out:
# [['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['fear'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['joy'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['sadness'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['disgust'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['sadness'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['disgust'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['fear'],
#  ['joy'],
#  ...]

# %%
predictions
# Out:
# [['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['neutral'],
#  ['disgust'],
#  ['anger'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['anger'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ...]

# %%
mlb = MultiLabelBinarizer()

# %%
y_true_mhot = mlb.fit_transform(grounds)
y_pred_mhot = mlb.transform(predictions)

# %%
y_true_mhot.shape
# Out:
# (2070, 7)

# %%
y_pred_mhot.shape
# Out:
# (2070, 7)

# %%
mlb.classes_
# Out:
# array(['anger', 'disgust', 'fear', 'joy', 'neutral', 'sadness',
#        'surprise'], dtype=object)

# %%
print(classification_report(y_true_mhot, y_pred_mhot, target_names=mlb.classes_, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        anger      0.590     0.187     0.284       246
#      disgust      0.611     0.234     0.338        47
#         fear      0.357     0.119     0.179        42
#          joy      0.708     0.299     0.420       365
#      neutral      0.583     0.959     0.726      1002
#      sadness      0.615     0.142     0.231       169
#     surprise      0.658     0.397     0.495       199
#
#    micro avg      0.597     0.597     0.597      2070
#    macro avg      0.589     0.334     0.382      2070
# weighted avg      0.612     0.597     0.537      2070
#  samples avg      0.597     0.597     0.597      2070
