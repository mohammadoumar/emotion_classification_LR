# %%
import json
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from itertools import chain
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### Read data

# %%
# Load the pickled list
with open("/Utilisateurs/umushtaq/emotion_analysis_comics/finetuning/saved_models/comics35_llama-3-8b-Instruct-bnb-4bit/comics35_results_2.pickle", 'rb') as f:
    
    results = pickle.load(f)

# %%
results
# Out:
# {'grounds': ['{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Disgust", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Disgust", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Disgust", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Disgust", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#   '{"list_emotion_classes": ["Disgust", "Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness", "Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Fear", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Disgust"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Surprise"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger", "Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust"]}',
#   '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger", "Sadness"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Sadness"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Fear"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Surprise", "Joy"]}',
#   '{"list_emotion_classes": ["Fear", "Surprise"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger", "Fear"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Surprise"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": [["Neutral"]]}',
#   '{"list_emotion_classes": ["Joy"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   '{"list_emotion_classes": ["Anger"]}',
#   ...],
#  'predictions': [{'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
# ...
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#   {'role': 'assistant',
#    'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#   {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#   ...]}

# %%
#all_labels = ["Anger", "Disgust", "Fear", "Sadness", "Surprise", "Joy"]

# %%
grounds = results['grounds']
predictions = results['predictions']

# %%
len(grounds), len(predictions)
# Out:
# (1326, 1326)

# %%
grounds
# Out:
# ['{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Disgust", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Disgust", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Disgust", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Disgust", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#  '{"list_emotion_classes": ["Disgust", "Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness", "Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Fear", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Disgust"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Surprise"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger", "Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust"]}',
#  '{"list_emotion_classes": ["Anger", "Disgust", "Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Sadness", "Surprise"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger", "Sadness"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Sadness"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Fear"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Surprise", "Joy"]}',
#  '{"list_emotion_classes": ["Fear", "Surprise"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger", "Fear"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Surprise"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": [["Neutral"]]}',
#  '{"list_emotion_classes": ["Joy"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  '{"list_emotion_classes": ["Anger"]}',
#  ...]

# %%
predictions
# Out:
# [{'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Disgust", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
# ...
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Sadness", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Surprise", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Disgust"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": [["Neutral"]]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Fear", "Surprise"]}'},
#  {'role': 'assistant',
#   'content': '{"list_emotion_classes": ["Anger", "Sadness"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Joy"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Anger"]}'},
#  {'role': 'assistant', 'content': '{"list_emotion_classes": ["Fear"]}'},
#  ...]

# %%
grounds = [json.loads(x)["list_emotion_classes"] for x in grounds]

# %%
predictions = [json.loads(x["content"]) for x in predictions]

# %%
len(grounds), len(predictions)
# Out:
# (1326, 1326)

# %%
predictions = [x['list_emotion_classes'] for x in predictions]

# %%
len(grounds), len(predictions)
# Out:
# (1326, 1326)

# %%
grounds
# Out:
# [[['Neutral']],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Joy'],
#  ['Disgust', 'Fear', 'Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness', 'Surprise'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear'],
#  ['Disgust', 'Surprise'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Disgust', 'Surprise'],
#  ['Surprise'],
#  ['Disgust', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Sadness', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Surprise', 'Joy'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Sadness'],
#  ['Joy'],
#  ['Disgust', 'Sadness'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Fear', 'Sadness', 'Surprise'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Joy'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear'],
#  [['Neutral']],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Anger', 'Fear', 'Sadness'],
#  [['Neutral']],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  [['Neutral']],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Sadness'],
#  [['Neutral']],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  [['Neutral']],
#  ['Fear'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Surprise'],
#  ['Anger', 'Sadness'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Sadness'],
#  ['Sadness', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Surprise'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Anger', 'Sadness', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Surprise'],
#  ['Surprise', 'Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise', 'Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Sadness', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Sadness', 'Joy'],
#  ['Fear', 'Sadness', 'Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Fear'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear'],
#  [['Neutral']],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear'],
#  ['Joy'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear'],
#  ['Anger'],
#  [['Neutral']],
#  ['Fear'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness', 'Surprise'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust', 'Sadness'],
#  ['Anger', 'Disgust', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Fear', 'Surprise', 'Joy'],
#  ['Fear', 'Surprise', 'Joy'],
#  ['Fear', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Disgust'],
#  ['Disgust'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear'],
#  ['Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  [['Neutral']],
#  ['Joy'],
#  ['Fear'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  [['Neutral']],
#  ['Fear'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear'],
#  ['Anger', 'Fear'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Disgust'],
#  ['Fear'],
#  [['Neutral']],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Disgust'],
#  [['Neutral']],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  [['Neutral']],
#  ['Surprise', 'Joy'],
#  ['Surprise'],
#  ['Surprise'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  [['Neutral']],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger', 'Fear'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Disgust', 'Joy'],
#  ['Anger', 'Disgust', 'Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Disgust', 'Joy'],
#  ['Disgust', 'Surprise', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Surprise'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Fear'],
#  ['Sadness', 'Surprise'],
#  ['Fear'],
#  ['Anger', 'Sadness', 'Surprise', 'Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear'],
#  ['Anger', 'Joy'],
#  ['Fear'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Fear'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Anger', 'Joy'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Disgust', 'Joy'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Anger', 'Disgust', 'Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Disgust', 'Sadness'],
#  ['Disgust', 'Sadness'],
#  ['Disgust', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness', 'Joy'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Surprise'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Anger', 'Fear'],
#  ['Fear'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Surprise', 'Joy'],
#  [['Neutral']],
#  ['Anger', 'Fear'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Disgust'],
#  [['Neutral']],
#  [['Neutral']],
#  [['Neutral']],
#  ['Disgust'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Anger', 'Disgust'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  [['Neutral']],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Anger'],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust', 'Sadness'],
#  ['Anger'],
#  [['Neutral']],
#  ['Joy'],
#  ['Anger', 'Sadness', 'Surprise'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Anger'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ...]

# %%
predictions
# Out:
# [['Anger', 'Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  [['Neutral']],
#  ['Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  [['Neutral']],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Anger', 'Disgust'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear'],
#  ['Fear'],
#  ['Anger'],
#  [['Neutral']],
#  ['Sadness'],
#  [['Neutral']],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Surprise'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Fear'],
#  ['Surprise'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger', 'Fear'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Anger', 'Fear'],
#  ['Sadness'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Fear'],
#  ['Anger', 'Sadness'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness', 'Joy'],
#  ['Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  [['Neutral']],
#  ['Fear'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Sadness'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear'],
#  ['Fear'],
#  ['Anger'],
#  ['Joy'],
#  [['Neutral']],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Fear'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear', 'Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Surprise'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness', 'Surprise'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear'],
#  ['Sadness', 'Surprise'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Fear'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger'],
#  [['Neutral']],
#  [['Neutral']],
#  ['Joy'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger', 'Surprise'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger', 'Joy'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger', 'Joy'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Anger'],
#  ['Sadness', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Fear'],
#  ['Sadness'],
#  ['Disgust', 'Sadness'],
#  ['Surprise'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger'],
#  ['Fear'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Fear'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear'],
#  ['Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Joy'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Joy'],
#  ['Sadness'],
#  ['Sadness', 'Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Joy'],
#  ['Surprise', 'Joy'],
#  ['Sadness', 'Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Anger'],
#  ['Sadness'],
#  ['Anger', 'Fear'],
#  ['Anger', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Fear'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear'],
#  ['Sadness'],
#  ['Joy'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear'],
#  ['Surprise'],
#  ['Fear'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Anger'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Fear', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Joy'],
#  ['Surprise'],
#  ['Fear', 'Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Sadness', 'Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear', 'Joy'],
#  ['Sadness'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Joy'],
#  ['Anger', 'Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  [['Neutral']],
#  ['Anger', 'Fear'],
#  ['Sadness'],
#  ['Joy'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness', 'Surprise'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Surprise', 'Joy'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Sadness'],
#  ['Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Anger', 'Fear'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Anger'],
#  ['Sadness'],
#  ['Fear'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Fear', 'Sadness'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Fear'],
#  ['Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Sadness'],
#  ['Surprise'],
#  [['Neutral']],
#  ['Sadness'],
#  ['Anger', 'Disgust'],
#  ['Sadness'],
#  ['Anger', 'Sadness'],
#  ['Fear'],
#  ['Anger'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Surprise'],
#  ['Anger', 'Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Anger', 'Sadness'],
#  ['Sadness'],
#  ['Sadness'],
#  ['Anger'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Joy'],
#  ['Sadness'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger', 'Joy'],
#  ['Joy'],
#  ['Anger'],
#  ['Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Anger', 'Disgust'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  ['Anger'],
#  [['Neutral']],
#  ['Joy'],
#  ['Anger', 'Fear', 'Sadness'],
#  ['Surprise'],
#  ['Anger'],
#  ['Joy'],
#  ['Sadness'],
#  ['Fear'],
#  ['Surprise'],
#  ['Surprise'],
#  ['Sadness'],
#  ['Fear'],
#  ['Anger', 'Joy'],
#  ['Fear', 'Surprise'],
#  ['Anger'],
#  ['Anger', 'Sadness'],
#  ['Fear'],
#  ['Surprise'],
#  ['Fear', 'Sadness'],
#  ['Fear'],
#  ['Surprise'],
#  ['Joy'],
#  ['Joy'],
#  ['Anger', 'Disgust'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger', 'Surprise'],
#  [['Neutral']],
#  ['Surprise'],
#  ['Joy'],
#  ['Anger', 'Sadness'],
#  ['Joy'],
#  ['Joy'],
#  ['Fear'],
#  ['Fear', 'Surprise'],
#  ['Joy'],
#  ['Anger'],
#  ['Anger'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear', 'Surprise'],
#  ['Anger', 'Sadness'],
#  ['Anger'],
#  ['Anger'],
#  ['Fear'],
#  ['Joy'],
#  ['Anger'],
#  ['Fear'],
#  ...]

# %%
grounds = [['Neutral'] if elem == [['Neutral']] else elem for elem in grounds]
predictions = [['Neutral'] if elem == [['Neutral']] else elem for elem in predictions]

# %%
len(grounds), len(predictions)
# Out:
# (1326, 1326)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()

# %%
y_true_mhot = mlb.fit_transform(grounds)

# %%
y_true_mhot.shape
# Out:
# (1326, 7)

# %%
y_pred_mhot = mlb.transform(predictions)

# %%
y_pred_mhot.shape
# Out:
# (1326, 7)

# %%
class_labels = mlb.classes_

# %%
class_labels
# Out:
# array(['Anger', 'Disgust', 'Fear', 'Joy', 'Neutral', 'Sadness',
#        'Surprise'], dtype=object)

# %%
print(classification_report(y_true_mhot, y_pred_mhot, target_names=class_labels, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        Anger      0.539     0.557     0.548       454
#      Disgust      0.303     0.200     0.241        50
#         Fear      0.474     0.488     0.481       299
#          Joy      0.531     0.556     0.543       297
#      Neutral      0.708     0.156     0.256       109
#      Sadness      0.487     0.445     0.465       344
#     Surprise      0.687     0.563     0.619       355
#
#    micro avg      0.539     0.495     0.516      1908
#    macro avg      0.533     0.424     0.450      1908
# weighted avg      0.549     0.495     0.510      1908
#  samples avg      0.547     0.508     0.506      1908

# %%
with open("/Utilisateurs/umushtaq/emotion_analysis_comics/finetuning/saved_models/comics35_llama-3-8b-Instruct-bnb-4bit/classification_report_2.pickle", 'wb') as fh:
    
    pickle.dump(classification_report(y_true_mhot, y_pred_mhot, target_names=class_labels, digits=3, output_dict=True), fh)
