# %% [markdown]
# # Data Pre-Processing

# %%
import json
import pandas as pd

from pathlib import Path

# %%
CURRENT_DIR = Path.cwd()
#EAC_DIR = CURRENT_DIR.parent.parent
EAC_DIR = Path(CURRENT_DIR) / "emotion_analysis_comics"

# %%
EAC_DIR
# Out:
# PosixPath('/Utilisateurs/umushtaq/emotion_analysis_comics')

# %%
DATA_FILE = Path(EAC_DIR) / "dataset_files" / "comics_dataset.csv"
DATASET_DIR = Path(EAC_DIR) / "finetuning" / "datasets"

# %%
df = pd.read_csv(DATA_FILE, index_col=False)

# %%
def get_unique_emotion(row):

    utterance_emotions = row.emotion

    utterance_emotions_l = []
    emotion_class_labels = ["anger", "disgust", "fear", "sadness", "surprise", "joy"]

    if utterance_emotions == 'Neutral':
        
        utterance_emotions_l.append('neutral')
    
    else:
        utterance_emotions = utterance_emotions.split("-")
       
        #emotion_annotation_l = []

        for idx, emotion_annotation in enumerate(utterance_emotions):

            if '0' not in emotion_annotation:
         
                #emotion_annotation_l.append(emotion_class_labels[idx])
                #utterance_emotions_l.append(emotion_annotation[:-1])
                utterance_emotions_l.append(emotion_class_labels[idx])

    return utterance_emotions_l

# %%
df['emotion_c'] = df.apply(lambda row: get_unique_emotion(row), axis=1)

# %%
# Page level

# %%
grouped_df = df.groupby(['file_name', 'page_nr', 'split']).agg({
    'utterance': list,
    'emotion_c': list
}).reset_index()

# %%
grouped_df['split'].value_counts()
# Out:
# split
# TRAIN    718
# TEST     156
# Name: count, dtype: int64

# %%
grouped_df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1    [NO--  #GKKK…#, #CHOMP!, BY THE SKIN OF MATILD...
# 2    [COME ON, BEAST!, SHOW YOURSELF!, WHY DO YOU H...
# 3                                           [#AARGH! ]
# 4    [I, THE GREEN TORCH, HAVE BEEN TASKED WITH PRO...
# ..                                                 ...
# 869  [WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO ...
# 870  [SO WHAT ARE WE GOING TO DO?, THE WAY I SEE IT...
# 871  [KIDDIE COUNCIL'S BEEN GOING A LONG TIME... , ...
# 872  [IT'S BEEN… PEACEFUL. ASIDE FROM SHIT LIKE THI...
# 873              [" AND PAY OUR NEIGHBOURS A VISIT. "]
#
#                                              emotion_c
# 0    [[anger], [anger], [fear], [fear], [fear, sadn...
# 1    [[fear], [anger], [surprise], [anger], [joy], ...
# 2                     [[joy], [joy], [anger], [anger]]
# 3                                   [[fear, surprise]]
# 4    [[anger], [anger], [fear], [fear, surprise], [...
# ..                                                 ...
# 869  [[anger], [anger], [anger], [anger], [anger, s...
# 870  [[sadness, surprise], [anger], [anger], [anger...
# 871  [[anger, sadness], [anger], [anger], [anger], ...
# 872  [[anger], [joy], [joy], [anger, surprise], [an...
# 873                                     [[anger, joy]]
#
# [874 rows x 5 columns]

# %%
train_df = grouped_df[grouped_df.split == "TRAIN"].reset_index(drop=True)

# %%
train_df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 713  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       16  TRAIN
# 714  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       17  TRAIN
# 715  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       18  TRAIN
# 716  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       19  TRAIN
# 717  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       20  TRAIN
#
#                                              utterance  \
# 0    [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 1    [NO--  #GKKK…#, #CHOMP!, BY THE SKIN OF MATILD...
# 2    [COME ON, BEAST!, SHOW YOURSELF!, WHY DO YOU H...
# 3                                           [#AARGH! ]
# 4    [I, THE GREEN TORCH, HAVE BEEN TASKED WITH PRO...
# ..                                                 ...
# 713  [YOU BETTER HOPE I FORGET THAT SHIT JUST FELL ...
# 714  [IT'S NOTHING--, YOU TOUCH IT --AND I TAKE THE...
# 715  [YOU BRING EVERYTHING ABOUT THIS TO HIM., TOMO...
# 716  [ASK YOU ONE MORE TIME, SON--, THE FUCK DID YO...
# 717  [COHEN, HERE--, @AGENT COHEN, IT'S EMMA., @I N...
#
#                                              emotion_c
# 0    [[anger], [anger], [fear], [fear], [fear, sadn...
# 1    [[fear], [anger], [surprise], [anger], [joy], ...
# 2                     [[joy], [joy], [anger], [anger]]
# 3                                   [[fear, surprise]]
# 4    [[anger], [anger], [fear], [fear, surprise], [...
# ..                                                 ...
# 713  [[anger, disgust], [anger], [anger], [anger], ...
# 714  [[fear, surprise], [anger], [anger], [neutral]...
# 715  [[neutral], [neutral], [neutral], [sadness], [...
# 716  [[anger], [anger], [sadness], [fear], [sadness...
# 717                            [[joy], [fear], [fear]]
#
# [718 rows x 5 columns]

# %%
train_emotions_l = train_df.emotion_c.tolist()

# %%
len(train_emotions_l)
# Out:
# 718

# %%
train_emotions_l
# Out:
# [[['anger'],
#   ['anger'],
#   ['fear'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['anger'],
#   ['surprise'],
#   ['surprise'],
#   ['fear', 'surprise']],
#  [['fear'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['joy'], ['joy'], ['anger'], ['anger']],
#  [['fear', 'surprise']],
#  [['anger'],
#   ['anger'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['anger', 'joy'],
#   ['anger']],
#  [['sadness'],
#   ['fear'],
#   ['joy'],
#   ['neutral'],
#   ['surprise'],
#   ['fear'],
#   ['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['sadness', 'surprise']],
#  [['surprise'], ['fear', 'sadness'], ['surprise'], ['surprise'], ['joy']],
#  [['fear'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['anger', 'surprise'],
#   ['fear'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['anger']],
#  [['fear'],
#   ['fear'],
#   ['anger'],
#   ['anger', 'fear', 'surprise'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['fear'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger']],
#  [['joy'],
#   ['joy'],
#   ['fear'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['anger', 'disgust', 'surprise'],
#   ['anger', 'disgust'],
#   ['fear'],
#   ['anger', 'disgust'],
#   ['fear', 'surprise']],
#  [['anger'], ['joy'], ['joy'], ['anger']],
#  [['fear'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['fear'],
#   ['sadness']],
#  [['joy'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy']],
#  [['anger', 'surprise'], ['anger', 'joy'], ['anger'], ['anger']],
#  [['fear'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['surprise'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'], ['anger', 'fear'], ['fear']],
#  [['anger'], ['anger'], ['disgust', 'joy'], ['joy']],
#  [['anger', 'joy']],
#  [['anger'], ['anger'], ['anger'], ['anger', 'joy'], ['anger']],
#  [['fear', 'surprise'],
#   ['surprise'],
#   ['fear'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['joy']],
#  [['fear'],
#   ['surprise'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['fear'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['surprise']],
#  [['anger', 'sadness'], ['anger'], ['anger'], ['anger']],
#  [['fear'],
#   ['surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger']],
#  [['surprise'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['fear'],
#   ['surprise'],
#   ['joy'],
#   ['fear'],
#   ['fear', 'joy']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['sadness', 'surprise'],
#   ['surprise'],
#   ['anger', 'sadness']],
#  [['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'disgust'],
#   ['neutral'],
#   ['surprise']],
#  [['fear'],
#   ['surprise'],
#   ['fear', 'joy'],
#   ['fear', 'joy'],
#   ['surprise'],
#   ['fear', 'joy'],
#   ['fear', 'joy'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise']],
#  [['sadness'], ['joy'], ['joy'], ['surprise', 'joy']],
#  [['joy'],
#   ['fear'],
#   ['sadness'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['joy'],
#   ['fear']],
#  [['joy'], ['joy'], ['fear'], ['joy']],
#  [['fear'], ['fear'], ['fear'], ['fear']],
#  [['fear'], ['fear'], ['anger'], ['fear'], ['fear', 'surprise']],
#  [['joy'], ['fear'], ['fear']],
#  [['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'joy']],
#  [['anger'], ['anger'], ['anger']],
#  [['joy'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['surprise']],
#  [['fear', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['fear'],
#   ['fear']],
#  [['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger'],
#   ['anger']],
#  [['anger'], ['fear'], ['anger', 'disgust'], ['anger'], ['anger']],
#  [['sadness'], ['surprise']],
#  [['joy'], ['surprise'], ['joy'], ['joy']],
#  [['sadness', 'surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness', 'surprise'],
#   ['sadness']],
#  [['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['surprise']],
#  [['surprise'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['anger'],
#   ['joy'],
#   ['surprise', 'joy']],
#  [['surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise'],
#   ['neutral'],
#   ['neutral']],
#  [['fear'],
#   ['fear'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['fear', 'sadness']],
#  [['surprise'],
#   ['fear'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['anger', 'surprise'],
#   ['surprise'],
#   ['anger', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness'],
#   ['anger', 'fear'],
#   ['fear']],
#  [['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'fear'],
#   ['fear'],
#   ['fear'],
#   ['joy'],
#   ['fear'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['fear'],
#   ['sadness']],
#  [['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['fear', 'joy'],
#   ['fear', 'joy']],
#  [['surprise'],
#   ['surprise', 'joy'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['joy'], ['surprise', 'joy'], ['surprise', 'joy'], ['fear', 'surprise']],
#  [['fear']],
#  [['surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['surprise'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['surprise'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise']],
#  [['surprise', 'joy']],
#  [['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['fear'],
#   ['surprise'],
#   ['joy'],
#   ['anger']],
#  [['anger']],
#  [['anger'], ['anger', 'sadness'], ['anger', 'disgust'], ['anger']],
#  [['joy'], ['joy'], ['joy']],
#  [['joy'], ['sadness', 'joy']],
#  [['joy'], ['fear'], ['fear'], ['surprise', 'joy'], ['joy'], ['joy']],
#  [['surprise'],
#   ['surprise'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['joy'],
#   ['fear', 'joy'],
#   ['sadness']],
#  [['anger'], ['anger'], ['fear'], ['fear']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise']],
#  [['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['anger']],
#  [['anger'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'surprise'],
#   ['sadness', 'surprise']],
#  [['joy'], ['joy'], ['fear', 'joy'], ['surprise']],
#  [['fear'],
#   ['anger'],
#   ['surprise', 'joy'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['surprise', 'joy']],
#  [['fear', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['surprise'],
#   ['anger']],
#  [['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy']],
#  [['joy'], ['joy'], ['joy']],
#  [['anger'], ['anger', 'surprise'], ['fear']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'disgust'],
#   ['anger', 'sadness']],
#  [['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['anger', 'disgust'],
#   ['anger', 'surprise'],
#   ['disgust', 'surprise'],
#   ['disgust', 'joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['surprise', 'joy'],
#   ['anger', 'surprise'],
#   ['anger', 'disgust'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust', 'surprise'],
#   ['sadness', 'surprise']],
#  [['surprise'],
#   ['anger', 'surprise'],
#   ['surprise', 'joy'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'surprise'],
#   ['anger', 'sadness', 'surprise'],
#   ['sadness'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['sadness'],
#   ['surprise', 'joy'],
#   ['sadness', 'surprise'],
#   ['surprise', 'joy'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'surprise'],
#   ['surprise', 'joy']],
#  [['anger'],
#   ['sadness', 'surprise'],
#   ['anger', 'joy'],
#   ['anger', 'surprise'],
#   ['anger', 'disgust', 'surprise'],
#   ['sadness', 'surprise'],
#   ['anger', 'sadness'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['joy'],
#   ['surprise'],
#   ['fear'],
#   ['sadness', 'surprise'],
#   ['anger', 'sadness', 'surprise'],
#   ['anger', 'joy'],
#   ['surprise', 'joy']],
#  [['surprise'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['surprise'],
#   ['sadness'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['surprise'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy']],
#  [['anger'], ['anger', 'sadness']],
#  [['disgust', 'sadness'], ['neutral'], ['neutral'], ['neutral']],
#  [['surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['fear', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness']],
#  [['anger', 'sadness']],
#  [['joy'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['neutral'],
#   ['surprise', 'joy'],
#   ['neutral'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise']],
#  [['fear', 'sadness'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy']],
#  [['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['fear', 'sadness']],
#  [['joy'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'disgust', 'fear'],
#   ['anger', 'sadness']],
#  [['anger', 'fear'],
#   ['fear', 'sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger']],
#  [['neutral'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['surprise'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['anger', 'sadness']],
#  [['anger', 'fear'],
#   ['anger', 'disgust', 'surprise'],
#   ['fear', 'surprise'],
#   ['surprise', 'joy'],
#   ['disgust', 'fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['neutral'],
#   ['anger'],
#   ['joy'],
#   ['joy']],
#  [['surprise'], ['surprise'], ['fear', 'surprise']],
#  [['fear', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise']],
#  [['surprise']],
#  [['joy'], ['surprise', 'joy'], ['joy'], ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['anger']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['joy'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness']],
#  [['disgust', 'fear'],
#   ['joy'],
#   ['anger', 'disgust', 'fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['joy']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['fear', 'surprise'], ['anger', 'fear', 'surprise']],
#  [['surprise'], ['surprise'], ['joy'], ['joy']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['disgust', 'sadness']],
#  [['fear', 'surprise'],
#   ['surprise'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy']],
#  [['surprise'],
#   ['neutral'],
#   ['surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['surprise']],
#  [['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise'],
#   ['sadness', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['fear', 'sadness'],
#   ['surprise', 'joy'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise']],
#  [['joy'], ['joy']],
#  [['surprise', 'joy'], ['neutral']],
#  [['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy']],
#  [['neutral'], ['joy'], ['surprise', 'joy'], ['joy'], ['surprise']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness', 'surprise'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['disgust', 'sadness'],
#   ['sadness'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral']],
#  [['fear', 'surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['anger'],
#   ['neutral']],
#  [['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['surprise'],
#   ['anger'],
#   ['neutral'],
#   ['joy']],
#  [['joy'], ['joy']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['neutral']],
#  [['joy'], ['joy'], ['anger']],
#  [['fear', 'sadness'],
#   ['anger'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger', 'fear', 'sadness'],
#   ['fear']],
#  [['anger', 'fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['fear'],
#   ['anger'],
#   ['disgust', 'surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear', 'surprise'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness']],
#  [['anger', 'fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'disgust', 'fear']],
#  [['neutral'], ['neutral'], ['fear'], ['fear'], ['anger', 'fear']],
#  [['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise', 'joy']],
#  [['anger', 'fear', 'surprise'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['neutral']],
#  [['disgust', 'joy'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'fear'],
#   ['surprise'],
#   ['sadness', 'surprise'],
#   ['disgust', 'surprise'],
#   ['disgust', 'sadness'],
#   ['disgust', 'sadness'],
#   ['disgust', 'sadness'],
#   ['fear']],
#  [['disgust', 'surprise'],
#   ['disgust', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise']],
#  [['neutral'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise']],
#  [['neutral'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise', 'joy']],
#  [['surprise'], ['neutral'], ['surprise', 'joy'], ['surprise', 'joy']],
#  [['surprise'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger', 'surprise']],
#  [['sadness', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'surprise'],
#   ['sadness', 'joy'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'surprise', 'joy'],
#   ['fear', 'surprise']],
#  [['anger'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'disgust', 'surprise'],
#   ['anger', 'disgust'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger'],
#   ['disgust', 'surprise'],
#   ['surprise'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger']],
#  [['fear'], ['fear', 'surprise']],
#  [['surprise'], ['neutral']],
#  [['surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['fear'],
#   ['surprise']],
#  [['anger'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise']],
#  [['anger'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'sadness', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger']],
#  [['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['anger', 'joy'],
#   ['surprise']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['surprise'],
#   ['anger']],
#  [['fear'], ['fear'], ['fear'], ['joy'], ['neutral'], ['neutral'], ['joy']],
#  [['anger'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['sadness'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger']],
#  [['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['joy'],
#   ['neutral'],
#   ['sadness'],
#   ['neutral'],
#   ['neutral'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'joy']],
#  [['joy'], ['joy']],
#  [['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy']],
#  [['surprise'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust'],
#   ['anger', 'joy'],
#   ['sadness'],
#   ['anger'],
#   ['sadness'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['anger', 'surprise'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'fear'],
#   ['anger', 'sadness']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness', 'surprise'], ['joy'], ['anger', 'joy'], ['anger', 'joy']],
#  [['neutral'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['neutral'],
#   ['anger', 'surprise'],
#   ['anger', 'sadness'],
#   ['anger', 'surprise'],
#   ['fear', 'sadness'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['sadness'],
#   ['anger']],
#  [['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger']],
#  [['neutral'], ['surprise']],
#  [['anger', 'disgust'],
#   ['anger', 'joy'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness', 'surprise'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['anger', 'joy'], ['anger', 'joy'], ['anger', 'joy'], ['anger', 'joy']],
#  [['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'fear', 'sadness'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'joy']],
#  [['anger'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral']],
#  [['anger', 'sadness'], ['fear'], ['anger', 'surprise'], ['fear']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['joy'],
#   ['sadness'],
#   ['anger'],
#   ['sadness'],
#   ['sadness']],
#  [['neutral'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['fear'],
#   ['fear']],
#  [['anger'], ['fear', 'surprise'], ['fear', 'surprise'], ['anger', 'fear']],
#  [['sadness'], ['fear'], ['anger', 'fear']],
#  [['sadness'],
#   ['fear'],
#   ['anger', 'sadness'],
#   ['surprise'],
#   ['anger'],
#   ['surprise'],
#   ['sadness']],
#  [['anger'], ['anger'], ['anger', 'fear'], ['anger'], ['surprise'], ['anger']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['fear'], ['anger'], ['anger'], ['fear'], ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness']],
#  [['sadness'], ['anger'], ['surprise'], ['anger'], ['disgust'], ['anger']],
#  [['sadness'], ['fear'], ['fear'], ['sadness']],
#  [['fear'],
#   ['anger'],
#   ['neutral'],
#   ['anger', 'sadness'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['neutral'], ['neutral'], ['anger'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['fear', 'surprise', 'joy'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'sadness'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['fear'],
#   ['fear'],
#   ['anger']],
#  [['anger'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise'],
#   ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'fear'],
#   ['anger']],
#  [['anger'], ['fear'], ['anger'], ['anger']],
#  [['anger', 'sadness'],
#   ['anger', 'sadness', 'surprise'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['fear', 'sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['anger']],
#  [['anger'], ['anger'], ['anger'], ['anger', 'fear', 'surprise']],
#  [['fear', 'sadness'], ['anger', 'fear'], ['anger']],
#  [['neutral'],
#   ['sadness'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['fear'],
#   ['fear'],
#   ['sadness'],
#   ['anger', 'sadness']],
#  [['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['neutral'],
#   ['neutral'],
#   ['anger', 'fear', 'sadness'],
#   ['anger']],
#  [['anger', 'disgust'],
#   ['joy'],
#   ['anger', 'disgust'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['surprise'], ['anger'], ['anger'], ['surprise']],
#  [['sadness', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['neutral'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['anger'],
#   ['anger', 'sadness']],
#  [['anger'],
#   ['anger'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['anger'],
#   ['anger'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['surprise'],
#   ['anger'],
#   ['sadness', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger']],
#  [['sadness'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['anger', 'sadness'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['surprise']],
#  [['anger', 'fear'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['neutral'],
#   ['surprise'],
#   ['joy'],
#   ['joy']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear'],
#   ['joy']],
#  [['fear', 'sadness'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'fear'],
#   ['anger', 'sadness', 'surprise'],
#   ['fear'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['fear', 'surprise']],
#  [['anger', 'joy'],
#   ['anger', 'joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['neutral']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['neutral'],
#   ['neutral']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['neutral'],
#   ['neutral']],
#  [['neutral'], ['neutral'], ['neutral']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['fear'],
#   ['fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear', 'sadness']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['joy']],
#  [['surprise', 'joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['anger', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['anger'],
#   ['joy']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['fear', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['fear']],
#  [['fear', 'sadness']],
#  [['sadness'], ['fear', 'sadness'], ['fear', 'sadness'], ['fear']],
#  [['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'joy'],
#   ['fear', 'sadness'],
#   ['anger', 'joy'],
#   ['sadness', 'joy']],
#  [['sadness'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger']],
#  [['anger'], ['anger'], ['fear'], ['sadness'], ['sadness']],
#  [['sadness']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear'],
#   ['anger', 'surprise'],
#   ['anger', 'sadness', 'joy'],
#   ['sadness', 'joy']],
#  [['joy'],
#   ['fear'],
#   ['sadness'],
#   ['joy'],
#   ['surprise'],
#   ['fear'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['joy'],
#   ['fear']],
#  [['joy'],
#   ['fear'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['surprise'],
#   ['fear'],
#   ['fear'],
#   ['anger', 'surprise'],
#   ['fear'],
#   ['fear']],
#  [['sadness'],
#   ['sadness', 'joy'],
#   ['surprise'],
#   ['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger']],
#  [['anger'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['anger', 'fear']],
#  [['anger', 'fear'], ['fear', 'surprise'], ['fear'], ['anger']],
#  [['fear', 'sadness'], ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'surprise']],
#  [['fear'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['sadness'],
#   ['anger', 'fear', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness']],
#  [['joy'],
#   ['anger'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['sadness', 'joy'],
#   ['neutral'],
#   ['surprise', 'joy'],
#   ['neutral'],
#   ['joy'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['anger', 'sadness']],
#  [['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['surprise'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['sadness'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger']],
#  [['surprise'],
#   ['anger', 'surprise'],
#   ['sadness'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['surprise'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['surprise'],
#   ['anger', 'sadness'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness']],
#  [['surprise', 'joy'],
#   ['sadness'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['joy']],
#  [['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['surprise'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['joy']],
#  [['joy'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['disgust', 'fear'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['fear'],
#   ['surprise'],
#   ['surprise'],
#   ['anger', 'fear'],
#   ['joy']],
#  [['joy'],
#   ['surprise'],
#   ['joy'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'surprise']],
#  [['surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger', 'fear']],
#  [['anger', 'fear'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['anger', 'joy']],
#  [['anger'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['surprise'],
#   ['anger', 'surprise']],
#  [['fear'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['joy']],
#  [['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'surprise']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['anger'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['anger', 'fear'],
#   ['sadness'],
#   ['anger'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['fear'],
#   ['neutral'],
#   ['fear'],
#   ['neutral']],
#  [['sadness'],
#   ['anger'],
#   ['neutral'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['neutral']],
#  [['fear'],
#   ['fear', 'surprise'],
#   ['anger', 'disgust', 'fear'],
#   ['anger', 'fear'],
#   ['anger']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness', 'surprise'],
#   ['surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['surprise'],
#   ['neutral'],
#   ['surprise'],
#   ['neutral'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness']],
#  [['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['anger']],
#  [['fear'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['fear', 'surprise']],
#  [['sadness'], ['joy'], ['joy'], ['joy'], ['joy'], ['anger', 'sadness']],
#  [['anger', 'fear'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['fear'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'fear'],
#   ['sadness'],
#   ['fear'],
#   ['sadness'],
#   ['fear']],
#  [['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['neutral'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness']],
#  [['sadness', 'joy'], ['sadness', 'joy'], ['sadness', 'joy']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['neutral'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger']],
#  [['fear', 'surprise'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger']],
#  [['sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'disgust'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'surprise'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'disgust']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['disgust', 'surprise'],
#   ['joy'],
#   ['disgust'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['anger']],
#  [['neutral'],
#   ['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['anger'],
#   ['sadness'],
#   ['surprise'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['sadness'],
#   ['sadness']],
#  [['anger'],
#   ['anger', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'surprise'],
#   ['anger', 'joy'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['joy']],
#  [['neutral'],
#   ['sadness'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['sadness']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger']],
#  [['joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'joy'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'joy'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness']],
#  [['fear'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['fear']],
#  [['fear', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['fear']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['sadness', 'joy']],
#  [['sadness'], ['sadness']],
#  [['sadness'], ['sadness'], ['sadness'], ['sadness']],
#  [['sadness'], ['sadness'], ['sadness', 'joy'], ['sadness', 'joy']],
#  [['sadness'], ['sadness'], ['sadness'], ['joy'], ['sadness']],
#  [['anger', 'sadness']],
#  [['anger', 'sadness'], ['sadness']],
#  [['fear', 'sadness'], ['sadness'], ['sadness']],
#  [['sadness', 'joy'], ['sadness', 'joy'], ['anger', 'sadness'], ['sadness']],
#  [['sadness'], ['sadness'], ['sadness', 'joy'], ['sadness']],
#  [['sadness'], ['sadness']],
#  [['sadness'], ['sadness'], ['sadness', 'joy'], ['sadness', 'joy']],
#  [['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['anger', 'fear'],
#   ['joy'],
#   ['anger', 'fear', 'surprise'],
#   ['fear'],
#   ['anger', 'fear', 'surprise'],
#   ['fear'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'joy'],
#   ['anger', 'fear'],
#   ['fear', 'sadness'],
#   ['anger', 'disgust']],
#  [['joy']],
#  [['fear'], ['anger'], ['anger'], ['anger'], ['fear'], ['anger', 'disgust']],
#  [['anger', 'fear'],
#   ['anger', 'joy'],
#   ['anger', 'fear'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger']],
#  [['joy'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['neutral'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['anger'], ['anger', 'joy'], ['anger'], ['surprise'], ['surprise']],
#  [['fear']],
#  [['fear', 'surprise'], ['fear'], ['anger', 'sadness']],
#  [['anger', 'fear'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'fear', 'surprise'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger']],
#  [['anger', 'fear'], ['anger', 'joy'], ['fear', 'surprise']],
#  [['fear']],
#  [['fear'], ['surprise', 'joy'], ['joy'], ['joy'], ['joy'], ['fear']],
#  [['fear'], ['fear'], ['fear'], ['fear', 'surprise'], ['fear']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger']],
#  [['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['anger', 'fear', 'sadness'],
#   ['joy']],
#  [['anger', 'surprise', 'joy'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness', 'surprise'],
#   ['anger', 'disgust'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['surprise', 'joy'],
#   ['anger', 'disgust'],
#   ['sadness'],
#   ['anger', 'disgust', 'sadness'],
#   ['anger', 'disgust', 'sadness'],
#   ['anger', 'sadness'],
#   ['surprise']],
#  [['neutral'], ['neutral'], ['joy'], ['joy']],
#  [['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['surprise', 'joy'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness']],
#  [['joy'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['sadness'],
#   ['anger', 'surprise']],
#  [['joy'],
#   ['anger'],
#   ['sadness', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['anger'],
#   ['joy'],
#   ['sadness']],
#  [['joy'],
#   ['anger'],
#   ['sadness'],
#   ['surprise'],
#   ['surprise'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['surprise'],
#   ['sadness']],
#  [['surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['sadness'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'surprise']],
#  [['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['sadness', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['joy']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['surprise'],
#   ['surprise'],
#   ['anger']],
#  [['anger'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['fear'],
#   ['anger']],
#  [['fear']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['sadness']],
#  [['sadness', 'joy'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['disgust', 'sadness'],
#   ['disgust', 'surprise'],
#   ['sadness', 'surprise'],
#   ['disgust'],
#   ['anger', 'disgust']],
#  [['sadness'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['anger'],
#   ['disgust', 'sadness']],
#  [['sadness'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger', 'disgust'],
#   ['sadness', 'joy']],
#  [['anger'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['fear'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'surprise']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['fear', 'sadness']],
#  [['joy'], ['joy'], ['sadness']],
#  [['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['sadness', 'joy']],
#  [['sadness'], ['fear', 'sadness'], ['sadness'], ['sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['fear'],
#   ['surprise'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['fear'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'joy'],
#   ['sadness', 'joy'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness'], ['anger', 'sadness'], ['anger', 'sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['neutral'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['surprise', 'joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['sadness', 'joy'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['fear', 'sadness'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust']],
#  [['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness']],
#  [['anger', 'disgust'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['sadness', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear']],
#  [['anger'], ['fear'], ['anger'], ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['fear']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['fear'],
#   ['fear'],
#   ['sadness'],
#   ['anger'],
#   ['anger']],
#  [['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['surprise'],
#   ['anger', 'surprise']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'surprise'],
#   ['fear', 'joy'],
#   ['fear', 'joy'],
# ...
#   ['surprise']],
#  [['joy'],
#   ['anger'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['anger', 'fear'],
#   ['fear'],
#   ['anger', 'surprise'],
#   ['anger', 'joy']],
#  [['joy'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['fear', 'joy'],
#   ['surprise'],
#   ['sadness'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['fear', 'surprise'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['neutral'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['surprise'],
#   ['disgust'],
#   ['surprise', 'joy']],
#  [['neutral'],
#   ['neutral'],
#   ['surprise'],
#   ['sadness', 'surprise'],
#   ['surprise'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy']],
#  [['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'fear'],
#   ['sadness'],
#   ['sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['fear'],
#   ['anger'],
#   ['anger']],
#  [['joy'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear']],
#  [['surprise'],
#   ['anger', 'disgust'],
#   ['disgust'],
#   ['fear', 'surprise'],
#   ['disgust'],
#   ['surprise'],
#   ['neutral'],
#   ['fear'],
#   ['surprise'],
#   ['anger', 'disgust'],
#   ['anger', 'disgust']],
#  [['anger'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['disgust', 'surprise'],
#   ['joy']],
#  [['joy'],
#   ['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise']],
#  [['fear'],
#   ['fear'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['fear'],
#   ['fear'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['neutral'],
#   ['anger', 'surprise'],
#   ['anger']],
#  [['surprise'],
#   ['joy'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['neutral'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['joy'],
#   ['fear'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['joy'],
#   ['neutral'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['fear']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise']],
#  [['surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['surprise'],
#   ['surprise'],
#   ['joy'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['surprise']],
#  [['sadness', 'surprise']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['surprise'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'sadness', 'surprise'],
#   ['anger'],
#   ['anger']],
#  [['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['fear'],
#   ['disgust'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness']],
#  [['surprise'],
#   ['surprise', 'joy'],
#   ['sadness', 'surprise'],
#   ['surprise', 'joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['joy'],
#   ['sadness', 'surprise']],
#  [['joy'],
#   ['surprise'],
#   ['joy'],
#   ['disgust'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'surprise'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['fear']],
#  [['surprise'],
#   ['anger', 'surprise'],
#   ['sadness', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['sadness']],
#  [['surprise'],
#   ['surprise'],
#   ['neutral'],
#   ['surprise'],
#   ['anger'],
#   ['joy'],
#   ['sadness'],
#   ['fear', 'surprise']],
#  [['anger'], ['anger']],
#  [['fear'],
#   ['surprise'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger', 'fear'],
#   ['anger', 'surprise'],
#   ['sadness', 'surprise'],
#   ['fear', 'sadness'],
#   ['sadness', 'surprise'],
#   ['anger', 'sadness']],
#  [['fear'],
#   ['anger'],
#   ['fear'],
#   ['anger'],
#   ['neutral'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['fear'],
#   ['surprise']],
#  [['anger', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['sadness', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness', 'joy']],
#  [['anger']],
#  [['sadness'],
#   ['anger'],
#   ['surprise'],
#   ['sadness'],
#   ['anger', 'disgust'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['surprise']],
#  [['anger'],
#   ['anger', 'sadness'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['fear'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['anger']],
#  [['anger', 'fear'],
#   ['anger', 'disgust', 'surprise'],
#   ['anger'],
#   ['fear'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger']],
#  [['surprise'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['surprise'],
#   ['fear'],
#   ['fear'],
#   ['sadness'],
#   ['sadness']],
#  [['surprise'],
#   ['sadness', 'joy'],
#   ['fear'],
#   ['fear'],
#   ['neutral'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy']],
#  [['sadness'], ['sadness', 'joy'], ['joy']],
#  [['surprise'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['anger', 'surprise'],
#   ['fear'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['surprise'],
#   ['fear', 'sadness'],
#   ['anger', 'surprise'],
#   ['fear'],
#   ['surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear']],
#  [['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['fear'],
#   ['sadness'],
#   ['disgust'],
#   ['disgust', 'surprise'],
#   ['anger', 'disgust'],
#   ['neutral'],
#   ['neutral']],
#  [['neutral'],
#   ['neutral'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness']],
#  [['fear'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'fear'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['sadness', 'surprise'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'fear', 'sadness', 'surprise'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness']],
#  [['anger'], ['anger'], ['anger', 'fear']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['surprise'],
#   ['fear'],
#   ['sadness'],
#   ['surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'sadness'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise']],
#  [['sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['fear', 'surprise'],
#   ['neutral'],
#   ['neutral'],
#   ['fear', 'surprise'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['joy'],
#   ['fear'],
#   ['joy']],
#  [['surprise'],
#   ['surprise'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['joy'],
#   ['joy']],
#  [['sadness'], ['sadness'], ['sadness']],
#  [['neutral'], ['surprise'], ['neutral'], ['neutral']],
#  [['fear', 'surprise']],
#  [['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear']],
#  [['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['anger'],
#   ['fear', 'sadness']],
#  [['surprise'],
#   ['surprise'],
#   ['anger', 'disgust'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['fear'],
#   ['anger'],
#   ['sadness'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['sadness'],
#   ['joy']],
#  [['joy'],
#   ['fear', 'surprise'],
#   ['neutral'],
#   ['sadness'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['surprise', 'joy']],
#  [['fear', 'surprise'], ['joy'], ['joy'], ['fear']],
#  [['fear'], ['fear'], ['fear', 'surprise']],
#  [['fear', 'surprise']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['sadness'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'surprise']],
#  [['sadness'], ['sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness', 'surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['sadness']],
#  [['surprise', 'joy'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['neutral'],
#   ['neutral'],
#   ['fear'],
#   ['fear']],
#  [['anger', 'fear'], ['anger', 'fear']],
#  [['anger', 'fear'], ['fear', 'surprise']],
#  [['surprise', 'joy']],
#  [['anger', 'fear'],
#   ['surprise'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'fear'],
#   ['anger', 'fear']],
#  [['sadness', 'surprise', 'joy'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['fear'],
#   ['sadness'],
#   ['sadness'],
#   ['fear'],
#   ['anger'],
#   ['anger']],
#  [['joy'],
#   ['neutral'],
#   ['disgust'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['anger']],
#  [['fear'],
#   ['surprise'],
#   ['anger'],
#   ['sadness', 'surprise'],
#   ['anger', 'fear'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'joy'],
#   ['joy'],
#   ['fear'],
#   ['fear'],
#   ['sadness', 'joy']],
#  [['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['fear'],
#   ['fear'],
#   ['anger'],
#   ['neutral'],
#   ['sadness', 'joy'],
#   ['anger', 'fear'],
#   ['joy'],
#   ['joy']],
#  [['joy'],
#   ['joy'],
#   ['joy'],
#   ['anger'],
#   ['anger'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'joy'],
#   ['sadness', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise', 'joy'],
#   ['anger', 'fear'],
#   ['sadness', 'joy']],
#  [['joy'], ['joy'], ['anger', 'fear'], ['anger', 'fear'], ['neutral']],
#  [['joy'],
#   ['joy'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'fear', 'surprise']],
#  [['anger', 'fear'], ['anger', 'fear'], ['joy']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['anger']],
#  [['fear', 'surprise'], ['fear', 'surprise']],
#  [['anger', 'fear', 'surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger'],
#   ['fear', 'surprise']],
#  [['anger', 'fear', 'surprise']],
#  [['anger', 'fear', 'surprise'],
#   ['anger', 'fear', 'surprise'],
#   ['anger', 'fear', 'surprise']],
#  [['anger', 'fear', 'surprise'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear'],
#   ['anger', 'fear']],
#  [['joy'], ['joy'], ['joy'], ['joy'], ['joy']],
#  [['anger', 'fear'],
#   ['anger', 'fear'],
#   ['surprise'],
#   ['fear', 'surprise'],
#   ['surprise'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy'],
#   ['surprise', 'joy']],
#  [['anger', 'fear'], ['anger', 'fear'], ['anger'], ['anger']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['sadness'],
#   ['surprise'],
#   ['sadness'],
#   ['sadness'],
#   ['joy'],
#   ['joy'],
#   ['sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness']],
#  [['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'fear', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'sadness'],
#   ['fear'],
#   ['fear', 'joy'],
#   ['anger'],
#   ['fear', 'sadness'],
#   ['joy'],
#   ['anger', 'sadness'],
#   ['anger']],
#  [['anger', 'fear'],
#   ['anger', 'fear'],
#   ['joy'],
#   ['surprise'],
#   ['neutral'],
#   ['anger', 'disgust'],
#   ['sadness'],
#   ['joy'],
#   ['sadness']],
#  [['fear', 'surprise'],
#   ['fear'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['anger', 'disgust'],
#   ['disgust', 'sadness'],
#   ['disgust', 'sadness'],
#   ['surprise'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness']],
#  [['fear'], ['fear'], ['joy'], ['surprise']],
#  [['joy'],
#   ['joy'],
#   ['fear', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['sadness', 'joy']],
#  [['sadness']],
#  [['fear', 'sadness'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness']],
#  [['neutral'],
#   ['anger', 'disgust'],
#   ['neutral'],
#   ['fear'],
#   ['fear'],
#   ['anger', 'fear'],
#   ['fear', 'joy'],
#   ['fear', 'joy']],
#  [['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['fear', 'sadness', 'surprise'],
#   ['anger', 'fear'],
#   ['fear', 'sadness'],
#   ['fear', 'sadness'],
#   ['fear', 'surprise']],
#  [['anger'], ['anger', 'fear', 'sadness']],
#  [['joy'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['joy'],
#   ['surprise'],
#   ['joy'],
#   ['anger']],
#  [['joy'],
#   ['anger'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['joy'],
#   ['surprise', 'joy'],
#   ['anger'],
#   ['anger'],
#   ['fear', 'surprise'],
#   ['fear', 'surprise'],
#   ['anger'],
#   ['fear', 'sadness']],
#  [['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['fear']],
#  [['joy'],
#   ['joy'],
#   ['anger'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['neutral'],
#   ['anger', 'disgust'],
#   ['anger'],
#   ['surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy']],
#  [['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['anger'], ['anger'], ['surprise'], ['sadness'], ['surprise']],
#  [['anger', 'surprise'],
#   ['joy'],
#   ['joy'],
#   ['joy'],
#   ['surprise'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'surprise'],
#   ['anger'],
#   ['anger']],
#  [['joy'], ['joy'], ['surprise'], ['anger'], ['anger', 'joy']],
#  [['anger'],
#   ['anger', 'sadness'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['neutral'],
#   ['neutral'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['sadness'],
#   ['sadness'],
#   ['sadness']],
#  [['fear', 'sadness']],
#  [['anger'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['fear'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['joy'],
#   ['joy']],
#  [['surprise', 'joy'],
#   ['anger', 'surprise'],
#   ['fear', 'sadness'],
#   ['anger'],
#   ['anger']],
#  [['sadness', 'surprise'],
#   ['anger'],
#   ['sadness'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger']],
#  [['anger', 'disgust'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['anger'],
#   ['neutral'],
#   ['neutral'],
#   ['anger', 'surprise'],
#   ['anger', 'surprise']],
#  [['fear', 'surprise'],
#   ['anger'],
#   ['anger'],
#   ['neutral'],
#   ['neutral'],
#   ['anger'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['anger']],
#  [['neutral'],
#   ['neutral'],
#   ['neutral'],
#   ['sadness'],
#   ['anger', 'joy'],
#   ['anger', 'joy'],
#   ['sadness', 'joy'],
#   ['anger', 'sadness'],
#   ['anger', 'sadness'],
#   ['joy'],
#   ['joy']],
#  [['anger'], ['anger'], ['sadness'], ['fear'], ['sadness'], ['sadness']],
#  [['joy'], ['fear'], ['fear']]]

# %%
flat_list = lambda nested_list: [item for sublist in nested_list for item in (flat_list(sublist) if isinstance(sublist, list) else [sublist])]

# %%
train_emotions_l = flat_list(train_emotions_l)

# %%
len(train_emotions_l)
# Out:
# 8286

# %%
from collections import Counter

# %%
class_distribution = dict(Counter(train_emotions_l))

# %%
class_distribution
# Out:
# {'anger': 1927,
#  'fear': 1429,
#  'sadness': 1448,
#  'surprise': 1486,
#  'joy': 1390,
#  'neutral': 329,
#  'disgust': 277}

# %%
total_count = len(train_emotions_l)
class_distribution = {key: value / total_count for key, value in class_distribution.items()}

# %%
class_distribution
# Out:
# {'anger': 0.23256094617426984,
#  'fear': 0.17245957035964277,
#  'sadness': 0.17475259473811247,
#  'surprise': 0.1793386434950519,
#  'joy': 0.1677528361090997,
#  'neutral': 0.03970552739560705,
#  'disgust': 0.03342988172821627}

# %%
class_distribution = {key: value * 100 for key, value in class_distribution.items()}

# %%
class_distribution
# Out:
# {'anger': 23.256094617426985,
#  'fear': 17.245957035964278,
#  'sadness': 17.475259473811246,
#  'surprise': 17.933864349505193,
#  'joy': 16.77528361090997,
#  'neutral': 3.970552739560705,
#  'disgust': 3.342988172821627}

# %%
class_distribution = {key: round(value, 2 - int(len(str(int(value))))) for key, value in class_distribution.items()}

# %%
class_distribution
# Out:
# {'anger': 23.0,
#  'fear': 17.0,
#  'sadness': 17.0,
#  'surprise': 18.0,
#  'joy': 17.0,
#  'neutral': 4.0,
#  'disgust': 3.3}

# %% [markdown]
# ### Prepare prompts

# %%
# Formatting Fx
# Build questoin
# Build answer

# %%
def formatting_fct(instruction="", input="", output=""):
    
    prompt_d ={
            
        "instruction": f"""{instruction}""",
        "input": f"""{input}""",
        "output": f"""{output}"""
            
        }
    
    return prompt_d

# %%
# def build_instruction():
#     emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
#     formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
#     instruction = f"""### Emotion Analysis Expert Role

# You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.

# INPUT:
# - You will receive a list of utterances from a page in a comic book
# - The utterance may express one or multiple emotions

# TASK:
# 1. Carefully analyze the emotional context and tone of each utterance in the page
# 2. Identify applicable emotions from the following classes:
#    {formatted_classes}
# 3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.

# RULES:
# 1. Use ONLY the labels listed above
# 2. Output must be a JSON with single key "page_utterance_emotions"
# 3. Value must be an array where:
#    - Each element is an array of emotions for one utterance
#    - Order matches the input utterances order
#    - Multiple emotions are allowed per utterance
# 4. No explanations, only JSON output

# IMPORTANT:
# - Each array element corresponds to one utterance
# - One utterance can have multiple emotions
# - Maintain exact spelling and case of emotion labels
# - Keep emotions in arrays even for single emotions

# """
#     return instruction

# %%
def build_instruction(class_distribution=None):
    """
    Build instruction prompt with optional class distribution information.
    
    Args:
        class_distribution (dict, optional): Dictionary with emotion class frequencies 
            e.g., {"anger": 0.15, "joy": 0.25, ...}
    """
    emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
    formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
    # Base instruction
    instruction = f"""### Emotion Analysis Expert Role

You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.

INPUT:
- You will receive a list of utterances from a page in a comic book
- The utterance may express one or multiple emotions

TASK:
1. Carefully analyze the emotional context and tone of each utterance in the page
2. Identify applicable emotions from the following classes:
   {formatted_classes}
3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.
"""

    # Add distribution information if provided
    if class_distribution:
        distribution_text = "\nClass Distribution in Training Data:"
        for emotion in emotion_classes:
            if emotion in class_distribution:
                percentage = class_distribution[emotion]
                distribution_text += f"\n- {emotion}: {percentage:.1f}%"
        
        distribution_text += "\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy."
        instruction += distribution_text

    # Add remaining instructions
    instruction += """
    
RULES:
1. Use ONLY the labels listed above
2. Output must be a JSON with single key "page_utterance_emotions"
3. Value must be an array where:
   - Each element is an array of emotions for one utterance
   - Order matches the input utterances order
   - Multiple emotions are allowed per utterance
4. No explanations, only JSON output

IMPORTANT:
- Each array element corresponds to one utterance
- One utterance can have multiple emotions
- Maintain exact spelling and case of emotion labels
- Keep emotions in arrays even for single emotions
"""
    
    return instruction

# %%
def build_tagged_text(utterances):

    concatenated_utterances = '\n'.join(f"{i + 1}. {line}" for i, line in enumerate(utterances))
    
    question = f"""Now analyze these utterances from a page in a comics book:\n{concatenated_utterances}"""

    return question

# %%
def build_answer(utterance_emotions):
                

    return json.dumps({"page_utterance_emotions": utterance_emotions})

# %% [markdown]
# ### Build Data Files

# %%
df_train = grouped_df[grouped_df.split == 'TRAIN'].reset_index()

data_file_train = []

for index, _ in df_train.iterrows():
    
    i = index

    instruction = build_instruction(class_distribution)
    question = build_tagged_text(df_train.iloc[i].utterance)
    answer = build_answer(df_train.iloc[i].emotion_c)
    
    data_file_train.append( formatting_fct(instruction, question, answer) )

# %%
len(data_file_train)
# Out:
# 718

# %%
print(data_file_train[0]['instruction'])
# Out:
# ### Emotion Analysis Expert Role
#
# You are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.
#
# INPUT:
# - You will receive a list of utterances from a page in a comic book
# - The utterance may express one or multiple emotions
#
# TASK:
# 1. Carefully analyze the emotional context and tone of each utterance in the page
# 2. Identify applicable emotions from the following classes:
#    "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"
# 3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.
#
# Class Distribution in Training Data:
# - anger: 23.0%
# - disgust: 3.3%
# - fear: 17.0%
# - sadness: 17.0%
# - surprise: 18.0%
# - joy: 17.0%
# - neutral: 4.0%
#
# IMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.
#
# RULES:
# 1. Use ONLY the labels listed above
# 2. Output must be a JSON with single key "page_utterance_emotions"
# 3. Value must be an array where:
#    - Each element is an array of emotions for one utterance
#    - Order matches the input utterances order
#    - Multiple emotions are allowed per utterance
# 4. No explanations, only JSON output
#
# IMPORTANT:
# - Each array element corresponds to one utterance
# - One utterance can have multiple emotions
# - Maintain exact spelling and case of emotion labels
# - Keep emotions in arrays even for single emotions

# %%
print(data_file_train[0]['input'])
# Out:
# Now analyze these utterances from a page in a comics book:
# 1. THIS VILE THING ATTACKED THE SMALL BEASTS OF MY SHORES…
# 2. … IT PUNCHED MY BEAUTIFUL MATILDA… AND NOW IT BEGS FOR LIFE.
# 3. MY MASTER!
# 4. PLEASE!
# 5. BUT I HAVE NOT CHASED THIS MONSTER ALL THIS WAY TO LET IT GROVEL!
# 6. HEAL MEEE!
# 7. I HAVE COME TO CONQ--!
# 8. WHAT--
# 9. --IS THAT?!
# 10. NO! NO!

# %%
print(data_file_train[0]['output'])
# Out:
# {"page_utterance_emotions": [["anger"], ["anger"], ["fear"], ["fear"], ["fear", "sadness"], ["sadness"], ["anger"], ["surprise"], ["surprise"], ["fear", "surprise"]]}

# %%
df_test = grouped_df[grouped_df.split == 'TEST'].reset_index()

data_file_test = []

for index, _ in df_test.iterrows():
    
    i = index

    instruction = build_instruction(class_distribution)
    question = build_tagged_text(df_test.iloc[i].utterance)
    answer = build_answer(df_test.iloc[i].emotion_c)
    
    data_file_test.append( formatting_fct(instruction, question, answer) )

# %%
len(df_test)
# Out:
# 156

# %%
for i in range(10):
    print(data_file_test[i])
# Out:
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. HOW'S IT GOING?\n2. HEY.\n3. CAN I GET YOU ANYTHING?\n4. JUST A COKE.\n5. OKAY. COMING UP.\n6. THANKS.\n7. HOW IS IT OUT THERE? GETTING HOT?\n8. IT'S ALL RIGHT.\n9. ONE COKE. ENJOY.\n10. @ONCE UPON A TIME…\n11. @… IN A FAR OFF KINGDOM…", 'output': '{"page_utterance_emotions": [["surprise", "joy"], ["joy"], ["surprise", "joy"], ["joy"], ["joy"], ["joy"], ["surprise"], ["joy"], ["joy"], ["neutral"], ["neutral"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. … THERE LIVED FOUR STRAPPING YOUNG LADS WHO WERE, AS LADS TEND TO DO, CAUSING A HAIR OF TROUBLE FOR THE CITIZENS OF THE REALM.\n2. YOU SEE, THEIR CARRIAGE WAS BLOCKING THE MAIN ROAD IN THE TOWNSHIP, AND THE LOCALS COULD NOT GET THEIR WARES TO MARKET.\n3. # #@# NON-FAT! PULL OVER!\n4. IT'S THAT % # # # @ LADY COP!\n5. THE SITUATION WAS BECOMING QUITE UNTENABLE, WHEN ALONG CAME A GRAND AND AUGUST PRINCESS WHO WAS, AS PRINCESSES TEND TO BE, EAGER TO HELP.\n6. YEAH, THERE THEY ARE NOW. THEY'RE DRIVING RIGHT DOWN DANGER AT FIFTEEN MILES PER HOUR. JESUS. I GOT THEM.\n7. IF DORIS CALLS AGAIN, TELL HER I'M ALREADY HERE. SHE'LL KEEP WHINING ANYWAY, BUT YOU MIGHT AS WELL TELL HER.", 'output': '{"page_utterance_emotions": [["neutral"], ["neutral"], ["anger", "disgust"], ["anger", "disgust"], ["neutral"], ["sadness"], ["sadness"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. IT'S A HUNDRED AND FOUR DEGREES IN THE SHADE, I'M SUPPOSED TO BE INSIDE DOING THE WEEKLY REPORTS, AND I'M DRAGGED AWAY AGAIN BY YOU DINGBATS.\n2. I JUST WASHED THIS UNIFORM AND NOW IT'S ALREADY SOAKED THROUGH. JESUS.\n3. I DO NOT HAVE THE PATIENCE FOR THIS TODAY.\n4. WHAT'D WE DO, WHAT'D WE DO? WE'RE JUST DRIVING. IS IT ILLEGAL TO DRIVE IN CALIFORNIA NOW OR WHAT?\n5. NON-FAT, HOW OLD ARE YOU?\n6. KRUNCH IS SIXTEEN.\n7. YOU GOT A LICENSE, KRUNCH?\n8. HEY, DON'T BE MEAN TO KRUNCH! HE'S JUST GOT TO PASS THE WRITTEN PART.\n9. ON HIS SIXTH TEST HE GOT THREE WHOLE QUESTIONS RIGHT. A NEW RECORD!\n10. #HAHAHAHAHA!\n11. IT'S NOT FUNNY, BANANAS!\n12. I DID MORE THAN THREE! I DON'T WANT TO PUNCH YOU BUT I WILL PUNCH YOU IF YOU KEEP SAYING THINGS LIKE THAT.\n13. FINE! FOUR WHOLE QUESTIONS! HAPPY?!\n14. LOOK, LADY COP, THIS IS ALL… A LITTLE MISCOMMUNICATION.\n15. WE'RE JUST GOING OUT TO THE VALLEY TO DO SOME OFF ROADING. IT'S KIDS. IT'S FUN.\n16. YOU DON'T NEED A LICENSE FOR THAT, DO YOU?", 'output': '{"page_utterance_emotions": [["anger", "sadness"], ["anger", "sadness"], ["anger", "sadness"], ["fear", "surprise"], ["surprise"], ["joy"], ["anger", "surprise"], ["joy"], ["joy"], ["joy"], ["anger"], ["anger"], ["surprise", "joy"], ["fear", "sadness"], ["fear", "sadness"], ["fear", "surprise"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': 'Now analyze these utterances from a page in a comics book:\n1. DON\'T TOUCH ME, GOOD LOOKS, AND DON\'T EVER…\n2. ...EVER…\n3. … CALL ME " LADY COP. " ZERO TOLERANCE. OKAY?\n4. BUT OF COURSE, MA\'AM. MY DEEP APOLOGIES.\n5. BUT… AM I SO WRONG ABOUT THE LAW HERE? I DON\'T KNOW THAT I AM.\n6. YOU DON\'T NEED A DRIVER\'S LICENSE TO OFF-ROAD IN THE VALLEY.\n7. YOU DO NEED A DRIVER\'S LICENSE AND A PERMIT TO DRIVE THIS… THING ON A PAVED STREET IN THE MIDDLE OF TOWN.\n8. THAT\'S A TWO-HUNDRED - DOLLAR TICKET.\n9. CAN DRIVE IT THERE? CAN\'T DRIVE IT HERE?\n10. WHAT\'RE WE SUPPOSED TO DO, CARRY IT?!\n11. HEY! KRUNCH COULD PUT IT ON HIS HEAD AND WALK IT OVER, BALANCE IT. HE\'S GOT NOTHING UP THERE TO DAMAGE.\n12. I COULD FIND SOMETHING OF YOURS TO DAMAGE!\n13. LOOK, IT\'S TOO HOT TO FIGHT.\n14. AND FRANKLY, I\'D RATHER HAVE YOU GUYS KNOCKING EACH OTHER AROUND OUT IN THE SAND THAN HERE IN THE TOWN.\n15. I GET A LITTLE TIRED OF BEING CALLED OUT OF THEA.C. EVERY TIME A DINGBAT DOES SOMETHING STUPID. WHICH IS OFTEN.\n16. I\'LL ESCORT YOU TO THE VALLEY. COME BACK IN A BIT TO PICK YOU UP.\n17. YOU GOT MY CELL. CALL ME WHEN YOU\'RE READY.\n18. YOU FOLLOW THE RULES, YOU STAY SAFE, WE FORGET ABOUT THE TICKET. OKAY?\n19. AH, LADY COP! YOU\'RE THE BEST!\n20. GOOD LOOKS, WHAT THE HELL IS WRONG WITH YOU?!\n21. WHAT\'D I JUST SAY ABOUT THAT? ARE YOU EVEN LISTENING?!', 'output': '{"page_utterance_emotions": [["anger", "disgust"], ["anger", "disgust"], ["anger", "disgust"], ["fear", "sadness"], ["fear", "sadness", "surprise"], ["sadness"], ["sadness"], ["fear", "sadness"], ["sadness", "surprise"], ["sadness", "surprise"], ["joy"], ["anger"], ["anger"], ["anger"], ["anger", "disgust"], ["joy"], ["joy"], ["surprise", "joy"], ["surprise", "joy"], ["anger", "surprise"], ["anger", "surprise"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': 'Now analyze these utterances from a page in a comics book:\n1. AT THAT SAME MOMENT, IN THE FAR EAST, AN OGRE SPIED A MAN DOING EVIL AND JUMPED OFF HIS PERCH TO INTERVENE.\n2. #HA HA HA HA HA HA HA HA HA HA HA HA HA HA\n3.   HA HA HA HA HA HA HA HA HA HA HA HA', 'output': '{"page_utterance_emotions": [["neutral"], ["joy"], ["joy"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. NOW, I GRANT YOU, MOST OGRES ARE NOT KNOWN FOR THEIR HEROIC DEEDS.\n2. #GAHHH!\n3. BUT PERHAPS THAT IS NOT THE FAULT OF OGRES.\n4. I DIDN'T DO IT… IT WAS SEAN… SEAN HAD THE GUN. YOU SEE THAT, MAN… IT WAS… IT WAS…\n5. #HEE HEE HEE HEE\n6. NO, I BELIEVE THE FAULT WITH THAT PARTICULAR PRESUMPTION FALLS UPON OUR SHOULDERS.\n7. SEAN, MAN, I WAS JUST… WE WEREN'T GOING TO SHOOT…\n8. IT'S NOT FAIR… NOTHING'S FAIR…\n9. #HAHAHAHAHAHAHA\n10. YOU SEE, OGRES ARE COMPLICATED CREATURES, AND ONE OGRE IS NOT LIKE ANOTHER.\n11. PLEASE DON'T… I… WHATEVER YOU WANT… I DIDN'T EVEN DO IT… I'LL JUST DO… WHATEVER…\n12. #HAHAHAHA\n13. AND WE SHOULD NOT JUDGE THEM AS A WHOLE…\n14. #HA HA HA HA HA HA\n15. #HA HA HA HA\n16. … BUT INSTEAD TAKE EACH AS THEY COME TO US.\n17. #HA HA HA HA HA\n18. @YOU SHOULDN'T FEEL BAD ABOUT THESE GUYS PASSING. THIS IS SMALL-TIME, LOCAL STUFF. I TOLD YOU THAT WHEN YOU AUDITIONED.\n19. @IT'S BELOW YOU ANYWAY.\n20. @I ACTUALLY HAVE SOMETHING BETTER I WANT TO TALK ABOUT.", 'output': '{"page_utterance_emotions": [["neutral"], ["fear"], ["neutral"], ["anger", "fear", "sadness"], ["joy"], ["sadness"], ["fear", "surprise"], ["anger", "fear", "sadness"], ["joy"], ["neutral"], ["fear"], ["joy"], ["neutral"], ["joy"], ["joy"], ["neutral"], ["joy"], ["anger"], ["anger"], ["surprise", "joy"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': 'Now analyze these utterances from a page in a comics book:\n1. YOU TOLD ME IT WAS BELOW ME SO I\'D GET A BIGGER OFFER.\n2. I\'M TIRED OF THIS.\n3. @I\'M NOT HERE ARGUING WITH YOU, JACK. I\'M JUST SAYING WHAT WE BOTH KNOW. IT\'S A BLESSING THAT IT DIDN\'T WORK OUT.\n4. @WHO NEEDS TO HEAR YOU IN TENNESSEE? EVERYONE IN TENNESSEE ALREADY BELIEVES IN WHAT YOU DO.\n5. @LET SOME OTHER JACK RYDER COPYCAT TELL THOSE HICKS HOW SMART THEY ARE.\n6. @THIS NEW THING IS MEGA-BIG, A CHANCE TO REACH EVERYONE. IT\'S A NEW SMALLER CABLE NETWORK, GTN, BUT THEY\'RE ON ALL THE PROVIDERS.\n7. @THEY GOT BIG BACKING. THEY\'RE GOING TO GROW. THIS IS GETTING IN ON THE GROUND FLOOR OF THE NEXT BIG THING.\n8. @AND THEY REACHED OUT ABOUT YOU, SPECIFICALLY.\n9. BECAUSE I\'LL GET THEM HEADLINES THEY\'LL GET EYES ON, AND THEY DON\'T CARE WHAT THE HEADLINES ARE FOR.\n10. " WHO\'D HIRE RYDER AFTER HIS INFAMOUS ON-AIR WHACKO RANT GOT HIM FIRED FROM NBS?!\n11. " TUNE IN AT ELEVEN! "\n12. @THEY\'RE BASED IN NEW YORK. THEY WANT TO SEE YOU TODAY. IT\'S A TRAIN RIDE. YOU GO IN, YOU MEET WITH THEM, WHAT\'S THE HARM?\n13. @IT\'S REAL MONEY AND REAL EXPOSURE.\n14. @I MEAN THIS AS A FRIEND, JACK, BUT YOU GOT TO TRUST ME ON THIS. I\'M LOOKING OUT FOR YOU. I WANT YOU TO BE HAPPY.\n15. @HAPPY AND { € A $ # RICH.', 'output': '{"page_utterance_emotions": [["anger", "sadness"], ["anger"], ["sadness"], ["surprise"], ["anger"], ["neutral"], ["joy"], ["joy"], ["joy"], ["anger", "surprise"], ["anger", "surprise"], ["anger", "surprise"], ["joy"], ["joy"], ["joy"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. BUT ENOUGH TALK OF OGRES, FOR I MUST INTRODUCE YOU TO TWO PRINCES WHO WERE THAT DAY GATHERED TO EAT.\n2. I'M NERVOUS.\n3. DON'T START.\n4. WHO WERE THAT DAY WAITING FOR YET ANOTHER PRINCE TO ARRIVE.\n5. THIS IS A BIG DEAL TO ME.\n6. I'M AWARE. BUT YOU HAVING ANOTHER ONE OF YOUR PANIC ATTACKS RIGHT NOW ISN'T GOING TO HELP ANYTHING.\n7. THIS GUY'S A PROFESSIONAL. SO ARE WE. THAT'S ALL IT IS.\n8. THE LOFTY WARLORD IS LECTURING ME ABOUT PROFESSIONALISM?\n9. HIDING BEHIND A BEARD AND A SWORD ISN'T A CAREER, IT'S A GAME.\n10. WE'RE BOTH SUPERHEROES. I DON'T NEED YOU OF ALL PEOPLE JUDGING ME.\n11. WHO'S JUDGING YOU?\n12. I'M JUST SAYING, CALM DOWN AND LOOK NORMAL.\n13. LET'S JUST TRY TO BE NORMAL, OKAY?\n14. YOU AND ALL THE NORMAL.\n15. WHAT'S NORMAL?\n16. BEATS ME, FELLOWS.", 'output': '{"page_utterance_emotions": [["neutral"], ["fear"], ["anger"], ["neutral"], ["fear"], ["anger"], ["anger", "surprise"], ["anger", "surprise"], ["anger"], ["anger", "disgust"], ["anger", "surprise"], ["anger"], ["anger", "surprise"], ["anger"], ["anger", "surprise"], ["neutral"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. AND THEN, FINALLY, THE THREE GLORIOUS PRINCES OF THE REALM WERE UNITED!\n2. GUESS WHO MADE THE TRADE AND GOT THE THING?!\n3. EH, YOU'LL NEVER GUESS, IT WAS ME!\n4. METAMORPHO!\n5. WONDERFUL. THE WAITRESS IS COMING OVER. YOU COULDN'T PUT ON A COAT, COME IN THE DOOR?\n6. YOU HAVE IT HERE? CAN I SEE IT?\n7. I'M GAS. I CAN'T CARRY THINGS.\n8. IT'S IN THE CAR.\n9. YOU LEFT IT IN THE CAR?! WHERE'S YOUR CAR?\n10. OUTSIDE. I GOT A SPOT ON THE STREET.\n11. YOU GUYS ORDER? ANYTHING LOOK GOOD?\n12. DOES IT HURT?", 'output': '{"page_utterance_emotions": [["joy"], ["joy"], ["joy"], ["joy"], ["surprise", "joy"], ["surprise", "joy"], ["sadness"], ["sadness"], ["fear", "surprise"], ["neutral"], ["surprise"], ["fear", "surprise"]]}'}
# {'instruction': '### Emotion Analysis Expert Role\n\nYou are an advanced emotion analysis expert specializing in comic book dialogue interpretation. Your task is to analyze utterances and identify their emotional content.\n\nINPUT:\n- You will receive a list of utterances from a page in a comic book\n- The utterance may express one or multiple emotions\n\nTASK:\n1. Carefully analyze the emotional context and tone of each utterance in the page\n2. Identify applicable emotions from the following classes:\n   "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n3. For each utterance in a comic page, identify all emotions present and return an array of emotion arrays in order.\n\nClass Distribution in Training Data:\n- anger: 23.0%\n- disgust: 3.3%\n- fear: 17.0%\n- sadness: 17.0%\n- surprise: 18.0%\n- joy: 17.0%\n- neutral: 4.0%\n\nIMPORTANT: Consider these class frequencies when making decisions while maintaining accuracy.\n    \nRULES:\n1. Use ONLY the labels listed above\n2. Output must be a JSON with single key "page_utterance_emotions"\n3. Value must be an array where:\n   - Each element is an array of emotions for one utterance\n   - Order matches the input utterances order\n   - Multiple emotions are allowed per utterance\n4. No explanations, only JSON output\n\nIMPORTANT:\n- Each array element corresponds to one utterance\n- One utterance can have multiple emotions\n- Maintain exact spelling and case of emotion labels\n- Keep emotions in arrays even for single emotions\n', 'input': "Now analyze these utterances from a page in a comics book:\n1. C'MON, WE'RE GOING.\n2. WHAT'S WITH YOU?\n3. HE JUST GOT HERE! LOOK WHAT HE'S BEEN THROUGH! LET HIM EAT.\n4. I COULD EAT LATER.\n5. IT'S NO TROUBLE.\n6. IT'S IN HIS CAR.\n7. WE'RE LEAVING. HURRY UP.\n8. ALL RIGHT, I'M COMING!\n9. GOD, EVERYTHING'S AN ORDER TO YOU. YOU'RE NOT IN THE MILITARY ANYMORE, TRAVIS. I'M NOT YOUR PRIVATE. YES, SIR! NO, SIR!\n10. DON'T GET RUFFLED. I PARKED RIGHT OUTSIDE, NOT IN THE LOT.\n11. I'M SURE IT'S FINE.", 'output': '{"page_utterance_emotions": [["anger"], ["fear", "surprise"], ["fear"], ["joy"], ["joy"], ["anger"], ["anger"], ["anger"], ["anger", "disgust"], ["joy"], ["joy"]]}'}

# %% [markdown]
# ### Create and save JSON files

# %%
file_path = Path(DATASET_DIR) / "comics35_utterance_pg_classp_train.json"

with open(file_path, 'w') as file:
    
    json.dump(data_file_train, file)

# %%
file_path = Path(DATASET_DIR) / "comics35_utterance_pg_classp_test.json"

with open(file_path, 'w') as file:
    
    json.dump(data_file_test, file)
