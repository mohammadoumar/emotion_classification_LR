# %%
import torch
import json
import json_repair
import pandas as pd

from tqdm import tqdm
from datasets import Dataset

from pathlib import Path
from PIL import Image

from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth.chat_templates import get_chat_template
from unsloth import FastLanguageModel, FastVisionModel, is_bfloat16_supported

from sklearn.metrics import classification_report
from sklearn.preprocessing import MultiLabelBinarizer
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
max_seq_length = 4096

model, tokenizer = FastVisionModel.from_pretrained(
    #model_name="unsloth/Qwen2.5-32B-Instruct-bnb-4bit",
    #model_name="unsloth/Qwen2.5-7B-Instruct-bnb-4bit",
    model_name="unsloth/Llama-3.2-11B-Vision-Instruct",
    
    #model_name="unsloth/Pixtral-12B-2409-bnb-4bit",
    #model_name="unsloth/Qwen2-VL-7B-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    load_in_4bit=True,
    dtype=None,
)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Mllama vision patching. Transformers: 4.47.0.
#    \\   /|    GPU: NVIDIA H100 NVL. Max memory: 93.003 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 9.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### model

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True, # False if not finetuning vision layers
    finetune_language_layers   = True, # False if not finetuning language layers
    finetune_attention_modules = True, # False if not finetuning attention layers
    finetune_mlp_modules       = True, # False if not finetuning MLP layers

    r = 64,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 64,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],
    use_gradient_checkpointing=True,
    #target_modules = "all-linear", # Optional now! Can specify a list if needed
)

# %% [markdown]
# ## data

# %%
df = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/dataset_files/comics_dataset_pg.csv", index_col=0)

# %%
df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    ["THIS VILE THING ATTACKED THE SMALL BEASTS OF...
# 1    ["NO--  #GKKK\u2026#", "#CHOMP!", "BY THE SKIN...
# 2    ["COME ON, BEAST!", "SHOW YOURSELF!", "WHY DO ...
# 3                                         ["#AARGH! "]
# 4    ["I, THE GREEN TORCH, HAVE BEEN TASKED WITH PR...
# ..                                                 ...
# 869  ["WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO...
# 870  ["SO WHAT ARE WE GOING TO DO?", "THE WAY I SEE...
# 871  ["KIDDIE COUNCIL'S BEEN GOING A LONG TIME... "...
# 872  ["IT'S BEEN\u2026 PEACEFUL. ASIDE FROM SHIT LI...
# 873          ["\" AND PAY OUR NEIGHBOURS A VISIT. \""]
#
#                                              emotion_c
# 0    [['anger'], ['anger'], ['fear'], ['fear'], ['f...
# 1    [['fear'], ['anger'], ['surprise'], ['anger'],...
# 2             [['joy'], ['joy'], ['anger'], ['anger']]
# 3                               [['fear', 'surprise']]
# 4    [['anger'], ['anger'], ['fear'], ['fear', 'sur...
# ..                                                 ...
# 869  [['anger'], ['anger'], ['anger'], ['anger'], [...
# 870  [['sadness', 'surprise'], ['anger'], ['anger']...
# 871  [['anger', 'sadness'], ['anger'], ['anger'], [...
# 872  [['anger'], ['joy'], ['joy'], ['anger', 'surpr...
# 873                                 [['anger', 'joy']]
#
# [874 rows x 5 columns]

# %%
file_names_l = df.file_name.unique().tolist()

# %%
comics_titles_full = [
    
    "Jurassic League #4",      
    "Nightwing #95",    
    "Dark Crisis: Worlds Without a Justice League - Green Lantern #1", 
    "Dark Crisis: Worlds Without a Justice League - Green Lantern - Very Merry Multiverse",
    "Dark Crisis: The Flash #783",
    "Danger Street #1",
    "Tiny Titans #25",
    "Human Target #9",
    "DC vs. Vampires #11",
    "John Carpenter's Tales for a Halloweenight #3",
    "The Amazing Adventures of the Ninja Turtles #5",
    "Sonic The Hedgehog #44",
    "Love Everlasting #2",
    "Fantasmas vol. 1 - Ghosted #2",
    "Fantasmas vol. 1 - Ghosted #3",
    "Fantasmas vol. 1 - Ghosted #4",
    "Fantasmas vol. 1 - Ghosted #5",
    "Fantasmas vol. 1 - Ghosted #1",
    "Fantasmas vol. 1 - Ghosted #6",
    "Fantasmas vol. 1 - Ghosted #7",
    "Fantasmas vol. 1 - Ghosted #8",
    "Fantasmas vol. 1 - Ghosted #9",
    "Fantasmas vol. 1 - Ghosted #10",
    "American Vampire vol. 4 - #6",
    "American Vampire vol. 4 - #7",
    "American Vampire vol. 4 - #8",
    "Dragon Age vol. 3 Engano - Deception #1",
    "Dragon Age vol. 3 Engano - Deception #2",
    "Dragon Age vol. 3 Engano - Deception #3",
    "The Walking Dead vol 15 - #169",
    "The Walking Dead vol 15 - #170",
    "The Walking Dead vol 15 - #171",
    "The Walking Dead vol 15 - #173",
    "Thief Of Thieves 1 - #11",
    "Stillwater #13",

]

# %%
len(comics_titles_full)
# Out:
# 35

# %%
df['comics_title'] = df['file_name'].apply(lambda x: comics_titles_full[file_names_l.index(x)] if x in file_names_l else None)

# %%
df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    ["THIS VILE THING ATTACKED THE SMALL BEASTS OF...
# 1    ["NO--  #GKKK\u2026#", "#CHOMP!", "BY THE SKIN...
# 2    ["COME ON, BEAST!", "SHOW YOURSELF!", "WHY DO ...
# 3                                         ["#AARGH! "]
# 4    ["I, THE GREEN TORCH, HAVE BEEN TASKED WITH PR...
# ..                                                 ...
# 869  ["WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO...
# 870  ["SO WHAT ARE WE GOING TO DO?", "THE WAY I SEE...
# 871  ["KIDDIE COUNCIL'S BEEN GOING A LONG TIME... "...
# 872  ["IT'S BEEN\u2026 PEACEFUL. ASIDE FROM SHIT LI...
# 873          ["\" AND PAY OUR NEIGHBOURS A VISIT. \""]
#
#                                              emotion_c        comics_title
# 0    [['anger'], ['anger'], ['fear'], ['fear'], ['f...  Jurassic League #4
# 1    [['fear'], ['anger'], ['surprise'], ['anger'],...  Jurassic League #4
# 2             [['joy'], ['joy'], ['anger'], ['anger']]  Jurassic League #4
# 3                               [['fear', 'surprise']]  Jurassic League #4
# 4    [['anger'], ['anger'], ['fear'], ['fear', 'sur...  Jurassic League #4
# ..                                                 ...                 ...
# 869  [['anger'], ['anger'], ['anger'], ['anger'], [...      Stillwater #13
# 870  [['sadness', 'surprise'], ['anger'], ['anger']...      Stillwater #13
# 871  [['anger', 'sadness'], ['anger'], ['anger'], [...      Stillwater #13
# 872  [['anger'], ['joy'], ['joy'], ['anger', 'surpr...      Stillwater #13
# 873                                 [['anger', 'joy']]      Stillwater #13
#
# [874 rows x 6 columns]

# %%
df.file_name.tolist()
# Out:
# ['QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1499 - 58 ECC Co_mics 50 _The Jurassic League 4_.xlsx',
#  'QC copy - 1501 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCWWJL GL 1.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1502 - 09 Mundos sin Liga de la Justicia Green Lantern 1 - DCVMM Lobo.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1503 - 10 Crisis Oscura Flash - FLS 783.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1507 - 22 Calle Peligro 1.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1513 - 21 Blanco Humano 9.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1514 - 15 DC contra Vampiros 11.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1517 - 37 John Carpenter Historias para una noche de Halloween 3.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1518 - 50 Las asombrosas aventuras de las Tortugas Ninja 5.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1521 - 40 Amor eterno 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted 2.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted 4.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted 5.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted 1.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted 6.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted 10.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1642 - 23 American Vampire vol. 4 - AVC2 6.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1643 - 23 American Vampire vol. 4 - AVC2 7.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1644 - 23 American Vampire vol. 4 - AVC2 8.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1733 - 34 The Walking Dead vol 15 - 169_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1734 - 34 The Walking Dead vol 15 - 170_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1735 - 34 The Walking Dead vol 15 - 171_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1737 - 34 The Walking Dead vol 15 - 173_TWD.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 1910 - 35 Ladro_n de ladrones 1 - ToT 11.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx',
#  'QC copy - 2200 - Stillwater 13.xlsx']

# %%
def get_comics_id(row):
    
    return row.file_name.split("-")[1].strip()

# %%
df['comics_id'] = df.apply(lambda row: get_comics_id(row), axis=1)

# %%
df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    ["THIS VILE THING ATTACKED THE SMALL BEASTS OF...
# 1    ["NO--  #GKKK\u2026#", "#CHOMP!", "BY THE SKIN...
# 2    ["COME ON, BEAST!", "SHOW YOURSELF!", "WHY DO ...
# 3                                         ["#AARGH! "]
# 4    ["I, THE GREEN TORCH, HAVE BEEN TASKED WITH PR...
# ..                                                 ...
# 869  ["WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO...
# 870  ["SO WHAT ARE WE GOING TO DO?", "THE WAY I SEE...
# 871  ["KIDDIE COUNCIL'S BEEN GOING A LONG TIME... "...
# 872  ["IT'S BEEN\u2026 PEACEFUL. ASIDE FROM SHIT LI...
# 873          ["\" AND PAY OUR NEIGHBOURS A VISIT. \""]
#
#                                              emotion_c        comics_title  \
# 0    [['anger'], ['anger'], ['fear'], ['fear'], ['f...  Jurassic League #4
# 1    [['fear'], ['anger'], ['surprise'], ['anger'],...  Jurassic League #4
# 2             [['joy'], ['joy'], ['anger'], ['anger']]  Jurassic League #4
# 3                               [['fear', 'surprise']]  Jurassic League #4
# 4    [['anger'], ['anger'], ['fear'], ['fear', 'sur...  Jurassic League #4
# ..                                                 ...                 ...
# 869  [['anger'], ['anger'], ['anger'], ['anger'], [...      Stillwater #13
# 870  [['sadness', 'surprise'], ['anger'], ['anger']...      Stillwater #13
# 871  [['anger', 'sadness'], ['anger'], ['anger'], [...      Stillwater #13
# 872  [['anger'], ['joy'], ['joy'], ['anger', 'surpr...      Stillwater #13
# 873                                 [['anger', 'joy']]      Stillwater #13
#
#     comics_id
# 0        1499
# 1        1499
# 2        1499
# 3        1499
# 4        1499
# ..        ...
# 869      2200
# 870      2200
# 871      2200
# 872      2200
# 873      2200
#
# [874 rows x 7 columns]

# %%
comics_images_dir = Path("/Utilisateurs/umushtaq/emotion_analysis_comics/comics_dataset_images")

# %%
def get_image_file_path(row):
    
    page_nr = row.page_nr
    comics_dir = "00" + row.comics_id
    
    images_dir = Path(comics_images_dir) / comics_dir / "images"    
    file_name = "page" + f"{page_nr:05d}" + ".jpg"
        
    file_path = images_dir / file_name    
    
    return file_path

# %%
df['image_path'] = df.apply(lambda row: get_image_file_path(row), axis=1)

# %%
df
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 869                QC copy - 2200 - Stillwater 13.xlsx       16   TEST
# 870                QC copy - 2200 - Stillwater 13.xlsx       17   TEST
# 871                QC copy - 2200 - Stillwater 13.xlsx       18   TEST
# 872                QC copy - 2200 - Stillwater 13.xlsx       19   TEST
# 873                QC copy - 2200 - Stillwater 13.xlsx       20   TEST
#
#                                              utterance  \
# 0    ["THIS VILE THING ATTACKED THE SMALL BEASTS OF...
# 1    ["NO--  #GKKK\u2026#", "#CHOMP!", "BY THE SKIN...
# 2    ["COME ON, BEAST!", "SHOW YOURSELF!", "WHY DO ...
# 3                                         ["#AARGH! "]
# 4    ["I, THE GREEN TORCH, HAVE BEEN TASKED WITH PR...
# ..                                                 ...
# 869  ["WE WERE IN GALEN'S OFFICE. YOU WERE ABOUT TO...
# 870  ["SO WHAT ARE WE GOING TO DO?", "THE WAY I SEE...
# 871  ["KIDDIE COUNCIL'S BEEN GOING A LONG TIME... "...
# 872  ["IT'S BEEN\u2026 PEACEFUL. ASIDE FROM SHIT LI...
# 873          ["\" AND PAY OUR NEIGHBOURS A VISIT. \""]
#
#                                              emotion_c        comics_title  \
# 0    [['anger'], ['anger'], ['fear'], ['fear'], ['f...  Jurassic League #4
# 1    [['fear'], ['anger'], ['surprise'], ['anger'],...  Jurassic League #4
# 2             [['joy'], ['joy'], ['anger'], ['anger']]  Jurassic League #4
# 3                               [['fear', 'surprise']]  Jurassic League #4
# 4    [['anger'], ['anger'], ['fear'], ['fear', 'sur...  Jurassic League #4
# ..                                                 ...                 ...
# 869  [['anger'], ['anger'], ['anger'], ['anger'], [...      Stillwater #13
# 870  [['sadness', 'surprise'], ['anger'], ['anger']...      Stillwater #13
# 871  [['anger', 'sadness'], ['anger'], ['anger'], [...      Stillwater #13
# 872  [['anger'], ['joy'], ['joy'], ['anger', 'surpr...      Stillwater #13
# 873                                 [['anger', 'joy']]      Stillwater #13
#
#     comics_id                                         image_path
# 0        1499  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 1        1499  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 2        1499  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 3        1499  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 4        1499  /Utilisateurs/umushtaq/emotion_analysis_comics...
# ..        ...                                                ...
# 869      2200  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 870      2200  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 871      2200  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 872      2200  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 873      2200  /Utilisateurs/umushtaq/emotion_analysis_comics...
#
# [874 rows x 8 columns]

# %%
df_train = df[df.split == "TRAIN"].reset_index(drop=True)

# %%
df_train
# Out:
#                                              file_name  page_nr  split  \
# 0    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        1  TRAIN
# 1    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        2  TRAIN
# 2    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        3  TRAIN
# 3    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        4  TRAIN
# 4    QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...        5  TRAIN
# ..                                                 ...      ...    ...
# 713  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       16  TRAIN
# 714  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       17  TRAIN
# 715  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       18  TRAIN
# 716  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       19  TRAIN
# 717  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...       20  TRAIN
#
#                                              utterance  \
# 0    ["THIS VILE THING ATTACKED THE SMALL BEASTS OF...
# 1    ["NO--  #GKKK\u2026#", "#CHOMP!", "BY THE SKIN...
# 2    ["COME ON, BEAST!", "SHOW YOURSELF!", "WHY DO ...
# 3                                         ["#AARGH! "]
# 4    ["I, THE GREEN TORCH, HAVE BEEN TASKED WITH PR...
# ..                                                 ...
# 713  ["YOU BETTER HOPE I FORGET THAT SHIT JUST FELL...
# 714  ["IT'S NOTHING--", "YOU TOUCH IT --AND I TAKE ...
# 715  ["YOU BRING EVERYTHING ABOUT THIS TO HIM.", "T...
# 716  ["ASK YOU ONE MORE TIME, SON--", "THE FUCK DID...
# 717  ["COHEN, HERE--", "@AGENT COHEN, IT'S EMMA.", ...
#
#                                              emotion_c  \
# 0    [['anger'], ['anger'], ['fear'], ['fear'], ['f...
# 1    [['fear'], ['anger'], ['surprise'], ['anger'],...
# 2             [['joy'], ['joy'], ['anger'], ['anger']]
# 3                               [['fear', 'surprise']]
# 4    [['anger'], ['anger'], ['fear'], ['fear', 'sur...
# ..                                                 ...
# 713  [['anger', 'disgust'], ['anger'], ['anger'], [...
# 714  [['fear', 'surprise'], ['anger'], ['anger'], [...
# 715  [['neutral'], ['neutral'], ['neutral'], ['sadn...
# 716  [['anger'], ['anger'], ['sadness'], ['fear'], ...
# 717                      [['joy'], ['fear'], ['fear']]
#
#                  comics_title comics_id  \
# 0          Jurassic League #4      1499
# 1          Jurassic League #4      1499
# 2          Jurassic League #4      1499
# 3          Jurassic League #4      1499
# 4          Jurassic League #4      1499
# ..                        ...       ...
# 713  Thief Of Thieves 1 - #11      1910
# 714  Thief Of Thieves 1 - #11      1910
# 715  Thief Of Thieves 1 - #11      1910
# 716  Thief Of Thieves 1 - #11      1910
# 717  Thief Of Thieves 1 - #11      1910
#
#                                             image_path
# 0    /Utilisateurs/umushtaq/emotion_analysis_comics...
# 1    /Utilisateurs/umushtaq/emotion_analysis_comics...
# 2    /Utilisateurs/umushtaq/emotion_analysis_comics...
# 3    /Utilisateurs/umushtaq/emotion_analysis_comics...
# 4    /Utilisateurs/umushtaq/emotion_analysis_comics...
# ..                                                 ...
# 713  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 714  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 715  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 716  /Utilisateurs/umushtaq/emotion_analysis_comics...
# 717  /Utilisateurs/umushtaq/emotion_analysis_comics...
#
# [718 rows x 8 columns]

# %%
df_train.iloc[451]
# Out:
# file_name       QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted...
# page_nr                                                        11
# split                                                       TRAIN
# utterance       ["GET THE FUCK BACK, MAGICIAN.", "OKIE DOKIE T...
# emotion_c       [['anger', 'disgust'], ['fear', 'sadness'], ['...
# comics_title                        Fantasmas vol. 1 - Ghosted #6
# comics_id                                                    1567
# image_path      /Utilisateurs/umushtaq/emotion_analysis_comics...
# Name: 451, dtype: object

# %%
df_train.iloc[451]['image_path']
# Out:
# PosixPath('/Utilisateurs/umushtaq/emotion_analysis_comics/comics_dataset_images/001567/images/page00011.jpg')

# %%
import random

# %%
train_titles_l = df_train.comics_title.unique().tolist()

# %%
eval_titles = random.sample(train_titles_l, 5)

# %%
train_titles = [title for title in train_titles_l if title not in eval_titles]

# %%
len(train_titles), len(eval_titles)
# Out:
# (23, 5)

# %%
df_train_f = df_train[df_train.comics_title.isin(train_titles)]

# %%
df_eval_f = df_train[df_train.comics_title.isin(eval_titles)]

# %%
len(df_train_f), len(df_eval_f)
# Out:
# (602, 116)

# %%
#df.to_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/dataset_files/comics_pg_w_images.csv")

# %% [markdown]
# ## Build vision dataset

# %%
def build_generation_instruction(comics_title, page_utterances):
   
    emotion_classes = ["anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"]
    formatted_classes = ", ".join([f'"{emotion}"' for emotion in emotion_classes])
    
    instruction = f"""### Emotion Analysis for Comics

You are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.

INPUT:
- List of utterances from a page in a comic
- An image of the comics page

OUTPUT:
- JSON with single key "emotions"
- Value: array of emotion arrays matching utterance order
- ONLY use these emotions: {formatted_classes}
- NO OTHER EMOTION LABELS ARE ALLOWED

RULES:
1. Each utterance must have at least one emotion from the list above
2. Multiple emotions per utterance are allowed
3. Keep emotions in arrays even for single emotions
4. Maintain exact emotion spelling and case
5. No explanations, only JSON output

Example format:
{{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}}

Comic Information:
Title: {comics_title}

Utterances to Classify:
{page_utterances}

"""
    return instruction

# %%
def build_image_modality(image_path):
    
    return Image.open(image_path)

# %%
def convert_to_conversation(row):
  
    comics_title = row.comics_title
    image_path = row.image_path
    labels = row.emotion_c
    
    utterances_l = eval(row['utterance'])
    pg_utterances = "\n".join(f"{i+1}. {title}" for i, title in enumerate(utterances_l))
  
    instruction = build_generation_instruction(comics_title, pg_utterances)
    image = build_image_modality(image_path)
    
    conversation = [
        { "role": "user",
          "content" : [
            {"type" : "text",  "text"  : instruction},
            {"type" : "image", "image" : image} ]
        },
        { "role" : "assistant",
          "content" : [
            {"type" : "text",  "text"  : {"emotions": labels}} ]
        },
    ]
    return { "messages" : conversation }
pass

# %%
# Apply the function to each row and store the results in a list
comics_mm_dataset_train = [convert_to_conversation(row) for _, row in df_train_f.iterrows()]
comics_mm_dataset_eval = [convert_to_conversation(row) for _, row in df_eval_f.iterrows()]

# %%
len(comics_mm_dataset_eval)
# Out:
# 116

# %%
comics_mm_dataset_eval[0]
# Out:
# {'messages': [{'role': 'user',
#    'content': [{'type': 'text',
#      'text': '### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Nightwing #95\n\nUtterances to Classify:\n1. DID YOU HAVE TO ELECTROCUTE HER SO HARD?\n2. IT\'S NOT LIKE I HAVE DIFFERENT SETTINGS.\n3. YOU\'RE ELECTROCUTIONER. IT\'S YOUR WHOLE THING. YOU\'D THINK YOU\'D HAVE SOME DEGREE OF CONTROL?\n4. OH, HEY. I THINK SHE\'S AWAKE.\n5. WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRETTY PISSED WITH YOU.\n6. HE KNOWS YOU\'RE WORKING WITH DICK GRAYSON.\n7. HE WANTS ME TO GET INFORMATION OUT OF YOU.\n8. SHE\'S AWAKE, BOSS. SHE--\n\n'},
#     {'type': 'image',
#      'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3968x6070>}]},
#   {'role': 'assistant',
#    'content': [{'type': 'text',
#      'text': {'emotions': "[['fear', 'surprise'], ['surprise'], ['fear'], ['surprise'], ['anger'], ['anger', 'surprise'], ['joy'], ['joy']]"}}]}]}

# %%
# def split_dataset(dataset, train_ratio=0.8):
#     train_test = dataset.train_test_split(test_size=1 - train_ratio)
#     return train_test

# dataset_split = split_dataset(comics_mm_dataset)

# %%
from unsloth import is_bf16_supported
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

# %%
FastVisionModel.for_training(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MllamaForConditionalGeneration(
#       (vision_model): MllamaVisionModel(
#         (patch_embedding): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14), padding=valid, bias=False)
#         (gated_positional_embedding): MllamaPrecomputedPositionEmbedding(
#           (tile_embedding): Embedding(9, 8197120)
#         )
#         (pre_tile_positional_embedding): MllamaPrecomputedAspectRatioEmbedding(
#           (embedding): Embedding(9, 5120)
#         )
#         (post_tile_positional_embedding): MllamaPrecomputedAspectRatioEmbedding(
#           (embedding): Embedding(9, 5120)
#         )
#         (layernorm_pre): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (layernorm_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (transformer): MllamaVisionEncoder(
#           (layers): ModuleList(
#             (0-12): 13 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#             (13): MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#             (14-31): 18 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (global_transformer): MllamaVisionEncoder(
#           (layers): ModuleList(
#             (0-7): 8 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#       (language_model): MllamaForCausalLM(
#         (model): MllamaTextModel(
#           (embed_tokens): Embedding(128264, 4096, padding_idx=128004)
#           (layers): ModuleList(
#             (0): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (1): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear(
#                   (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (2): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (3): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (4-7): 4 x MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (8): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (9-12): 4 x MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
# ...
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (38): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (39): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#           )
#           (norm): MllamaTextRMSNorm((4096,), eps=1e-05)
#           (rotary_emb): MllamaRotaryEmbedding()
#         )
#         (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#       )
#       (multi_modal_projector): Linear(in_features=7680, out_features=4096, bias=True)
#     )
#   )
# )

# %%
args = SFTConfig(
    
        do_train = True,
        do_eval=True,

        per_device_train_batch_size = 4,
        gradient_accumulation_steps = 2,
        warmup_steps = 5,
        #max_steps = 30,
        num_train_epochs = 3, # Set this instead of max_steps for full training runs
        learning_rate = 2e-4,
        fp16 = not is_bf16_supported(),
        bf16 = is_bf16_supported(),
        logging_steps = 25,
        eval_steps = 25,
        eval_strategy = "steps",
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "/Utilisateurs/umushtaq/emotion_analysis_comics/outputs_dir_tmp",
        report_to = "none",     # For Weights and Biases
        load_best_model_at_end=True,
        metric_for_best_model="eval_loss",

        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        dataset_num_proc = 4,
        max_seq_length = 2048,
    )

# %%
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = UnslothVisionDataCollator(model, tokenizer), # Must use!
    train_dataset = comics_mm_dataset_train,
    eval_dataset = comics_mm_dataset_eval,
    args = args,
)

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA H100 NVL. Max memory = 93.003 GB.
# 30.836 GB of memory reserved.

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 602 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 2
# \        /    Total batch size = 8 | Total steps = 225
#  "-____-"     Number of trainable parameters = 235,929,600
# 🦥 Unsloth needs about 1-3 minutes to load everything - please wait!
#     <div>
#
#       <progress value='225' max='225' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [225/225 37:02, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.099600</td>
#       <td>0.140835</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.094300</td>
#       <td>0.143142</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.090700</td>
#       <td>0.138553</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.059700</td>
#       <td>0.154810</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.060100</td>
#       <td>0.147008</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.049900</td>
#       <td>0.155361</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.038700</td>
#       <td>0.179822</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.032600</td>
#       <td>0.179585</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.033500</td>
#       <td>0.177836</td>
#     </tr>
#   </tbody>
# </table><p>
# Could not locate the best model at outputs/checkpoint-75/pytorch_model.bin, if you are running a distributed training on multiple nodes, you should activate `--save_on_each_node`.
# TrainOutput(global_step=225, training_loss=0.0621332229508294, metrics={'train_runtime': 2230.8594, 'train_samples_per_second': 0.81, 'train_steps_per_second': 0.101, 'total_flos': 6.04819658094937e+16, 'train_loss': 0.0621332229508294, 'epoch': 2.966887417218543})

# %%
FastVisionModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MllamaForConditionalGeneration(
#       (vision_model): MllamaVisionModel(
#         (patch_embedding): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14), padding=valid, bias=False)
#         (gated_positional_embedding): MllamaPrecomputedPositionEmbedding(
#           (tile_embedding): Embedding(9, 8197120)
#         )
#         (pre_tile_positional_embedding): MllamaPrecomputedAspectRatioEmbedding(
#           (embedding): Embedding(9, 5120)
#         )
#         (post_tile_positional_embedding): MllamaPrecomputedAspectRatioEmbedding(
#           (embedding): Embedding(9, 5120)
#         )
#         (layernorm_pre): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (layernorm_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (transformer): MllamaVisionEncoder(
#           (layers): ModuleList(
#             (0-12): 13 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#             (13): MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#             (14-31): 18 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (global_transformer): MllamaVisionEncoder(
#           (layers): ModuleList(
#             (0-7): 8 x MllamaVisionEncoderLayer(
#               (self_attn): MllamaVisionSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=1280, out_features=1280, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=1280, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1280, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaVisionMLP(
#                 (activation_fn): GELUActivation()
#                 (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#                 (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#               )
#               (input_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#               (post_attention_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#       (language_model): MllamaForCausalLM(
#         (model): MllamaTextModel(
#           (embed_tokens): Embedding(128264, 4096, padding_idx=128004)
#           (layers): ModuleList(
#             (0): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (1): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear(
#                   (base_layer): Linear(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (2): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (3): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (4-7): 4 x MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (8): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (9-12): 4 x MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
# ...
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (38): MllamaCrossAttentionDecoderLayer(
#               (cross_attn): MllamaTextCrossSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear(
#                   (base_layer): Linear(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#                 (k_norm): MllamaTextRMSNorm((128,), eps=1e-05)
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#             (39): MllamaSelfAttentionDecoderLayer(
#               (self_attn): MllamaTextSelfSdpaAttention(
#                 (q_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (k_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=1024, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (o_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (mlp): MllamaTextMLP(
#                 (gate_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (up_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=4096, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=14336, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (down_proj): lora.Linear4bit(
#                   (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Identity()
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=14336, out_features=64, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=64, out_features=4096, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (act_fn): SiLU()
#               )
#               (input_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#               (post_attention_layernorm): MllamaTextRMSNorm((4096,), eps=1e-05)
#             )
#           )
#           (norm): MllamaTextRMSNorm((4096,), eps=1e-05)
#           (rotary_emb): MllamaRotaryEmbedding()
#         )
#         (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#       )
#       (multi_modal_projector): Linear(in_features=7680, out_features=4096, bias=True)
#     )
#   )
# )

# %%
def convert_to_conversation_test(row):
  
    comics_title = row.comics_title
    image_path = row.image_path
    labels = row.emotion_c
    
    utterances_l = eval(row['utterance'])
    pg_utterances = "\n".join(f"{i+1}. {title}" for i, title in enumerate(utterances_l))
  
    instruction = build_generation_instruction(comics_title, pg_utterances)
    image = build_image_modality(image_path)
    
    conversation = [
        { "role": "user",
          "content" : [
            {"type" : "text",  "text"  : instruction},
            {"type" : "image", "image" : image} ]
        },
        { "role" : "assistant",
          "content" : ""
        },
    ]
    return { "messages" : conversation }
pass

# %%
df_test = df[df.split == "TEST"].reset_index(drop=True)

# %%
comics_mm_dataset_test = [convert_to_conversation_test(row) for _, row in df_test.iterrows()]

# %%
len(comics_mm_dataset_test)
# Out:
# 156

# %%
comics_mm_dataset_test[0]
# Out:
# {'messages': [{'role': 'user',
#    'content': [{'type': 'text',
#      'text': '### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. HOW\'S IT GOING?\n2. HEY.\n3. CAN I GET YOU ANYTHING?\n4. JUST A COKE.\n5. OKAY. COMING UP.\n6. THANKS.\n7. HOW IS IT OUT THERE? GETTING HOT?\n8. IT\'S ALL RIGHT.\n9. ONE COKE. ENJOY.\n10. @ONCE UPON A TIME…\n11. @… IN A FAR OFF KINGDOM…\n\n'},
#     {'type': 'image',
#      'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3968x6070>}]},
#   {'role': 'assistant', 'content': ''}]}

# %%
#comics_mm_dataset_test[0]['messages'][0]['content'][1]['image']

# %%
raw_outputs = []

for message in tqdm(comics_mm_dataset_test):
    
    input_text = tokenizer.apply_chat_template(message['messages'], add_generation_prompt = True)
    image = message['messages'][0]['content'][1]['image']
    #print(input_text)
    #break
   
    inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")
    #print(inputs['input_ids'])
    #print(tokenizer.decode(inputs['input_ids'][0]))
    #break
    
    #output = model.generate(input_ids=inputs, max_new_tokens=128)[0]
    output = model.generate(**inputs, max_new_tokens=512)[0]
    
    #input_length = inputs.shape[1]
    #generated_tokens = output[input_length:]
    
    #decoded_output = tokenizer.decode(generated_tokens, skip_special_tokens=True)  
    decoded_output = tokenizer.decode(output, skip_special_tokens=True)
    raw_outputs.append(decoded_output)
# Out:
# 100%|██████████| 156/156 [12:28<00:00,  4.80s/it]

# %%
len(raw_outputs)
# Out:
# 156

# %%
raw_outputs
# Out:
# ['user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. HOW\'S IT GOING?\n2. HEY.\n3. CAN I GET YOU ANYTHING?\n4. JUST A COKE.\n5. OKAY. COMING UP.\n6. THANKS.\n7. HOW IS IT OUT THERE? GETTING HOT?\n8. IT\'S ALL RIGHT.\n9. ONE COKE. ENJOY.\n10. @ONCE UPON A TIME…\n11. @… IN A FAR OFF KINGDOM…\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'neutral\'], [\'neutral\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. … THERE LIVED FOUR STRAPPING YOUNG LADS WHO WERE, AS LADS TEND TO DO, CAUSING A HAIR OF TROUBLE FOR THE CITIZENS OF THE REALM.\n2. YOU SEE, THEIR CARRIAGE WAS BLOCKING THE MAIN ROAD IN THE TOWNSHIP, AND THE LOCALS COULD NOT GET THEIR WARES TO MARKET.\n3. # #@# NON-FAT! PULL OVER!\n4. IT\'S THAT % # # # @ LADY COP!\n5. THE SITUATION WAS BECOMING QUITE UNTENABLE, WHEN ALONG CAME A GRAND AND AUGUST PRINCESS WHO WAS, AS PRINCESSES TEND TO BE, EAGER TO HELP.\n6. YEAH, THERE THEY ARE NOW. THEY\'RE DRIVING RIGHT DOWN DANGER AT FIFTEEN MILES PER HOUR. JESUS. I GOT THEM.\n7. IF DORIS CALLS AGAIN, TELL HER I\'M ALREADY HERE. SHE\'LL KEEP WHINING ANYWAY, BUT YOU MIGHT AS WELL TELL HER.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'sadness\'], [\'sadness\'], [\'anger\'], [\'anger\'], [\'sadness\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. IT\'S A HUNDRED AND FOUR DEGREES IN THE SHADE, I\'M SUPPOSED TO BE INSIDE DOING THE WEEKLY REPORTS, AND I\'M DRAGGED AWAY AGAIN BY YOU DINGBATS.\n2. I JUST WASHED THIS UNIFORM AND NOW IT\'S ALREADY SOAKED THROUGH. JESU
. WHAT\'RE WE SUPPOSED TO DO, CARRY IT?!\n11. HEY! KRUNCH COULD PUT IT ON HIS HEAD AND WALK IT OVER, BALANCE IT. HE\'S GOT NOTHING UP THERE TO DAMAGE.\n12. I COULD FIND SOMETHING OF YOURS TO DAMAGE!\n13. LOOK, IT\'S TOO HOT TO FIGHT.\n14. AND FRANKLY, I\'D RATHER HAVE YOU GUYS KNOCKING EACH OTHER AROUND OUT IN THE SAND THAN HERE IN THE TOWN.\n15. I GET A LITTLE TIRED OF BEING CALLED OUT OF THEA.C. EVERY TIME A DINGBAT DOES SOMETHING STUPID. WHICH IS OFTEN.\n16. I\'LL ESCORT YOU TO THE VALLEY. COME BACK IN A BIT TO PICK YOU UP.\n17. YOU GOT MY CELL. CALL ME WHEN YOU\'RE READY.\n18. YOU FOLLOW THE RULES, YOU STAY SAFE, WE FORGET ABOUT THE TICKET. OKAY?\n19. AH, LADY COP! YOU\'RE THE BEST!\n20. GOOD LOOKS, WHAT THE HELL IS WRONG WITH YOU?!\n21. WHAT\'D I JUST SAY ABOUT THAT? ARE YOU EVEN LISTENING?!\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'fear\',\'sadness\'], [\'surprise\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'neutral\'], [\'neutral\'], [\'anger\'], [\'anger\'], [\'anger\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AT THAT SAME MOMENT, IN THE FAR EAST, AN OGRE SPIED A MAN DOING EVIL AND JUMPED OFF HIS PERCH TO INTERVENE.\n2. #HA HA HA HA HA HA HA HA HA HA HA HA HA HA\n3.   HA HA HA HA HA HA HA HA HA HA HA HA\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. NOW, I GRANT YOU, MOST OGRES ARE NOT KNOWN FOR THEIR HEROIC DEEDS.\n2. #GAHHH!\n3. BUT PERHAPS THAT IS NOT THE FAULT OF OGRES.\n4. I DIDN\'T DO IT… IT WAS SEAN… SEAN HAD THE GUN. YOU SEE THAT, MAN… IT WAS… IT WAS…\n5. #HEE HEE HEE HEE\n6. NO, I BELIEVE THE FAULT WITH THAT PARTICULAR PRESUMPTION FALLS UPON OUR SHOULDERS.\n7. SEAN, MAN, I WAS JUST… WE WEREN\'T GOING TO SHOOT…\n8. IT\'S NOT FAIR… NOTHING\'S FAIR…\n9. #HAHAHAHAHAHAHA\n10. YOU SEE, OGRES ARE COMPLICATED CREATURES, AND ONE OGRE IS NOT LIKE ANOTHER.\n11. PLEASE DON\'T… I… WHATEVER YOU WANT… I DIDN\'T EVEN DO IT… I\'LL JUST DO… WHATEVER…\n12. #HAHAHAHA\n13. AND WE SHOULD NOT JUDGE THEM AS A WHOLE…\n14. #HA HA HA HA HA HA\n15. #HA HA HA HA\n16. … BUT INSTEAD TAKE EACH AS THEY COME TO US.\n17. #HA HA HA HA HA\n18. @YOU SHOULDN\'T FEEL BAD ABOUT THESE GUYS PASSING. THIS IS SMALL-TIME, LOCAL STUFF. I TOLD YOU THAT WHEN YOU AUDITIONED.\n19. @IT\'S BELOW YOU ANYWAY.\n20. @I ACTUALLY HAVE SOMETHING BETTER I WANT TO TALK ABOUT.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\',\'sadness\'], [\'anger\', \'fear\'], [\'anger\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'joy\'], [\'anger\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'joy\'], [\'anger\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\'], [\'joy\'], [\'anger\'], [\'joy\'], [\'anger\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. YOU TOLD ME IT WAS BELOW ME SO I\'D GET A BIGGER OFFER.\n2. I\'M TIRED OF THIS.\n3. @I\'M NOT HERE ARGUING WITH YOU, JACK. I\'M JUST SAYING WHAT WE BOTH KNOW. IT\'S A BLESSING THAT IT DIDN\'T WORK OUT.\n4. @WHO NEEDS TO HEAR YOU IN TENNESSEE? EVERYONE IN TENNESSEE ALREADY BELIEVES IN WHAT YOU DO.\n5. @LET SOME OTHER JACK RYDER COPYCAT TELL THOSE HICKS HOW SMART THEY ARE.\n6. @THIS NEW THING IS MEGA-BIG, A CHANCE TO REACH EVERYONE. IT\'S A NEW SMALLER CABLE NETWORK, GTN, BUT THEY\'RE ON ALL THE PROVIDERS.\n7. @THEY GOT BIG BACKING. THEY\'RE GOING TO GROW. THIS IS GETTING IN ON THE GROUND FLOOR OF THE NEXT BIG THING.\n8. @AND THEY REACHED OUT ABOUT YOU, SPECIFICALLY.\n9. BECAUSE I\'LL GET THEM HEADLINES THEY\'LL GET EYES ON, AND THEY DON\'T CARE WHAT THE HEADLINES ARE FOR.\n10. " WHO\'D HIRE RYDER AFTER HIS INFAMOUS ON-AIR WHACKO RANT GOT HIM FIRED FROM NBS?!\n11. " TUNE IN AT ELEVEN! "\n12. @THEY\'RE BASED IN NEW YORK. THEY WANT TO SEE YOU TODAY. IT\'S A TRAIN RIDE. YOU GO IN, YOU MEET WITH THEM, WHAT\'S THE HARM?\n13. @IT\'S REAL MONEY AND REAL EXPOSURE.\n14. @I MEAN THIS AS A FRIEND, JACK, BUT YOU GOT TO TRUST ME ON THIS. I\'M LOOKING OUT FOR YOU. I WANT YOU TO BE HAPPY.\n15. @HAPPY AND { € A $ # RICH.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'anger\'], [\'surprise\'], [\'neutral\'], [\'surprise\'], [\'neutral\'], [\'sadness\', \'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. BUT ENOUGH TALK OF OGRES, FOR I MUST INTRODUCE YOU TO TWO PRINCES WHO WERE THAT DAY GATHERED TO EAT.\n2. I\'M NERVOUS.\n3. DON\'T START.\n4. WHO WERE THAT DAY WAITING FOR YET ANOTHER PRINCE TO ARRIVE.\n5. THIS IS A BIG DEAL TO ME.\n6. I\'M AWARE. BUT YOU HAVING ANOTHER ONE OF YOUR PANIC ATTACKS RIGHT NOW ISN\'T GOING TO HELP ANYTHING.\n7. THIS GUY\'S A PROFESSIONAL. SO ARE WE. THAT\'S ALL IT IS.\n8. THE LOFTY WARLORD IS LECTURING ME ABOUT PROFESSIONALISM?\n9. HIDING BEHIND A BEARD AND A SWORD ISN\'T A CAREER, IT\'S A GAME.\n10. WE\'RE BOTH SUPERHEROES. I DON\'T NEED YOU OF ALL PEOPLE JUDGING ME.\n11. WHO\'S JUDGING YOU?\n12. I\'M JUST SAYING, CALM DOWN AND LOOK NORMAL.\n13. LET\'S JUST TRY TO BE NORMAL, OKAY?\n14. YOU AND ALL THE NORMAL.\n15. WHAT\'S NORMAL?\n16. BEATS ME, FELLOWS.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'fear\'], [\'fear\'], [\'surprise\'], [\'fear\'], [\'fear\',\'surprise\'], [\'fear\'], [\'surprise\'], [\'fear\'], [\'anger\'], [\'fear\',\'surprise\'], [\'fear\'], [\'fear\'], [\'anger\'], [\'surprise\'], [\'anger\',\'sadness\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AND THEN, FINALLY, THE THREE GLORIOUS PRINCES OF THE REALM WERE UNITED!\n2. GUESS WHO MADE THE TRADE AND GOT THE THING?!\n3. EH, YOU\'LL NEVER GUESS, IT WAS ME!\n4. METAMORPHO!\n5. WONDERFUL. THE WAITRESS IS COMING OVER. YOU COULDN\'T PUT ON A COAT, COME IN THE DOOR?\n6. YOU HAVE IT HERE? CAN I SEE IT?\n7. I\'M GAS. I CAN\'T CARRY THINGS.\n8. IT\'S IN THE CAR.\n9. YOU LEFT IT IN THE CAR?! WHERE\'S YOUR CAR?\n10. OUTSIDE. I GOT A SPOT ON THE STREET.\n11. YOU GUYS ORDER? ANYTHING LOOK GOOD?\n12. DOES IT HURT?\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'surprise\', \'joy\'], [\'surprise\'], [\'sadness\'], [\'sadness\'], [\'surprise\'], [\'joy\'], [\'surprise\', \'joy\'], [\'sadness\',\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. C\'MON, WE\'RE GOING.\n2. WHAT\'S WITH YOU?\n3. HE JUST GOT HERE! LOOK WHAT HE\'S BEEN THROUGH! LET HIM EAT.\n4. I COULD EAT LATER.\n5. IT\'S NO TROUBLE.\n6. IT\'S IN HIS CAR.\n7. WE\'RE LEAVING. HURRY UP.\n8. ALL RIGHT, I\'M COMING!\n9. GOD, EVERYTHING\'S AN ORDER TO YOU. YOU\'RE NOT IN THE MILITARY ANYMORE, TRAVIS. I\'M NOT YOUR PRIVATE. YES, SIR! NO, SIR!\n10. DON\'T GET RUFFLED. I PARKED RIGHT OUTSIDE, NOT IN THE LOT.\n11. I\'M SURE IT\'S FINE.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'surprise\'], [\'surprise\', \'joy\'], [\'neutral\'], [\'joy\'], [\'neutral\'], [\'anger\'], [\'fear\',\'surprise\'], [\'anger\',\'surprise\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AS OUR THREE PRINCES SET OFF UPON THEIR QUEST, WE TURN OUR ATTENTION NOW TO A GREAT AND POWERFUL WIZARD…\n2. WE HAVE SPENT A HUNDRED GENERATIONS PREPARING FOR THIS EVIL TO ARISE.\n3. NOW THEY HAVE FINALLY REVEALED THEMSELVES. THEY ARE HERE.\n4. THE TRUE HUNT BEGINS.\n5. AND HIS SACRED AND MOST TRUSTWORTHY SERVANT… THE GOOD KNIGHT OF THE REALM.\n6. THEY MAY RUN.\n7. THEY WILL DIE.\n8. THERE IS, HOWEVER AND MOST UNFORTUNATELY, A COMPLICATION THAT I FEAR MAY TEST YOU, MANHUNTER.\n9. SOMETHING THAT MAY INSPIRE YOUR MERCY.\n10. THERE IS NO MERCY IN THE HUNT.\n11. IF THAT IS YOUR TEST, IT IS PASSED.\n12. MY BOY, POOR BOY, I HAVE WATCHED YOU SINCE YOU WERE A BABE. I HAVE SEEN YOU FORGED, AND I AM SORRY FOR WHAT YOU MUST DO…\n13. MARK, MY SON…\n14. … THEY\'RE CHILDREN.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'neutral\'], [\'fear\'], [\'fear\'], [\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'fear\'], [\'fear\'], [\'sadness\'], [\'sadness\'], [\'sadness\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. BACK, THEN, TO OUR LADS, WHO WERE ENJOYING THEMSELVES MIGHTILY AS THEY SPED THROUGH THE HEAT OF THE NEARBY DESERT.\n2. THEIR GRANDIOSE AND GRACIOUS YELP SINGING THROUGH THE AIR.\n3. DINGBATS OF DANGER STREET ON THE MOTHER Ø < % @ ¥ RISE, MOTHER $# % # $ #!\n4. # @ $ # # #!\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'joy\'], [\'anger\',\'surprise\'], [\'fear\',\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. NOT FAR OFF, THE THREE GOOD PRINCES RODE THEIR OWN STEED AT A STEADIER PACE.\n2. WE\'RE FAR ENOUGH, AND THERE\'S NO ONE HERE. CAN I LOOK AT IT?\n3. THERE\'LL BE PLENTY OF TIME WHEN WE STOP.\n4. I DON\'T NEED YOU DROPPING IT IN THE ROAD.\n5. YOU\'RE TOO HARD ON THE KID.\n6. LET HIM SEE. WHAT\'S THE HARM?\n7. KID? STARMAN?\n8. HE\'S OLDER THAN THE TWO OF US COMBINED. THEY JUST HAVE DIFFERENT YEARS ON HIS PLANET.\n9. NO ONE\'S OLDER THAN YOU ON ANY PLANET.\n10. LET ME SEE IT.\n11. YOU\'RE MEAN WHEN YOU WANT THINGS. IT SHOULD BE THE OTHER WAY.\n12. HERE.\n13. ENJOY.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'anger\',\'surprise\'], [\'joy\'], [\'anger\', \'disgust\'], [\'surprise\'], [\'joy\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'anger\', \'disgust\'], [\'sadness\',\'surprise\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. HOW LONG HAVE WE BEEN WAITING FOR THIS?\n2. IT\'LL BE WORTH IT, YOU\'LL SEE. WHEN WE GET THIS DONE… WHEN PEOPLE FIND OUT, BIG PEOPLE, I\'M SAYING…\n3....THERE\'S NOTHING LIKE BEING IN THE LEAGUE. IT\'S FIRST CLASS ALL THE WAY.\n4. IT\'S NOT ABOUT THAT.\n5. IT\'S AN OPPORTUNITY FOR SERVICE.\n6. OH, LISTEN TO YOU.\n7. HOW MANY FACES YOU WEAR.\n8. JESUS, IT\'S BEAUTIFUL.\n9. YOU ALMOST FEEL SORRY FOR DARKSEID.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\', \'disgust\',\'surprise\'], [\'joy\'], [\'joy\'], [\'sadness\'], [\'joy\'], [\'joy\'], [\'joy\'], [\
REVENT THESE DEGENERATES FROM ILLEGALLY TAKING WHAT THEY NEVER EARNED.\n19. ALL OF THAT IS PAID FOR BY YOU. BY SALES TAX AND FEDERAL TAX AND WHATEVER OTHER KIND OF TAX THEY\'RE SCRAPING OUT OF YOU.\n20. A MAYOR LETS HIS CITY ROT AND YOU MISS A PAYMENT ON YOUR TRUCK, AND YOU DON\'T KNOW WHY. YOU DON\'T SEE THAT IT\'S ALL CONNECTED.\n21. THE VICTIMS OF CRIME EXTEND FAR OUT FROM THE MOMENTS OF CRIME. THAT\'S THE TRUTH, AND TO DENY THAT WOULD BE PUTTING YOUR HEAD IN THE SAND.\n22. AND WE\'RE NOT--\n23. OKAY, THAT\'S GREAT, JACK. WHY DON\'T WE TAKE A BREAK THERE? I LOVE IT.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'anger\'], [\'anger\'], [\'neutral\'], [\'anger\'], [\'anger\'], [\'neutral\'], [\'neutral\'], [\'anger\'], [\'anger\'], [\'neutral\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. ARE YOU SURE? I CAN DO TEN MORE MINUTES EASY.\n2. I\'VE ALSO GOT A SEGMENT THAT LEANS MORE INTO HUMOR, SORT OF A " TOP TEN " COUNTDOWN THING.\n3. NO, NO, WE\'RE FINE. YOU DID GREAT.\n4. THE EXPECTATION WAS EXCEEDED, HONESTLY. I KNOW YOU DIDN\'T HAVE ALL THE TIME IN THE WORLD TO PUT THIS TOGETHER.\n5. WE\'RE REALLY GRATEFUL.\n6. OKAY, OKAY, GREAT.\n7. JUST LET ME KNOW IF YOU NEED ANYTHING ELSE.\n8. NOPE, I THINK THAT\'S IT.\n9. IF YOU WANT TO GO BACK TO MAKEUP, THEY\'LL CLEAN YOU UP.\n10. GET YOUR MIC OFF FIRST.\n11. THAT SOUNDS GOOD. DO YOU NEED ME AFTER THAT ANYWHERE?\n12. I DON\'T KNOW IF I NEED TO BE HERE IN THE BUILDING OR…\n13. MY HOTEL\'S NOT TOO FAR.\n14. TOTALLY UNDERSTAND. WHY DON\'T YOU GO BACK TO YOUR HOTEL, RELAX.\n15. LET US TAKE A LOOK AT SOME THINGS, SEND THEM UPSTAIRS. I\'M SURE THE BOYS WILL WANT A MEET WITH YOU.\n16. SO WE\'LL GIVE YOU A CALL. IF THAT\'S OKAY?\n17. YEAH.\n18. GREAT, EXCELLENT, THAT ALL WORKS.\n19. I\'LL JUST… YEAH.\n20. I\'LL SEE YOU LATER. LOOKING FORWARD TO IT.\n21. THANK YOU SO MUCH.\n22. THANK YOU, JACK!\n23. REALLY IMPRESSED!\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. BUT WHAT OF OUR PRINCESS, YOU ASK? AT THAT MOMENT SHE WAS IDLING AWAY THE TIME, PLAYING GAMES WITH ANOTHER MEMBER OF HER COURT…\n2. ANY PROBLEM WITH THAT CALL, CHIEF?\n3. … LETTING HER MIND WANDER INTO YEARS PAST.\n4. AFTER THE FIRST ONE --CHICK --THE REST COMES EASY.\n5. DROPPING ONE BY ONE --LIKE CARDS.\n6. WHEN SHE WAS YOUNG AND HAD YET TO DISCOVER THE WEIGHT OF THE CROWN THAT SHE WAS BOTH BLESSED AND CURSED TO WEAR.\n7. PLENTY OF CARDS LEFT IN MY DECK --TO DEAL TO THE CHICKS I\'M GOING TO MEET.\n8. CHIEF?\n9. WHAT?\n10. NOTHING, CHIEF, JUST ASKING ABOUT THE… THE CALL, Y\'KNOW, FROM DORIS. EARLIER.\n11. OH, OH, YEAH, THAT WAS NOTHING.\n12. JUST THE DINGBATS BEING DINGBATS OUT IN THE MIDDLE OF DANGER STREET.\n13. WE\'LL GET THE SAME STUPID CALL TOMORROW, I BET.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'anger\',\'surprise\'], [\'neutral\'], [\'joy\'], [\'joy\'], [\'sadness\'], [\'joy\'], [\'anger\',\'surprise\'], [\'anger\',\'surprise\'], [\'fear\'], [\'fear\'], [\'anger\',\'surprise\'], [\'anger\',\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AND WHILE THE PRINCESS RESTED, OUR THREE PRINCES WERE HARD AT WORK TRYING TO MAKE A BETTER WORLD.\n2. SO DO WE SAY IT OR DO WE HAVE TO, LIKE, SING IT? AND DO YOU THINK IT\'S, LIKE, JUST ONCE OR OVER AND OVER?\n3. LOOKING BACK, DESPITE THE HORRORS THAT FOLLOWED, ONE STILL ENVIES THEIR AMBITION.\n4. #% # $ # #.\n5. I TOLD YOU WE NEEDED A ROCK.\n6. I DIDN\'T ASK ALL THE QUESTIONS IN THE WORLD. THEY GAVE ME THE WORDS AND SAID JUST DO THE WORDS.\n7. I HANDED OVER MY ARM, THEN I SAID OKAY, THANK YOU, HAVE A NICE DAY, AND I LEFT.\n8. " DO THE WORDS. " WHAT DOES THAT MEAN?\n9. THIS IS HOW EVERYONE GETS IN TROUBLE AND NOTHING GETS DONE.\n10. YOU\'RE OVERTHINKING THINGS.\n11. WE\'RE HERE. WE GOT EVERYTHING WE NEED.\n12. THE THREE OF US ARE GOING TO BE GOLDEN.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'surprise\'], [\'joy\'], [\'fear\'], [\'joy\'], [\'fear\',\'sadness\'], [\'sadness\'], [\'surprise\'], [\'sadness\'], [\'sadness\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. YOU EVER MET HIM BEFORE, LIKE IN A BIG CRISIS BATTLE OR SOMETHING?\n2. OH SURE, PLENTY OF TIMES. HE\'S AROUND HERE ALL THE TIME, ALWAYS LOOKING FOR HIS MATH ANTI-THING, WHATEVER THAT IS.\n3. DON\'T WORRY, HE\'S BIG, BUT WHO ISN\'T, YOU KNOW? EVERYONE\'S GOT THEIR ANGLE.\n4. I\'M GLAD HE\'LL BE T
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. THE LADS WAITED SOME TIME FOR THEIR DEAR FRIEND TO RECOVER SO THAT THEY MIGHT RESUME THEIR FOLLY. THEIR PATIENCE, HOWEVER, WAS NOT INFINITE.\n2. IF HE\'S NOT SAYING THE WORD, I GOT A WORD.\n3. YOU HEAR THAT WORD, BANANAS?\n4. I DON\'T HEAR ANY WORD, NON-FAT.\n5. WHAT ABOUT YOU, KRUNCH?\n6. WHAT? I DON\'T GET IT. WHAT\'S THE WORD?\n7. GO, MY FRIEND.\n8. GO IS THE € $ # # ## % WORD!\n9. #WOOOOOOO!\n10. #URRLKKCHHH.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'sadness\'], [\'anger\'], [\'surprise\'], [\'anger\'], [\'surprise\'], [\'surprise\'], [\'joy\'], [\'anger\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. MILES AND MILES TO THE EAST, THE OGRE SET OUT ON A JOURNEY THAT HE HOPED WOULD LEAD TO TRIUMPH AND FAME.\n2. @LOOK, THIS IS AMAZING! THEY WANT TO SPEAK TO YOU TONIGHT. YOU MUST\'VE MADE A HELL OF AN IMPRESSION.\n3. TONIGHT?\n4. @THESE GUYS ARE IN A HURRY. THEY\'RE SETTING UP A NATIONAL NEWS NETWORK THAT THEY WANT TO COMPETE WITH THE BIG GUNS.\n5. @I KNOW CROSSTOWN TRAFFIC IS TOUGH THIS TIME OF DAY, BUT THEY HAVE AN OPENING LITERALLY NOW. CAN YOU MAKE IT?\n6. I\'LL BE THERE.\n7. WITH BELLS ON.\n8. @NOW, I GOT TO TELL YOU, JUST SO YOU DON\'T FREAK OUT, THE OWNERS OF THE NETWORK, THESE BILLIONAIRES…\n9. @THEY EARNED THEIR MONEY FAST. THESE ARE SOME OF THE SMARTEST PEOPLE IN AMERICA. THEY GOT IT QUICK.\n10. @BUT JUST SO YOU KNOW…\n11. @… THEY\'RE PRETTY YOUNG.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'surprise\'], [\'surprise\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'neutral\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AS THE OGRE LEAPED INTO UNCERTAINTY, OUR THREE SPLENDID PRINCES SET ABOUT TO CONTROL THEIR OWN FATE.\n2. SO TO SPEAK.\n3. YOU SEE THIS? THIS IS MY DIAMOND FORM. UNBREAKABLE.\n4. JUST IN CASE DARKSEID HAS A LITTLE FIGHT LEFT IN HIM.\n5. I\'M READY, I\'M READY.\n6. HERE IT COMES. IT\'S OPENING, SEE?\n7. GUESS WE DIDN\'T HAVE TO SING THE WORDS. HAHAHA.\n8. GOODBYE, DARKSEID, HELLO, JUSTICE LEAGUE OF AMERICA MEMBERSHIP.\n9. #HAHAHA.\n10. WHAT?\n11. WHO THE HELL IS THAT?!\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'neutral\'], [\'neutral\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'surprise\'], [\'anger\',\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. AND THAT WAS WHEN THE GIANT ARRIVED!\n2. THE SKY IS FALLING!\n3. AND THE GIANT, AS GIANTS TEND TO DO, CHANGED EVERYTHING.\n4. THE SKY IS FALLING!\n5. WHAT? WHAT\'S GOING ON?\n6. HEY PAL, YOU\'RE NOT WHO WE WERE EXPECTING. JUST GIVE US A SECOND!\n7. WE\'RE ALL A LITTLE LOST HERE, OKAY? WHY DON\'T YOU CALM DOWN A BIT?\n8. THE TEAM WILL SEE YOU NOW, MR. RYDER.\n9. YOU CAN GO RIGHT IN.\n10. THE SKY IS FALLING!\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\'], [\'anger\'], [\'anger\'], [\'anger\'], [\'fear\',\'surprise\'], [\'anger\'], [\'anger\'], [\'neutral\'], [\'neutral\'], [\'anger\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Danger Street #1\n\nUtterances to Classify:\n1. WHAT DID YOU DO?!\n2. STOP! JUST STOP IT!\n3. THE SKY IS FALLING!\n4. OKAY, JACK, LET\'S INTRODUCE EVERYONE. THESE ARE MY PARTNERS HERE AT GT.\n5. ABDUL SMITH, YOU\'VE PROBABLY HAD HIS NAME ON YOUR SHOES. J.P. HOUSTON, YOU\'VE PROBABLY HAD HIS GAS IN YOUR CAR.\n6. CECIL SUNBEAM, YOU PROBABLY HAVE HIS MOVIES ON YOUR DVR.\n7. AND YOU ICAN CALL ME THE COMMODORE, AND MAYBE YOU HAVEN\'T RIDDEN ON ONE OF MY YACHTS, BUT YOU WILL.\n8. THE SKY IS FALLING!\n9. #AAAAAA!\n10. WHAT?\n11. THE SKY IS FALLING!\n12. NO IT ISN\'T…\n13. TRAVIS… TRAVIS…\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\', \'fear\'], [\'anger\', \'fear\'], [\'fear\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'anger\', \'disgust\',\'surprise\'], [\'fear\'], [\'fear\'], [\'surprise\'], [\'fear\'], [\'anger\', \'fear\'], [\'fear\']]"}',
# ...
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. IT\'S A MIRACLE.\n2. IN A TOWN FORGED BY A MIRACLE.\n3. @KREEGS AND I ARE HEADING BACK.\n4. @WHAT\'S THE SITREP?\n5. @HAVE YOU SECURED DANIEL YET?\n6. I DON\'T KNOW WHAT\'S HAPPENING, BUT WHATEVER IT IS, IT MEANS SOMETHING.\n7. AND I DON\'T THINK FUCKIN\' TED IS THE GUY TO FIGURE THAT OUT.\n8. GET OUT OF HERE.\n9. Don\'t look the proverbial gift horse in the mouth.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'joy\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'fear\',\'surprise\'], [\'fear\',\'sadness\'], [\'anger\'], [\'anger\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. Just go.\n2. YOU FUCKIN\'… IDIOT…\n3. HE\'S JUST SOME… DIPSHIT… HE AIN\'T THE… MESSIAH…\n4. I KNOW HE ISN\'T, TREY…\n5. BUT HE DID THE IMPOSSIBLE BECAUSE OF GOD. FIGURE THAT BUYS HIM SOMETHING.\n6. SHIT.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\'], [\'anger\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'sadness\'], [\'anger\', \'fear\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. WHERE THE FUCK IS HE?\n2. UNITY?\n3. SH-SHE LET THEM GO!\n4. HE CAN\'T DIE OUT OF TOWN!\n5. IT\'S AMAZING! IT\'S --\n6. I LET HIM GO.\n7. HE\'S SPECIAL, TED. ABOUT TIME WE RECOGNIZED THAT.\n8. HE ISN\'T SPECIAL. HE\'S FUCKING LUCKY.\n9. KREEGS AND I HEALED UP OUTSIDE OF TOWN, TOO. THIS IS BIGGER THAN DANIEL.\n10. EVEN IF IT WASN\'T, GIRL--\n11. THAT KID SHOT ME IN THE FACE.\n12. HE COULD BE JESUS HIMSELF, AND I\'M STILL GONNA TAKE A CRACK AT HIM, YOU FUCKIN\' HEAR ME?\n13. PATIENCE, EVERYONE…\n14. PATIENCE.\n15. YOU OKAY, BOSS?\n16. WE\'RE ALL OKAY, EVENTUALLY.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\', \'fear\',\'surprise\'], [\'surprise\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\',\'surprise\'], [\'surprise\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'joy\'], [\'anger\', \'joy\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'fear\',\'surprise\'], [\'anger\', \'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. YOU LET THEM GET AWAY?\n2. YEAH. YEAH, I DID.\n3. SAY THE WORD AND I\'LL--\n4. YOU\'LL WHAT?\n5. SHE\'S FORGIVEN. YOU ALL ARE.\n6. THEY WON\'T LEAVE TOWN. THEY KNOW WE\'LL HUNT THEM AND THERE\'S NO HEALING OUT THERE.\n7. WAIT, BUT…\n8. THERE IS, THOUGH. WE ALL HEALED AT THE EDGE. THE STILLNESS IS--\n9. DIFFERENT. I\'LL EXPLAIN AT THE  TREEHOUSE. \n10. MEET ME THERE IN TWO HOURS. EVERYTHING HAS CHANGED…\n11. AND I HAVE PLANS.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\',\'surprise\'], [\'anger\',\'sadness\'], [\'fear\'], [\'anger\',\'surprise\'], [\'joy\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'joy\'], [\'neutral\'], [\'neutral\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. ALL RIGHT, GIVE ME FIVE MINUTES-\n2. AND WE CAN HEAD OUT OF TOWN.\n3. HEAD OUT OF TOWN…?\n4. TO WHERE?\n5. THEY\'LL HUNT US DOWN. AND WE WON\'T BE ABLE TO SURVIVE THAT OUT THERE.\n6. MAYBE WE CAN…\n7. THE CURSE EXTENDS OUT OF TOWN NOW. I DON\'T KNOW HOW FAR, BUT--\n8. IT\'S NOT FAR AT ALL…\n9. NOT AT ALL…\n10. WE CHANGED THE MAP.\n11. WAIT. WHAT?\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\'], [\'joy\'], [\'surprise\'], [\'surprise\'], [\'fear\'], [\'surprise\'], [\'fear\'], [\'fear\'], [\'sadness\'], [\'sadness\'], [\'fear\',\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. WE WERE IN GALEN\'S OFFICE. YOU WERE ABOUT TO DIE.\n2. I SAW THE ORIGINAL TOWN MAP AND JUST THOUGHT… WHAT MAKES A TOWN?\n3. THE CURSE FOLLOWS ITS BORDERS, SO WHAT IF WE…\n4. CHANGED THE BORDERS.\n5. HOLY SHIT.\n6. HOLY SHIT.\n7. GALEN KNOWS.\n8. I\'M NOT SURE WHAT HE\'S GOING TO DO WITH THE INFORMATION, BUT IT\'S PROBABLY NOT GOING TO BE GOOD\n9. WE NEED TO STOP HIM.\n10. I KNOW YOU WANT TO LEAVE. BUT YOU\'VE LIVED HERE FOR DECADES, LAURA.    \n11. THESE PEOPLE MUST MEAN SOMETHING TO YOU.\n12. WE HAVE AN ADVANTAGE NOW. YOU SAW HOW UNITY TREATED YOU, HOW THE TOWNSPEOPLE REACTED TO THE NEWS OF YOUR "MIRACLE".\n13. DANIEL…\n14. YOU CAN BE THE TOWN\'S SAVIOR.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'anger\', \'fear\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\'], [\'anger\', \'fear\'], [\'anger\', \'fear\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. SO WHAT ARE WE GOING TO DO?\n2. THE WAY I SEE IT, WE HAVE A PROBLEM THAT GOES BEYOND THE SITUATION WITH DANIEL AND HIS MOTHER.\n3. NO KIDDING. THIS TOWN CAN\'T STOP TEARING ITSELF APART.\n4. IT\'S IN-FIGHTING. AND YOU KNOW WHAT THE CAUSE OF IN-FIGHTING IS?\n5. A LACK OF A COMMON ENEMY. A LACK OF A GOAL.\n6. THIS TOWN\'S STAGNATION, ITS REPETITION, IS THE REAL CAUSE OF THE UPHEAVAL.\n7. SO LET\'S CHANGE THAT.\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'surprise\'], [\'sadness\'], [\'sadness\',\'surprise\'], [\'sadness\'], [\'sadness\'], [\'sadness\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. KIDDIE COUNCIL\'S BEEN GOING A LONG TIME... \n2. THEY HAVEN\'T STEERED US WRONG YET,  MARINE. LET\'S  JUST--\n3. EXCUSE ME?\n4. GALEN WOULD LIKE TO SEE MR. KREEGS AND TED.\n5. SORRY TO KEEP YOU WAITING…\n6. WE JUST NEEDED TO HAMMER OUT SOME DETAILS FIRST.\n7. WHAT KIND OF DETAILS…\n8. AND DO ANY OF THEM INVOLVE KILLING THOSE TRAITORS?\n9. LAURA AND HER CREW…\n10. ARE NOT THE PROBLEM.\n11. TELL ME, KREEGS, HOW HAVE YOU ENJOYED YOUR TIME IN STILLWATER SO FAR?\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'surprise\'], [\'neutral\'], [\'sadness\'], [\'sadness\'], [\'surprise\'], [\'anger\',\'surprise\'], [\'anger\'], [\'anger\'], [\'surprise\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. IT\'S BEEN… PEACEFUL. ASIDE FROM SHIT LIKE THIS.\n2. "PEACEFUL".\n3. AND BORING, YEAH?\n4. SUPPOSE SO. WHY?\n5. DANIEL DIDN\'T SURVIVE BECAUSE OF A MIRACLE. HE SURVIVED BECAUSE…\n6. HIS MOTHER CHANGED THE BORDERS ON STILLWATER\'S ORIGINAL MAP.\n7. ARE YOU-- ARE YOU SERIOUS?\n8. IS THAT SO HARD TO BELIEVE? THE STILLNESS OPERATES PERFECTLY WITHIN MAN-MADE BORDERS…\n9. SO WHY NOT MAN-ALTERED BORDERS?\n10. I HAVE AN IDEA, GENTLEMEN. ONE THAT WILL ALLEVIATE BOREDOM, GIVE OUR TOWN SOMETHING TO DO. A COMMON GOAL.\n11. LET\'S EXPAND OUR WORLD SOME. THE MAP IS OF THE COUNTY.\n12. SO LET\'S CHANGE OUR BORDERS…\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'anger\',\'sadness\'], [\'neutral\'], [\'anger\',\'sadness\'], [\'surprise\'], [\'sadness\'], [\'neutral\'], [\'fear\',\'surprise\'], [\'anger\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\']]"}',
#  'user\n\n### Emotion Analysis for Comics\n\nYou are an emotion analysis expert for comic dialogue. Your task is to analyze utterances based on the immediate context.\n\nINPUT:\n- List of utterances from a page in a comic\n- An image of the comics page\n\nOUTPUT:\n- JSON with single key "emotions"\n- Value: array of emotion arrays matching utterance order\n- ONLY use these emotions: "anger", "disgust", "fear", "sadness", "surprise", "joy", "neutral"\n- NO OTHER EMOTION LABELS ARE ALLOWED\n\nRULES:\n1. Each utterance must have at least one emotion from the list above\n2. Multiple emotions per utterance are allowed\n3. Keep emotions in arrays even for single emotions\n4. Maintain exact emotion spelling and case\n5. No explanations, only JSON output\n\nExample format:\n{"emotions": [["joy"], ["anger", "fear"], ["neutral"]]}\n\nComic Information:\nTitle: Stillwater #13\n\nUtterances to Classify:\n1. " AND PAY OUR NEIGHBOURS A VISIT. "\n\nassistant\n\nassistant\n\n{\'emotions\': "[[\'joy\']]"}']

# %%
op = []

for output in raw_outputs:
    op.append(output.split("assistant\n\nassistant\n\n")[1])

# %%
op
# Out:
# ['{\'emotions\': "[[\'joy\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'neutral\'], [\'neutral\']]"}',
#  '{\'emotions\': "[[\'sadness\'], [\'sadness\'], [\'anger\'], [\'anger\'], [\'sadness\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\']]"}',
#  '{\'emotions\': "[[\'anger\', \'disgust\',\'sadness\'], [\'anger\', \'disgust\',\'sadness\'], [\'anger\', \'disgust\',\'sadness\'], [\'fear\',\'surprise\'], [\'surprise\'], [\'neutral\'], [\'anger\',\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\'], [\'anger\', \'disgust\'], [\'anger\'], [\'anger\',\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\']]"}',
#  '{\'emotions\': "[[\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'fear\',\'sadness\'], [\'surprise\'], [\'neutral\'], [\'neutral\'], [\'neutral\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'anger\', \'disgust\'], [\'neutral\'], [\'neutral\'], [\'anger\'], [\'anger\'], [\'anger\']]"}',
#  '{\'emotions\': "[[\'neutral\'], [\'joy\'], [\'joy\']]"}',
#  '{\'emotions\': "[[\'anger\',\'surprise\'], [\'anger\',\'sadness\'], [\'fear\'], [\'anger\',\'surprise\'], [\'joy\'], [\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'joy\'], [\'neutral\'], [\'neutral\'], [\'joy\']]"}',
#  '{\'emotions\': "[[\'joy\'], [\'joy\'], [\'surprise\'], [\'surprise\'], [\'fear\'], [\'surprise\'], [\'fear\'], [\'fear\'], [\'sadness\'], [\'sadness\'], [\'fear\',\'surprise\']]"}',
#  '{\'emotions\': "[[\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'fear\',\'sadness\'], [\'anger\', \'fear\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\'], [\'anger\', \'fear\'], [\'anger\', \'fear\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'sadness\'], [\'anger\', \'fear\',\'surprise\'], [\'anger\', \'fear\']]"}',
#  '{\'emotions\': "[[\'surprise\'], [\'sadness\'], [\'sadness\',\'surprise\'], [\'sadness\'], [\'sadness\'], [\'sadness\'], [\'joy\']]"}',
#  '{\'emotions\': "[[\'anger\',\'sadness\'], [\'anger\',\'sadness\'], [\'surprise\'], [\'neutral\'], [\'sadness\'], [\'sadness\'], [\'surprise\'], [\'anger\',\'surprise\'], [\'anger\'], [\'anger\'], [\'surprise\']]"}',
#  '{\'emotions\': "[[\'anger\',\'sadness\'], [\'neutral\'], [\'anger\',\'sadness\'], [\'surprise\'], [\'sadness\'], [\'neutral\'], [\'fear\',\'surprise\'], [\'anger\'], [\'surprise\'], [\'joy\'], [\'joy\'], [\'joy\']]"}',
#  '{\'emotions\': "[[\'joy\']]"}']

# %%
grounds = df_test.emotion_c.tolist()

# %%
import ast

# %%
grounds = [ast.literal_eval(x) for x in grounds]

# %%
bad_idx = []
predictions = []

for i, x in enumerate(op):
    try:
        predictions.append(json_repair.loads(x)['emotions'])
    except:
        print(i)
        bad_idx.append(i)

# %%
bad_idx.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in bad_idx:
    
    del grounds[idx]
    #del predictions[idx]

# %%
len(grounds), len(predictions)
# Out:
# (156, 156)

# %%
predictions
# Out:
# ["[['joy'], ['surprise'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['neutral'], ['neutral']]",
#  "[['sadness'], ['sadness'], ['anger'], ['anger'], ['sadness'], ['anger','sadness'], ['anger','sadness']]",
#  "[['anger', 'disgust','sadness'], ['anger', 'disgust','sadness'], ['anger', 'disgust','sadness'], ['fear','surprise'], ['surprise'], ['neutral'], ['anger','surprise'], ['joy'], ['joy'], ['joy'], ['anger', 'disgust'], ['anger'], ['anger','surprise'], ['joy'], ['joy'], ['joy']]",
#  "[['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['fear','sadness'], ['surprise'], ['neutral'], ['neutral'], ['neutral'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['neutral'], ['neutral'], ['anger'], ['anger'], ['anger']]",
#  "[['fear','sadness'], ['fear','sadness'], ['fear','sadness'], ['surprise'], ['anger','sadness'], ['surprise'], ['surprise'], ['anger','surprise'], ['sadness'], ['fear','sadness','surprise'], ['anger','sadness'], ['fear'], ['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['anger','sadness']]",
#  "[['anger'], ['anger'], ['anger'], ['fear','surprise'], ['anger']]",
#  "[['fear','surprise']]",
#  "[['anger', 'joy'], ['anger', 'joy']]",
#  "[['anger','sadness'], ['anger','sadness'], ['anger','surprise'], ['sadness'], ['fear','surprise'], ['anger']]",
#  "[['anger','surprise'], ['fear','sadness'], ['fear'], ['anger'], ['anger']]",
#  "[['anger','surprise'], ['anger']]",
#  "[['anger'], ['anger','surprise'], ['anger','sadness'], ['anger','sadness'], ['anger','surprise'], ['anger'], ['anger', 'fear'], ['anger']]",
#  "[['anger', 'joy'], ['anger', 'joy'], ['anger','surprise'], ['anger'], ['surprise', 'joy'], ['surprise', 'joy'], ['surprise', 'joy']]",
#  "[['fear','sadness'], ['anger', 'fear'], ['fear','sadness'], ['sadness'], ['anger','sadness'], ['anger','sadness'], ['sadness'], ['surprise'], ['sadness'], ['sadness'], ['sadness', 'joy'], ['sadness', 'joy'], ['sadness']]",
#  "[['anger'], ['anger'], ['anger','sadness'], ['anger','sadness'], ['anger'], ['anger','surprise'], ['anger'], ['anger','sadness'], ['anger', 'fear'], ['anger', 'joy'], ['anger','surprise']]",
#  "[['sadness'], ['anger'], ['anger', 'joy'], ['anger']]",
#  "[['fear'], ['fear','surprise']]",
#  "[['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger'], ['anger'], ['surprise'], ['anger'], ['surprise'], ['anger'], ['anger']]",
#  "[['anger','surprise'], ['anger'], ['neutral']]",
#  "[['anger', 'fear'], ['sadness'], ['fear','sadness','surprise'], ['anger', 'fear'], ['fear','surprise'], ['anger'], ['anger'], ['anger']]",
#  "[['surprise', 'joy'], ['anger'], ['joy'], ['joy'], ['joy'], ['anger'], ['anger'], ['anger'], ['anger'], ['surprise', 'joy'], ['joy']]",
#  "[['anger', 'fear'], ['anger', 'joy'], ['anger', 'joy']]",
#  "[['surprise'], ['fear','sadness'], ['surprise', 'joy'], ['surprise', 'joy'], ['surprise', 'joy'], ['surprise', 'joy'], ['surprise']]",
#  "[['sadness'], ['surprise', 'joy'], ['fear','surprise'], ['anger', 'disgust'], ['anger'], ['fear','surprise'], ['sadness', 'joy'], ['joy']]",
#  "[['anger'], ['anger', 'joy'], ['sadness', 'joy'], ['anger', 'fear','surprise'], ['anger','surprise'], ['anger', 'fear','surprise'], ['anger', 'joy']]",
#  "[['sadness'], ['sadness'], ['sadness'], ['sadness']]",
#  "[['anger','surprise'], ['joy'], ['joy'], ['joy'], ['joy'], ['anger','sadness']]",
#  "[['joy'], ['anger', 'fear'], ['anger'], ['anger'], ['anger','sadness'], ['anger','sadness']]",
#  "[['joy'], ['joy'], ['joy'], ['joy']]",
#  "[['sadness'], ['sadness'], ['sadness', 'joy'], ['sadness', 'joy']]",
#  "[['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness']]",
#  "[['sadness'], ['joy'], ['joy'], ['joy'], ['joy'], ['joy'], ['anger','sadness']]",
#  "[['fear','surprise'], ['fear','surprise', 'joy'], ['surprise', 'joy'], ['surprise', 'joy'], ['sadness','surprise'], ['anger','sadness'], ['anger']]",
#  "[['surprise'], ['joy'], ['joy'], ['surprise', 'joy'], ['joy'], ['anger'], ['anger'], ['anger']]",
#  "[['anger'], ['fear','surprise'], ['fear','surprise']]",
#  "[['joy'], ['joy'], ['fear','sadness'], ['fear','surprise'], ['sadness'], ['surprise'], ['fear','sadness'], ['sadness', 'joy'], ['sadness', 'joy']]",
#  "[['joy'], ['joy'], ['sadness', 'joy'], ['sadness', 'joy']]",
#  "[['joy'], ['joy'], ['joy'], ['anger', 'joy'], ['anger', 'joy'], ['anger', 'joy']]",
#  "[['anger', 'joy'], ['anger', 'joy']]",
#  "[['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear']]",
#  "[['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness']]",
#  "[['fear','surprise'], ['anger', 'fear'], ['fear','surprise'], ['fear','surprise'], ['anger', 'joy'], ['fear','sadness']]",
#  "[['fear','surprise'], ['fear','surprise']]",
#  "[['joy'], ['anger', 'joy']]",
#  "[['anger', 'fear'], ['fear','surprise'], ['anger'], ['anger'], ['anger','surprise'], ['anger'], ['surprise']]",
#  "[['anger'], ['fear','surprise'], ['neutral'], ['anger'], ['anger'], ['anger','surprise']]",
#  "[['joy'], ['surprise', 'joy']]",
#  "[['anger'], ['surprise'], ['anger','sadness'], ['anger','sadness'], ['anger','surprise'], ['surprise'], ['surprise'], ['anger','surprise']]",
#  "[['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'disgust'], ['fear','surprise'], ['sadness'], ['anger', 'disgust'], ['anger']]",
#  "[['anger', 'disgust'], ['anger', 'fear','surprise'], ['anger','surprise'], ['anger', 'fear','surprise'], ['joy'], ['joy'], ['anger', 'disgust','surprise'], ['anger','surprise'], ['anger','surprise'], ['joy'], ['anger','surprise'], ['anger','surprise']]",
#  "[['sadness'], ['sadness'], ['joy'], ['anger','surprise'], ['sadness'], ['surprise'], ['anger'], ['surprise'], ['joy'], ['joy']]",
#  "[['anger', 'fear','surprise'], ['anger', 'fear','surprise'], ['fear','sadness'], ['anger', 'fear'], ['anger'], ['anger'], ['anger'], ['fear','sadness'], ['anger', 'fear']]",
#  "[['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['surprise'], ['anger'], ['anger']]",
#  "[['joy'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger'], ['joy'], ['neutral'], ['joy'], ['sadness'], ['surprise'], ['neutral'], ['joy']]",
#  "[['joy'], ['joy'], ['surprise'], ['surprise'], ['joy'], ['joy'], ['anger', 'disgust'], ['joy'], ['sadness'], ['sadness']]",
#  "[['joy'], ['surprise', 'joy'], ['fear','surprise'], ['neutral'], ['surprise'], ['surprise', 'joy'], ['joy'], ['anger', 'disgust','sadness'], ['anger'], ['joy'], ['joy'], ['disgust','surprise'], ['disgust'], ['surprise', 'joy'], ['joy']]",
#  "[['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['fear','surprise'], ['fear','surprise'], ['neutral'], ['neutral'], ['neutral'], ['fear','surprise']]",
#  "[['surprise', 'joy']]",
#  "[['anger', 'disgust','sadness'], ['anger', 'disgust','sadness']]",
#  "[['neutral'], ['neutral'], ['joy'], ['neutral'], ['neutral'], ['anger'], ['anger'], ['surprise']]",
#  "[['surprise'], ['anger','surprise'], ['surprise'], ['anger','surprise'], ['neutral'], ['surprise'], ['surprise'], ['surprise']]",
#  "[['fear','surprise'], ['anger', 'fear'], ['anger', 'fear']]",
#  "[['joy'], ['joy'], ['joy'], ['joy'], ['surprise'], ['joy']]",
#  "[['anger'], ['fear'], ['fear','sadness'], ['sadness', 'joy']]",
#  "[['sadness','surprise']]",
#  "[['fear','surprise'], ['sadness'], ['joy'], ['joy'], ['neutral'], ['surprise'], ['neutral'], ['neutral'], ['neutral'], ['anger','surprise']]",
#  "[['anger', 'joy'], ['anger', 'joy'], ['fear','surprise'], ['anger', 'fear'], ['fear','sadness'], ['fear','sadness'], ['sadness'], ['sadness']]",
#  "[['joy'], ['sadness'], ['surprise'], ['joy'], ['sadness', 'joy'], ['anger'], ['joy'], ['joy'], ['joy'], ['anger', 'joy'], ['anger', 'joy'], ['anger', 'joy'], ['joy']]",
#  "[['surprise'], ['fear','surprise'], ['fear','surprise']]",
#  "[['surprise'], ['surprise'], ['fear','surprise'], ['surprise'], ['surprise'], ['fear'], ['fear']]",
#  "[['anger', 'fear'], ['anger', 'fear']]",
#  "[['anger','surprise'], ['fear','surprise'], ['sadness'], ['anger'], ['anger','sadness'], ['anger','sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear']]",
#  "[['neutral'], ['neutral'], ['sadness'], ['sadness'], ['anger','sadness'], ['anger','sadness'], ['fear','sadness'], ['anger','sadness']]",
#  "[['sadness'], ['sadness'], ['surprise'], ['anger','surprise'], ['anger', 'fear','surprise'], ['fear','surprise']]",
#  "[['fear','sadness'], ['surprise'], ['surprise'], ['fear','sadness'], ['anger', 'fear']]",
#  "[['neutral'], ['fear','surprise'], ['anger', 'fear'], ['surprise'], ['surprise', 'joy'], ['fear','sadness'], ['fear','sadness'], ['surprise']]",
#  "[['sadness'], ['sadness'], ['sadness','surprise'], ['sadness','surprise'], ['anger', 'disgust'], ['anger', 'disgust'], ['sadness']]",
#  "[['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['fear','sadness']]",
#  "[['anger'], ['anger','sadness'], ['fear','sadness'], ['anger'], ['anger'], ['fear','surprise']]",
#  "[['anger'], ['anger'], ['anger'], ['anger','sadness'], ['anger'], ['sadness'], ['sadness']]",
#  "[['surprise'], ['anger'], ['sadness'], ['sadness'], ['sadness'], ['anger'], ['anger','sadness'], ['anger'], ['sadness'], ['anger'], ['fear','surprise'], ['sadness']]",
#  "[['sadness'], ['fear','surprise'], ['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness']]",
#  "[['sadness'], ['sadness'], ['sadness'], ['sadness'], ['sadness','surprise'], ['sadness','surprise'], ['sadness', 'joy'], ['sadness', 'joy']]",
#  "[['anger'], ['anger','sadness'], ['anger', 'joy'], ['anger', 'disgust'], ['anger'], ['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['anger','sadness'], ['anger'], ['anger']]",
#  "[['sadness'], ['sadness'], ['anger','sadness'], ['sadness'], ['surprise'], ['fear'], ['fear','sadness'], ['neutral']]",
#  "[['joy'], ['anger'], ['fear','surprise'], ['fear','surprise'], ['anger'], ['anger'], ['anger'], ['joy'], ['anger']]",
#  "[['neutral'], ['neutral'], ['anger']]",
#  "[['fear','surprise'], ['surprise', 'joy']]",
#  "[['sadness'], ['fear','sadness'], ['fear','sadness'], ['fear','sadness'], ['fear','surprise'], ['fear','surprise']]",
#  "[['fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear', 'joy'], ['fear'], ['anger'], ['fear','sadness']]",
#  "[['surprise'], ['surprise', 'joy'], ['surprise'], ['surprise', 'joy'], ['surprise'], ['anger']]",
#  "[['anger','surprise'], ['anger', 'fear','surprise'], ['anger', 'fear','surprise'], ['anger', 'disgust'], ['anger', 'disgust'], ['anger', 'fear']]",
#  "[['anger'], ['surprise'], ['fear'], ['anger'], ['fear','surprise'], ['anger']]",
#  "[['fear'], ['anger','surprise'], ['anger','sadness'], ['anger', 'fear'], ['anger', 'fear','surprise']]",
#  "[['fear'], ['fear'], ['fear','surprise'], ['fear','surprise'], ['fear'], ['anger', 'disgust']]",
#  "[['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear']]",
#  "[['anger','surprise'], ['anger'], ['fear','surprise'], ['fear','surprise'], ['neutral'], ['fear','surprise'], ['fear','surprise'], ['anger'], ['anger'], ['anger'], ['anger'], ['anger']]",
#  "[['joy'], ['joy'], ['neutral'], ['neutral'], ['neutral'], ['fear','surprise'], ['fear','sadness'], ['anger'], ['anger']]",
#  "[['anger'], ['anger'], ['anger','sadness'], ['anger','sadness'], ['sadness'], ['anger', 'fear']]",
#  "[['anger', 'fear','surprise'], ['surprise'], ['anger', 'fear','surprise'], ['anger', 'fear','surprise'], ['surprise'], ['anger', 'fear','surprise'], ['anger', 'joy'], ['anger', 'joy'], ['anger','sadness'], ['anger','sadness'], ['anger', 'fear','sadness'], ['anger', 'fear','sadness'], ['anger','sadness'], ['anger','sadness'], ['fear','surprise'], ['anger', 'joy']]",
#  "[['anger','surprise'], ['anger','sadness'], ['fear'], ['anger','surprise'], ['joy'], ['anger','sadness'], ['anger','sadness'], ['joy'], ['neutral'], ['neutral'], ['joy']]",
#  "[['joy'], ['joy'], ['surprise'], ['surprise'], ['fear'], ['surprise'], ['fear'], ['fear'], ['sadness'], ['sadness'], ['fear','surprise']]",
#  "[['fear','sadness'], ['fear','sadness'], ['fear','sadness'], ['anger', 'fear'], ['anger', 'fear','surprise'], ['anger', 'fear','surprise'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear'], ['anger', 'fear','sadness'], ['anger', 'fear','sadness'], ['anger', 'fear','sadness'], ['anger', 'fear','surprise'], ['anger', 'fear']]",
#  "[['surprise'], ['sadness'], ['sadness','surprise'], ['sadness'], ['sadness'], ['sadness'], ['joy']]",
#  "[['anger','sadness'], ['anger','sadness'], ['surprise'], ['neutral'], ['sadness'], ['sadness'], ['surprise'], ['anger','surprise'], ['anger'], ['anger'], ['surprise']]",
#  "[['anger','sadness'], ['neutral'], ['anger','sadness'], ['surprise'], ['sadness'], ['neutral'], ['fear','surprise'], ['anger'], ['surprise'], ['joy'], ['joy'], ['joy']]",
#  "[['joy']]"]

# %%
bad_idx = []
predictions_l = []

for i, x in enumerate(predictions):
    try:
        predictions_l.append(ast.literal_eval(x))
    except:
        print(i)
        bad_idx.append(i)

# %%
bad_idx.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in bad_idx:
    
    del grounds[idx]
    #del predictions[idx]

# %%
len(grounds), len(predictions_l)
# Out:
# (156, 156)

# %%
bad_idx = []

for idx, (i,j) in enumerate(zip(grounds, predictions_l)):
    if len(i) != len(j):
        print(idx, len(i), len(j))
        bad_idx.append(idx)
# Out:
# 3 21 20
# 5 20 18
# 27 17 16
# 36 17 16

# %%
bad_idx.sort(reverse=True)

# Remove elements from 'grounds' at the specified indices
for idx in bad_idx:
    
    del grounds[idx]
    del predictions_l[idx]

# %%
grounds_l = [item for sublist in grounds for item in sublist]
predictions_l = [item for sublist in predictions_l for item in sublist]

# %%
len(grounds_l), len(predictions_l)
# Out:
# (1251, 1251)

# %%
grounds_l
# Out:
# [['surprise', 'joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness', 'surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'surprise', 'joy'],
#  ['fear', 'surprise', 'joy'],
#  ['fear', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['disgust'],
#  ['disgust'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['fear'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['disgust'],
#  ['fear'],
#  ['neutral'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'fear'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['sadness'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'joy'],
#  ['anger', 'fear', 'joy'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'joy'],
#  ['anger', 'fear', 'sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['anger', 'disgust'],
#  ['sadness', 'joy'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['sadness', 'surprise'],
#  ['anger', 'sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'disgust', 'surprise'],
#  ['anger', 'joy'],
#  ['anger', 'fear', 'surprise'],
#  ['sadness', 'joy'],
#  ['fear', 'sadness'],
#  ['anger', 'surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'sadness', 'surprise'],
#  ['fear'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger', 'fear', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger', 'fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['disgust', 'surprise'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'surprise'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['surprise', 'joy'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['joy'],
#  ['fear', 'sadness'],
#  ['anger', 'joy'],
#  ['anger', 'joy'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['anger'],
#  ['sadness'],
#  ['joy'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['disgust', 'joy'],
#  ['anger', 'disgust', 'joy'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'disgust', 'joy'],
#  ['disgust', 'surprise', 'joy'],
#  ['sadness', 'joy'],
#  ['surprise'],
#  ['fear', 'sadness'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['anger', 'fear'],
#  ['sadness', 'surprise'],
#  ['fear'],
#  ['anger', 'sadness', 'surprise', 'joy'],
#  ['joy'],
#  ['fear'],
#  ['fear'],
#  ['anger', 'joy'],
#  ['fear'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['anger', 'sadness'],
#  ['fear'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger', 'joy'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'disgust', 'joy'],
#  ['sadness'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['anger'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'joy'],
#  ['anger', 'disgust', 'sadness'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['surprise'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['surprise'],
#  ['anger', 'fear'],
#  ['fear'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['surprise', 'joy'],
#  ['neutral'],
#  ['anger', 'fear'],
#  ['joy'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['joy'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['disgust'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['disgust'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['surprise'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['anger', 'disgust'],
#  ['surprise', 'joy'],
#  ['joy'],
#  ['joy'],
#  ['anger'],
#  ['anger', 'sadness'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['sadness'],
#  ['anger', 'surprise'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['neutral'],
#  ['anger', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['neutral'],
#  ['anger'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust'],
#  ['anger', 'disgust', 'sadness'],
#  ['anger'],
#  ['neutral'],
#  ['joy'],
#  ['anger', 'sadness', 'surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['sadness'],
#  ['sadness'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['surprise'],
#  ['joy'],
#  ['fear'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['anger'],
#  ['anger'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['neutral'],
#  ['neutral'],
#  ['joy'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['anger'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['surprise'],
#  ['joy'],
#  ['joy'],
#  ['neutral'],
#  ['joy'],
#  ['surprise', 'joy'],
#  ['surprise', 'joy'],
#  ['fear', 'surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['joy'],
#  ['disgust', 'fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness', 'surprise'],
#  ['sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['anger'],
#  ['neutral'],
#  ['surprise'],
#  ['fear'],
#  ['disgust', 'surprise'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['fear'],
#  ['disgust', 'surprise'],
#  ['surprise'],
#  ['disgust', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['sadness', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['surprise'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['fear', 'surprise'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise', 'joy'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['neutral'],
#  ['sadness'],
#  ['joy'],
#  ['disgust', 'sadness'],
#  ['anger', 'disgust'],
#  ['joy'],
#  ['joy'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['surprise'],
#  ['fear', 'surprise'],
#  ['joy'],
#  ['joy'],
#  ['sadness', 'joy'],
#  ['joy'],
#  ['sadness', 'surprise'],
#  ['fear', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'surprise'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['anger', 'disgust'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['surprise'],
#  ['anger', 'surprise'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['anger', 'fear'],
#  ['anger', 'fear', 'surprise'],
#  ['anger'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['anger', 'fear', 'sadness', 'surprise'],
#  ['anger', 'fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['anger', 'surprise'],
#  ['sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['sadness', 'surprise'],
#  ['sadness'],
#  ['anger', 'sadness'],
#  ['anger', 'sadness'],
#  ['joy'],
#  ['joy'],
#  ['fear', 'joy'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['surprise'],
#  ['anger'],
#  ['anger'],
#  ['anger'],
#  ['fear'],
#  ['anger'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['neutral'],
#  ['fear'],
#  ['fear'],
#  ['neutral'],
#  ['anger', 'fear', 'sadness'],
#  ['anger', 'fear', 'sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['neutral'],
#  ['sadness'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['surprise'],
#  ['neutral'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['neutral'],
#  ['fear'],
#  ['neutral'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['anger'],
#  ['anger', 'surprise'],
#  ['anger'],
#  ['surprise'],
#  ['sadness'],
#  ['fear', 'sadness'],
#  ['sadness'],
#  ['sadness'],
#  ['fear', 'sadness', 'surprise'],
#  ['sadness', 'surprise'],
#  ['fear', 'sadness'],
#  ['anger', 'sadness'],
#  ['surprise'],
#  ['anger', 'sadness'],
#  ['surprise', 'joy'],
#  ['fear', 'sadness'],
#  ['sadness', 'joy'],
#  ['sadness', 'joy'],
#  ['surprise'],
#  ['fear'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'sadness'],
#  ['fear', 'surprise'],
#  ['fear'],
#  ['fear'],
#  ['joy'],
#  ['joy'],
#  ['anger', 'fear'],
#  ['anger', 'fear'],
#  ['anger'],
#  ['anger'],
#  ['surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ['fear', 'sadness', 'surprise'],
#  ...]

# %%
set([type(item) for sublist in grounds_l for item in sublist])
# Out:
# {str}

# %%
mlb = MultiLabelBinarizer()

# %%
y_true_mhot = mlb.fit_transform(grounds_l)
y_pred_mhot = mlb.transform(predictions_l)

# %%
y_pred_mhot.shape
# Out:
# (1251, 7)

# %%
print(classification_report(y_true_mhot, y_pred_mhot, target_names=mlb.classes_, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        anger      0.572     0.630     0.600       441
#      disgust      0.031     0.022     0.026        46
#         fear      0.444     0.470     0.456       279
#          joy      0.596     0.543     0.568       280
#      neutral      0.460     0.404     0.430        99
#      sadness      0.517     0.502     0.509       325
#     surprise      0.614     0.582     0.598       328
#
#    micro avg      0.537     0.532     0.534      1798
#    macro avg      0.462     0.450     0.455      1798
# weighted avg      0.534     0.532     0.532      1798
#  samples avg      0.570     0.553     0.534      1798

# %%
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
#print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
#print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# Peak reserved memory = 31.213 GB.
# Peak reserved memory for training = 0.377 GB.
# Peak reserved memory % of max memory = 33.561 %.
# Peak reserved memory for training % of max memory = 0.405 %.

# %%
# image1 = Image.open("/Utilisateurs/umushtaq/emotion_analysis_comics/comics_dataset_images/001499/images/page00001.jpg")
# #image2 = Image.open(requests.get("http://images.cocodataset.org/val2017/000000039769.jpg", stream=True).raw)
# #display(image1)
# #display(image2)

# %%
#instruction = "You are an expert in comics. Explain the emotional content of this comics page."

# %%
# messages = [
#     {"role": "user", "content": [
#         {"type": "image"},
#         {"type": "text", "text": instruction}
#     ]}
# ]

# %%
#input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)

# %%
# inputs = tokenizer(
#     image1,
#     input_text,
#     add_special_tokens = False,
#     return_tensors = "pt",
# ).to("cuda")

# %%
# from transformers import TextStreamer
# text_streamer = TextStreamer(tokenizer, skip_prompt = True)

# %%
# _ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
#                    use_cache = True, temperature = 1.5, min_p = 0.1)
