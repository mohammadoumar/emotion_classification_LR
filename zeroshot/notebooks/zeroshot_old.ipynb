# %% [markdown]
# # Zero Shot Classification on Comics dataset

# %%
import os
import json
import torch
import pickle

import pandas as pd

from tqdm.notebook import tqdm
from pathlib import Path
from sklearn.metrics import classification_report
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
MODEL_NAME = "microsoft/Phi-3-mini-4k-instruct"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Phi3ForCausalLM(
#   (model): Phi3Model(
#     (embed_tokens): Embedding(32064, 3072, padding_idx=32000)
#     (embed_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-31): 32 x Phi3DecoderLayer(
#         (self_attn): Phi3Attention(
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (qkv_proj): Linear(in_features=3072, out_features=9216, bias=False)
#           (rotary_emb): Phi3RotaryEmbedding()
#         )
#         (mlp): Phi3MLP(
#           (gate_up_proj): Linear(in_features=3072, out_features=16384, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=3072, bias=False)
#           (activation_fn): SiLU()
#         )
#         (input_layernorm): Phi3RMSNorm((3072,), eps=1e-05)
#         (resid_attn_dropout): Dropout(p=0.0, inplace=False)
#         (resid_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (post_attention_layernorm): Phi3RMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): Phi3RMSNorm((3072,), eps=1e-05)
#   )
#   (lm_head): Linear(in_features=3072, out_features=32064, bias=False)
# )

# %%
# def generate_prompt(text, labels):
#     prompt = f"Classify the following text into one of these categories. Restrict your answer to only one token. Do not generate any tokens other than the label: {', '.join(labels)}.\n\nText: {text}\n\nCategory:"
#     return prompt

# %%
def generate_prompt(text):
    prompt = f"""You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.

Utterance: {text}

You must absolutely not generate any text or explanation other than the following JSON format: 
{{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}}. 

Answer:
"""

    #prompt = "### Task description: You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(s): anger, surprise, fear, disgust, sadness, joy, neutral. You must absolutely not generate any text or explanation other than the following JSON format: {utterance_emotion: <predicted emotion classes for the utterance (str)>}" + f"\n\n# Utterance:\n{text}\n\n# Result:\n"
    #prompt = f"You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(s): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: {text}\n\nYou must absolutely not generate any text or explanation other than the following JSON format: {utterance_emotion: <predicted emotion classes for the utterance (str)>}. Answer:"
    return prompt

# %%
# def generate_prompt(text, labels):
#     prompt = f"""You are an expert in emotion analysis. You are given a text from a comics book.\n\n### Here is the text: {text}\n\nYou must classify the emotion of this text into one or more of the following emotion labels: {labels}. Do not generate any explanation after the answer. ###Answer:###"""
#     return prompt

# %%
# def generate_prompt(text, labels):
#     prompt = (
#         f"You are an expert in emotion analysis. Below is a passage from a comic book.\n\n"
#         f"### Text:\n{text}\n\n"
#         f"Classify the emotion(s) of the text using one of the following labels: anger, surprise, fear, disgust, sadness, joy, neutral. Provide only the labels.\n\n"
#         f"### Answer:"
#     )
#     return prompt

# %%
text_to_classify = "The stock market saw a sharp rise today."
labels = ["anger", "surprise", "fear", "disgust", "sadness", "joy", "neutral"]

# %%
generate_prompt(text_to_classify)
# Out:
# 'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: The stock market saw a sharp rise today.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n'

# %%
def classify_text(text, labels):
    # Create the prompt
    prompt = generate_prompt(text)
    
    # Tokenize and encode the prompt
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generate output
    outputs = model.generate(**inputs, max_new_tokens=16, eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.eos_token_id)
    
    # Decode the generated output
    classification = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Extract the predicted category (after the prompt)
    #predicted_category = classification.split("Answer:")[-1].strip()
    return classification
    #return predicted_category

# %%
# text_to_classify = "The stock market saw a sharp rise today."
# labels = ["anger", "surprise", "fear", "disgust", "sadness", "joy", "neutral"]

# %%
#predicted_category = classify_text(text_to_classify, labels)

# %%
#print(f"Predicted category: {predicted_category}")

# %% [markdown]
# ### Read the data sets

# %%
df = pd.read_csv("/Utilisateurs/umushtaq/emotion_analysis_comics/zeroshot/datasets/comics_data_processed.csv")

# %%
df = df.drop(columns=[df.columns[0], df.columns[1]])

# %%
emotion_map = {
    'AN': 'anger',
    'DI': 'disgust',
    'FE': 'fear',
    'SA': 'sadness',
    'SU': 'surprise',
    'JO': 'joy'
}

# %%
def extract_emotions(row):

    emotion_str = row.emotion

    if emotion_str == 'Neutral':
        return ['neutral']

    emotions = emotion_str.split('-')
    tags = []

    for emotion in emotions:
        abbrev = emotion[:2]  # Get the abbreviation
        value_part = emotion[2:]  # Get the value part
        
        if abbrev in emotion_map and value_part.isdigit():
            value = int(value_part)
            if value > 0:
                tags.append(emotion_map[abbrev].lower())
        else:
            print(f"Warning: Skipping invalid emotion entry: '{emotion}'")
    return tags

# %%
df['emotions_list'] = df.apply(lambda row: extract_emotions(row), axis=1)

# %%
#df = df[df['emotions_list'].apply(lambda x: len(x) == 1)].reset_index()

# %%
texts = df.utterance.tolist()

# %%
labels = ["anger", "surprise", "fear", "disgust", "sadness", "joy", "neutral"]

# %%
predictions = []

for i in tqdm(range(len(texts))):
    predicted_category = classify_text(texts[i], labels)
    predictions.append(predicted_category)
# Out:
#   0%|          | 0/5282 [00:00<?, ?it/s]

# %%
predictions
# Out:
# ['You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: DID YOU HAVE TO ELECTROCUTE HER SO HARD?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: IT\'S NOT LIKE I HAVE DIFFERENT SETTINGS.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YOU\'RE ELECTROCUTIONER. IT\'S YOUR WHOLE THING. YOU\'D THINK YOU\'D HAVE SOME DEGREE OF CONTROL?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OH, HEY. I THINK SHE\'S AWAKE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRETTY PISSED WITH YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: HE KNOWS YOU\'RE WORKING WITH DICK GRAYSON.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: HE WANTS ME TO GET INFORMATION OUT OF YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SHE\'S AWAKE, BOSS. SHE--\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: CAN YOU WALK?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: HOW DID YOU FIND ME?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: ORACLE HAD THE LAST PING OFF YOUR PHONE. AND AUDRE FOLLOWED BLOCKBUSTER\'S LIMO.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AUDRE\'S HERE?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: IN A CAR OUTSIDE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SHE WASN\'T SUPPOSED TO FOLLOW. I TOLD HER I\'D BE OKAY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SURE. AND I CAN APPRECIATE THAT AS THE POSTER BOY FOR STUBBORN SELF-RELIANCE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BUT I THINK YOU HAVE TO CEDE THE MORAL HIGH GROUND TO AUDRE HERE, SEEING AS YOU WERE KIDNAPPED AND ELECTROCUTED.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: NIGHTWING…\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I AM VERY DISAPPOINTED TO SEE THIS, MELINDA.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "sadness"}\n\n\nInput',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OKAY…\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: … I GUESS WE\'RE GOING THROUGH YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YOU THINK YOU CAN GO THROUGH ME?! NOTHING CAN--\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: GET IN!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AUDRE!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: HEY!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: #HNNNN. \n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: GO. GO. GO.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " TELL US EVERYTHING YOU KNOW. "\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YOU WORKING FOR MAGGIE SAWYER NOW, ARE YOU, DETECTIVES?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I\'VE NEVER BEEN YOUR BIGGEST FAN, EX-COMMISSIONER MACLEAN. I\'M MORE THAN HAPPY TO PUT YOU AWAY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OH, I\'M NOT GOING AWAY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THERE\'S A FILE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHAT FILE?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: A BLOCKBUSTER FILE. EVERY INTEREST HE HAS. SPREADSHEETS. DROP-OFFS. ACCOUNTS. HE ASKED ME TO KEEP IT SAFE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHERE IS IT?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I… CAN\'T ANSWER THAT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "fear"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: DO YOU NOT HAVE IT, THEN?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OF COURSE I HAVE IT. BUT IT\'S HIDDEN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: DOES ANYONE OTHER THAN YOU KNOW WHERE IT\'S HIDDEN?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: ABSOLUTELY NOT. IT\'S MY INSURANCE. THE ONLY WAY ANYONE GETS THEIR HANDS ON THOSE FILES IS IF I GET FULL IMMUNITY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SO, YOU\'LL TURN THE FILES OVER IF YOU\'RE PROMISED PROTECTION?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MAGGIE SAWYER WOULD HAVE TO ASK VERY NICELY BUT, YES, I THINK WE COULD MAKE A DEAL.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THAT\'S A SHAME.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "sadness"}\n\n\nU',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHAT DO YOU MEAN?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THAT\'S NOT WHAT BLOCKBUSTER WANTED TO HEAR AT ALL.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: @ # $ %.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHO WAS IN HERE WITH HIM?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHO?!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THIS @ # $ % # & CITY!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MAGGIE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: IT\'S THE MAYOR. SHE WANTS TO TALK. IN PRIVATE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: COMMISSIONER. I HAVE BEEN WORKING TO BRING DOWN BLOCKBUSTER AND MARONI… IN SECRET.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SUPPOSING I CHOOSE TO BELIEVE YOU, IF IT\'S A SECRET, WHY ARE YOU TELLING ME?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BECAUSE BLOCKBUSTER KNOWS I\'M WORKING AGAINST HIM NOW. BUT HE DOESN\'T KNOW WHAT I HAVE ON HIM.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I HAVE ENOUGH TO TAKE DOWN SEVERAL OF HIS MAJOR OPERATIONS. BUT WE ONLY GET ONE CHANCE AT THIS. WE HAVE TO ACT TONIGHT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AND HOW WOULD YOU PROPOSE WE DO THAT?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: FOLLOW ME. PLEASE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE JUST NEED TO CATCH THEM IN THE ACT…\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: … WE KNOW WHERE THEY\'RE GOING TO BE. WE KNOW WHAT THEY\'RE GOING TO DO.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: EVEN IF THAT\'S TRUE, I DON\'T HAVE ENOUGH COPS I TRUST FOR AN OPERATION LIKE THIS. OUR CHIEF WITNESS WAS SHOT IN MY STATION.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger, fear"}\n\n\nInput',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MACLEAN IS DEAD?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YES.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: PROBABLY BECAUSE BLOCKBUSTER THINKS HE HAD WHAT WE HAVE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I CAN\'T TRUST ANYONE. I\'M COMPLETELY ON MY OWN HERE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: NO…\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: … YOU\'RE NOT ON YOUR OWN, MAGGIE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: IT\'S GOOD TO HAVE YOU IN BLÜDHAVEN, COMMISSIONER--SUPERMAN HAS SPOKEN HIGHLY OF YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AND AS CHARACTER REFERENCES GO, IT DOESN\'T GET BETTER THAN THAT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I GET YOU\'RE HERE SO THAT I TRUST WHAT YOU\'RE SAYING, BATWOMAN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "trust, respect"}\n\n\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE HAVE THE PEOPLE. WE\'LL DO THE WORK. WE CAN CATCH MARONI AND BLOCKBUSTER\'S LIEUTENANTS IN THE ACT. WE\'LL SUBDUE THEM AND WE\'LL MAKE SURE THERE\'S EVIDENCE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE JUST NEED YOU BEHIND US TO PICK THEM UP AND DO EVERYTHING ELSE BY THE BOOK.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: EVEN IF I WANTED TO DO THIS, I DON\'T KNOW WHO I CAN DEPEND ON IN THE DEPARTMENT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "sadness"}\n\n\nU',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YOU\'RE ABOUT TO.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THIS IS A LIST OF EVERY COP WHO\'S EVER TAKEN A DIME FROM MARONI AND BLOCKBUSTER.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BUT I\'VE MADE THE MISTAKE OF TRUSTING YOU BEFORE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "sadness"}\n\n\nInput',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I DON\'T KNOW WHAT… THIS IS.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BUT THIS CITY HAS BEEN RUN BY CORRUPT, VIOLENT MEN, WHO THINK THEIR MONEY AND POWER PUTS THEM ABOVE THE LAW, ABOVE CONSEQUENCES.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE HAVE AN OPPORTUNITY TO CARRY OUT THE SINGLE BIGGEST STRIKE AGAINST ORGANIZED CRIME THIS CITY HAS EVER SEEN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: ARE YOU IN?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE\'RE ALL IN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THANK YOU. SERIOUSLY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BLOCKBUSTER AND MARONI HAVE FOUR MAJOR CRIMES PLANNED TONIGHT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AND THEY HAVE NO IDEA WE KNOW THIS.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " THERE\'S A SHIPMENT OF ARMS COMING INTO THE BLÜDHAVEN DOCKS.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " A CARGO PLANE TRAFFICKING PEOPLE LEFT BLÜDHAVEN AIRPORT TWENTY MINUTES AGO.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " A FEW TONS OF A VERY POORLY MADE, VERY HARMFUL SUBSTANCE ARE BEING TRUCKED IN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " AND BOSS MARONI HIMSELF WILL BE AT A RARE JEWELS BUY. HE LIKES SHINY THINGS. "\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " WE CAN TAKE DOWN MARONI AND BLOCKBUSTER IF WE DO THIS RIGHT. ”\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " WE NEED TO TIME THIS PERFECTLY. WE DON\'T WANT ANY OTHER OPERATION GETTING WIND OF WHAT\'S COMING FOR THEM. "\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: BRING THEM DOWN!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " WE\'LL ONLY SUCCEED IF WE HIT EVERY ONE OF THESE AT THE SAME TIME. "\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHAT THE…?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: HI. WOULD YOU MIND PULLING OVER? OR I CAN JUST TAKE OFF YOUR WHEELS?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: " MAKE SURE WE SUBDUE THEM FOR COMMISSIONER SAWYER\'S TASK FORCE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
# ...
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MY SISTER IS NAIVE. SHE TRUSTS TOO EASILY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THE VENATORI NEARLY DESTROYED TEVINTER. THE WORLD, EVEN. WE MUST FIND ALL FAMILIES WHO WERE PART OF THE GROUP --OR EVEN ASSISTED THEM.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger, fear, sadness"}\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I ASSURE YOU, NEITHER FRANCESCA NOR I--\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: YOU KNOW HOW IT IS, ONCE A NAME IS IN A REPORT, I HAVE TO DO MY DUE DILIGENCE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: CALIX…?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MY BROTHER IS SPEAKING WITH THAT MAGISTER, SO WE ONLY HAVE A SHORT TIME.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WE WEREN\'T SURE IF YOUR FATHER IWAS WITH THE CAUSE, BUT NOW WE KNOW.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I\'D LIKE OUR HOUSES TO FORM AN ALLIANCE… AGAINST PERSECUTION FROM THE LUCERNI. OR ANYONE ELSE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: IS THERE NOTHING I CAN DO TO MAKE THIS GO AWAY? MY SISTER AND I WOULD NOT WANT TO BLUNDER INTO ANYTHING THAT HURTS OUR FAMILY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "sadness"}\n\n\nU',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OF COURSE. WE SHOULD TALK SOMEPLACE PRIVATE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THIS STONE CAN SERVE AS A FOCUS FOR SPECIAL MAGICKS…\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: FRANCESCA!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THANK YOU FOR THIS GIFT.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I\'LL SEE YOU LATER. I NEED TO WRAP THINGS UP WITH THE MAGISTER.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "neutral"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: A LOVELY GEMSTONE. USEFUL FOR MAGIC, NO? PERHAPS A DEMONSTRATION, YOUNG MASTER QINTARA?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: SHE IS NOT A MAGISTER! SHE\'S A CON ARTIST!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AND THIS YOUNG MAN IS MOST CERTAINLY NOT A QINTARA. HE IS A GRIFTER.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WAIT… YOU\'RE NOT…?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: ONE WHO DOESN\'T UNDERSTAND THE RULES OF THE GAME, APPARENTLY.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: JULIUS! GRAB THE OTHERS! A PAIR OF CON ARTISTS HAVE JUST TRIED TO SWINDLE MY SISTER!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: WHAT\'S WRONG WITH YOU DOLTS? MAGIC KILLS MABARI SAME AS MEN.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: THE MABARI\'S GOT THE RIGHT IDEA.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nUt',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: NOW #HUFF#  WILL YOU JUST AGREE TO #HUFF# WORK WITH ME?\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nUtter',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: OH, DO SHUT UP!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: GOOD GIRL! WE\'LL HIDE IN THERE.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: AUTUMN! YOU\'VE GROWN SINCE I LAST SAW YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "surprise"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: MY DEAR OLIVIA… IT\'S GOOD TO SEE YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "joy"}\n\n\nInput:',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: LOOKS LIKE YOU\'RE IN NEED OF SOME HELP. SO AM I.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "helpfulness, neutral"}\n\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: FROM BOTH OF YOU.\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  'You are an expert sentiment analysis assistant that takes an utterance from a comic book and must classify the utterance into appropriate emotion class(es): anger, surprise, fear, disgust, sadness, joy, neutral.\n\nUtterance: I MEANT NO OFFENSE!\n\nYou must absolutely not generate any text or explanation other than the following JSON format: \n{"utterance_emotion": "<predicted emotion classes for the utterance (str)>"}. \n\nAnswer:\n{"utterance_emotion": "anger"}\n\n\nInput:\n',
#  ...]

# %%
len(predictions)
# Out:
# 5282

# %%
import re

# %%
preds = []

for prediction in predictions:

    match = re.search(r'Answer:\s*(\{.*?\})', prediction)

    if match:

        json_str = match.group(1)  # Extract the JSON object as a string
        try:
            # Parse the extracted JSON string
            parsed_json = json.loads(json_str)
            preds.append(parsed_json)
            #print("Extracted JSON:", parsed_json)
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON: {e}")

# %%
preds
# Out:
# [{'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'trust, respect'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'frustration'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger, fear, disgust'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'frustration'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger, fear, disgust'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'disgust'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'frustration'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'disgust'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'disgust'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'disgust'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'fear, sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, sadness'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger, fear, neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger, fear'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger, disgust'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'fear'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger, fear, sadness'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'sadness'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'neutral'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'surprise'},
#  {'utterance_emotion': 'joy'},
#  {'utterance_emotion': 'helpfulness, neutral'},
#  {'utterance_emotion': 'anger'},
#  {'utterance_emotion': 'anger'},
#  ...]

# %%
len(preds)
# Out:
# 5279

# %%
preds = []

for prediction in predictions:
    try:
        preds.append(prediction.split("\n\n\n")[-1].split("Answer:")[1][1:])
    except:
        preds.append("neutral")

# %%
preds
# Out:
# ['neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "anger, fear, disgust"}',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "anger, fear, disgust"}',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "fear, sadness"}\n\n',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "anger, fear, neutral"}\n\n',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "anger, disgust"}\n\n',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "anger, fear, sadness"}\n',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  '{"utterance_emotion": "helpfulness, neutral"}\n\n',
#  'neutral',
#  'neutral',
#  ...]

# %%
len(preds)
# Out:
# 5282

# %%
grounds = [x for [x] in df.emotions_list.tolist()]

# %%
for idx, (ground, pred) in enumerate(zip(grounds, preds)):

    if pred not in labels:
        del grounds[idx]
        del preds[idx]

# %%
print(classification_report(grounds, preds))
# Out:
#               precision    recall  f1-score   support
#
#            '       0.00      0.00      0.00         0
#     Answer:
#        0.00      0.00      0.00         0
#          The       0.00      0.00      0.00         0
#        anger       0.63      0.27      0.38       601
#          dis       0.00      0.00      0.00         0
#      disgust       0.00      0.00      0.00        14
#         fear       0.25      0.18      0.21       245
#          joy       0.43      0.71      0.53       612
#      neutral       0.22      0.33      0.26       271
#          sad       0.00      0.00      0.00         0
#      sadness       0.00      0.00      0.00       314
#     surprise       0.39      0.36      0.38       338
#
#     accuracy                           0.36      2395
#    macro avg       0.16      0.15      0.15      2395
# weighted avg       0.37      0.36      0.34      2395
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Utilisateurs/umushtaq/.conda/envs/er_nb_env/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
